# %% [markdown]
# - SVC : 서포트 벡터 머신 분류모델
#     - 그 구조가 딥러닝의 인공신경망과 유사하여 가끔 딥러닝을 대체하여 사용되기도 함
#     - 손실함수 : 손실을 최소화하는 함수

# %% [markdown]
# - sklearn의 각 모델에 대한 기본적인 원리 및 공식, 파라미터는 암기하는 것이 좋음
#     - 직무능력에서 요구함

# %%
import sys
sys.path.append("Y:\Python\Mega_IT")

import warnings
warnings.filterwarnings('ignore')

from yjk_module.preprocessing import *
from yjk_module.ml_module import *

# %%
from hossam.util import *
from hossam.plot import *
from hossam.analysis import *
from hossam.classification import *

# %%
from sklearn.svm import LinearSVC, SVC

# %%
origin1 = pd.read_excel("./data/dogs.xlsx")

# %%
origin1.head()
# Out:
#   dog  length  height
# 0   d   55.01   29.27
# 1   d   59.01   29.39
# 2   d   56.53   28.50
# 3   d   53.66   28.50
# 4   d   49.67   31.97

# %%
pp = YjkPreprocessor()
pp.set_strategy(null = None, outline = None)
# Out:
# 아래와 같이 처리합니다.
# +-------------+----------------+
# | 범주        | 처리방법       |
# |-------------+----------------|
# | 이상치 처리 | 처리하지 않음  |
# | 결측치 처리 | 처리하지 않음  |
# | 스케일러    | StandardScaler |
# | 인코딩      | 원핫인코딩     |
# +-------------+----------------+

# %%
df1_p = pp.fit_transform(origin1, yname = 'dog', ylabeling = True)
# Out:
# 데이터프레임 크기 : (200, 3)
# 데이터프레임에 결측치는 없습니다.
# 연속형 데이터 컬럼 : ['length', 'height'], 총 2개
# 종속변수 컬럼명 : dog / 종속변수 라벨링 여부 : True

# %%
X = df1_p.copy()
Y = X.pop('dog')

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, random_state = 0, test_size = 0.25, stratify = Y)

# %%
SVC = LinearSVC()

# %%
SVC.fit(x_train, y_train)
# Out:
# LinearSVC()

# %%
SVC.score(x_test, y_test)
# Out:
# 1.0

# %%
support = YjkClassifierSupport()
# Out:
# 사용 가능한 모델 : ['LogisticRegression', 'SGDClassifier', 'KNeighborsClassifier', 'LinearSVC', 'SVC', 'CatboostClassifier']

# %%
yjk_classifier_multi_gridsearch(support, x_train, y_train, x_test, y_test, randomized_search = True, secondary_score = ['roc_auc', 'recall'])
# Out:
# LogisticRegression 모델 소요 시간 : 0:00:02
# SGDClassifier 모델 소요 시간 : 0:00:01
# KNeighborsClassifier 모델 소요 시간 : 0:00:00
# LinearSVC 모델 소요 시간 : 0:00:00
# SVC 모델 소요 시간 : 0:00:00
# exception calling callback for <Future at 0x16bea5af9d0 state=finished raised TerminatedWorkerError>
# Traceback (most recent call last):
#   File "C:\Users\yjg10\anaconda3\lib\site-packages\joblib\externals\loky\_base.py", line 26, in _invoke_callbacks
#     callback(self)
#   File "C:\Users\yjg10\anaconda3\lib\site-packages\joblib\parallel.py", line 385, in __call__
#     self.parallel.dispatch_next()
#   File "C:\Users\yjg10\anaconda3\lib\site-packages\joblib\parallel.py", line 834, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "C:\Users\yjg10\anaconda3\lib\site-packages\joblib\parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\yjg10\anaconda3\lib\site-packages\joblib\parallel.py", line 819, in _dispatch
# ...

# %%
# from sklearnex import patch_sklearn
# patch_sklearn()

# %%
# yjk_classifier_multi_gridsearch(support, x_train, x_test, y_train, y_test, randomized_search = False, primary_score = 'accuracy', secondary_score = 'recall')

# %%
origin2 = pd.read_excel("./data/pima_indians_diabetes.xlsx")

# %%
zero_features = ['Glucose', 'BloodPressure','SkinThickness','Insulin','BMI']

df2 = origin2.copy()
df2[zero_features] = df2[zero_features].replace(0, np.nan)
df2_2 = my_replace_missing_value(df2)

# %%
total_count = len(origin2)

for feature in zero_features:
    zero_count = origin2[origin2[feature] == 0][feature].count()
    print('{0} 0 건수는 {1}, 퍼센트는 {2:.2f} %'.format(feature, zero_count, 100*zero_count/total_count))

print("---" * 30)

for feature in zero_features:
    zero_count = df2_2[df2_2[feature] == 0][feature].count()
    print('{0} 0 건수는 {1}, 퍼센트는 {2:.2f} %'.format(feature, zero_count, 100*zero_count/total_count))

# %%
df2_2['Outcome'] = df2_2['Outcome'].astype('int')

x_train, x_test, y_train, y_test = my_train_test_split(df2_2, yname='Outcome', test_size=0.2, scalling=False)

# %%
yjk_classifier_multi_gridsearch(support, x_train, y_train, x_test, y_test, randomized_search = True, secondary_score = ['roc_auc', 'recall'])

# %%
origin3 = pd.read_excel("./data/iris.xlsx")

# %%
df3 = my_labelling(origin3, 'Species')

x_train, x_test, y_train, y_test = my_train_test_split(df3, yname='Species', test_size=0.2, scalling=True)
x_train.shape, x_test.shape, y_train.shape, y_test.shape

# %%
yjk_classifier_multi_gridsearch(support, x_train, y_train, x_test, y_test, randomized_search = True, secondary_score = ['roc_auc', 'recall'])

# %%
origin4 = pd.read_excel("./data/wine.xlsx")

# %%
df4 = origin4.copy()
df4['class'] = df4['class'].astype('int')

x_train, x_test, y_train, y_test = my_train_test_split(df4, yname='class', scalling=True)
x_train.shape, x_test.shape, y_train.shape, y_test.shape

# %%
yjk_classifier_multi_gridsearch(support, x_train, y_train, x_test, y_test, randomized_search = True, secondary_score = ['roc_auc', 'recall'])
