# %% [markdown]
# - 선형회귀에 의한 그래프는 직선형으로 직선이 아닌 실데이터에 대해 잔차가 발생
# - 로지스틱 회귀는 시그모이드(이진), 소프트맥스(다중) 식을 사용
# - 상당수 지도학습 알고리즘은 회귀식(절편, 기울기)이 없는 경우가 많음

# %%
import sys
sys.path.append("Y:\Python\Mega_IT")

from yjk_module.preprocessing import *
from yjk_module.ml_module import *

# %%
from sklearn.neighbors import KNeighborsClassifier
from hossam.util import *
from hossam.plot import *
from hossam.analysis import *
from hossam.classification import *

# %% [markdown]
# - KNN 회귀

# %%
origin1 = pd.read_excel("./data/dogs.xlsx")

# %%
df1 = origin1.copy()
df1.head()
# Out:
#   dog  length  height
# 0   d   55.01   29.27
# 1   d   59.01   29.39
# 2   d   56.53   28.50
# 3   d   53.66   28.50
# 4   d   49.67   31.97

# %%
df1_2 = my_labelling(df1, 'dog')

# %%
x_train, x_test, y_train, y_test = my_train_test_split(df1_2, yname = 'dog', random_state = 0, test_size = 0.2, scalling = False)

# %%
estimator = KNeighborsClassifier(n_neighbors = 5, n_jobs = -1)
estimator.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_jobs=-1)

# %%
my_classification_result(estimator, x_train, y_train, x_test, y_test)
# Out:
# [분류분석 성능평가]
# +-------------------------+--------------+--------------+-----------------------------------------------------------+
# |                         |   훈련데이터 |   검증데이터 | 설명                                                      |
# |-------------------------+--------------+--------------+-----------------------------------------------------------|
# | 의사결정계수(Pseudo R2) |            1 |            1 | 로지스틱회귀의 성능 측정 지표로, 1에 가까울수록 좋은 모델 |
# | 정확도(Accuracy)        |            1 |            1 | 예측 결과(TN,FP,TP,TN)가 실제 결과(TP,TN)와 일치하는 정도 |
# | 정밀도(Precision)       |            1 |            1 | 양성으로 예측한 결과(TP,FP) 중 실제 양성(TP)인 비율       |
# | 재현율(Recall)          |            1 |            1 | 실제 양성(TP,FN) 중 양성(TP)으로 예측한 비율              |
# | 위양성율(Fallout)       |            0 |            0 | 실제 음성(FP,TN) 중 양성(FP)으로 잘못 예측한 비율         |
# | 특이성(TNR)             |            1 |            1 | 실제 음성(FP,TN) 중 음성(TN)으로 정확히 예측한 비율       |
# ...
