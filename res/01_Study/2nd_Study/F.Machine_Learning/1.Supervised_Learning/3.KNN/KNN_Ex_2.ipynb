# %%
import sys
sys.path.append("Y:\Python\Mega_IT")

from yjk_module.preprocessing import *
from yjk_module.ml_module import *

# %%
from sklearn.neighbors import KNeighborsClassifier
from hossam.util import *
from hossam.plot import *
from hossam.analysis import *
from hossam.classification import *

# %% [markdown]
# # 문제2

# %%
origin1 = pd.read_excel("./data/apple_quality.xlsx")

# %%
origin1.head()
# Out:
#    A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0   0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1   1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2   2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3   3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4   4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
#
#     Acidity Quality
# 0  -0.49159    good
# 1 -0.722809    good
# 2  2.621636     bad
# 3  0.790723    good
# 4  0.501984    good

# %%
origin1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4001 entries, 0 to 4000
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   A_id         4000 non-null   float64
#  1   Size         4000 non-null   float64
#  2   Weight       4000 non-null   float64
#  3   Sweetness    4000 non-null   float64
#  4   Crunchiness  4000 non-null   float64
#  5   Juiciness    4000 non-null   float64
#  6   Ripeness     4000 non-null   float64
#  7   Acidity      4001 non-null   object
#  8   Quality      4000 non-null   object
# dtypes: float64(7), object(2)
# memory usage: 281.4+ KB

# %%
origin1.isnull().sum()
# Out:
# A_id           1
# Size           1
# Weight         1
# Sweetness      1
# Crunchiness    1
# Juiciness      1
# Ripeness       1
# Acidity        0
# Quality        1
# dtype: int64

# %%
origin1.dropna(inplace = True)

# %%
origin1.describe()
# Out:
#               A_id         Size       Weight    Sweetness  Crunchiness  \
# count  4000.000000  4000.000000  4000.000000  4000.000000  4000.000000
# mean   1999.500000    -0.503015    -0.989547    -0.470479     0.985478
# std    1154.844867     1.928059     1.602507     1.943441     1.402757
# min       0.000000    -7.151703    -7.149848    -6.894485    -6.055058
# 25%     999.750000    -1.816765    -2.011770    -1.738425     0.062764
# 50%    1999.500000    -0.513703    -0.984736    -0.504758     0.998249
# 75%    2999.250000     0.805526     0.030976     0.801922     1.894234
# max    3999.000000     6.406367     5.790714     6.374916     7.619852
#
#          Juiciness     Ripeness
# count  4000.000000  4000.000000
# mean      0.512118     0.498277
# std       1.930286     1.874427
# min      -5.961897    -5.864599
# 25%      -0.801286    -0.771677
# 50%       0.534219     0.503445
# 75%       1.835976     1.766212
# max       7.364403     7.237837

# %%
origin1.describe(include = 'O')
# Out:
#            Acidity Quality
# count   4000.00000    4000
# unique  4000.00000       2
# top       -0.49159    good
# freq       1.00000    2004

# %%
origin1['Acidity'] = origin1['Acidity'].astype('float64')

# %%
origin1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4000 entries, 0 to 3999
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   A_id         4000 non-null   float64
#  1   Size         4000 non-null   float64
#  2   Weight       4000 non-null   float64
#  3   Sweetness    4000 non-null   float64
#  4   Crunchiness  4000 non-null   float64
#  5   Juiciness    4000 non-null   float64
#  6   Ripeness     4000 non-null   float64
#  7   Acidity      4000 non-null   float64
#  8   Quality      4000 non-null   object
# dtypes: float64(8), object(1)
# memory usage: 312.5+ KB

# %%
origin1.drop('A_id', axis = 1, inplace = True)

# %%
origin1['Quality'].value_counts()
# Out:
# Quality
# good    2004
# bad     1996
# Name: count, dtype: int64

# %%
my_boxplot(origin1.drop('Quality', axis = 1))

# %%
pp = YjkPreprocessor()
pp.set_strategy(outline = None, null = None)
# Out:
# 아래와 같이 처리합니다.
# +-------------+----------------+
# | 범주        | 처리방법       |
# |-------------+----------------|
# | 이상치 처리 | 처리하지 않음  |
# | 결측치 처리 | 처리하지 않음  |
# | 스케일러    | StandardScaler |
# | 인코딩      | 원핫인코딩     |
# +-------------+----------------+

# %%
df1_p = pp.fit_transform(origin1, yname = 'Quality', ylabeling = True)
# Out:
# 데이터프레임 크기 : (4000, 8)
# 데이터프레임에 결측치는 없습니다.
# 연속형 데이터 컬럼 : ['Size', 'Weight', 'Sweetness', 'Crunchiness', 'Juiciness', 'Ripeness', 'Acidity'], 총 7개
# 종속변수 컬럼명 : Quality / 종속변수 라벨링 여부 : True

# %%
df1_p
# Out:
#           Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0    -1.798424 -0.950373   2.993421    -1.424150   0.690545 -0.089872
# 1    -0.359060 -1.154404   2.127698     0.429746   0.176767  0.197020
# 2     0.109445 -0.225759  -0.652507    -0.946892   1.205422 -0.286156
# 3    -0.079977 -0.800146   0.923916    -0.772399   1.619575 -2.087320
# 4     0.968573 -0.191640   0.044164    -1.096894   1.305025 -0.961548
# ...        ...       ...        ...          ...        ...       ...
# 3995  0.291729 -0.048594  -1.669449    -0.365345   0.614425  0.931482
# 3996  0.108878  1.834105   0.137124    -1.159058  -0.252634 -0.846326
# 3997 -1.105655 -0.716904  -1.013784    -0.234036   0.874379  2.275957
# 3998 -1.818112 -0.492908   1.459901    -0.845446   0.854549 -0.151419
# 3999  0.405409 -0.453071   0.304496    -1.525439   0.390954 -0.680212
#
#        Acidity  Quality
# 0    -0.269415        1
# 1    -0.378997        1
# 2     1.206044        0
# 3     0.338315        1
# 4     0.201472        1
# ...        ...      ...
# 3995  0.028866        0
# 3996  0.842347        1
# 3997 -0.668950        0
# 3998 -1.093171        1
# 3999  0.721761        1
#
# [4000 rows x 8 columns]

# %%
X = df1_p.copy()
Y = X.pop('Quality')

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0 , stratify = Y)

# %%
my_logistic_classification(x_train, y_train, x_test, y_test)
# Out:
# [교차검증]
# +----+-------+------------+-----------+-------------------+
# |    |     C |   max_iter | penalty   |   mean_test_score |
# |----+-------+------------+-----------+-------------------|
# |  7 |   0.1 |        500 | l2        |          0.744688 |
# | 13 |    10 |        500 | l2        |          0.743437 |
# | 16 |   100 |        500 | l2        |          0.743437 |
# | 10 |     1 |        500 | l2        |          0.743125 |
# |  4 |  0.01 |        500 | l2        |          0.738125 |
# |  1 | 0.001 |        500 | l2        |          0.715625 |
# +----+-------+------------+-----------+-------------------+
#
# [분류분석 성능평가]
# +-------------------------+--------------+--------------+-----------------------------------------------------------+
# |                         |   훈련데이터 |   검증데이터 | 설명                                                      |
# |-------------------------+--------------+--------------+-----------------------------------------------------------|
# | 의사결정계수(Pseudo R2) |      0.24701 |     0.296238 | 로지스틱회귀의 성능 측정 지표로, 1에 가까울수록 좋은 모델 |
# | 정확도(Accuracy)        |        0.745 |       0.7675 | 예측 결과(TN,FP,TP,TN)가 실제 결과(TP,TN)와 일치하는 정도 |
# | 정밀도(Precision)       |     0.736336 |     0.769424 | 양성으로 예측한 결과(TP,FP) 중 실제 양성(TP)인 비율       |
# | 재현율(Recall)          |     0.764816 |     0.765586 | 실제 양성(TP,FN) 중 양성(TP)으로 예측한 비율              |
# | 위양성율(Fallout)       |      0.27489 |     0.230576 | 실제 음성(FP,TN) 중 양성(FP)으로 잘못 예측한 비율         |
# | 특이성(TNR)             |      0.72511 |     0.769424 | 실제 음성(FP,TN) 중 음성(TN)으로 정확히 예측한 비율       |
# | F1 Score                |     0.750306 |       0.7675 | 정밀도와 재현율의 조화평균                                |
# | AUC                     |      0.81768 |     0.847662 | ROC Curve의 밑면적으로, 1에 가까울수록 좋은 모델          |
# +-------------------------+--------------+--------------+-----------------------------------------------------------+
#
# [혼동행렬]
# [Roc Curve]
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# [학습곡선]
# +----+------------+-------------+--------------------+------------+---------+------------+---------+------------+
# |    | 종속변수   | 독립변수    |   B(비표준화 계수) |   표준오차 |       t |   유의확률 |     VIF |   OddsRate |
# |----+------------+-------------+--------------------+------------+---------+------------+---------+------------|
# |  0 | Quality    | Size        |             1.1437 |      0.115 |  9.9559 |          0 | 1.37188 |     3.1383 |
# |  1 | Quality    | Weight      |             0.3951 |      0.102 |  3.8879 |          0 |  1.3012 |     1.4846 |
# |  2 | Quality    | Sweetness   |             0.9958 |       0.11 |  9.0696 |          0 | 1.41833 |     2.7069 |
# |  3 | Quality    | Crunchiness |             0.0276 |      0.091 |  0.3039 |      0.761 | 1.20037 |      1.028 |
# |  4 | Quality    | Juiciness   |             0.7751 |      0.103 |  7.5027 |          0 | 1.21016 |     2.1709 |
# |  5 | Quality    | Ripeness    |            -0.2629 |      0.102 | -2.5829 |       0.01 |  1.4233 |     0.7689 |
# |  6 | Quality    | Acidity     |            -0.5542 |      0.097 | -5.6851 |          0 | 1.14688 |     0.5745 |
# +----+------------+-------------+--------------------+------------+---------+------------+---------+------------+
# LogisticRegression(C=0.1, max_iter=500, n_jobs=-1)

# %%
pp_roll = YjkPreprocessor()

# %%
outline_li = ['q', 'm', 'a', None]
scaler_li = ['s', 'm', 'r', None]
encoder_li = ['o', 'ord']

# %%
results_pp = []

def add_result_pp(model, note, x_test, y_test):
    global results_pp
    tmp_dict = {}
    tmp_dict['How'] = note
    tmp_dict['Accuracy'] = model.score(x_test, y_test)
    tmp_dict['model'] = model
    results_pp.append(tmp_dict)

# %%
# for i in scaler_li:
#     for j in encoder_li:
#         for k in outline_li:
#             pp_roll.set_strategy(outline = k, null = None, encoder = j, scaler = i, alert = False)
#             df1_p = pp_roll.fit_transform(origin1, yname = 'Quality', ylabeling = True, alert = False)
#             X = df1_p.drop('Quality', axis = 1)
#             Y = df1_p['Quality']
    
#             x_train, x_test, y_train, y_test = train_test_split(X, Y, random_state = 0, test_size = 0.2, stratify = Y)
#             model = my_knn_classification(x_train, y_train, x_test, y_test, report = False, learning_curve = False)
#             add_result_pp(model, f"Scaler : {i}, Encoder : {j}, outline : {k}", x_test, y_test)

# %%
# pd.DataFrame(results_pp).sort_values('Accuracy', ascending = False).head()

# %%
pp1 = YjkPreprocessor()
pp1.set_strategy(outline = 'q', null = None, scaler = 'r')
# Out:
# 아래와 같이 처리합니다.
# +-------------+---------------+
# | 범주        | 처리방법      |
# |-------------+---------------|
# | 이상치 처리 | 경계값 대체   |
# | 결측치 처리 | 처리하지 않음 |
# | 스케일러    | RobustScaler  |
# | 인코딩      | 원핫인코딩    |
# +-------------+---------------+

# %%
df1_p = pp1.fit_transform(origin1, yname = 'Quality', ylabeling = True)
# Out:
# 데이터프레임 크기 : (4000, 8)
# 데이터프레임에 결측치는 없습니다.
# 연속형 데이터 컬럼 : ['Size', 'Weight', 'Sweetness', 'Crunchiness', 'Juiciness', 'Ripeness', 'Acidity'], 총 7개
# 종속변수 컬럼명 : Quality / 종속변수 라벨링 여부 : True

# %%
X = df1_p.copy()
Y = X.pop('Quality')

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0, stratify = Y)

# %%
my_logistic_classification(x_train, y_train, x_test, y_test)
# Out:
# [교차검증]
# +----+-------+------------+-----------+-------------------+
# |    |     C |   max_iter | penalty   |   mean_test_score |
# |----+-------+------------+-----------+-------------------|
# |  7 |   0.1 |        500 | l2        |          0.745313 |
# | 10 |     1 |        500 | l2        |          0.743438 |
# | 13 |    10 |        500 | l2        |          0.743125 |
# | 16 |   100 |        500 | l2        |          0.743125 |
# |  4 |  0.01 |        500 | l2        |          0.733437 |
# |  1 | 0.001 |        500 | l2        |          0.711563 |
# +----+-------+------------+-----------+-------------------+
#
# [분류분석 성능평가]
# +-------------------------+--------------+--------------+-----------------------------------------------------------+
# |                         |   훈련데이터 |   검증데이터 | 설명                                                      |
# |-------------------------+--------------+--------------+-----------------------------------------------------------|
# | 의사결정계수(Pseudo R2) |     0.244458 |     0.293259 | 로지스틱회귀의 성능 측정 지표로, 1에 가까울수록 좋은 모델 |
# | 정확도(Accuracy)        |     0.742812 |       0.7625 | 예측 결과(TN,FP,TP,TN)가 실제 결과(TP,TN)와 일치하는 정도 |
# | 정밀도(Precision)       |     0.734375 |     0.764411 | 양성으로 예측한 결과(TP,FP) 중 실제 양성(TP)인 비율       |
# | 재현율(Recall)          |     0.762321 |     0.760599 | 실제 양성(TP,FN) 중 양성(TP)으로 예측한 비율              |
# | 위양성율(Fallout)       |     0.276769 |     0.235589 | 실제 음성(FP,TN) 중 양성(FP)으로 잘못 예측한 비율         |
# | 특이성(TNR)             |     0.723231 |     0.764411 | 실제 음성(FP,TN) 중 음성(TN)으로 정확히 예측한 비율       |
# | F1 Score                |     0.748087 |       0.7625 | 정밀도와 재현율의 조화평균                                |
# | AUC                     |     0.816686 |     0.847368 | ROC Curve의 밑면적으로, 1에 가까울수록 좋은 모델          |
# +-------------------------+--------------+--------------+-----------------------------------------------------------+
#
# [혼동행렬]
# [Roc Curve]
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# [학습곡선]
# +----+------------+-------------+--------------------+------------+---------+------------+---------+------------+
# |    | 종속변수   | 독립변수    |   B(비표준화 계수) |   표준오차 |       t |   유의확률 |     VIF |   OddsRate |
# |----+------------+-------------+--------------------+------------+---------+------------+---------+------------|
# |  0 | Quality    | Size        |             1.4801 |      0.153 |  9.6665 |          0 | 1.36972 |     4.3935 |
# |  1 | Quality    | Weight      |             0.4626 |      0.129 |  3.5783 |          0 | 1.29476 |     1.5882 |
# |  2 | Quality    | Sweetness   |             1.2385 |      0.141 |  8.7863 |          0 |  1.4144 |     3.4506 |
# |  3 | Quality    | Crunchiness |             0.0284 |      0.121 |  0.2335 |      0.815 | 1.19848 |     1.0288 |
# |  4 | Quality    | Juiciness   |              1.016 |      0.139 |  7.2979 |          0 | 1.21092 |     2.7621 |
# |  5 | Quality    | Ripeness    |             -0.368 |      0.136 | -2.7032 |      0.007 | 1.41223 |     0.6922 |
# |  6 | Quality    | Acidity     |            -0.7166 |      0.132 | -5.4492 |          0 | 1.14635 |     0.4884 |
# +----+------------+-------------+--------------------+------------+---------+------------+---------+------------+
# LogisticRegression(C=0.1, max_iter=500, n_jobs=-1)

# %%
my_knn_classification(x_train, y_train, x_test, y_test)
# Out:
# [교차검증]
# +----+-----------+---------------+-----------+-------------------+
# |    | metric    |   n_neighbors | weights   |   mean_test_score |
# |----+-----------+---------------+-----------+-------------------|
# |  5 | euclidean |             7 | distance  |          0.890625 |
# |  4 | euclidean |             7 | uniform   |           0.88875 |
# |  3 | euclidean |             5 | distance  |          0.888437 |
# |  2 | euclidean |             5 | uniform   |          0.888125 |
# |  0 | euclidean |             3 | uniform   |          0.884063 |
# |  1 | euclidean |             3 | distance  |          0.884063 |
# | 11 | manhattan |             7 | distance  |          0.881875 |
# | 10 | manhattan |             7 | uniform   |          0.880937 |
# |  8 | manhattan |             5 | uniform   |           0.87875 |
# |  9 | manhattan |             5 | distance  |          0.878438 |
# |  6 | manhattan |             3 | uniform   |          0.876563 |
# |  7 | manhattan |             3 | distance  |           0.87625 |
# +----+-----------+---------------+-----------+-------------------+
#
# [분류분석 성능평가]
# +-------------------+--------------+--------------+-----------------------------------------------------------+
# |                   |   훈련데이터 |   검증데이터 | 설명                                                      |
# |-------------------+--------------+--------------+-----------------------------------------------------------|
# | 정확도(Accuracy)  |            1 |       0.9175 | 예측 결과(TN,FP,TP,TN)가 실제 결과(TP,TN)와 일치하는 정도 |
# | 정밀도(Precision) |            1 |     0.899761 | 양성으로 예측한 결과(TP,FP) 중 실제 양성(TP)인 비율       |
# | 재현율(Recall)    |            1 |      0.94015 | 실제 양성(TP,FN) 중 양성(TP)으로 예측한 비율              |
# | 위양성율(Fallout) |            0 |     0.105263 | 실제 음성(FP,TN) 중 양성(FP)으로 잘못 예측한 비율         |
# | 특이성(TNR)       |            1 |     0.894737 | 실제 음성(FP,TN) 중 음성(TN)으로 정확히 예측한 비율       |
# | F1 Score          |            1 |     0.919512 | 정밀도와 재현율의 조화평균                                |
# | AUC               |            1 |       0.9716 | ROC Curve의 밑면적으로, 1에 가까울수록 좋은 모델          |
# +-------------------+--------------+--------------+-----------------------------------------------------------+
#
# [혼동행렬]
# [Roc Curve]
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# [학습곡선]
# KNeighborsClassifier(metric='euclidean', n_jobs=-1, n_neighbors=7,
#                      weights='distance')

# %%
support = YjkClassifierSupport()
# Out:
# 사용 가능한 모델 : ['LogisticRegression', 'SGDClassifier', 'KNeighborsClassifier']

# %%
# %%time

result_df1 = yjk_classifier_multi_gridsearch(support, x_train, x_test, y_train, y_test)
result_df1
# Out:
# CPU times: total: 31.3 s
# Wall time: 1min 11s
#                                                              best_model  \
# model_name
# KNeighborsClassifier  KNeighborsClassifier(n_jobs=-1, n_neighbors=6,...
# SGDClassifier         SGDClassifier(alpha=0.001, loss='huber', max_i...
# LogisticRegression    LogisticRegression(C=0.001, n_jobs=-1, penalty...
#
#                                                              best_param  \
# model_name
# KNeighborsClassifier  {'n_neighbors': 6, 'p': 2, 'weights': 'distance'}
# SGDClassifier         {'alpha': 0.001, 'loss': 'huber', 'max_iter': ...
# LogisticRegression       {'C': 0.001, 'max_iter': 100, 'penalty': None}
#
#                       accuracy_train  accuracy_test
# model_name
# KNeighborsClassifier        0.895312        0.91875
# SGDClassifier               0.745625        0.77125
# LogisticRegression          0.744062        0.77000

# %%
final_model1 = result_df1.iloc[0, 0]

# %%
final_model1.score(x_test, y_test)
# Out:
# 0.91875

# %% [markdown]
# - 로지스틱 : 정확도 0.76, ROC_AUC : 0.85
# - KNN : 정확도 0.9, ROC_AUC : 0.97
#     - KNN의 성능이 더 우수하다

# %% [markdown]
# # 문제3

# %%
origin2 = pd.read_excel("./data/smoker_status.xlsx")

# %%
origin2.head()
# Out:
#    age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  eyesight(right)  \
# 0   55         165          60       81.0             0.5              0.6
# 1   70         165          65       89.0             0.6              0.7
# 2   20         170          75       81.0             0.4              0.5
# 3   35         180          95      105.0             1.5              1.2
# 4   30         165          60       80.5             1.5              1.0
#
#    hearing(left)  hearing(right)  systolic  relaxation  ...  HDL  LDL  \
# 0              1               1       135          87  ...   40   75
# 1              2               2       146          83  ...   57  126
# 2              1               1       118          75  ...   45   93
# 3              1               1       131          88  ...   38  102
# 4              1               1       121          76  ...   44   93
#
#    hemoglobin  Urine protein  serum creatinine  AST  ALT  Gtp  dental caries  \
# 0        16.5              1               1.0   22   25   27              0
# 1        16.2              1               1.1   27   23   37              1
# 2        17.4              1               0.8   27   31   53              0
# 3        15.9              1               1.0   20   27   30              1
# 4        15.4              1               0.8   19   13   17              0
#
#    smoking
# 0        1
# 1        0
# 2        1
# 3        0
# 4        1
#
# [5 rows x 23 columns]

# %%
origin2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159256 entries, 0 to 159255
# Data columns (total 23 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   age                  159256 non-null  int64
#  1   height(cm)           159256 non-null  int64
#  2   weight(kg)           159256 non-null  int64
#  3   waist(cm)            159256 non-null  float64
#  4   eyesight(left)       159256 non-null  float64
#  5   eyesight(right)      159256 non-null  float64
#  6   hearing(left)        159256 non-null  int64
#  7   hearing(right)       159256 non-null  int64
#  8   systolic             159256 non-null  int64
#  9   relaxation           159256 non-null  int64
#  10  fasting blood sugar  159256 non-null  int64
#  11  Cholesterol          159256 non-null  int64
#  12  triglyceride         159256 non-null  int64
#  13  HDL                  159256 non-null  int64
#  14  LDL                  159256 non-null  int64
#  15  hemoglobin           159256 non-null  float64
#  16  Urine protein        159256 non-null  int64
#  17  serum creatinine     159256 non-null  float64
#  18  AST                  159256 non-null  int64
#  19  ALT                  159256 non-null  int64
#  20  Gtp                  159256 non-null  int64
#  21  dental caries        159256 non-null  int64
#  22  smoking              159256 non-null  int64
# dtypes: float64(5), int64(18)
# memory usage: 27.9 MB

# %%
origin2['smoking'].value_counts()
# Out:
# smoking
# 0    89603
# 1    69653
# Name: count, dtype: int64

# %%
my_boxplot(origin2.drop('smoking', axis = 1))

# %%
df2 = origin2.copy()

# %%
df2['dental caries'] = df2['dental caries'].astype('category')

# %%
outline_li = ['q', 'm', 'a', None]
scaler_li = ['s', 'm', 'r', None]
encoder_li = ['o', 'ord']

# %%
results_pp = []

# %%
# for i in scaler_li:
#     for j in encoder_li:
#         for k in outline_li:
#             pp_roll.set_strategy(outline = k, null = None, encoder = j, scaler = i, alert = False)
#             df2_p = pp_roll.fit_transform(df2, yname = 'smoking', ylabeling = True, alert = False)
#             X = df2_p.drop('smoking', axis = 1)
#             Y = df2_p['smoking']
    
#             x_train, x_test, y_train, y_test = train_test_split(X, Y, random_state = 0, test_size = 0.2, stratify = Y)
#             model = my_logistic_classification(x_train, y_train, x_test, y_test, report = False, learning_curve = False, hist = False, roc = False, pr = False)
#             add_result_pp(model, f"Scaler : {i}, Encoder : {j}, outline : {k}", x_test, y_test)

# %%
# pd.DataFrame(results_pp).sort_values('Accuracy', ascending = False).head()

# %%
pp2 = YjkPreprocessor()
pp2.set_strategy(outline = 'q', scaler = 'm', encoder = 'o')
# Out:
# 아래와 같이 처리합니다.
# +-------------+--------------+
# | 범주        | 처리방법     |
# |-------------+--------------|
# | 이상치 처리 | 경계값 대체  |
# | 결측치 처리 | 중앙값 대체  |
# | 스케일러    | MinMaxScaler |
# | 인코딩      | 원핫인코딩   |
# +-------------+--------------+

# %%
df2_p = pp2.fit_transform(df2, yname = 'smoking', ylabeling = True)
# Out:
# 데이터프레임 크기 : (159256, 23)
# 데이터프레임에 결측치는 없습니다.
# 연속형 데이터 컬럼 : ['age', 'height(cm)', 'weight(kg)', 'waist(cm)', 'eyesight(left)', 'eyesight(right)', 'hearing(left)', 'hearing(right)', 'systolic', 'relaxation', 'fasting blood sugar', 'Cholesterol', 'triglyceride', 'HDL', 'LDL', 'hemoglobin', 'Urine protein', 'serum creatinine', 'AST', 'ALT', 'Gtp'], 총 21개
# 명목형 데이터 컬럼 : ['dental caries'], 총 1개
# 종속변수 컬럼명 : smoking / 종속변수 라벨링 여부 : True

# %%
X = df2_p.copy()
Y = X.pop('smoking')

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0, stratify = Y)

# %%
my_logistic_classification(x_train, y_train, x_test, y_test, pr = False, hist = False, roc = False, learning_curve = False, report = False)
# Out:
# [교차검증]
# +----+-------+------------+-----------+-------------------+
# |    |     C |   max_iter | penalty   |   mean_test_score |
# |----+-------+------------+-----------+-------------------|
# | 16 |   100 |        500 | l2        |          0.752794 |
# | 13 |    10 |        500 | l2        |          0.752763 |
# | 10 |     1 |        500 | l2        |          0.752661 |
# |  7 |   0.1 |        500 | l2        |          0.752378 |
# |  4 |  0.01 |        500 | l2        |          0.750659 |
# |  1 | 0.001 |        500 | l2        |          0.735236 |
# +----+-------+------------+-----------+-------------------+
#
# [분류분석 성능평가]
# +-------------------------+--------------+--------------+-----------------------------------------------------------+
# |                         |   훈련데이터 |   검증데이터 | 설명                                                      |
# |-------------------------+--------------+--------------+-----------------------------------------------------------|
# | 의사결정계수(Pseudo R2) |     0.294405 |     0.291961 | 로지스틱회귀의 성능 측정 지표로, 1에 가까울수록 좋은 모델 |
# | 정확도(Accuracy)        |      0.75281 |     0.752574 | 예측 결과(TN,FP,TP,TN)가 실제 결과(TP,TN)와 일치하는 정도 |
# | 정밀도(Precision)       |     0.709895 |     0.710362 | 양성으로 예측한 결과(TP,FP) 중 실제 양성(TP)인 비율       |
# | 재현율(Recall)          |     0.735311 |     0.733257 | 실제 양성(TP,FN) 중 양성(TP)으로 예측한 비율              |
# | 위양성율(Fallout)       |     0.233587 |     0.232409 | 실제 음성(FP,TN) 중 양성(FP)으로 잘못 예측한 비율         |
# | 특이성(TNR)             |     0.766413 |     0.767591 | 실제 음성(FP,TN) 중 음성(TN)으로 정확히 예측한 비율       |
# | F1 Score                |     0.722379 |     0.721628 | 정밀도와 재현율의 조화평균                                |
# | AUC                     |     0.839142 |     0.837945 | ROC Curve의 밑면적으로, 1에 가까울수록 좋은 모델          |
# +-------------------------+--------------+--------------+-----------------------------------------------------------+
#
# [혼동행렬]
# [Roc Curve]
# LogisticRegression(C=100, max_iter=500, n_jobs=-1)

# %%
my_knn_classification(x_train, y_train, x_test, y_test, pr = False, hist = False, roc = False, learning_curve = False, report = False)
# Out:
# [교차검증]
# +----+-------------------+
# |    |   mean_test_score |
# |----+-------------------|
# |  0 |          0.734671 |
# +----+-------------------+
#
# [분류분석 성능평가]
# +-------------------+--------------+--------------+-----------------------------------------------------------+
# |                   |   훈련데이터 |   검증데이터 | 설명                                                      |
# |-------------------+--------------+--------------+-----------------------------------------------------------|
# | 정확도(Accuracy)  |     0.819056 |     0.735119 | 예측 결과(TN,FP,TP,TN)가 실제 결과(TP,TN)와 일치하는 정도 |
# | 정밀도(Precision) |     0.775098 |     0.685083 | 양성으로 예측한 결과(TP,FP) 중 실제 양성(TP)인 비율       |
# | 재현율(Recall)    |     0.825939 |     0.729883 | 실제 양성(TP,FN) 중 양성(TP)으로 예측한 비율              |
# | 위양성율(Fallout) |     0.186295 |     0.260811 | 실제 음성(FP,TN) 중 양성(FP)으로 잘못 예측한 비율         |
# | 특이성(TNR)       |     0.813705 |     0.739189 | 실제 음성(FP,TN) 중 음성(TN)으로 정확히 예측한 비율       |
# | F1 Score          |     0.799712 |     0.706774 | 정밀도와 재현율의 조화평균                                |
# | AUC               |     0.905793 |     0.804211 | ROC Curve의 밑면적으로, 1에 가까울수록 좋은 모델          |
# +-------------------+--------------+--------------+-----------------------------------------------------------+
#
# [혼동행렬]
# [Roc Curve]
# KNeighborsClassifier(n_jobs=-1)

# %%
# %%time

result2 = yjk_classifier_multi_gridsearch(support, x_train, x_test, y_train, y_test, randomized_search = True, cv = 5)
result2
# Out:
# CPU times: total: 58min 19s
# Wall time: 6min 34s
#                                                              best_model  \
# model_name
# LogisticRegression    LogisticRegression(C=100, max_iter=300, n_jobs...
# SGDClassifier         SGDClassifier(alpha=0.001, loss='log_loss', ma...
# KNeighborsClassifier  KNeighborsClassifier(n_jobs=-1, n_neighbors=7,...
#
#                                                              best_param  \
# model_name
# LogisticRegression         {'penalty': None, 'max_iter': 300, 'C': 100}
# SGDClassifier         {'tol': 0.01, 'penalty': 'l2', 'max_iter': 500...
# KNeighborsClassifier   {'weights': 'uniform', 'p': 1, 'n_neighbors': 7}
#
#                       accuracy_train  accuracy_test
# model_name
# LogisticRegression          0.752771       0.752574
# SGDClassifier               0.752323       0.748336
# KNeighborsClassifier        0.743226       0.743470

# %% [markdown]
# - 로지스틱 회귀 : 정확도 0.75, ROC_AUC 0.84
# - KNN : 정확도 0.69 ROC_AUC 0.8
#     - 로지스틱 회귀의 성능이 더 우수함

# %%
origin3 = pd.read_excel("./data/customer_segmentation.xlsx")

# %%
origin3.head()
# Out:
#        ID  Gender Ever_Married  Age Graduated     Profession  Work_Experience  \
# 0  462809    Male           No   22        No     Healthcare              1.0
# 1  462643  Female          Yes   38       Yes       Engineer              NaN
# 2  466315  Female          Yes   67       Yes       Engineer              1.0
# 3  461735    Male          Yes   67       Yes         Lawyer              0.0
# 4  462669  Female          Yes   40       Yes  Entertainment              NaN
#
#   Spending_Score  Family_Size  Var_1 Segmentation
# 0            Low          4.0  Cat_4            D
# 1        Average          3.0  Cat_4            A
# 2            Low          1.0  Cat_6            B
# 3           High          2.0  Cat_6            B
# 4           High          6.0  Cat_6            A

# %%
origin3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10695 entries, 0 to 10694
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               10695 non-null  int64
#  1   Gender           10695 non-null  object
#  2   Ever_Married     10505 non-null  object
#  3   Age              10695 non-null  int64
#  4   Graduated        10593 non-null  object
#  5   Profession       10533 non-null  object
#  6   Work_Experience  9597 non-null   float64
#  7   Spending_Score   10695 non-null  object
#  8   Family_Size      10247 non-null  float64
#  9   Var_1            10587 non-null  object
#  10  Segmentation     10695 non-null  object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 919.2+ KB

# %%
origin3.isnull().sum()
# Out:
# ID                    0
# Gender                0
# Ever_Married        190
# Age                   0
# Graduated           102
# Profession          162
# Work_Experience    1098
# Spending_Score        0
# Family_Size         448
# Var_1               108
# Segmentation          0
# dtype: int64

# %%
origin3['Ever_Married'].value_counts()
# Out:
# Ever_Married
# Yes    6163
# No     4342
# Name: count, dtype: int64

# %%
origin3['Graduated'].value_counts()
# Out:
# Graduated
# Yes    6570
# No     4023
# Name: count, dtype: int64

# %%
origin3['Profession'].value_counts()
# Out:
# Profession
# Artist           3318
# Healthcare       1750
# Entertainment    1250
# Engineer          935
# Doctor            930
# Lawyer            844
# Executive         775
# Marketing         403
# Homemaker         328
# Name: count, dtype: int64

# %%
origin3['Family_Size'].value_counts()
# Out:
# Family_Size
# 2.0    3158
# 1.0    1965
# 3.0    1952
# 4.0    1823
# 5.0     812
# 6.0     290
# 7.0     122
# 8.0      65
# 9.0      60
# Name: count, dtype: int64

# %%
origin3['Var_1'].value_counts()
# Out:
# Var_1
# Cat_6    6910
# Cat_4    1475
# Cat_3    1089
# Cat_2     563
# Cat_7     269
# Cat_1     167
# Cat_5     114
# Name: count, dtype: int64

# %%
df3 = origin3.drop('ID', axis = 1)

# %%
my_boxplot(df3)

# %%
results_pp = []

# %%
# for i in scaler_li:
#     for j in encoder_li:
#         for k in outline_li:
#             pp_roll.set_strategy(outline = k, null = 'median', encoder = j, scaler = i, alert = False)
#             df3_p = pp_roll.fit_transform(df3, yname = 'Segmentation', ylabeling = True, alert = False)
#             X = df3_p.drop('Segmentation', axis = 1)
#             Y = df3_p['Segmentation']
    
#             x_train, x_test, y_train, y_test = train_test_split(X, Y, random_state = 0, test_size = 0.2, stratify = Y)
#             model = my_logistic_classification(x_train, y_train, x_test, y_test, report = False, learning_curve = False, hist = False, roc = False, pr = False)
#             add_result_pp(model, f"Scaler : {i}, Encoder : {j}, outline : {k}", x_test, y_test)

# %%
# pd.DataFrame(results_pp).sort_values('Accuracy', ascending = False).head()

# %%
pp3 = YjkPreprocessor()
pp3.set_strategy(outline = 'a', null = 'median', scaler = None, encoder = 'o')
# Out:
# 아래와 같이 처리합니다.
# +-------------+---------------+
# | 범주        | 처리방법      |
# |-------------+---------------|
# | 이상치 처리 | 평균값 대체   |
# | 결측치 처리 | 중앙값 대체   |
# | 스케일러    | 처리하지 않음 |
# | 인코딩      | 원핫인코딩    |
# +-------------+---------------+

# %%
df3_p = pp3.fit_transform(df3, yname = 'Segmentation', ylabeling = True)
# Out:
# 데이터프레임 크기 : (10695, 10)
#
# [열별 결측치 개수]
# +-----------------+-------------+
# | 열명            |   결측치 수 |
# |-----------------+-------------|
# | Ever_Married    |         190 |
# | Graduated       |         102 |
# | Profession      |         162 |
# | Work_Experience |        1098 |
# | Family_Size     |         448 |
# | Var_1           |         108 |
# +-----------------+-------------+
#
# 연속형 데이터 컬럼 : ['Age', 'Work_Experience', 'Family_Size'], 총 3개
# 명목형 데이터 컬럼 : ['Gender', 'Ever_Married', 'Graduated', 'Profession', 'Spending_Score', 'Var_1'], 총 6개
# 종속변수 컬럼명 : Segmentation / 종속변수 라벨링 여부 : True

# %%
X = df3_p.copy()
Y = X.pop('Segmentation')

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0, stratify = Y)

# %%
my_logistic_classification(x_train, y_train, x_test, y_test)
# Out:
# [교차검증]
# +----+-------+------------+-----------+-------------------+
# |    |     C |   max_iter | penalty   |   mean_test_score |
# |----+-------+------------+-----------+-------------------|
# | 10 |     1 |        500 | l2        |          0.467739 |
# |  4 |  0.01 |        500 | l2        |          0.467389 |
# | 16 |   100 |        500 | l2        |          0.467155 |
# | 13 |    10 |        500 | l2        |          0.467155 |
# |  7 |   0.1 |        500 | l2        |          0.466337 |
# |  1 | 0.001 |        500 | l2        |          0.445067 |
# +----+-------+------------+-----------+-------------------+
#
# [분류분석 성능평가]
# +-------------------+--------------+--------------+-----------------------------------------------------------+
# |                   |   훈련데이터 |   검증데이터 | 설명                                                      |
# |-------------------+--------------+--------------+-----------------------------------------------------------|
# | 정확도(Accuracy)  |     0.474287 |     0.471248 | 예측 결과(TN,FP,TP,TN)가 실제 결과(TP,TN)와 일치하는 정도 |
# | 정밀도(Precision) |     0.459415 |     0.456866 | 양성으로 예측한 결과(TP,FP) 중 실제 양성(TP)인 비율       |
# | 재현율(Recall)    |     0.474287 |     0.457968 | 실제 양성(TP,FN) 중 양성(TP)으로 예측한 비율              |
# | F1 Score          |     0.443535 |     0.441277 | 정밀도와 재현율의 조화평균                                |
# | AUC(ovo)          |     0.717636 |     0.706346 | One vs One에 대한 AUC로, 1에 가까울수록 좋은 모델         |
# | AUC(ovr)          |     0.721606 |     0.710757 | One vs Rest에 대한 AUC로, 1에 가까울수록 좋은 모델        |
# +-------------------+--------------+--------------+-----------------------------------------------------------+
#
# [혼동행렬]
# [Roc Curve]
# mean roc auc ovo: 0.6763
# mean roc auc ovo: 0.7108
#
# [학습곡선]
# +----+--------------+---------+--------------------------+-----------+-------------+---------+------------+---------+------------+
# |    | 종속변수     |   CLASS | 독립변수                 |   B(계수) |    표준오차 |       t |   유의확률 |     VIF |   OddsRate |
# |----+--------------+---------+--------------------------+-----------+-------------+---------+------------+---------+------------|
# |  0 | Segmentation |       0 | Age                      |   -0.0044 |       0.004 | -1.1007 |      0.271 | 2.44396 |     0.9956 |
# |  1 | Segmentation |       0 | Work_Experience          |    0.0102 |       0.015 |  0.6819 |      0.495 | 1.05979 |     1.0102 |
# |  2 | Segmentation |       0 | Family_Size              |   -0.0873 |       0.035 | -2.5019 |      0.012 | 1.27153 |     0.9164 |
# |  3 | Segmentation |       0 | Gender_Female            |    0.0611 |  2.1876e+06 |       0 |          1 |     inf |      1.063 |
# |  4 | Segmentation |       0 | Gender_Male              |     0.132 | 2.18624e+06 |       0 |          1 |     inf |     1.1411 |
# |  5 | Segmentation |       0 | Ever_Married_No          |    0.0583 |         nan |     nan |        nan |     inf |     1.0601 |
# |  6 | Segmentation |       0 | Ever_Married_Yes         |    0.1348 |         nan |     nan |        nan |     inf |     1.1443 |
# |  7 | Segmentation |       0 | Graduated_No             |    0.1602 | 2.12641e+06 |       0 |          1 |     inf |     1.1738 |
# |  8 | Segmentation |       0 | Graduated_Yes            |    0.0329 | 2.13447e+06 |       0 |          1 |     inf |     1.0334 |
# |  9 | Segmentation |       0 | Profession_Artist        |   -0.0006 | 2.16298e+06 |      -0 |          1 |     inf |     0.9994 |
# | 10 | Segmentation |       0 | Profession_Doctor        |    0.0677 |  2.2036e+06 |       0 |          1 |     inf |     1.0701 |
# | 11 | Segmentation |       0 | Profession_Engineer      |    0.2931 |  2.1937e+06 |       0 |          1 |     inf |     1.3406 |
# | 12 | Segmentation |       0 | Profession_Entertainment |    0.3196 | 2.19721e+06 |       0 |          1 |     inf |     1.3765 |
# | 13 | Segmentation |       0 | Profession_Executive     |   -0.1108 | 2.18643e+06 |      -0 |          1 |     inf |     0.8951 |
# | 14 | Segmentation |       0 | Profession_Healthcare    |   -0.4723 | 2.18114e+06 |      -0 |          1 |     inf |     0.6235 |
# | 15 | Segmentation |       0 | Profession_Homemaker     |    0.0403 | 2.20106e+06 |       0 |          1 |     inf |     1.0411 |
# | 16 | Segmentation |       0 | Profession_Lawyer        |    0.1941 | 2.18208e+06 |       0 |          1 |     inf |     1.2142 |
# | 17 | Segmentation |       0 | Profession_Marketing     |    -0.138 | 2.20219e+06 |      -0 |          1 |     inf |     0.8711 |
# | 18 | Segmentation |       0 | Spending_Score_Average   |   -0.1475 |         nan |     nan |        nan |     inf |     0.8628 |
# | 19 | Segmentation |       0 | Spending_Score_High      |    0.0562 |         nan |     nan |        nan |     inf |     1.0578 |
# | 20 | Segmentation |       0 | Spending_Score_Low       |    0.2845 |         nan |     nan |        nan |     inf |     1.3291 |
# | 21 | Segmentation |       0 | Var_1_Cat_1              |    0.0093 | 2.08676e+06 |       0 |          1 |     inf |     1.0093 |
# | 22 | Segmentation |       0 | Var_1_Cat_2              |   -0.0333 | 2.08676e+06 |      -0 |          1 |     inf |     0.9672 |
# | 23 | Segmentation |       0 | Var_1_Cat_3              |    0.0495 | 2.08676e+06 |       0 |          1 |     inf |     1.0508 |
# | 24 | Segmentation |       0 | Var_1_Cat_4              |    0.1825 | 2.08676e+06 |       0 |          1 |     inf |     1.2002 |
# | 25 | Segmentation |       0 | Var_1_Cat_5              |   -0.0021 | 2.08676e+06 |      -0 |          1 |     inf |     0.9979 |
# | 26 | Segmentation |       0 | Var_1_Cat_6              |   -0.0816 | 2.08676e+06 |      -0 |          1 |     inf |     0.9216 |
# | 27 | Segmentation |       0 | Var_1_Cat_7              |    0.0689 | 2.08676e+06 |       0 |          1 |     inf |     1.0713 |
# +----+--------------+---------+--------------------------+-----------+-------------+---------+------------+---------+------------+
# +----+--------------+---------+--------------------------+-----------+-------------+---------+------------+---------+------------+
# |    | 종속변수     |   CLASS | 독립변수                 |   B(계수) |    표준오차 |       t |   유의확률 |     VIF |   OddsRate |
# |----+--------------+---------+--------------------------+-----------+-------------+---------+------------+---------+------------|
# |  0 | Segmentation |       1 | Age                      |    0.0118 |       0.004 |  2.7919 |      0.005 | 2.44396 |     1.0118 |
# |  1 | Segmentation |       1 | Work_Experience          |   -0.0207 |       0.018 |  -1.177 |      0.239 | 1.05979 |     0.9795 |
# |  2 | Segmentation |       1 | Family_Size              |   -0.0153 |       0.038 | -0.4021 |      0.688 | 1.27153 |     0.9848 |
# |  3 | Segmentation |       1 | Gender_Female            |   -0.0493 |         nan |     nan |        nan |     inf |     0.9519 |
# |  4 | Segmentation |       1 | Gender_Male              |   -0.0844 |         nan |     nan |        nan |     inf |     0.9191 |
# |  5 | Segmentation |       1 | Ever_Married_No          |   -0.1234 | 1.07557e+06 |      -0 |          1 |     inf |     0.8839 |
# |  6 | Segmentation |       1 | Ever_Married_Yes         |   -0.0103 |  1.0893e+06 |      -0 |          1 |     inf |     0.9897 |
# |  7 | Segmentation |       1 | Graduated_No             |   -0.1443 | 2.96339e+06 |      -0 |          1 |     inf |     0.8657 |
# |  8 | Segmentation |       1 | Graduated_Yes            |    0.0105 | 2.97439e+06 |       0 |          1 |     inf |     1.0106 |
# |  9 | Segmentation |       1 | Profession_Artist        |    0.2424 |  3.4255e+06 |       0 |          1 |     inf |     1.2744 |
# | 10 | Segmentation |       1 | Profession_Doctor        |    0.0478 |  3.2982e+06 |       0 |          1 |     inf |      1.049 |
# | 11 | Segmentation |       1 | Profession_Engineer      |    0.2216 | 3.38771e+06 |       0 |          1 |     inf |      1.248 |
# | 12 | Segmentation |       1 | Profession_Entertainment |    0.0369 | 3.40297e+06 |       0 |          1 |     inf |     1.0376 |
# | 13 | Segmentation |       1 | Profession_Executive     |    -0.045 | 3.42829e+06 |      -0 |          1 |     inf |      0.956 |
# | 14 | Segmentation |       1 | Profession_Healthcare    |   -0.2093 | 3.42857e+06 |      -0 |          1 |     inf |     0.8111 |
# | 15 | Segmentation |       1 | Profession_Homemaker     |    0.1499 | 3.33728e+06 |       0 |          1 |     inf |     1.1617 |
# | 16 | Segmentation |       1 | Profession_Lawyer        |   -0.4062 | 3.37344e+06 |      -0 |          1 |     inf |     0.6662 |
# | 17 | Segmentation |       1 | Profession_Marketing     |   -0.1719 | 3.36528e+06 |      -0 |          1 |     inf |      0.842 |
# | 18 | Segmentation |       1 | Spending_Score_Average   |   -0.0025 | 1.61427e+06 |      -0 |          1 |     inf |     0.9975 |
# | 19 | Segmentation |       1 | Spending_Score_High      |    0.0501 |  1.5952e+06 |       0 |          1 |     inf |     1.0514 |
# | 20 | Segmentation |       1 | Spending_Score_Low       |   -0.1813 | 1.59868e+06 |      -0 |          1 |     inf |     0.8342 |
# | 21 | Segmentation |       1 | Var_1_Cat_1              |   -0.2298 |      282100 |      -0 |          1 |     inf |     0.7947 |
# | 22 | Segmentation |       1 | Var_1_Cat_2              |    0.1388 |      282100 |       0 |          1 |     inf |     1.1489 |
# | 23 | Segmentation |       1 | Var_1_Cat_3              |    0.0464 |      282100 |       0 |          1 |     inf |     1.0475 |
# | 24 | Segmentation |       1 | Var_1_Cat_4              |    0.0445 |      282100 |       0 |          1 |     inf |     1.0455 |
# | 25 | Segmentation |       1 | Var_1_Cat_5              |   -0.0405 |      282100 |      -0 |          1 |     inf |     0.9603 |
# | 26 | Segmentation |       1 | Var_1_Cat_6              |   -0.0606 |      282100 |      -0 |          1 |     inf |     0.9412 |
# | 27 | Segmentation |       1 | Var_1_Cat_7              |   -0.0324 |      282100 |      -0 |          1 |     inf |     0.9681 |
# +----+--------------+---------+--------------------------+-----------+-------------+---------+------------+---------+------------+
# +----+--------------+---------+--------------------------+-----------+-------------+---------+------------+---------+------------+
# |    | 종속변수     |   CLASS | 독립변수                 |   B(계수) |    표준오차 |       t |   유의확률 |     VIF |   OddsRate |
# |----+--------------+---------+--------------------------+-----------+-------------+---------+------------+---------+------------|
# |  0 | Segmentation |       2 | Age                      |     0.019 |       0.004 |  4.4111 |          0 | 2.44396 |     1.0192 |
# |  1 | Segmentation |       2 | Work_Experience          |   -0.0125 |       0.018 | -0.7005 |      0.484 | 1.05979 |     0.9876 |
# |  2 | Segmentation |       2 | Family_Size              |    0.1189 |       0.038 |  3.1568 |      0.002 | 1.27153 |     1.1262 |
# |  3 | Segmentation |       2 | Gender_Female            |    -0.132 |         nan |     nan |        nan |     inf |     0.8763 |
# |  4 | Segmentation |       2 | Gender_Male              |   -0.3112 |         nan |     nan |        nan |     inf |     0.7326 |
# |  5 | Segmentation |       2 | Ever_Married_No          |   -0.1924 |         nan |     nan |        nan |     inf |     0.8249 |
# |  6 | Segmentation |       2 | Ever_Married_Yes         |   -0.2507 |         nan |     nan |        nan |     inf |     0.7782 |
# |  7 | Segmentation |       2 | Graduated_No             |    -0.452 | 1.13865e+06 |      -0 |          1 |     inf |     0.6364 |
# |  8 | Segmentation |       2 | Graduated_Yes            |    0.0088 | 1.17676e+06 |       0 |          1 |     inf |     1.0089 |
# |  9 | Segmentation |       2 | Profession_Artist        |    0.5076 |         nan |     nan |        nan |     inf |     1.6614 |
# | 10 | Segmentation |       2 | Profession_Doctor        |    0.0466 |         nan |     nan |        nan |     inf |     1.0477 |
# | 11 | Segmentation |       2 | Profession_Engineer      |   -0.3876 |         nan |     nan |        nan |     inf |     0.6787 |
# | 12 | Segmentation |       2 | Profession_Entertainment |   -0.2103 |         nan |     nan |        nan |     inf |     0.8103 |
# | 13 | Segmentation |       2 | Profession_Executive     |    0.1292 |         nan |     nan |        nan |     inf |      1.138 |
# | 14 | Segmentation |       2 | Profession_Healthcare    |    0.1716 |         nan |     nan |        nan |     inf |     1.1873 |
# | 15 | Segmentation |       2 | Profession_Homemaker     |   -0.2543 |         nan |     nan |        nan |     inf |     0.7755 |
# | 16 | Segmentation |       2 | Profession_Lawyer        |   -0.3202 |         nan |     nan |        nan |     inf |      0.726 |
# | 17 | Segmentation |       2 | Profession_Marketing     |   -0.1259 |         nan |     nan |        nan |     inf |     0.8817 |
# | 18 | Segmentation |       2 | Spending_Score_Average   |    0.2719 |         nan |     nan |        nan |     inf |     1.3125 |
# | 19 | Segmentation |       2 | Spending_Score_High      |   -0.0917 |         nan |     nan |        nan |     inf |     0.9123 |
# | 20 | Segmentation |       2 | Spending_Score_Low       |   -0.6233 |         nan |     nan |        nan |     inf |     0.5362 |
# | 21 | Segmentation |       2 | Var_1_Cat_1              |   -0.0375 |         nan |     nan |        nan |     inf |     0.9631 |
# | 22 | Segmentation |       2 | Var_1_Cat_2              |    0.0788 |         nan |     nan |        nan |     inf |     1.0819 |
# | 23 | Segmentation |       2 | Var_1_Cat_3              |   -0.1252 |         nan |     nan |        nan |     inf |     0.8823 |
# | 24 | Segmentation |       2 | Var_1_Cat_4              |   -0.4666 |         nan |     nan |        nan |     inf |     0.6271 |
# | 25 | Segmentation |       2 | Var_1_Cat_5              |    0.0093 |         nan |     nan |        nan |     inf |     1.0094 |
# | 26 | Segmentation |       2 | Var_1_Cat_6              |    0.1094 |         nan |     nan |        nan |     inf |     1.1156 |
# | 27 | Segmentation |       2 | Var_1_Cat_7              |   -0.0113 |         nan |     nan |        nan |     inf |     0.9888 |
# +----+--------------+---------+--------------------------+-----------+-------------+---------+------------+---------+------------+
# +----+--------------+---------+--------------------------+-----------+-------------+---------+------------+---------+------------+
# |    | 종속변수     |   CLASS | 독립변수                 |   B(계수) |    표준오차 |       t |   유의확률 |     VIF |   OddsRate |
# |----+--------------+---------+--------------------------+-----------+-------------+---------+------------+---------+------------|
# |  0 | Segmentation |       3 | Age                      |   -0.0263 |       0.005 | -5.7163 |          0 | 2.44396 |      0.974 |
# |  1 | Segmentation |       3 | Work_Experience          |     0.023 |       0.014 |  1.6541 |      0.098 | 1.05979 |     1.0232 |
# |  2 | Segmentation |       3 | Family_Size              |   -0.0162 |       0.032 | -0.5141 |      0.607 | 1.27153 |     0.9839 |
# |  3 | Segmentation |       3 | Gender_Female            |    0.1202 | 1.09197e+06 |       0 |          1 |     inf |     1.1277 |
# |  4 | Segmentation |       3 | Gender_Male              |    0.2636 | 1.02905e+06 |       0 |          1 |     inf |     1.3016 |
# |  5 | Segmentation |       3 | Ever_Married_No          |    0.2575 |         nan |     nan |        nan |     inf |     1.2937 |
# |  6 | Segmentation |       3 | Ever_Married_Yes         |    0.1263 |         nan |     nan |        nan |     inf |     1.1346 |
# |  7 | Segmentation |       3 | Graduated_No             |     0.436 | 1.52016e+06 |       0 |          1 |     inf |     1.5465 |
# |  8 | Segmentation |       3 | Graduated_Yes            |   -0.0522 |  1.5436e+06 |      -0 |          1 |     inf |     0.9491 |
# |  9 | Segmentation |       3 | Profession_Artist        |   -0.7495 | 2.13518e+06 |      -0 |          1 |     inf |     0.4726 |
# | 10 | Segmentation |       3 | Profession_Doctor        |   -0.1622 | 2.13657e+06 |      -0 |          1 |     inf |     0.8503 |
# | 11 | Segmentation |       3 | Profession_Engineer      |   -0.1271 | 2.13815e+06 |      -0 |          1 |     inf |     0.8807 |
# | 12 | Segmentation |       3 | Profession_Entertainment |   -0.1462 | 2.13448e+06 |      -0 |          1 |     inf |      0.864 |
# | 13 | Segmentation |       3 | Profession_Executive     |    0.0265 | 2.13512e+06 |       0 |          1 |     inf |     1.0269 |
# | 14 | Segmentation |       3 | Profession_Healthcare    |      0.51 |  2.1488e+06 |       0 |          1 |     inf |     1.6653 |
# | 15 | Segmentation |       3 | Profession_Homemaker     |    0.0641 | 2.13956e+06 |       0 |          1 |     inf |     1.0662 |
# | 16 | Segmentation |       3 | Profession_Lawyer        |    0.5323 | 2.14471e+06 |       0 |          1 |     inf |     1.7028 |
# | 17 | Segmentation |       3 | Profession_Marketing     |    0.4359 | 2.13018e+06 |       0 |          1 |     inf |     1.5463 |
# | 18 | Segmentation |       3 | Spending_Score_Average   |   -0.1219 | 2.99892e+06 |      -0 |          1 |     inf |     0.8852 |
# | 19 | Segmentation |       3 | Spending_Score_High      |   -0.0145 | 3.03677e+06 |      -0 |          1 |     inf |     0.9856 |
# | 20 | Segmentation |       3 | Spending_Score_Low       |    0.5202 | 3.02132e+06 |       0 |          1 |     inf |     1.6823 |
# | 21 | Segmentation |       3 | Var_1_Cat_1              |    0.2581 |      259465 |       0 |          1 |     inf |     1.2944 |
# | 22 | Segmentation |       3 | Var_1_Cat_2              |   -0.1842 |      259465 |      -0 |          1 |     inf |     0.8318 |
# | 23 | Segmentation |       3 | Var_1_Cat_3              |    0.0293 |      259465 |       0 |          1 |     inf |     1.0297 |
# | 24 | Segmentation |       3 | Var_1_Cat_4              |    0.2396 |      259465 |       0 |          1 |     inf |     1.2707 |
# | 25 | Segmentation |       3 | Var_1_Cat_5              |    0.0333 |      259465 |       0 |          1 |     inf |     1.0339 |
# | 26 | Segmentation |       3 | Var_1_Cat_6              |    0.0328 |      259465 |       0 |          1 |     inf |     1.0334 |
# | 27 | Segmentation |       3 | Var_1_Cat_7              |   -0.0252 |      259465 |      -0 |          1 |     inf |     0.9752 |
# +----+--------------+---------+--------------------------+-----------+-------------+---------+------------+---------+------------+
# LogisticRegression(C=1, max_iter=500, n_jobs=-1)

# %%
my_knn_classification(x_train, y_train, x_test, y_test)
# Out:
# [교차검증]
# +----+-----------+---------------+-----------+-------------------+
# |    | metric    |   n_neighbors | weights   |   mean_test_score |
# |----+-----------+---------------+-----------+-------------------|
# | 10 | manhattan |             7 | uniform   |           0.43408 |
# |  8 | manhattan |             5 | uniform   |          0.420407 |
# | 11 | manhattan |             7 | distance  |          0.419121 |
# |  4 | euclidean |             7 | uniform   |          0.418888 |
# |  2 | euclidean |             5 | uniform   |          0.412811 |
# |  6 | manhattan |             3 | uniform   |           0.40977 |
# |  5 | euclidean |             7 | distance  |           0.40837 |
# |  9 | manhattan |             5 | distance  |          0.407785 |
# |  3 | euclidean |             5 | distance  |          0.400773 |
# |  0 | euclidean |             3 | uniform   |          0.398669 |
# |  7 | manhattan |             3 | distance  |          0.396329 |
# |  1 | euclidean |             3 | distance  |          0.390604 |
# +----+-----------+---------------+-----------+-------------------+
#
# [분류분석 성능평가]
# +-------------------+--------------+--------------+-----------------------------------------------------------+
# |                   |   훈련데이터 |   검증데이터 | 설명                                                      |
# |-------------------+--------------+--------------+-----------------------------------------------------------|
# | 정확도(Accuracy)  |     0.570477 |     0.430108 | 예측 결과(TN,FP,TP,TN)가 실제 결과(TP,TN)와 일치하는 정도 |
# | 정밀도(Precision) |     0.571682 |     0.430305 | 양성으로 예측한 결과(TP,FP) 중 실제 양성(TP)인 비율       |
# | 재현율(Recall)    |     0.570477 |     0.422124 | 실제 양성(TP,FN) 중 양성(TP)으로 예측한 비율              |
# | F1 Score          |       0.5658 |     0.423976 | 정밀도와 재현율의 조화평균                                |
# | AUC(ovo)          |     0.826904 |     0.670757 | One vs One에 대한 AUC로, 1에 가까울수록 좋은 모델         |
# | AUC(ovr)          |      0.82869 |     0.673288 | One vs Rest에 대한 AUC로, 1에 가까울수록 좋은 모델        |
# +-------------------+--------------+--------------+-----------------------------------------------------------+
#
# [혼동행렬]
# [Roc Curve]
# mean roc auc ovo: 0.6515
# mean roc auc ovo: 0.6733
#
# [학습곡선]
# KNeighborsClassifier(metric='manhattan', n_jobs=-1, n_neighbors=7)

# %%
# %%time

resulf_df = yjk_classifier_multi_gridsearch(support, x_train, x_test, y_train, y_test, randomized_search = True, cv = 5)
resulf_df
# Out:
# CPU times: total: 1min 4s
# Wall time: 48 s
#                                                              best_model  \
# model_name
# LogisticRegression    LogisticRegression(C=0.1, max_iter=300, n_jobs...
# SGDClassifier         SGDClassifier(alpha=0.01, max_iter=500, n_jobs...
# KNeighborsClassifier  KNeighborsClassifier(n_jobs=-1, n_neighbors=7,...
#
#                                                              best_param  \
# model_name
# LogisticRegression         {'penalty': 'l2', 'max_iter': 300, 'C': 0.1}
# SGDClassifier         {'tol': 0.0001, 'penalty': None, 'max_iter': 5...
# KNeighborsClassifier  {'weights': 'distance', 'p': 1, 'n_neighbors': 7}
#
#                       accuracy_train  accuracy_test
# model_name
# LogisticRegression          0.468323       0.469846
# SGDClassifier               0.433610       0.446470
# KNeighborsClassifier        0.422511       0.412810

# %% [markdown]
# - 로지스틱 회귀의 성능이 더 좋음
