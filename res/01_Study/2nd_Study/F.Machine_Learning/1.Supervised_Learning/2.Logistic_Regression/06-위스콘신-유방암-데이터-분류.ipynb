# %% [markdown]
# # 위스콘신 유방암 데이터 분류
#
# 유방에서 만져지는 덩어리에 대한 세침 흡인 검사(FNA, 유방생검)를 통해 수집된 표본의 세포핵의 특성을 설명하는 데이터를 통해 암이 양성인지 악성인지 예측하기 위한 데이터 셋
#
# > https://www.kaggle.com/datasets/uciml/breast-cancer-wisconsin-data
#
# > https://archive.ics.uci.edu/dataset/17/breast+cancer+wisconsin+diagnostic
#
# ## #01. 준비작업
#
# ### [1] 패키지 가져오기

# %%
import sys
import os
work_path = os.path.abspath(os.path.join(os.getcwd(), "../.."))
sys.path.append(work_path)

from helper.util import *
from helper.plot import *
from helper.analysis import *
from helper.classification import *

from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler, SMOTE

# %% [markdown]
# ### [2] 데이터 가져오기
#
# | 변수 | 설명 |
# |---|---|
# | id | 일련번호
# | diagnosis | 유방조직의 진단 (`M`=악성, `B`=양성) |
# | 그 밖의 변수 | 종양 세포에 관한 의학적 지표들 |

# %%
origin = my_read_excel("https://data.hossam.kr/mldata/breast-cancer-wisconsin.xlsx", index_col="id", categories=["diagnosis"])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 569 entries, 842302 to 92751
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    category
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
#  13  perimeter_se             569 non-null    float64
#  14  area_se                  569 non-null    float64
#  15  smoothness_se            569 non-null    float64
#  16  compactness_se           569 non-null    float64
#  17  concavity_se             569 non-null    float64
#  18  concave points_se        569 non-null    float64
#  19  symmetry_se              569 non-null    float64
#  20  fractal_dimension_se     569 non-null    float64
#  21  radius_worst             569 non-null    float64
#  22  texture_worst            569 non-null    float64
#  23  perimeter_worst          569 non-null    float64
#  24  area_worst               569 non-null    float64
#  25  smoothness_worst         569 non-null    float64
#  26  compactness_worst        569 non-null    float64
#  27  concavity_worst          569 non-null    float64
#  28  concave points_worst     569 non-null    float64
#  29  symmetry_worst           569 non-null    float64
#  30  fractal_dimension_worst  569 non-null    float64
# dtypes: category(1), float64(30)
# memory usage: 138.5 KB
# None
#
# 데이터프레임 상위 5개 행
# +----------+-------------+---------------+----------------+------------------+-------------+-------------------+--------------------+------------------+-----------------------+-----------------+--------------------------+-------------+--------------+----------------+-----------+-----------------+------------------+----------------+---------------------+---------------+------------------------+----------------+-----------------+-------------------+--------------+--------------------+---------------------+-------------------+------------------------+------------------+---------------------------+
# |       id | diagnosis   |   radius_mean |   texture_mean |   perimeter_mean |   area_mean |   smoothness_mean |   compactness_mean |   concavity_mean |   concave points_mean |   symmetry_mean |   fractal_dimension_mean |   radius_se |   texture_se |   perimeter_se |   area_se |   smoothness_se |   compactness_se |   concavity_se |   concave points_se |   symmetry_se |   fractal_dimension_se |   radius_worst |   texture_worst |   perimeter_worst |   area_worst |   smoothness_worst |   compactness_worst |   concavity_worst |   concave points_worst |   symmetry_worst |   fractal_dimension_worst |
# |----------+-------------+---------------+----------------+------------------+-------------+-------------------+--------------------+------------------+-----------------------+-----------------+--------------------------+-------------+--------------+----------------+-----------+-----------------+------------------+----------------+---------------------+---------------+------------------------+----------------+-----------------+-------------------+--------------+--------------------+---------------------+-------------------+------------------------+------------------+---------------------------|
# |   842302 | M           |         17.99 |          10.38 |            122.8 |        1001 |            0.1184 |             0.2776 |           0.3001 |                0.1471 |          0.2419 |                  0.07871 |       1.095 |       0.9053 |          8.589 |     153.4 |        0.006399 |          0.04904 |        0.05373 |             0.01587 |       0.03003 |               0.006193 |          25.38 |           17.33 |             184.6 |         2019 |             0.1622 |              0.6656 |            0.7119 |                 0.2654 |           0.4601 |                    0.1189 |
# |   842517 | M           |         20.57 |          17.77 |            132.9 |        1326 |           0.08474 |            0.07864 |           0.0869 |               0.07017 |          0.1812 |                  0.05667 |      0.5435 |       0.7339 |          3.398 |     74.08 |        0.005225 |          0.01308 |         0.0186 |              0.0134 |       0.01389 |               0.003532 |          24.99 |           23.41 |             158.8 |         1956 |             0.1238 |              0.1866 |            0.2416 |                  0.186 |            0.275 |                   0.08902 |
# | 84300903 | M           |         19.69 |          21.25 |              130 |        1203 |            0.1096 |             0.1599 |           0.1974 |                0.1279 |          0.2069 |                  0.05999 |      0.7456 |       0.7869 |          4.585 |     94.03 |         0.00615 |          0.04006 |        0.03832 |             0.02058 |        0.0225 |               0.004571 |          23.57 |           25.53 |             152.5 |         1709 |             0.1444 |              0.4245 |            0.4504 |                  0.243 |           0.3613 |                   0.08758 |
# | 84348301 | M           |         11.42 |          20.38 |            77.58 |       386.1 |            0.1425 |             0.2839 |           0.2414 |                0.1052 |          0.2597 |                  0.09744 |      0.4956 |        1.156 |          3.445 |     27.23 |         0.00911 |          0.07458 |        0.05661 |             0.01867 |       0.05963 |               0.009208 |          14.91 |            26.5 |             98.87 |        567.7 |             0.2098 |              0.8663 |            0.6869 |                 0.2575 |           0.6638 |                     0.173 |
# | 84358402 | M           |         20.29 |          14.34 |            135.1 |        1297 |            0.1003 |             0.1328 |            0.198 |                0.1043 |          0.1809 |                  0.05883 |      0.7572 |       0.7813 |          5.438 |     94.44 |         0.01149 |          0.02461 |        0.05688 |             0.01885 |       0.01756 |               0.005115 |          22.54 |           16.67 |             152.2 |         1575 |             0.1374 |               0.205 |               0.4 |                 0.1625 |           0.2364 |                   0.07678 |
# +----------+-------------+---------------+----------------+------------------+-------------+-------------------+--------------------+------------------+-----------------------+-----------------+--------------------------+-------------+--------------+----------------+-----------+-----------------+------------------+----------------+---------------------+---------------+------------------------+----------------+-----------------+-------------------+--------------+--------------------+---------------------+-------------------+------------------------+------------------+---------------------------+
#
# 데이터프레임 하위 5개 행
# +--------+-------------+---------------+----------------+------------------+-------------+-------------------+--------------------+------------------+-----------------------+-----------------+--------------------------+-------------+--------------+----------------+-----------+-----------------+------------------+----------------+---------------------+---------------+------------------------+----------------+-----------------+-------------------+--------------+--------------------+---------------------+-------------------+------------------------+------------------+---------------------------+
# |     id | diagnosis   |   radius_mean |   texture_mean |   perimeter_mean |   area_mean |   smoothness_mean |   compactness_mean |   concavity_mean |   concave points_mean |   symmetry_mean |   fractal_dimension_mean |   radius_se |   texture_se |   perimeter_se |   area_se |   smoothness_se |   compactness_se |   concavity_se |   concave points_se |   symmetry_se |   fractal_dimension_se |   radius_worst |   texture_worst |   perimeter_worst |   area_worst |   smoothness_worst |   compactness_worst |   concavity_worst |   concave points_worst |   symmetry_worst |   fractal_dimension_worst |
# |--------+-------------+---------------+----------------+------------------+-------------+-------------------+--------------------+------------------+-----------------------+-----------------+--------------------------+-------------+--------------+----------------+-----------+-----------------+------------------+----------------+---------------------+---------------+------------------------+----------------+-----------------+-------------------+--------------+--------------------+---------------------+-------------------+------------------------+------------------+---------------------------|
# | 926424 | M           |         21.56 |          22.39 |              142 |        1479 |             0.111 |             0.1159 |           0.2439 |                0.1389 |          0.1726 |                  0.05623 |       1.176 |        1.256 |          7.673 |     158.7 |          0.0103 |          0.02891 |        0.05198 |             0.02454 |       0.01114 |               0.004239 |          25.45 |            26.4 |             166.1 |         2027 |              0.141 |              0.2113 |            0.4107 |                 0.2216 |            0.206 |                   0.07115 |
# | 926682 | M           |         20.13 |          28.25 |            131.2 |        1261 |            0.0978 |             0.1034 |            0.144 |               0.09791 |          0.1752 |                  0.05533 |      0.7655 |        2.463 |          5.203 |     99.04 |        0.005769 |          0.02423 |         0.0395 |             0.01678 |       0.01898 |               0.002498 |          23.69 |           38.25 |               155 |         1731 |             0.1166 |              0.1922 |            0.3215 |                 0.1628 |           0.2572 |                   0.06637 |
# | 926954 | M           |          16.6 |          28.08 |            108.3 |       858.1 |           0.08455 |             0.1023 |          0.09251 |               0.05302 |           0.159 |                  0.05648 |      0.4564 |        1.075 |          3.425 |     48.55 |        0.005903 |          0.03731 |         0.0473 |             0.01557 |       0.01318 |               0.003892 |          18.98 |           34.12 |             126.7 |         1124 |             0.1139 |              0.3094 |            0.3403 |                 0.1418 |           0.2218 |                    0.0782 |
# | 927241 | M           |          20.6 |          29.33 |            140.1 |        1265 |            0.1178 |              0.277 |           0.3514 |                 0.152 |          0.2397 |                  0.07016 |       0.726 |        1.595 |          5.772 |     86.22 |        0.006522 |          0.06158 |        0.07117 |             0.01664 |       0.02324 |               0.006185 |          25.74 |           39.42 |             184.6 |         1821 |              0.165 |              0.8681 |            0.9387 |                  0.265 |           0.4087 |                     0.124 |
# |  92751 | B           |          7.76 |          24.54 |            47.92 |         181 |           0.05263 |            0.04362 |                0 |                     0 |          0.1587 |                  0.05884 |      0.3857 |        1.428 |          2.548 |     19.15 |        0.007189 |          0.00466 |              0 |                   0 |       0.02676 |               0.002783 |          9.456 |           30.37 |             59.16 |        268.6 |            0.08996 |             0.06444 |                 0 |                      0 |           0.2871 |                   0.07039 |
# +--------+-------------+---------------+----------------+------------------+-------------+-------------------+--------------------+------------------+-----------------------+-----------------+--------------------------+-------------+--------------+----------------+-----------+-----------------+------------------+----------------+---------------------+---------------+------------------------+----------------+-----------------+-------------------+--------------+--------------------+---------------------+-------------------+------------------------+------------------+---------------------------+
#
# 기술통계
# +-------------------------+---------+------------+------------+-----------+----------+----------+----------+---------+-------+
# |                         |   count |       mean |        std |       min |      25% |      50% |      75% |     max |   nan |
# |-------------------------+---------+------------+------------+-----------+----------+----------+----------+---------+-------|
# | radius_mean             |     569 |    14.1273 |    3.52405 |     6.981 |     11.7 |    13.37 |    15.78 |   28.11 |     0 |
# | texture_mean            |     569 |    19.2896 |    4.30104 |      9.71 |    16.17 |    18.84 |     21.8 |   39.28 |     0 |
# | perimeter_mean          |     569 |     91.969 |     24.299 |     43.79 |    75.17 |    86.24 |    104.1 |   188.5 |     0 |
# | area_mean               |     569 |    654.889 |    351.914 |     143.5 |    420.3 |    551.1 |    782.7 |    2501 |     0 |
# | smoothness_mean         |     569 |  0.0963603 |  0.0140641 |   0.05263 |  0.08637 |  0.09587 |   0.1053 |  0.1634 |     0 |
# | compactness_mean        |     569 |   0.104341 |  0.0528128 |   0.01938 |  0.06492 |  0.09263 |   0.1304 |  0.3454 |     0 |
# | concavity_mean          |     569 |  0.0887993 |  0.0797198 |         0 |  0.02956 |  0.06154 |   0.1307 |  0.4268 |     0 |
# | concave points_mean     |     569 |  0.0489191 |  0.0388028 |         0 |  0.02031 |   0.0335 |    0.074 |  0.2012 |     0 |
# | symmetry_mean           |     569 |   0.181162 |  0.0274143 |     0.106 |   0.1619 |   0.1792 |   0.1957 |   0.304 |     0 |
# | fractal_dimension_mean  |     569 |  0.0627976 | 0.00706036 |   0.04996 |   0.0577 |  0.06154 |  0.06612 | 0.09744 |     0 |
# | radius_se               |     569 |   0.405172 |   0.277313 |    0.1115 |   0.2324 |   0.3242 |   0.4789 |   2.873 |     0 |
# | texture_se              |     569 |    1.21685 |   0.551648 |    0.3602 |   0.8339 |    1.108 |    1.474 |   4.885 |     0 |
# | perimeter_se            |     569 |    2.86606 |    2.02185 |     0.757 |    1.606 |    2.287 |    3.357 |   21.98 |     0 |
# | area_se                 |     569 |    40.3371 |     45.491 |     6.802 |    17.85 |    24.53 |    45.19 |   542.2 |     0 |
# | smoothness_se           |     569 | 0.00704098 | 0.00300252 |  0.001713 | 0.005169 |  0.00638 | 0.008146 | 0.03113 |     0 |
# | compactness_se          |     569 |  0.0254781 |  0.0179082 |  0.002252 |  0.01308 |  0.02045 |  0.03245 |  0.1354 |     0 |
# | concavity_se            |     569 |  0.0318937 |  0.0301861 |         0 |  0.01509 |  0.02589 |  0.04205 |   0.396 |     0 |
# | concave points_se       |     569 |  0.0117961 | 0.00617029 |         0 | 0.007638 |  0.01093 |  0.01471 | 0.05279 |     0 |
# | symmetry_se             |     569 |  0.0205423 | 0.00826637 |  0.007882 |  0.01516 |  0.01873 |  0.02348 | 0.07895 |     0 |
# | fractal_dimension_se    |     569 |  0.0037949 | 0.00264607 | 0.0008948 | 0.002248 | 0.003187 | 0.004558 | 0.02984 |     0 |
# | radius_worst            |     569 |    16.2692 |    4.83324 |      7.93 |    13.01 |    14.97 |    18.79 |   36.04 |     0 |
# | texture_worst           |     569 |    25.6772 |    6.14626 |     12.02 |    21.08 |    25.41 |    29.72 |   49.54 |     0 |
# | perimeter_worst         |     569 |    107.261 |    33.6025 |     50.41 |    84.11 |    97.66 |    125.4 |   251.2 |     0 |
# | area_worst              |     569 |    880.583 |    569.357 |     185.2 |    515.3 |    686.5 |     1084 |    4254 |     0 |
# | smoothness_worst        |     569 |   0.132369 |  0.0228324 |   0.07117 |   0.1166 |   0.1313 |    0.146 |  0.2226 |     0 |
# | compactness_worst       |     569 |   0.254265 |   0.157336 |   0.02729 |   0.1472 |   0.2119 |   0.3391 |   1.058 |     0 |
# | concavity_worst         |     569 |   0.272188 |   0.208624 |         0 |   0.1145 |   0.2267 |   0.3829 |   1.252 |     0 |
# | concave points_worst    |     569 |   0.114606 |  0.0657323 |         0 |  0.06493 |  0.09993 |   0.1614 |   0.291 |     0 |
# | symmetry_worst          |     569 |   0.290076 |  0.0618675 |    0.1565 |   0.2504 |   0.2822 |   0.3179 |  0.6638 |     0 |
# | fractal_dimension_worst |     569 |  0.0839458 |  0.0180613 |   0.05504 |  0.07146 |  0.08004 |  0.09208 |  0.2075 |     0 |
# +-------------------------+---------+------------+------------+-----------+----------+----------+----------+---------+-------+
#
# 카테고리 정보
# +-------------+---------+
# | diagnosis   |   count |
# |-------------+---------|
# | B           |     357 |
# | M           |     212 |
# +-------------+---------+

# %% [markdown]
# ## #02. 탐색적 데이터 분석
#
# ### [1] 상자그림

# %%
my_boxplot(origin, orient='h', figsize=(10, 20))

# %% [markdown]
# > 데이터 스케일링이 필요할 것으로 판단됨

# %% [markdown]
# ### [2] 종속변수에 따른 데이터 분포 비교

# %%
yname = 'diagnosis'
xnames = list(origin.drop(yname, axis=1).columns)

# %%
for x in xnames:
    if origin[x].dtype == 'category':
        my_stackplot(origin, xname=x, hue=yname, dpi=100, callback=lambda ax: ax.set_title(x))
    else:
        my_kdeplot(origin, xname=x, hue=yname, fill=True, dpi=100, callback=lambda ax: ax.set_title(x))

# %% [markdown]
# > 일부 변수에서 악성,양성에 따른 평균이 유의미한 차이가 없는 것으로 보이기는 하지만 일단 모든 변수를 다 투입하여 분석을 시도

# %% [markdown]
# ## #03. 데이터 전처리
#
# ### [1] 스케일링

# %%
df = my_standard_scaler(origin, 'diagnosis')
my_boxplot(df, orient='h', figsize=(10, 20))

# %% [markdown]
# ### [2] 종속변수 라벨링
#
# `M`=악성=`1`, `B`=양성=`0`

# %%
df2 = my_labelling(df, 'diagnosis')
my_pretty_table(df2.head())
# Out:
# +----------+---------------+----------------+------------------+-------------+-------------------+--------------------+------------------+-----------------------+-----------------+--------------------------+-------------+--------------+----------------+-----------+-----------------+------------------+----------------+---------------------+---------------+------------------------+----------------+-----------------+-------------------+--------------+--------------------+---------------------+-------------------+------------------------+------------------+---------------------------+-------------+
# |       id |   radius_mean |   texture_mean |   perimeter_mean |   area_mean |   smoothness_mean |   compactness_mean |   concavity_mean |   concave points_mean |   symmetry_mean |   fractal_dimension_mean |   radius_se |   texture_se |   perimeter_se |   area_se |   smoothness_se |   compactness_se |   concavity_se |   concave points_se |   symmetry_se |   fractal_dimension_se |   radius_worst |   texture_worst |   perimeter_worst |   area_worst |   smoothness_worst |   compactness_worst |   concavity_worst |   concave points_worst |   symmetry_worst |   fractal_dimension_worst |   diagnosis |
# |----------+---------------+----------------+------------------+-------------+-------------------+--------------------+------------------+-----------------------+-----------------+--------------------------+-------------+--------------+----------------+-----------+-----------------+------------------+----------------+---------------------+---------------+------------------------+----------------+-----------------+-------------------+--------------+--------------------+---------------------+-------------------+------------------------+------------------+---------------------------+-------------|
# |   842302 |       1.09706 |       -2.07334 |          1.26993 |    0.984375 |           1.56847 |            3.28351 |          2.65287 |               2.53248 |         2.21752 |                  2.25575 |     2.48973 |    -0.565265 |        2.83303 |   2.48758 |       -0.214002 |          1.31686 |       0.724026 |             0.66082 |       1.14876 |               0.907083 |        1.88669 |        -1.35929 |            2.3036 |      2.00124 |            1.30769 |             2.61667 |           2.10953 |                2.29608 |          2.75062 |                   1.93701 |           1 |
# |   842517 |       1.82982 |      -0.353632 |          1.68595 |     1.90871 |         -0.826962 |          -0.487072 |       -0.0238459 |              0.548144 |      0.00139236 |                -0.868652 |    0.499255 |    -0.876244 |       0.263327 |  0.742402 |       -0.605351 |        -0.692926 |       -0.44078 |            0.260162 |      -0.80545 |             -0.0994437 |        1.80593 |       -0.369203 |           1.53513 |      1.89049 |          -0.375612 |           -0.430444 |         -0.146749 |                1.08708 |         -0.24389 |                   0.28119 |           1 |
# | 84300903 |       1.57989 |       0.456187 |           1.5665 |     1.55888 |           0.94221 |            1.05293 |          1.36348 |               2.03723 |        0.939685 |                -0.398008 |     1.22868 |    -0.780083 |       0.850928 |   1.18134 |       -0.297005 |         0.814974 |       0.213076 |             1.42483 |      0.237036 |               0.293559 |        1.51187 |      -0.0239744 |           1.34748 |      1.45628 |           0.527407 |             1.08293 |          0.854974 |                  1.955 |          1.15226 |                  0.201391 |           1 |
# | 84348301 |     -0.768909 |       0.253732 |        -0.592687 |   -0.764464 |           3.28355 |            3.40291 |           1.9159 |               1.45171 |         2.86738 |                  4.91092 |    0.326373 |    -0.110409 |       0.286593 | -0.288378 |        0.689702 |          2.74428 |       0.819518 |             1.11501 |       4.73268 |                2.04751 |      -0.281464 |        0.133984 |         -0.249939 |    -0.550021 |            3.39427 |              3.8934 |           1.98959 |                2.17579 |          6.04604 |                   4.93501 |           1 |
# | 84358402 |        1.7503 |       -1.15182 |          1.77657 |     1.82623 |          0.280372 |            0.53934 |          1.37101 |               1.42849 |     -0.00956047 |                 -0.56245 |     1.27054 |    -0.790244 |        1.27319 |   1.19036 |         1.48307 |       -0.0485199 |       0.828471 |              1.1442 |     -0.361092 |               0.499328 |        1.29858 |        -1.46677 |           1.33854 |      1.22072 |           0.220556 |           -0.313395 |          0.613179 |               0.729259 |        -0.868353 |                   -0.3971 |           1 |
# +----------+---------------+----------------+------------------+-------------+-------------------+--------------------+------------------+-----------------------+-----------------+--------------------------+-------------+--------------+----------------+-----------+-----------------+------------------+----------------+---------------------+---------------+------------------------+----------------+-----------------+-------------------+--------------+--------------------+---------------------+-------------------+------------------------+------------------+---------------------------+-------------+

# %% [markdown]
# ## #04. 모든 데이터를 활용한 기본 분석 모형 구현
#
# ### [1] 데이터 분할

# %%
x_train, x_test, y_train, y_test = my_train_test_split(df2, 'diagnosis')
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((455, 30), (114, 30), (455,), (114,))

# %% [markdown]
# ### [2] 로지스틱 회귀

# %%
my_logistic_classification(x_train, y_train, x_test, y_test)
# Out:
# [교차검증]
# +----+-------+-----------+-------------------+
# |    |     C | penalty   |   mean_test_score |
# |----+-------+-----------+-------------------|
# |  7 |   0.1 | l2        |          0.978022 |
# | 10 |     1 | l2        |          0.978022 |
# | 13 |    10 | l2        |          0.971429 |
# | 16 |   100 | l2        |          0.964835 |
# |  4 |  0.01 | l2        |          0.945055 |
# |  1 | 0.001 | l2        |          0.883516 |
# +----+-------+-----------+-------------------+
#
# [분류분석 성능평가]
# +-------------------------+--------------+--------------+-----------------------------------------------------------+
# |                         |   훈련데이터 |   검증데이터 | 설명                                                      |
# |-------------------------+--------------+--------------+-----------------------------------------------------------|
# | 의사결정계수(Pseudo R2) |      0.86966 |     0.859274 | 로지스틱회귀의 성능 측정 지표로, 1에 가까울수록 좋은 모델 |
# | 정확도(Accuracy)        |     0.982418 |     0.982456 | 예측 결과(TN,FP,TP,TN)가 실제 결과(TP,TN)와 일치하는 정도 |
# | 정밀도(Precision)       |     0.993939 |            1 | 양성으로 예측한 결과(TP,FP) 중 실제 양성(TP)인 비율       |
# | 재현율(Recall)          |     0.959064 |      0.95122 | 실제 양성(TP,FN) 중 양성(TP)으로 예측한 비율              |
# | 위양성율(Fallout)       |   0.00352113 |            0 | 실제 음성(FP,TN) 중 양성(FP)으로 잘못 예측한 비율         |
# | 특이성(TNR)             |     0.996479 |            1 | 실제 음성(FP,TN) 중 음성(TN)으로 정확히 예측한 비율       |
# | F1 Score                |      0.97619 |        0.975 | 정밀도와 재현율의 조화평균                                |
# | AUC                     |     0.997467 |     0.990311 | ROC Curve의 밑면적으로, 1에 가까울수록 좋은 모델          |
# +-------------------------+--------------+--------------+-----------------------------------------------------------+
#
# [혼동행렬]
# [학습곡선]
# +----+------------+-------------------------+--------------------+------------+---------+------------+---------+------------+
# |    | 종속변수   | 독립변수                |   B(비표준화 계수) |   표준오차 |       t |   유의확률 |     VIF |   OddsRate |
# |----+------------+-------------------------+--------------------+------------+---------+------------+---------+------------|
# |  2 | diagnosis  | perimeter_mean          |             0.3858 |      73.71 |  0.0052 |      0.996 | 8652.28 |     1.4708 |
# |  0 | diagnosis  | radius_mean             |             0.3973 |     74.032 |  0.0054 |      0.996 | 7154.91 |     1.4877 |
# | 20 | diagnosis  | radius_worst            |             0.5022 |     33.821 |  0.0148 |      0.988 | 989.505 |     1.6524 |
# | 22 | diagnosis  | perimeter_worst         |             0.4563 |     23.252 |  0.0196 |      0.984 | 836.304 |     1.5781 |
# |  3 | diagnosis  | area_mean               |             0.3787 |     29.356 |  0.0129 |       0.99 | 710.047 |     1.4603 |
# | 23 | diagnosis  | area_worst              |             0.4485 |      30.71 |  0.0146 |      0.988 | 443.129 |     1.5659 |
# | 12 | diagnosis  | perimeter_se            |             0.3073 |     13.489 |  0.0228 |      0.982 |   381.6 |     1.3597 |
# | 10 | diagnosis  | radius_se               |             0.4249 |     15.473 |  0.0275 |      0.978 | 280.125 |     1.5294 |
# |  6 | diagnosis  | concavity_mean          |             0.3586 |      8.317 |  0.0431 |      0.966 | 137.153 |     1.4313 |
# | 13 | diagnosis  | area_se                 |             0.3556 |     18.505 |  0.0192 |      0.985 | 113.958 |      1.427 |
# |  7 | diagnosis  | concave points_mean     |             0.4323 |      6.883 |  0.0628 |       0.95 |   101.3 |     1.5408 |
# | 26 | diagnosis  | concavity_worst         |             0.4011 |      7.774 |  0.0516 |      0.959 | 97.1002 |     1.4934 |
# | 25 | diagnosis  | compactness_worst       |             0.1407 |      10.07 |   0.014 |      0.989 | 89.7201 |     1.1511 |
# |  5 | diagnosis  | compactness_mean        |             0.0336 |      7.837 |  0.0043 |      0.997 | 69.6279 |     1.0342 |
# | 27 | diagnosis  | concave points_worst    |             0.5006 |      5.176 |  0.0967 |      0.923 | 65.8185 |     1.6497 |
# | 29 | diagnosis  | fractal_dimension_worst |             0.1098 |      5.927 |  0.0185 |      0.985 | 52.9215 |      1.116 |
# | 15 | diagnosis  | compactness_se          |            -0.2357 |     11.065 | -0.0213 |      0.983 | 48.8702 |       0.79 |
# | 16 | diagnosis  | concavity_se            |            -0.0307 |      8.203 | -0.0037 |      0.997 | 38.3895 |     0.9698 |
# | 17 | diagnosis  | concave points_se       |             0.1046 |      4.902 |  0.0213 |      0.983 | 32.7898 |     1.1103 |
# | 19 | diagnosis  | fractal_dimension_se    |            -0.2495 |      7.037 | -0.0355 |      0.972 | 25.1579 |     0.7792 |
# | 24 | diagnosis  | smoothness_worst        |             0.4159 |      3.147 |  0.1321 |      0.895 | 17.9739 |     1.5157 |
# |  9 | diagnosis  | fractal_dimension_mean  |             -0.233 |      3.764 | -0.0619 |      0.951 | 14.6266 |     0.7921 |
# | 21 | diagnosis  | texture_worst           |             0.5909 |      4.057 |  0.1456 |      0.884 | 14.5422 |     1.8056 |
# |  4 | diagnosis  | smoothness_mean         |             0.1668 |      3.061 |  0.0545 |      0.957 | 13.9662 |     1.1815 |
# |  1 | diagnosis  | texture_mean            |             0.4102 |      3.174 |  0.1293 |      0.897 | 10.9017 |     1.5071 |
# | 28 | diagnosis  | symmetry_worst          |             0.3941 |       2.82 |  0.1397 |      0.889 | 10.6323 |     1.4831 |
# | 18 | diagnosis  | symmetry_se             |             -0.152 |      3.053 | -0.0498 |       0.96 | 8.56692 |      0.859 |
# | 14 | diagnosis  | smoothness_se           |             0.0787 |      2.272 |  0.0346 |      0.972 | 8.48963 |     1.0819 |
# | 11 | diagnosis  | texture_se              |            -0.0725 |      2.829 | -0.0256 |       0.98 | 4.87224 |     0.9301 |
# |  8 | diagnosis  | symmetry_mean           |             0.1109 |      1.482 |  0.0748 |       0.94 | 3.99262 |     1.1173 |
# +----+------------+-------------------------+--------------------+------------+---------+------------+---------+------------+
# LogisticRegression(C=0.1, max_iter=500, n_jobs=-1)

# %% [markdown]
# ## #05. 성능 개선 시도
#
# ### [1] 다중 공선성 제거

# %%
ignore = ['perimeter_mean', 'perimeter_worst', 'radius_mean', 'radius_worst', 'radius_se', 'concavity_mean', 'compactness_worst', 'concave points_worst', 'area_se', 'concave points_mean', 'concavity_worst', 'area_mean', 'compactness_se', 'smoothness_worst', 'texture_worst', 'fractal_dimension_worst']
x_tr = x_train.drop(ignore, axis=1)
x_te = x_test.drop(ignore, axis=1)
my_logistic_classification(x_tr, y_train, x_te, y_test)
# Out:
# [교차검증]
# +----+-------+-----------+-------------------+
# |    |     C | penalty   |   mean_test_score |
# |----+-------+-----------+-------------------|
# |  7 |   0.1 | l2        |          0.953846 |
# | 10 |     1 | l2        |          0.953846 |
# | 13 |    10 | l2        |          0.951648 |
# | 16 |   100 | l2        |          0.951648 |
# |  4 |  0.01 | l2        |           0.90989 |
# |  1 | 0.001 | l2        |          0.698901 |
# +----+-------+-----------+-------------------+
#
# [분류분석 성능평가]
# +-------------------------+--------------+--------------+-----------------------------------------------------------+
# |                         |   훈련데이터 |   검증데이터 | 설명                                                      |
# |-------------------------+--------------+--------------+-----------------------------------------------------------|
# | 의사결정계수(Pseudo R2) |      0.77265 |     0.781534 | 로지스틱회귀의 성능 측정 지표로, 1에 가까울수록 좋은 모델 |
# | 정확도(Accuracy)        |     0.962637 |     0.964912 | 예측 결과(TN,FP,TP,TN)가 실제 결과(TP,TN)와 일치하는 정도 |
# | 정밀도(Precision)       |      0.98125 |            1 | 양성으로 예측한 결과(TP,FP) 중 실제 양성(TP)인 비율       |
# | 재현율(Recall)          |     0.918129 |     0.902439 | 실제 양성(TP,FN) 중 양성(TP)으로 예측한 비율              |
# | 위양성율(Fallout)       |    0.0105634 |            0 | 실제 음성(FP,TN) 중 양성(FP)으로 잘못 예측한 비율         |
# | 특이성(TNR)             |     0.989437 |            1 | 실제 음성(FP,TN) 중 음성(TN)으로 정확히 예측한 비율       |
# | F1 Score                |      0.94864 |     0.948718 | 정밀도와 재현율의 조화평균                                |
# | AUC                     |     0.993658 |     0.990311 | ROC Curve의 밑면적으로, 1에 가까울수록 좋은 모델          |
# +-------------------------+--------------+--------------+-----------------------------------------------------------+
#
# [혼동행렬]
# [학습곡선]
# +----+------------+------------------------+--------------------+------------+---------+------------+---------+------------+
# |    | 종속변수   | 독립변수               |   B(비표준화 계수) |   표준오차 |       t |   유의확률 |     VIF |   OddsRate |
# |----+------------+------------------------+--------------------+------------+---------+------------+---------+------------|
# |  2 | diagnosis  | compactness_mean       |             0.7178 |      1.435 |  0.5003 |      0.617 |  9.3501 |     2.0498 |
# |  8 | diagnosis  | concavity_se           |              0.119 |      1.689 |  0.0704 |      0.944 | 7.97004 |     1.1263 |
# |  4 | diagnosis  | fractal_dimension_mean |            -0.4528 |      1.317 |  -0.344 |      0.731 |  6.8349 |     0.6358 |
# | 11 | diagnosis  | fractal_dimension_se   |            -0.2456 |      1.322 | -0.1857 |      0.853 | 5.88982 |     0.7823 |
# | 12 | diagnosis  | area_worst             |             1.5583 |      1.677 |  0.9295 |      0.353 | 5.84549 |     4.7507 |
# |  6 | diagnosis  | perimeter_se           |             0.6929 |      1.327 |  0.5223 |      0.601 |  4.7246 |     1.9995 |
# |  1 | diagnosis  | smoothness_mean        |              0.507 |      0.857 |  0.5914 |      0.554 | 4.50398 |     1.6603 |
# |  9 | diagnosis  | concave points_se      |             0.3553 |       1.23 |  0.2889 |      0.773 | 4.21534 |     1.4266 |
# | 10 | diagnosis  | symmetry_se            |            -0.4545 |      0.841 | -0.5404 |      0.589 | 3.10347 |     0.6348 |
# | 13 | diagnosis  | symmetry_worst         |             0.7591 |      0.734 |  1.0339 |      0.301 | 2.84553 |     2.1364 |
# |  7 | diagnosis  | smoothness_se          |            -0.0252 |      0.663 |  -0.038 |       0.97 | 2.53115 |     0.9751 |
# |  3 | diagnosis  | symmetry_mean          |              0.082 |      0.629 |  0.1303 |      0.896 | 2.39372 |     1.0854 |
# |  5 | diagnosis  | texture_se             |            -0.1333 |      0.751 | -0.1776 |      0.859 | 2.21066 |     0.8752 |
# |  0 | diagnosis  | texture_mean           |             0.7689 |      0.695 |  1.1064 |      0.269 |  1.7914 |     2.1575 |
# +----+------------+------------------------+--------------------+------------+---------+------------+---------+------------+
# LogisticRegression(C=0.1, max_iter=500, n_jobs=-1)

# %% [markdown]
# > 성능에 큰 차이를 보이지 않는다.
# >
# > 오히려 정확도는 2% 떨어졌다.
# >
# > 재현률도 95%에서 90%로 떨어졌다.

# %% [markdown]
# ### [2] 데이터 불균형 해소
#
# #### (1) RandomUnderSampler

# %%
undersampler = RandomUnderSampler(sampling_strategy="majority", random_state=777)
x_under, y_under = undersampler.fit_resample(x_train, y_train)
y_under.value_counts()
# Out:
# 0    171
# 1    171
# Name: diagnosis, dtype: int64

# %%
my_logistic_classification(x_under, y_under, x_test, y_test, report=False)
# Out:
# [교차검증]
# +----+-------+-----------+-------------------+
# |    |     C | penalty   |   mean_test_score |
# |----+-------+-----------+-------------------|
# |  7 |   0.1 | l2        |          0.973743 |
# | 10 |     1 | l2        |          0.970759 |
# | 13 |    10 | l2        |          0.967775 |
# | 16 |   100 | l2        |           0.96202 |
# |  4 |  0.01 | l2        |          0.944544 |
# |  1 | 0.001 | l2        |          0.923998 |
# +----+-------+-----------+-------------------+
#
# [분류분석 성능평가]
# +-------------------------+--------------+--------------+-----------------------------------------------------------+
# |                         |   훈련데이터 |   검증데이터 | 설명                                                      |
# |-------------------------+--------------+--------------+-----------------------------------------------------------|
# | 의사결정계수(Pseudo R2) |     0.860619 |     0.852291 | 로지스틱회귀의 성능 측정 지표로, 1에 가까울수록 좋은 모델 |
# | 정확도(Accuracy)        |     0.979532 |     0.991228 | 예측 결과(TN,FP,TP,TN)가 실제 결과(TP,TN)와 일치하는 정도 |
# | 정밀도(Precision)       |     0.988095 |            1 | 양성으로 예측한 결과(TP,FP) 중 실제 양성(TP)인 비율       |
# | 재현율(Recall)          |      0.97076 |      0.97561 | 실제 양성(TP,FN) 중 양성(TP)으로 예측한 비율              |
# | 위양성율(Fallout)       |    0.0116959 |            0 | 실제 음성(FP,TN) 중 양성(FP)으로 잘못 예측한 비율         |
# | 특이성(TNR)             |     0.988304 |            1 | 실제 음성(FP,TN) 중 음성(TN)으로 정확히 예측한 비율       |
# | F1 Score                |     0.979351 |     0.987654 | 정밀도와 재현율의 조화평균                                |
# | AUC                     |     0.997401 |     0.990645 | ROC Curve의 밑면적으로, 1에 가까울수록 좋은 모델          |
# +-------------------------+--------------+--------------+-----------------------------------------------------------+
#
# [혼동행렬]
# [학습곡선]
# LogisticRegression(C=0.1, max_iter=500, n_jobs=-1)

# %% [markdown]
# > 정확도가 99% 까지 상승했다.
# >
# > 재현률이 97%로 증가했다.

# %% [markdown]
# #### (2) RandomOverSampler

# %%
oversampler = RandomOverSampler(sampling_strategy="minority", random_state=777)
x_over, y_over = oversampler.fit_resample(x_train, y_train)
y_over.value_counts()
# Out:
# 1    284
# 0    284
# Name: diagnosis, dtype: int64

# %%
my_logistic_classification(x_over, y_over, x_test, y_test, report=False)
# Out:
# [교차검증]
# +----+-------+-----------+-------------------+
# |    |     C | penalty   |   mean_test_score |
# |----+-------+-----------+-------------------|
# | 10 |     1 | l2        |          0.978885 |
# | 16 |   100 | l2        |          0.977131 |
# |  7 |   0.1 | l2        |          0.977131 |
# | 13 |    10 | l2        |          0.971852 |
# |  4 |  0.01 | l2        |          0.964835 |
# |  1 | 0.001 | l2        |          0.926098 |
# +----+-------+-----------+-------------------+
#
# [분류분석 성능평가]
# +-------------------------+--------------+--------------+-----------------------------------------------------------+
# |                         |   훈련데이터 |   검증데이터 | 설명                                                      |
# |-------------------------+--------------+--------------+-----------------------------------------------------------|
# | 의사결정계수(Pseudo R2) |     0.933718 |     0.887346 | 로지스틱회귀의 성능 측정 지표로, 1에 가까울수록 좋은 모델 |
# | 정확도(Accuracy)        |     0.987676 |     0.991228 | 예측 결과(TN,FP,TP,TN)가 실제 결과(TP,TN)와 일치하는 정도 |
# | 정밀도(Precision)       |     0.992883 |            1 | 양성으로 예측한 결과(TP,FP) 중 실제 양성(TP)인 비율       |
# | 재현율(Recall)          |     0.982394 |      0.97561 | 실제 양성(TP,FN) 중 양성(TP)으로 예측한 비율              |
# | 위양성율(Fallout)       |   0.00704225 |            0 | 실제 음성(FP,TN) 중 양성(FP)으로 잘못 예측한 비율         |
# | 특이성(TNR)             |     0.992958 |            1 | 실제 음성(FP,TN) 중 음성(TN)으로 정확히 예측한 비율       |
# | F1 Score                |     0.987611 |     0.987654 | 정밀도와 재현율의 조화평균                                |
# | AUC                     |     0.999095 |     0.991313 | ROC Curve의 밑면적으로, 1에 가까울수록 좋은 모델          |
# +-------------------------+--------------+--------------+-----------------------------------------------------------+
#
# [혼동행렬]
# [학습곡선]
# LogisticRegression(C=1, max_iter=500, n_jobs=-1)

# %% [markdown]
# > 정확도가 99% 까지 상승했다.
# >
# > 재현률이 97%까지 증가했다.

# %% [markdown]
# #### (3) SMOTE

# %%
smote_sampler = SMOTE(sampling_strategy="minority", k_neighbors=3, random_state=777)
x_sm, y_sm = smote_sampler.fit_resample(x_train, y_train)
y_sm.value_counts()
# Out:
# 1    284
# 0    284
# Name: diagnosis, dtype: int64

# %%
estimator = my_logistic_classification(x_sm, y_sm, x_test, y_test)
# Out:
# [교차검증]
# +----+-------+-----------+-------------------+
# |    |     C | penalty   |   mean_test_score |
# |----+-------+-----------+-------------------|
# |  7 |   0.1 | l2        |          0.977131 |
# | 10 |     1 | l2        |          0.973591 |
# | 13 |    10 | l2        |          0.971852 |
# | 16 |   100 | l2        |          0.971852 |
# |  4 |  0.01 | l2        |          0.959587 |
# |  1 | 0.001 | l2        |          0.933163 |
# +----+-------+-----------+-------------------+
#
# [분류분석 성능평가]
# +-------------------------+--------------+--------------+-----------------------------------------------------------+
# |                         |   훈련데이터 |   검증데이터 | 설명                                                      |
# |-------------------------+--------------+--------------+-----------------------------------------------------------|
# | 의사결정계수(Pseudo R2) |     0.885934 |     0.865081 | 로지스틱회귀의 성능 측정 지표로, 1에 가까울수록 좋은 모델 |
# | 정확도(Accuracy)        |     0.980634 |     0.991228 | 예측 결과(TN,FP,TP,TN)가 실제 결과(TP,TN)와 일치하는 정도 |
# | 정밀도(Precision)       |      0.99278 |            1 | 양성으로 예측한 결과(TP,FP) 중 실제 양성(TP)인 비율       |
# | 재현율(Recall)          |      0.96831 |      0.97561 | 실제 양성(TP,FN) 중 양성(TP)으로 예측한 비율              |
# | 위양성율(Fallout)       |   0.00704225 |            0 | 실제 음성(FP,TN) 중 양성(FP)으로 잘못 예측한 비율         |
# | 특이성(TNR)             |     0.992958 |            1 | 실제 음성(FP,TN) 중 음성(TN)으로 정확히 예측한 비율       |
# | F1 Score                |     0.980392 |     0.987654 | 정밀도와 재현율의 조화평균                                |
# | AUC                     |     0.997991 |     0.990311 | ROC Curve의 밑면적으로, 1에 가까울수록 좋은 모델          |
# +-------------------------+--------------+--------------+-----------------------------------------------------------+
#
# [혼동행렬]
# [학습곡선]
# +----+------------+-------------------------+--------------------+------------+---------+------------+---------+------------+
# |    | 종속변수   | 독립변수                |   B(비표준화 계수) |   표준오차 |       t |   유의확률 |     VIF |   OddsRate |
# |----+------------+-------------------------+--------------------+------------+---------+------------+---------+------------|
# |  2 | diagnosis  | perimeter_mean          |             0.3931 |     80.564 |  0.0049 |      0.996 | 8652.28 |     1.4816 |
# |  0 | diagnosis  | radius_mean             |             0.4043 |     81.192 |   0.005 |      0.996 | 7154.91 |     1.4982 |
# | 20 | diagnosis  | radius_worst            |             0.5496 |     36.849 |  0.0149 |      0.988 | 989.505 |     1.7325 |
# | 22 | diagnosis  | perimeter_worst         |             0.4914 |      25.33 |  0.0194 |      0.985 | 836.304 |     1.6346 |
# |  3 | diagnosis  | area_mean               |             0.3849 |     31.712 |  0.0121 |       0.99 | 710.047 |     1.4694 |
# | 23 | diagnosis  | area_worst              |             0.4901 |     33.798 |  0.0145 |      0.988 | 443.129 |     1.6325 |
# | 12 | diagnosis  | perimeter_se            |             0.3125 |     14.527 |  0.0215 |      0.983 |   381.6 |     1.3669 |
# | 10 | diagnosis  | radius_se               |             0.4452 |     16.851 |  0.0264 |      0.979 | 280.125 |     1.5608 |
# |  6 | diagnosis  | concavity_mean          |             0.3773 |      9.116 |  0.0414 |      0.967 | 137.153 |     1.4583 |
# | 13 | diagnosis  | area_se                 |             0.3787 |     19.781 |  0.0191 |      0.985 | 113.958 |     1.4603 |
# |  7 | diagnosis  | concave points_mean     |             0.4525 |      7.208 |  0.0628 |       0.95 |   101.3 |     1.5722 |
# | 26 | diagnosis  | concavity_worst         |             0.4302 |      8.503 |  0.0506 |       0.96 | 97.1002 |     1.5375 |
# | 25 | diagnosis  | compactness_worst       |             0.1365 |     10.597 |  0.0129 |       0.99 | 89.7201 |     1.1462 |
# |  5 | diagnosis  | compactness_mean        |             0.0165 |      8.521 |  0.0019 |      0.998 | 69.6279 |     1.0166 |
# | 27 | diagnosis  | concave points_worst    |             0.5374 |      5.587 |  0.0962 |      0.923 | 65.8185 |     1.7116 |
# | 29 | diagnosis  | fractal_dimension_worst |              0.165 |      6.319 |  0.0261 |      0.979 | 52.9215 |     1.1794 |
# | 15 | diagnosis  | compactness_se          |            -0.2903 |     11.664 | -0.0249 |       0.98 | 48.8702 |      0.748 |
# | 16 | diagnosis  | concavity_se            |            -0.0382 |      8.801 | -0.0043 |      0.997 | 38.3895 |     0.9625 |
# | 17 | diagnosis  | concave points_se       |              0.088 |      5.094 |  0.0173 |      0.986 | 32.7898 |     1.0919 |
# | 19 | diagnosis  | fractal_dimension_se    |             -0.269 |      7.266 |  -0.037 |       0.97 | 25.1579 |     0.7642 |
# | 24 | diagnosis  | smoothness_worst        |             0.4712 |      3.321 |  0.1419 |      0.887 | 17.9739 |     1.6019 |
# |  9 | diagnosis  | fractal_dimension_mean  |            -0.2053 |      4.016 | -0.0511 |      0.959 | 14.6266 |     0.8144 |
# | 21 | diagnosis  | texture_worst           |             0.6551 |      4.164 |  0.1573 |      0.875 | 14.5422 |     1.9254 |
# |  4 | diagnosis  | smoothness_mean         |             0.1581 |      3.167 |  0.0499 |       0.96 | 13.9662 |     1.1713 |
# |  1 | diagnosis  | texture_mean            |             0.4048 |      3.201 |  0.1265 |      0.899 | 10.9017 |      1.499 |
# | 28 | diagnosis  | symmetry_worst          |             0.4142 |       3.13 |  0.1324 |      0.895 | 10.6323 |     1.5132 |
# | 18 | diagnosis  | symmetry_se             |            -0.1787 |       3.29 | -0.0543 |      0.957 | 8.56692 |     0.8363 |
# | 14 | diagnosis  | smoothness_se           |             0.0656 |      2.389 |  0.0274 |      0.978 | 8.48963 |     1.0678 |
# | 11 | diagnosis  | texture_se              |            -0.0816 |      2.892 | -0.0282 |      0.977 | 4.87224 |     0.9216 |
# |  8 | diagnosis  | symmetry_mean           |             0.1049 |       1.52 |   0.069 |      0.945 | 3.99262 |     1.1106 |
# +----+------------+-------------------------+--------------------+------------+---------+------------+---------+------------+

# %% [markdown]
# > 정확도가 99% 까지 상승했다.
# >
# > 재현률이 97% 까지 증가했다.
