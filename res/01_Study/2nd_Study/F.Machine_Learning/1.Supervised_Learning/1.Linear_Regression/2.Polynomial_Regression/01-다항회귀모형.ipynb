# %% [markdown]
# # 다항회귀모형(Polynomial Regression)
#
# 피쳐들(독립변수)과 레이블(종속변수)이 2차 함수 이상의 관계를 가지는 것으로 곡선이나 좀 더 복잡한 모양을 표현하는 것이 가능한 회귀 모형
#
# 단순히 독립변수를 제곱한 파생변수를 추가하고 다중선형회귀를 적용한다.
#
# ![img](res/1.png)
#
# ## #01. 준비작업
#
# ### [1] 패키지 참조

# %%
# %%time

import sys
import os
work_path = os.path.abspath(os.path.join(os.getcwd(), "../../.."))
sys.path.append(work_path)

from my_helper.regression import *
from my_helper.util import *
from my_helper.plot import *
from my_helper.analysis import *

import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from pandas import DataFrame
# Out:
# CPU times: total: 125 ms
# Wall time: 1.23 s

# %% [markdown]
# ### [2] 데이터 가져오기
#
# 자동차의 속도와 제동거리 데이터

# %%
origin = my_read_excel("https://data.hossam.kr/mldata/cars.xlsx", info=False)
my_pretty_table(origin.head())
# Out:
# +----+---------+--------+
# |    |   speed |   dist |
# |----+---------+--------|
# |  0 |       4 |      2 |
# |  1 |       4 |     10 |
# |  2 |       7 |      4 |
# |  3 |       7 |     22 |
# |  4 |       8 |     16 |
# +----+---------+--------+

# %% [markdown]
# ## #02. 탐색적 데이터 분석
#
# ### [1] 산점도 그래프 시각화

# %%
my_scatterplot(origin, "speed", "dist", figsize=(10, 5), dpi=100)

# %% [markdown]
# > 속도에 따른 제동거리를 시각화 했을 때 선형보다는 곡선에 가까운 배치를 보인다.

# %% [markdown]
# ## #03. 단순선형회귀의 경우
#
# > 여기서는 좀 더 높은 설명력을 얻기 위해 데이터를 분할하지 않고 훈련데이터에 대해서만 score를 얻도록 함
#
# ### (1) 회귀모형 생성

# %%
fit = my_linear_regression(origin[['speed']], origin['dist'], use_plot=False, report=False)
# Out:
# [회귀식]
# dist = 3.932 * speed + -17.579
#
# [회귀분석 성능평가]
# +--------+----------------+---------------------+---------------------+------------------+---------------------------------+-----------------------+
# |        |   결정계수(R2) |   평균절대오차(MAE) |   평균제곱오차(MSE) |   평균오차(RMSE) |   평균 절대 백분오차 비율(MAPE) |   평균 비율 오차(MPE) |
# |--------+----------------+---------------------+---------------------+------------------+---------------------------------+-----------------------|
# | 데이터 |       0.651079 |             11.5801 |              227.07 |          15.0689 |                         38.3688 |              -8.28381 |
# +--------+----------------+---------------------+---------------------+------------------+---------------------------------+-----------------------+

# %% [markdown]
# ### 실제 데이터와 예측치 시각화

# %%
df = origin.copy()
plt.figure(figsize=(10, 5), dpi=100)

sb.scatterplot(x='speed', y='dist', data=df)

xmin, xmax = plt.xlim()
xrange = np.arange(xmin.round(), xmax.round())
y_pred = fit.predict(xrange.reshape(-1, 1))
sb.lineplot(x=xrange, y=y_pred, color='red')
      
plt.grid()
plt.show()
plt.close()

# %% [markdown]
# ## #04. 다항회귀의 경우
#
# ### [1] 독립변수에 대한 2차항을 추가

# %%
df = origin.copy()
df['speed2'] = df['speed'] ** 2
my_pretty_table(df.head())
# Out:
# +----+---------+--------+----------+
# |    |   speed |   dist |   speed2 |
# |----+---------+--------+----------|
# |  0 |       4 |      2 |       16 |
# |  1 |       4 |     10 |       16 |
# |  2 |       7 |      4 |       49 |
# |  3 |       7 |     22 |       49 |
# |  4 |       8 |     16 |       64 |
# +----+---------+--------+----------+

# %% [markdown]
# ### [2] 다중선형회귀 적용

# %%
x = df[['speed', 'speed2']]
y = df['dist']
fit = my_linear_regression(x, y, use_plot=False, report=True)
# Out:
# [회귀식]
# dist = 0.913 * speed + 0.100 * speed2 + 2.470
#
# [회귀분석 성능평가]
# +--------+----------------+---------------------+---------------------+------------------+---------------------------------+-----------------------+
# |        |   결정계수(R2) |   평균절대오차(MAE) |   평균제곱오차(MSE) |   평균오차(RMSE) |   평균 절대 백분오차 비율(MAPE) |   평균 비율 오차(MPE) |
# |--------+----------------+---------------------+---------------------+------------------+---------------------------------+-----------------------|
# | 데이터 |       0.667331 |             11.1069 |             216.494 |          14.7137 |                         38.3075 |              -19.5827 |
# +--------+----------------+---------------------+---------------------+------------------+---------------------------------+-----------------------+
#
# [선형회귀분석 결과보고]
# +----+------------+------------+--------------------+------------+------------------+-------+------------+--------+
# |    | 종속변수   | 독립변수   |   B(비표준화 계수) |   표준오차 |   β(표준화 계수) |     t |   유의확률 |    VIF |
# |----+------------+------------+--------------------+------------+------------------+-------+------------+--------|
# |  0 | dist       | speed      |             0.9133 |      2.034 |            0.187 | 0.449 |      0.656 | 18.382 |
# |  1 | dist       | speed2     |                0.1 |      0.066 |            0.632 | 1.515 |      0.136 | 18.382 |
# +----+------------+------------+--------------------+------------+------------------+-------+------------+--------+
#
# 𝑅^2(0.667), Adj.𝑅^2(0.653), F(47.141), P-value(5.852e-12), Durbin-Watson(1.762)
#
# dist에 대하여 speed,speed2로 예측하는 회귀분석을 실시한 결과,
# 이 회귀모형은 통계적으로 유의하다(F(2,47) = 47.141, p <= 0.05).
#
# speed의 회귀계수는 0.913(p > 0.05)로, dist에 대하여 유의하지 않은 예측변인인 것으로 나타났다.
# speed2의 회귀계수는 0.100(p > 0.05)로, dist에 대하여 유의하지 않은 예측변인인 것으로 나타났다.

# %% [markdown]
# ### [3] 결과 시각화

# %%
plt.figure(figsize=(10, 5), dpi=100)

sb.scatterplot(x='speed', y='dist', data=df)

xmin, xmax = plt.xlim()
xrange = np.arange(xmin.round(), xmax.round())
xrange2 = xrange ** 2
xdf = DataFrame({'speed': xrange, 'speed2': xrange2})
y_pred = fit.predict(xdf)
sb.lineplot(x=xrange, y=y_pred, color='red')
      
plt.grid()
plt.show()
plt.close()
