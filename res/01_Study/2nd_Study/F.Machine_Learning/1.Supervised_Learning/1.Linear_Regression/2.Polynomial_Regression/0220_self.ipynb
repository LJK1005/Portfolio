# %%
import sys
import os
work_path = os.path.abspath(os.path.join(os.getcwd(), "../../.."))
sys.path.append(work_path)

import numpy as np
import pandas as pd
from ljk_module.preprocessing import *
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import Ridge, Lasso, LinearRegression
from my_helper.regression import *
from my_helper.util import *
from my_helper.plot import *
from my_helper.analysis import *

# %%
df = pd.read_excel("./data/cars.xlsx")

# %%
df.head()
# Out:
#    speed  dist
# 0      4     2
# 1      4    10
# 2      7     4
# 3      7    22
# 4      8    16

# %%
X = df.copy()
Y = X.pop('dist')

# %%
pl = PolynomialFeatures(degree = 2, include_bias = False)

# %%
X_poly = pd.DataFrame(pl.fit_transform(X), columns = pl.get_feature_names_out())

# %%
X_poly.head()
# Out:
#    speed  speed^2
# 0    4.0     16.0
# 1    4.0     16.0
# 2    7.0     49.0
# 3    7.0     49.0
# 4    8.0     64.0

# %%
ss = StandardScaler()
X_poly_df = pd.DataFrame(ss.fit_transform(X_poly), columns = X_poly.columns)

# %%
x_train, x_test, y_train, y_test = train_test_split(X_poly_df, Y, test_size = 0.3, random_state = 50)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
model.score(x_test, y_test)
# Out:
# 0.45630728790200403

# %%
rg = Ridge()
rg.fit(x_train, y_train)
rg.score(x_test, y_test)
# Out:
# 0.4589141472118814

# %%
la = Lasso()
la.fit(x_train, y_train)
la.score(x_test, y_test)
# Out:
# 0.4660260327533525

# %%
my_linear_regression(X_poly_df, Y, cv = 5, use_plot = True, report = True, dpi = 100)
# Out:
# [교차검증]
# +----+-------------------+
# |    |   mean_test_score |
# |----+-------------------|
# |  0 |         -0.450665 |
# +----+-------------------+
#
# [회귀식]
# dist = 4.781 * speed + 16.135 * speed^2 + 42.980
#
# [회귀분석 성능평가]
# +--------+----------------+---------------------+---------------------+------------------+---------------------------------+-----------------------+
# |        |   결정계수(R2) |   평균절대오차(MAE) |   평균제곱오차(MSE) |   평균오차(RMSE) |   평균 절대 백분오차 비율(MAPE) |   평균 비율 오차(MPE) |
# |--------+----------------+---------------------+---------------------+------------------+---------------------------------+-----------------------|
# | 데이터 |       0.667331 |             11.1069 |             216.494 |          14.7137 |                         38.3075 |              -19.5827 |
# +--------+----------------+---------------------+---------------------+------------------+---------------------------------+-----------------------+
#
# [선형회귀분석 결과보고]
# +----+------------+------------+--------------------+------------+------------------+-------+------------+---------+
# |    | 종속변수   | 독립변수   |   B(비표준화 계수) |   표준오차 |   β(표준화 계수) |     t |   유의확률 |     VIF |
# |----+------------+------------+--------------------+------------+------------------+-------+------------+---------|
# |  0 | dist       | speed      |             4.7806 |     10.648 |            0.187 | 0.449 |      0.656 | 24.6149 |
# |  1 | dist       | speed^2    |            16.1347 |     10.648 |            0.632 | 1.515 |      0.136 | 24.6149 |
# +----+------------+------------+--------------------+------------+------------------+-------+------------+---------+
#
# 𝑅^2(0.667), Adj.𝑅^2(0.653), F(47.141), P-value(5.852e-12), Durbin-Watson(1.762)
#
# dist에 대하여 speed,speed^2로 예측하는 회귀분석을 실시한 결과,
# 이 회귀모형은 통계적으로 유의하다(F(2,47) = 47.141, p <= 0.05).
#
# speed의 회귀계수는 4.781(p > 0.05)로, dist에 대하여 유의하지 않은 예측변인인 것으로 나타났다.
# speed^2의 회귀계수는 16.135(p > 0.05)로, dist에 대하여 유의하지 않은 예측변인인 것으로 나타났다.
# LinearRegression(n_jobs=-1)

# %%
df2 = pd.read_excel("./data/fish.xlsx")

# %%
my_pretty_table(df2.head())
# Out:
# +----+--------+--------+--------+--------+
# |    |   길이 |   높이 |   두께 |   무게 |
# |----+--------+--------+--------+--------|
# |  0 |    8.4 |   2.11 |   1.41 |    5.9 |
# |  1 |   13.7 |   3.53 |      2 |     32 |
# |  2 |     15 |   3.82 |   2.43 |     40 |
# |  3 |   16.2 |   4.59 |   2.63 |   51.5 |
# |  4 |   17.4 |   4.59 |   2.94 |     70 |
# +----+--------+--------+--------+--------+

# %%
my_pairplot(df2)

# %%
poly = PolynomialFeatures(degree = 2, include_bias = False)
poly_fit = poly.fit_transform(df2.drop('무게', axis = 1))

# %%
poly_df = pd.DataFrame(poly_fit, columns = poly.get_feature_names_out())
my_pretty_table(poly_df.head())
# Out:
# +----+--------+--------+--------+----------+-------------+-------------+----------+-------------+----------+
# |    |   길이 |   높이 |   두께 |   길이^2 |   길이 높이 |   길이 두께 |   높이^2 |   높이 두께 |   두께^2 |
# |----+--------+--------+--------+----------+-------------+-------------+----------+-------------+----------|
# |  0 |    8.4 |   2.11 |   1.41 |    70.56 |      17.724 |      11.844 |   4.4521 |      2.9751 |   1.9881 |
# |  1 |   13.7 |   3.53 |      2 |   187.69 |      48.361 |        27.4 |  12.4609 |        7.06 |        4 |
# |  2 |     15 |   3.82 |   2.43 |      225 |        57.3 |       36.45 |  14.5924 |      9.2826 |   5.9049 |
# |  3 |   16.2 |   4.59 |   2.63 |   262.44 |      74.358 |      42.606 |  21.0681 |     12.0717 |   6.9169 |
# |  4 |   17.4 |   4.59 |   2.94 |   302.76 |      79.866 |      51.156 |  21.0681 |     13.4946 |   8.6436 |
# +----+--------+--------+--------+----------+-------------+-------------+----------+-------------+----------+

# %%
fit = my_linear_regression(poly_df, df2['무게'], dpi = 100)
# Out:
# [회귀식]
# 무게 = -4.864 * 길이 + -55.902 * 높이 + 4.331 * 두께 + 0.553 * 길이^2 + -1.098 * 길이 높이 + -0.430 * 길이 두께 + 24.712 * 높이^2 + -56.267 * 높이 두께 + 51.478 * 두께^2 + 123.681
#
# [회귀분석 성능평가]
# +--------+----------------+---------------------+---------------------+------------------+---------------------------------+-----------------------+
# |        |   결정계수(R2) |   평균절대오차(MAE) |   평균제곱오차(MSE) |   평균오차(RMSE) |   평균 절대 백분오차 비율(MAPE) |   평균 비율 오차(MPE) |
# |--------+----------------+---------------------+---------------------+------------------+---------------------------------+-----------------------|
# | 데이터 |       0.989254 |             23.8874 |              1275.3 |          35.7113 |                         14.5569 |              -6.38191 |
# +--------+----------------+---------------------+---------------------+------------------+---------------------------------+-----------------------+
#
# [선형회귀분석 결과보고]
# +----+------------+------------+--------------------+------------+------------------+--------+------------+---------+
# |    | 종속변수   | 독립변수   |   B(비표준화 계수) |   표준오차 |   β(표준화 계수) |      t |   유의확률 |     VIF |
# |----+------------+------------+--------------------+------------+------------------+--------+------------+---------|
# |  0 | 무게       | 길이       |            -4.8636 |     23.319 |           -0.126 | -0.209 |      0.836 |   10923 |
# |  1 | 무게       | 높이       |           -55.9017 |     72.681 |           -0.463 | -0.769 |      0.446 | 10896.4 |
# |  2 | 무게       | 두께       |             4.3312 |     81.061 |            0.022 |  0.053 |      0.958 | 6063.32 |
# |  3 | 무게       | 길이^2     |             0.5534 |      2.051 |            0.844 |   0.27 |      0.788 |  114305 |
# |  4 | 무게       | 길이 높이  |             -1.098 |     13.812 |           -0.506 | -0.079 |      0.937 |  487667 |
# |  5 | 무게       | 길이 두께  |            -0.4305 |      9.323 |           -0.121 | -0.046 |      0.963 | 97740.9 |
# |  6 | 무게       | 높이^2     |            24.7115 |     26.256 |             3.46 |  0.941 |      0.352 |  165484 |
# |  7 | 무게       | 높이 두께  |           -56.2672 |     46.593 |           -4.801 | -1.208 |      0.233 |  206833 |
# |  8 | 무게       | 두께^2     |            51.4784 |     32.453 |            2.714 |  1.586 |       0.12 |   37301 |
# +----+------------+------------+--------------------+------------+------------------+--------+------------+---------+
#
# 𝑅^2(0.989), Adj.𝑅^2(0.987), F(470.532), P-value(1.11e-16), Durbin-Watson(1.481)
#
# 무게에 대하여 길이,높이,두께,길이^2,길이 높이,길이 두께,높이^2,높이 두께,두께^2로 예측하는 회귀분석을 실시한 결과,
# 이 회귀모형은 통계적으로 유의하다(F(9,46) = 470.532, p <= 0.05).
#
# 길이의 회귀계수는 -4.864(p > 0.05)로, 무게에 대하여 유의하지 않은 예측변인인 것으로 나타났다.
# 높이의 회귀계수는 -55.902(p > 0.05)로, 무게에 대하여 유의하지 않은 예측변인인 것으로 나타났다.
# 두께의 회귀계수는 4.331(p > 0.05)로, 무게에 대하여 유의하지 않은 예측변인인 것으로 나타났다.
# 길이^2의 회귀계수는 0.553(p > 0.05)로, 무게에 대하여 유의하지 않은 예측변인인 것으로 나타났다.
# 길이 높이의 회귀계수는 -1.098(p > 0.05)로, 무게에 대하여 유의하지 않은 예측변인인 것으로 나타났다.
# 길이 두께의 회귀계수는 -0.430(p > 0.05)로, 무게에 대하여 유의하지 않은 예측변인인 것으로 나타났다.
# 높이^2의 회귀계수는 24.712(p > 0.05)로, 무게에 대하여 유의하지 않은 예측변인인 것으로 나타났다.
# 높이 두께의 회귀계수는 -56.267(p > 0.05)로, 무게에 대하여 유의하지 않은 예측변인인 것으로 나타났다.
# 두께^2의 회귀계수는 51.478(p > 0.05)로, 무게에 대하여 유의하지 않은 예측변인인 것으로 나타났다.

# %%
ss = StandardScaler()
poly_ss = pd.DataFrame(ss.fit_transform(poly_df), columns = poly_df.columns)

# %%
x_train, x_test, y_train, y_test = train_test_split(poly_df, df2['무게'], test_size = 0.25, random_state = 0)
x_train_s, x_test_s, y_train_s, y_test_s = train_test_split(poly_ss, df2['무게'], test_size = 0.25, random_state = 0)

# %%
rg = Ridge()
rg2 = Ridge()
rg.fit(x_train, y_train)
rg2.fit(x_train_s, y_train_s)
# Out:
# Ridge()

# %%
rg.score(x_test, y_test)
# Out:
# 0.9535424365032135

# %%
rg2.score(x_test_s, y_test_s)
# Out:
# 0.9624131227147975

# %%
lr = LinearRegression()
lr2 = LinearRegression()
lr.fit(x_train, y_train)
lr2.fit(x_train_s, y_train_s)
# Out:
# LinearRegression()

# %%
lr.score(x_test, y_test)
# Out:
# 0.951536988440772

# %%
lr2.score(x_test_s, y_test_s)
# Out:
# 0.9515369884407732

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(max_depth = 5, n_estimators = 300, random_state = 0, n_jobs = -1)

# %%
rf.fit(x_train, y_train)
rf.score(x_test, y_test)
# Out:
# 0.9606065201859371
