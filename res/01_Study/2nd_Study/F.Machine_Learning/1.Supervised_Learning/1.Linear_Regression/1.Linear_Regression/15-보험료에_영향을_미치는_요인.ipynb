# %% [markdown]
# # 보험료에 영향을 미치는 요인
#
# 이 데이터세트에는 1,338행의 미국의 보험 데이터가 포함되어 있으며 보험 요금은 보험 가입자의 연령, 성별, BMI, 아동 수, 흡연자 및 지역 속성에 따라 제공된다.
#
# 속성은 숫자형 변수와 범주형 변수가 혼합되어 있습니다.
#
# 데이터 세트에 결측치는 포함되어 있지 않다.
#
# > https://www.kaggle.com/datasets/teertha/ushealthinsurancedataset
#
# | 변수 | 의미 | 기타 |
# |---|---|---|
# | age | 수익자의 연령 | 수치형 |
# | sex | 계약자의 성별 | 범주형 데이터(female/male) |
# | bmi | 미만도. 몸무게를 키의 제곱으로 나눈 값. | 수치형<br/>정상범위: 18.5~24.9 |
# | children | 의료보험이 적용되는 자녀 수 | 수치형 데이터 |
# | smoker | 흡연 여부 | 범주형 데이터(yes/no) |
# | region | 거주지역 | 범주형<br/>(북동: northeast, 남동: southeast / 남서: southwest / 북서: northwest) |
# | charges | 의료비 | 수치형 데이터 |

# %% [markdown]
# ## #01. 준비작업
#
# ### [1] 패키지 참조

# %%
# %%time

import sys
import os
work_path = os.path.abspath(os.path.join(os.getcwd(), "../../.."))
sys.path.append(work_path)

from my_helper.regression import *
from my_helper.util import *
from my_helper.plot import *
from my_helper.analysis import *
# Out:
# CPU times: total: 31.2 ms
# Wall time: 1.49 s

# %% [markdown]
# ### [2] 데이터 가져오기

# %%
# %%time
categories = ["sex", "smoker", "region"]
origin = my_read_excel("https://data.hossam.kr/mldata/us_health_insurance.xlsx", categories=categories)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   category
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   category
#  5   region    1338 non-null   category
#  6   charges   1338 non-null   float64
# dtypes: category(3), float64(2), int64(2)
# memory usage: 46.3 KB
# None
#
# 데이터프레임 상위 5개 행
# +----+-------+--------+--------+------------+----------+-----------+-----------+
# |    |   age | sex    |    bmi |   children | smoker   | region    |   charges |
# |----+-------+--------+--------+------------+----------+-----------+-----------|
# |  0 |    19 | female |   27.9 |          0 | yes      | southwest |   16884.9 |
# |  1 |    18 | male   |  33.77 |          1 | no       | southeast |   1725.55 |
# |  2 |    28 | male   |     33 |          3 | no       | southeast |   4449.46 |
# |  3 |    33 | male   | 22.705 |          0 | no       | northwest |   21984.5 |
# |  4 |    32 | male   |  28.88 |          0 | no       | northwest |   3866.86 |
# +----+-------+--------+--------+------------+----------+-----------+-----------+
#
# 데이터프레임 하위 5개 행
# +------+-------+--------+-------+------------+----------+-----------+-----------+
# |      |   age | sex    |   bmi |   children | smoker   | region    |   charges |
# |------+-------+--------+-------+------------+----------+-----------+-----------|
# | 1333 |    50 | male   | 30.97 |          3 | no       | northwest |   10600.5 |
# | 1334 |    18 | female | 31.92 |          0 | no       | northeast |   2205.98 |
# | 1335 |    18 | female | 36.85 |          0 | no       | southeast |   1629.83 |
# | 1336 |    21 | female |  25.8 |          0 | no       | southwest |   2007.94 |
# | 1337 |    61 | female | 29.07 |          0 | yes      | northwest |   29141.4 |
# +------+-------+--------+-------+------------+----------+-----------+-----------+
#
# 기술통계
# +----------+---------+---------+---------+---------+---------+---------+---------+---------+-------+
# |          |   count |    mean |     std |     min |     25% |     50% |     75% |     max |   nan |
# |----------+---------+---------+---------+---------+---------+---------+---------+---------+-------|
# | age      |    1338 |  39.207 |   14.05 |      18 |      27 |      39 |      51 |      64 |     0 |
# | bmi      |    1338 | 30.6634 | 6.09819 |   15.96 | 26.2963 |    30.4 | 34.6938 |   53.13 |     0 |
# | children |    1338 | 1.09492 | 1.20549 |       0 |       0 |       1 |       2 |       5 |     0 |
# | charges  |    1338 | 13270.4 |   12110 | 1121.87 | 4740.29 | 9382.03 | 16639.9 | 63770.4 |     0 |
# +----------+---------+---------+---------+---------+---------+---------+---------+---------+-------+
#
# 카테고리 정보
# +--------+-------+
# |        |   sex |
# |--------+-------|
# | male   |   676 |
# | female |   662 |
# +--------+-------+
# +-----+----------+
# |     |   smoker |
# |-----+----------|
# | no  |     1064 |
# | yes |      274 |
# +-----+----------+
# +-----------+----------+
# |           |   region |
# |-----------+----------|
# | southeast |      364 |
# | northwest |      325 |
# | southwest |      325 |
# | northeast |      324 |
# +-----------+----------+
# CPU times: total: 328 ms
# Wall time: 1.29 s

# %% [markdown]
# > 연속형 변수인 age, bmi, children은 데이터 분포가 상이하므로 스케일링을 수행해야 한다.
# >
# > 명목형 변수는 흡연 여부를 제외하고는 대체로 데이터가 균형잡혀 있다. 명목형에 대한 특별한 데이터 처리는 불필요할 것으로 보인다.
# >
# > 의료비지출 변수의 통계값을 살펴보면 중앙값이 `$9,382`이고, 평균이 `$13,270`인 것을 알 수 있다. 여기서 해당 변수의 평균값이 중앙값보다 크기 때문에 의료비 분포는 오른쪽으로 꼬리가 긴 분포를 지닐 것이다.

# %% [markdown]
# ## #02. 탐색적 데이터 분석
#
# ### [1] 연속형 변수에 대한 데이터 분포

# %%
for c in ['age', 'bmi', 'children', 'charges']:
    my_histplot(origin, c, bins=5, dpi=100)

# %% [markdown]
# > 대부분의 사람들은 연간 $15,000 이하의 의료비 지출에 분포되어 있음을 알 수 있다.
# >
# > 마찬가지로 bmi지수를 살펴보면 과체중이상의 데이터가 절반 이상을 차지하는 것을 알 수 있다.

# %% [markdown]
# ### [2] 각 변수간의 관계 파악

# %%
my_correlation(origin[['age', 'bmi', 'children', 'charges']], dpi=100)
# Out:
# +-------------------------+---------------+-------------+----------+
# |                         |   correlation |     p-value | result   |
# |-------------------------+---------------+-------------+----------|
# | ('age', 'bmi')          |      0.109272 | 6.19429e-05 | True     |
# | ('age', 'children')     |      0.042469 |    0.120493 | False    |
# | ('age', 'charges')      |      0.299008 | 4.88669e-29 | True     |
# | ('bmi', 'age')          |      0.109272 | 6.19429e-05 | True     |
# | ('bmi', 'children')     |     0.0127589 |     0.64101 | False    |
# | ('bmi', 'charges')      |      0.198341 | 2.45909e-13 | True     |
# | ('children', 'age')     |      0.042469 |    0.120493 | False    |
# | ('children', 'bmi')     |     0.0127589 |     0.64101 | False    |
# | ('children', 'charges') |     0.0679982 |   0.0128521 | True     |
# | ('charges', 'age')      |      0.299008 | 4.88669e-29 | True     |
# | ('charges', 'bmi')      |      0.198341 | 2.45909e-13 | True     |
# | ('charges', 'children') |     0.0679982 |   0.0128521 | True     |
# +-------------------------+---------------+-------------+----------+

# %% [markdown]
# > 연령, bmi지수, 부양가족 수, 의료비지출은 약하지만 모두 양(+)의 상관관계를 보이고 있다.
# >
# > 예를 들어, 연령과 bmi지수는 나이가 들어갈 수록 몸무게가 증가되면서 bmi 지수가 높아지는 경향을 설명할 수 있고, 부양가족 수가 증가하면 의료비 지출이 많아진다고 보는 것도 합리적인 판단이 될 수 있다.

# %%
for c in categories:
    my_countplot(origin, c, dpi=100)

# %% [markdown]
# > 흡연 여부의 경우 비흡연자가 많이 분포되어 있다.
# >
# > 그 밖에 성별과 지역의 경우 비슷하게 분포되어 있기 때문에 분산분석을 통해 통제요인으로 넣는 것을 고려해 볼 수 있겠다.

# %% [markdown]
# ### [3] 분산분석을 통한 통제요인 선정

# %%
from my_helper.analysis import my_anova

for c in categories:
    tmp = origin[[c, 'charges']]
    my_anova(tmp, hue=c, target='charges')
# Out:
# pingouin.anova
# +----+----------+-------------+------+------------+--------+-----------+------------+
# |    | Source   |          SS |   DF |         MS |      F |     p-unc |        np2 |
# |----+----------+-------------+------+------------+--------+-----------+------------|
# |  0 | sex      |  6.4359e+08 |    1 | 6.4359e+08 | 4.3997 | 0.0361327 | 0.00328238 |
# |  1 | Within   | 1.95431e+11 | 1336 | 1.4628e+08 |    nan |       nan |        nan |
# +----+----------+-------------+------+------------+--------+-----------+------------+
#
# statsmodels.anova.anova_lm
# +----------+------+-------------+------------+--------+-----------+
# |          |   df |      sum_sq |    mean_sq |      F |    PR(>F) |
# |----------+------+-------------+------------+--------+-----------|
# | C(sex)   |    1 |  6.4359e+08 | 6.4359e+08 | 4.3997 | 0.0361327 |
# | Residual | 1336 | 1.95431e+11 | 1.4628e+08 |    nan |       nan |
# +----------+------+-------------+------------+--------+-----------+
# [anova_lm] statistic: 4.400, p-value: 0.036, 대립가설 채택
# pingouin.anova
# +----+----------+-------------+------+-------------+---------+--------------+----------+
# |    | Source   |          SS |   DF |          MS |       F |        p-unc |      np2 |
# |----+----------+-------------+------+-------------+---------+--------------+----------|
# |  0 | smoker   |  1.2152e+11 |    1 |  1.2152e+11 | 2177.61 | 8.27144e-283 | 0.619765 |
# |  1 | Within   | 7.45543e+10 | 1336 | 5.58041e+07 |     nan |          nan |      nan |
# +----+----------+-------------+------+-------------+---------+--------------+----------+
#
# statsmodels.anova.anova_lm
# +-----------+------+-------------+-------------+---------+--------------+
# |           |   df |      sum_sq |     mean_sq |       F |       PR(>F) |
# |-----------+------+-------------+-------------+---------+--------------|
# | C(smoker) |    1 |  1.2152e+11 |  1.2152e+11 | 2177.61 | 8.27144e-283 |
# | Residual  | 1336 | 7.45543e+10 | 5.58041e+07 |     nan |          nan |
# +-----------+------+-------------+-------------+---------+--------------+
# [anova_lm] statistic: 2177.615, p-value: 0.000, 대립가설 채택
# pingouin.anova
# +----+----------+-------------+------+-------------+---------+-----------+------------+
# |    | Source   |          SS |   DF |          MS |       F |     p-unc |        np2 |
# |----+----------+-------------+------+-------------+---------+-----------+------------|
# |  0 | region   | 1.30076e+09 |    3 | 4.33587e+08 | 2.96963 | 0.0308934 | 0.00663402 |
# |  1 | Within   | 1.94773e+11 | 1334 | 1.46007e+08 |     nan |       nan |        nan |
# +----+----------+-------------+------+-------------+---------+-----------+------------+
#
# statsmodels.anova.anova_lm
# +-----------+------+-------------+-------------+---------+-----------+
# |           |   df |      sum_sq |     mean_sq |       F |    PR(>F) |
# |-----------+------+-------------+-------------+---------+-----------|
# | C(region) |    3 | 1.30076e+09 | 4.33587e+08 | 2.96963 | 0.0308934 |
# | Residual  | 1334 | 1.94773e+11 | 1.46007e+08 |     nan |       nan |
# +-----------+------+-------------+-------------+---------+-----------+
# [anova_lm] statistic: 2.970, p-value: 0.031, 대립가설 채택

# %%
tmp = origin[["sex", "smoker", "region", "charges"]]
my_anova(tmp, target="charges", hue=["sex", "smoker", "region"])
# Out:
# pingouin.anova
# +----+-----------------------+-------------+------+-------------+------------+--------------+-------------+
# |    | Source                |          SS |   DF |          MS |          F |        p-unc |         np2 |
# |----+-----------------------+-------------+------+-------------+------------+--------------+-------------|
# |  0 | sex                   | 4.99724e+06 |    1 | 4.99724e+06 |  0.0910793 |     0.762857 | 6.88903e-05 |
# |  1 | smoker                | 1.19401e+11 |    1 | 1.19401e+11 |    2176.19 | 1.25108e-281 |    0.622091 |
# |  2 | region                | 1.05877e+08 |    3 | 3.52923e+07 |   0.643235 |     0.587268 |  0.00145756 |
# |  3 | sex * smoker          | 4.10428e+08 |    1 | 4.10428e+08 |    7.48043 |   0.00632067 |  0.00562658 |
# |  4 | sex * region          | 1.38228e+06 |    3 |      460760 | 0.00839778 |     0.998944 | 1.90566e-05 |
# |  5 | smoker * region       | 1.32965e+09 |    3 | 4.43218e+08 |    8.07805 |  2.46961e-05 |   0.0180014 |
# |  6 | sex * smoker * region | 7.51706e+07 |    3 | 2.50569e+07 |   0.456684 |     0.712614 |  0.00103528 |
# |  7 | Residual              |  7.2534e+10 | 1322 | 5.48669e+07 |        nan |          nan |         nan |
# +----+-----------------------+-------------+------+-------------+------------+--------------+-------------+
#
# statsmodels.anova.anova_lm
# +----------------------------+-------------+------+------------+--------------+
# |                            |      sum_sq |   df |          F |       PR(>F) |
# |----------------------------+-------------+------+------------+--------------|
# | C(sex)                     | 4.99724e+06 |    1 |  0.0910793 |     0.762857 |
# | C(smoker)                  | 1.19401e+11 |    1 |    2176.19 | 1.25108e-281 |
# | C(region)                  | 1.05877e+08 |    3 |   0.643235 |     0.587268 |
# | C(sex):C(smoker)           | 4.10428e+08 |    1 |    7.48043 |   0.00632067 |
# | C(sex):C(region)           | 1.38228e+06 |    3 | 0.00839778 |     0.998944 |
# | C(smoker):C(region)        | 1.32965e+09 |    3 |    8.07805 |  2.46961e-05 |
# | C(sex):C(smoker):C(region) | 7.51706e+07 |    3 |   0.456684 |     0.712614 |
# | Residual                   |  7.2534e+10 | 1322 |        nan |          nan |
# +----------------------------+-------------+------+------------+--------------+
# [anova_lm] statistic: 0.091, p-value: 0.763, 귀무가설 채택

# %% [markdown]
# > 성별과 흡연량, 흡연량과 지역 간에는 교효작용 효과가 있음이 발견되었다.

# %% [markdown]
# ### [4] 교효작용에 대한 시각화 확인
#
# #### (1) 흡연 여부에 따른 성별 분포

# %%
my_countplot(origin, xname="smoker", hue='sex', dpi=100)

# %% [markdown]
# #### (2) 흡연 여부에 따른 지역 분포

# %%
my_countplot(origin, xname="smoker", hue='region', dpi=100)

# %% [markdown]
# ## #03. 데이터 전처리
#
# ### [1] 데이터 표준화

# %%
std_df = my_standard_scaler(origin, yname="charges")
my_pretty_table(std_df.head())
# Out:
# +----+-----------+-----------+------------+--------+----------+-----------+-----------+
# |    |       age |       bmi |   children | sex    | smoker   | region    |   charges |
# |----+-----------+-----------+------------+--------+----------+-----------+-----------|
# |  0 |  -1.43876 |  -0.45332 |  -0.908614 | female | yes      | southwest |   16884.9 |
# |  1 |  -1.50997 |  0.509621 | -0.0787672 | male   | no       | southeast |   1725.55 |
# |  2 | -0.797954 |  0.383307 |    1.58093 | male   | no       | southeast |   4449.46 |
# |  3 | -0.441948 |  -1.30553 |  -0.908614 | male   | no       | northwest |   21984.5 |
# |  4 | -0.513149 | -0.292556 |  -0.908614 | male   | no       | northwest |   3866.86 |
# +----+-----------+-----------+------------+--------+----------+-----------+-----------+

# %% [markdown]
# ### [2] 더미변수 생성

# %%
dummy_df = my_dummies(origin)
my_pretty_table(dummy_df.head())
# Out:
# +----+-------+--------+------------+-----------+------------+--------------+--------------------+--------------------+--------------------+
# |    |   age |    bmi |   children |   charges |   sex_male |   smoker_yes |   region_northwest |   region_southeast |   region_southwest |
# |----+-------+--------+------------+-----------+------------+--------------+--------------------+--------------------+--------------------|
# |  0 |    19 |   27.9 |          0 |   16884.9 |          0 |            1 |                  0 |                  0 |                  1 |
# |  1 |    18 |  33.77 |          1 |   1725.55 |          1 |            0 |                  0 |                  1 |                  0 |
# |  2 |    28 |     33 |          3 |   4449.46 |          1 |            0 |                  0 |                  1 |                  0 |
# |  3 |    33 | 22.705 |          0 |   21984.5 |          1 |            0 |                  1 |                  0 |                  0 |
# |  4 |    32 |  28.88 |          0 |   3866.86 |          1 |            0 |                  1 |                  0 |                  0 |
# +----+-------+--------+------------+-----------+------------+--------------+--------------------+--------------------+--------------------+

# %% [markdown]
# ### [4] 훈련, 검증 데이터 분리

# %%
x_train, x_test, y_train, y_test = my_train_test_split(dummy_df, "charges", test_size=0.2)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((1070, 8), (268, 8), (1070,), (268,))

# %% [markdown]
# ## #05. 선형회귀 분석
#
# ### [1] 전체 변수에 대한 분석

# %%
my_linear_regression(x_train, y_train, x_test, y_test, cv=5, dpi=100, use_plot=False, resid_test=False)
# Out:
# [교차검증]
# +----+-------------------+
# |    |   mean_test_score |
# |----+-------------------|
# |  0 |          0.732513 |
# +----+-------------------+
#
# [회귀식]
# charges = 255.647 * age + 342.676 * bmi + 451.587 * children + -83.442 * sex_male + 23501.011 * smoker_yes + -419.220 * region_northwest + -1033.274 * region_southeast + -1026.348 * region_southwest + -11830.463
#
# [회귀분석 성능평가]
# +--------+----------------+---------------------+---------------------+------------------+---------------------------------+-----------------------+
# |        |   결정계수(R2) |   평균절대오차(MAE) |   평균제곱오차(MSE) |   평균오차(RMSE) |   평균 절대 백분오차 비율(MAPE) |   평균 비율 오차(MPE) |
# |--------+----------------+---------------------+---------------------+------------------+---------------------------------+-----------------------|
# | 데이터 |       0.800174 |              4013.1 |         3.05524e+07 |          5527.43 |                         41.0093 |              -20.7827 |
# +--------+----------------+---------------------+---------------------+------------------+---------------------------------+-----------------------+
#
# [선형회귀분석 결과보고]
# +----+------------+------------------+--------------------+------------+------------------+--------+------------+---------+
# |    | 종속변수   | 독립변수         |   B(비표준화 계수) |   표준오차 |   β(표준화 계수) |      t |   유의확률 |     VIF |
# |----+------------+------------------+--------------------+------------+------------------+--------+------------+---------|
# |  0 | charges    | age              |            255.647 |     25.438 |            0.297 |  10.05 |          0 |  8.2612 |
# |  1 | charges    | bmi              |            342.676 |     57.123 |            0.165 |  5.999 |          0 | 11.7056 |
# |  2 | charges    | children         |            451.587 |    303.583 |            0.053 |  1.488 |      0.138 | 1.97886 |
# |  3 | charges    | sex_male         |           -83.4417 |    693.922 |           -0.014 |  -0.12 |      0.904 |  1.9987 |
# |  4 | charges    | smoker_yes       |              23501 |    833.642 |            0.849 | 28.191 |          0 | 1.30354 |
# |  5 | charges    | region_northwest |            -419.22 |    1021.77 |           -0.004 |  -0.41 |      0.682 | 1.74482 |
# |  6 | charges    | region_southeast |           -1033.27 |    1002.38 |           -0.035 | -1.031 |      0.304 | 2.09621 |
# |  7 | charges    | region_southwest |           -1026.35 |      950.7 |           -0.023 |  -1.08 |      0.281 | 2.22009 |
# +----+------------+------------------+--------------------+------------+------------------+--------+------------+---------+
#
# 𝑅^2(0.800), Adj.𝑅^2(0.794), F(129.641), P-value(1.11e-16), Durbin-Watson(1.967)
#
# charges에 대하여 age,bmi,children,sex_male,smoker_yes,region_northwest,region_southeast,region_southwest로 예측하는 회귀분석을 실시한 결과,
# 이 회귀모형은 통계적으로 유의하다(F(8,259) = 129.641, p <= 0.05).
#
# age의 회귀계수는 255.647(p <= 0.05)로, charges에 대하여 유의미한 예측변인인 것으로 나타났다.
# bmi의 회귀계수는 342.676(p <= 0.05)로, charges에 대하여 유의미한 예측변인인 것으로 나타났다.
# children의 회귀계수는 451.587(p > 0.05)로, charges에 대하여 유의하지 않은 예측변인인 것으로 나타났다.
# sex_male의 회귀계수는 -83.442(p > 0.05)로, charges에 대하여 유의하지 않은 예측변인인 것으로 나타났다.
# smoker_yes의 회귀계수는 23501.011(p <= 0.05)로, charges에 대하여 유의미한 예측변인인 것으로 나타났다.
# region_northwest의 회귀계수는 -419.220(p > 0.05)로, charges에 대하여 유의하지 않은 예측변인인 것으로 나타났다.
# region_southeast의 회귀계수는 -1033.274(p > 0.05)로, charges에 대하여 유의하지 않은 예측변인인 것으로 나타났다.
# region_southwest의 회귀계수는 -1026.348(p > 0.05)로, charges에 대하여 유의하지 않은 예측변인인 것으로 나타났다.
# LinearRegression(n_jobs=-1)

# %% [markdown]
# ### [2] bmi를 제외한 상태로 분석

# %%
ignore = ['bmi']
x_train2 = x_train.drop(ignore, axis=1)
x_test2 = x_test.drop(ignore, axis=1)

my_linear_regression(x_train2, y_train, x_test2, y_test, cv=5, dpi=100, use_plot=False, resid_test=False)
# Out:
# [교차검증]
# +----+-------------------+
# |    |   mean_test_score |
# |----+-------------------|
# |  0 |          0.706778 |
# +----+-------------------+
#
# [회귀식]
# charges = 270.725 * age + 474.541 * children + 149.559 * sex_male + 23369.090 * smoker_yes + -399.319 * region_northwest + 383.019 * region_southeast + -722.646 * region_southwest + -2504.752
#
# [회귀분석 성능평가]
# +--------+----------------+---------------------+---------------------+------------------+---------------------------------+-----------------------+
# |        |   결정계수(R2) |   평균절대오차(MAE) |   평균제곱오차(MSE) |   평균오차(RMSE) |   평균 절대 백분오차 비율(MAPE) |   평균 비율 오차(MPE) |
# |--------+----------------+---------------------+---------------------+------------------+---------------------------------+-----------------------|
# | 데이터 |       0.773724 |              3931.3 |         3.45966e+07 |          5881.89 |                         32.8914 |              -20.7933 |
# +--------+----------------+---------------------+---------------------+------------------+---------------------------------+-----------------------+
#
# [선형회귀분석 결과보고]
# +----+------------+------------------+--------------------+------------+------------------+--------+------------+---------+
# |    | 종속변수   | 독립변수         |   B(비표준화 계수) |   표준오차 |   β(표준화 계수) |      t |   유의확률 |     VIF |
# |----+------------+------------------+--------------------+------------+------------------+--------+------------+---------|
# |  0 | charges    | age              |            270.725 |     26.719 |            0.321 | 10.132 |          0 | 4.08624 |
# |  1 | charges    | children         |            474.541 |    322.409 |            0.055 |  1.472 |      0.142 | 1.88628 |
# |  2 | charges    | sex_male         |            149.559 |    736.999 |           -0.014 |  0.203 |      0.839 | 1.92477 |
# |  3 | charges    | smoker_yes       |            23369.1 |    884.975 |            0.854 | 26.407 |          0 | 1.26471 |
# |  4 | charges    | region_northwest |           -399.318 |     1085.1 |           -0.006 | -0.368 |      0.713 | 1.66691 |
# |  5 | charges    | region_southeast |            383.019 |    1029.55 |            0.015 |  0.372 |       0.71 |  1.7291 |
# |  6 | charges    | region_southwest |           -722.646 |    992.208 |            0.014 | -0.728 |      0.467 | 1.93151 |
# +----+------------+------------------+--------------------+------------+------------------+--------+------------+---------+
#
# 𝑅^2(0.774), Adj.𝑅^2(0.768), F(127.005), P-value(1.11e-16), Durbin-Watson(2.035)
#
# charges에 대하여 age,children,sex_male,smoker_yes,region_northwest,region_southeast,region_southwest로 예측하는 회귀분석을 실시한 결과,
# 이 회귀모형은 통계적으로 유의하다(F(7,260) = 127.005, p <= 0.05).
#
# age의 회귀계수는 270.725(p <= 0.05)로, charges에 대하여 유의미한 예측변인인 것으로 나타났다.
# children의 회귀계수는 474.541(p > 0.05)로, charges에 대하여 유의하지 않은 예측변인인 것으로 나타났다.
# sex_male의 회귀계수는 149.559(p > 0.05)로, charges에 대하여 유의하지 않은 예측변인인 것으로 나타났다.
# smoker_yes의 회귀계수는 23369.090(p <= 0.05)로, charges에 대하여 유의미한 예측변인인 것으로 나타났다.
# region_northwest의 회귀계수는 -399.318(p > 0.05)로, charges에 대하여 유의하지 않은 예측변인인 것으로 나타났다.
# region_southeast의 회귀계수는 383.019(p > 0.05)로, charges에 대하여 유의하지 않은 예측변인인 것으로 나타났다.
# region_southwest의 회귀계수는 -722.646(p > 0.05)로, charges에 대하여 유의하지 않은 예측변인인 것으로 나타났다.
# LinearRegression(n_jobs=-1)

# %% [markdown]
# ### [3] children을 제외한 후 분석

# %%
ignore = ['bmi', 'children']
x_train2 = x_train.drop(ignore, axis=1)
x_test2 = x_test.drop(ignore, axis=1)

my_linear_regression(x_train2, y_train, x_test2, y_test, cv=5, dpi=100, use_plot=False, resid_test=False)
# Out:
# [교차검증]
# +----+-------------------+
# |    |   mean_test_score |
# |----+-------------------|
# |  0 |          0.704795 |
# +----+-------------------+
#
# [회귀식]
# charges = 272.778 * age + 199.381 * sex_male + 23370.460 * smoker_yes + -343.994 * region_northwest + 392.585 * region_southeast + -650.862 * region_southwest + -2130.177
#
# [회귀분석 성능평가]
# +--------+----------------+---------------------+---------------------+------------------+---------------------------------+-----------------------+
# |        |   결정계수(R2) |   평균절대오차(MAE) |   평균제곱오차(MSE) |   평균오차(RMSE) |   평균 절대 백분오차 비율(MAPE) |   평균 비율 오차(MPE) |
# |--------+----------------+---------------------+---------------------+------------------+---------------------------------+-----------------------|
# | 데이터 |       0.770795 |             3970.02 |         3.50444e+07 |          5919.83 |                         34.6503 |               -22.007 |
# +--------+----------------+---------------------+---------------------+------------------+---------------------------------+-----------------------+
#
# [선형회귀분석 결과보고]
# +----+------------+------------------+--------------------+------------+------------------+--------+------------+---------+
# |    | 종속변수   | 독립변수         |   B(비표준화 계수) |   표준오차 |   β(표준화 계수) |      t |   유의확률 |     VIF |
# |----+------------+------------------+--------------------+------------+------------------+--------+------------+---------|
# |  0 | charges    | age              |            272.778 |     26.834 |            0.322 | 10.165 |          0 | 3.57317 |
# |  1 | charges    | sex_male         |            199.381 |    737.496 |           -0.019 |   0.27 |      0.787 | 1.92401 |
# |  2 | charges    | smoker_yes       |            23370.5 |    888.131 |            0.856 | 26.314 |          0 | 1.25098 |
# |  3 | charges    | region_northwest |           -343.994 |    1089.36 |           -0.004 | -0.316 |      0.752 | 1.64209 |
# |  4 | charges    | region_southeast |            392.585 |    1034.17 |            0.015 |   0.38 |      0.705 | 1.71351 |
# |  5 | charges    | region_southwest |           -650.862 |    996.437 |            0.012 | -0.653 |      0.514 | 1.92176 |
# +----+------------+------------------+--------------------+------------+------------------+--------+------------+---------+
#
# 𝑅^2(0.771), Adj.𝑅^2(0.766), F(146.286), P-value(1.11e-16), Durbin-Watson(2.034)
#
# charges에 대하여 age,sex_male,smoker_yes,region_northwest,region_southeast,region_southwest로 예측하는 회귀분석을 실시한 결과,
# 이 회귀모형은 통계적으로 유의하다(F(6,261) = 146.286, p <= 0.05).
#
# age의 회귀계수는 272.778(p <= 0.05)로, charges에 대하여 유의미한 예측변인인 것으로 나타났다.
# sex_male의 회귀계수는 199.381(p > 0.05)로, charges에 대하여 유의하지 않은 예측변인인 것으로 나타났다.
# smoker_yes의 회귀계수는 23370.460(p <= 0.05)로, charges에 대하여 유의미한 예측변인인 것으로 나타났다.
# region_northwest의 회귀계수는 -343.994(p > 0.05)로, charges에 대하여 유의하지 않은 예측변인인 것으로 나타났다.
# region_southeast의 회귀계수는 392.585(p > 0.05)로, charges에 대하여 유의하지 않은 예측변인인 것으로 나타났다.
# region_southwest의 회귀계수는 -650.862(p > 0.05)로, charges에 대하여 유의하지 않은 예측변인인 것으로 나타났다.
# LinearRegression(n_jobs=-1)

# %% [markdown]
# > 대부분의 변수가 소거되어 훈련 모델의 신뢰도가 상당히 낮다. 다른 변수들을 추가로 투입해야 할 것 같다.
