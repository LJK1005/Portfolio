# %% [markdown]
# # 주식 데이터 수집 - yfinance
#
# 야후 파이낸스에서 크롤링한 데이터를 제공하는 라이브러리
#
# 재무제표, 주주정보 등 수집하기 어려운 다양한 데이터도 제공
#
# 야후 파이낸스 특성상 미국 주식 데이터는 정확하지만 국내 주식 데이터는 불안정
#
# ## #01. 준비과정
#
# ### [1] 패키지 참조

# %%
import yfinance as yf

# %% [markdown]
# ## #02. 주가 검색
#
# 검색을 원하는 종목의 종목번호를 알아야 한다.
#
# 한국주식의 경우 종목번호 뒤에 `.KS`라고 덧붙여야 한다.
#
# ### 반환되는 컬럼의 의미
#
# | Open | High | Low | Close | Adj Close | Volume |
# |------|------|-----|-------|-----------|--------|
# | 시가   | 고가   | 저가  | 종가    | 수정 주가     | 거래량    |

# %%
# 종목번호(005930.KS=삼성, AAPL=애플), 검색시작일, 검색종료일 지정 
# 검색 종료일을 지정하지 않을 경우 가장 최근까지 검색한다.
df = yf.download("005930.KS", "2023-01-01", "2023-12-14")
df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-01-03  130.279999  130.899994  124.169998  125.070000  124.374802
# 2023-01-04  126.889999  128.660004  125.080002  126.360001  125.657639
# 2023-01-05  127.129997  127.769997  124.760002  125.019997  124.325089
# 2023-01-06  126.010002  130.289993  124.889999  129.619995  128.899521
# 2023-01-09  130.470001  133.410004  129.889999  130.149994  129.426559
# ...                ...         ...         ...         ...         ...
# 2023-12-07  193.630005  195.000000  193.589996  194.270004  194.270004
# 2023-12-08  194.199997  195.990005  193.669998  195.710007  195.710007
# 2023-12-11  193.110001  193.490005  191.419998  193.179993  193.179993
# 2023-12-12  193.080002  194.720001  191.720001  194.710007  194.710007
# 2023-12-13  195.089996  198.000000  194.850006  197.960007  197.960007
#
#                Volume
# Date
# ...

# %% [markdown]
# ## #03. 그 밖의 정보
#
# ### 특정 종목을 의미하는 객체 생성

# %%
aapl_yf = yf.Ticker("AAPL")
aapl_yf
# Out:
# yfinance.Ticker object <AAPL>

# %% [markdown]
# ### 재무재표

# %%
aapl_yf.financials
# Out:
#                                                         2023-09-30  \
# Tax Effect Of Unusual Items                                    0.0
# Tax Rate For Calcs                                        0.147192
# Normalized EBITDA                                   125820000000.0
# Net Income From Continuing Operation Net Minori...   96995000000.0
# Reconciled Depreciation                              11519000000.0
# Reconciled Cost Of Revenue                          214137000000.0
# EBITDA                                              125820000000.0
# EBIT                                                114301000000.0
# Net Interest Income                                            NaN
# Interest Expense                                               NaN
# Interest Income                                                NaN
# Normalized Income                                    96995000000.0
# Net Income From Continuing And Discontinued Ope...   96995000000.0
# ...

# %% [markdown]
# ### 주식 보유 지분

# %%
aapl_yf.major_holders
# Out:
#         0                                      1
# 0   0.07%        % of Shares Held by All Insider
# 1  61.66%       % of Shares Held by Institutions
# 2  61.71%        % of Float Held by Institutions
# 3    5888  Number of Institutions Holding Shares
