# %%
import pandas as pd
import cx_Oracle as cx
import chromedriver_autoinstaller
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time

# %%
class naver_review(): # 네이버 쇼핑에서 리뷰를 수집하는 클래스 객체
    def __init__(self): # 생성자에서 Selenium을 이용한 크롬드라이버 창 실행
        chromedriver_autoinstaller.install()
        self.driver = webdriver.Chrome()
        self.driver.implicitly_wait(2)

    def connect_url(self, url): # 특정 상품 페이지로 접속하는 메서드, url : 접속 대상 url을 텍스트 형식으로 입력
        self.driver.get(url) # url 접속
        time.sleep(1) # 페이지 로드 대기
        self.driver.execute_script("window.scrollTo(0, (document.body.scrollHeight)*0.15);") # 리뷰 메뉴 확인을 위한 스크롤 이동 (전체의 15% 지점)
        time.sleep(0.5) # 페이지 로드 대기
        # 리뷰 메뉴 지정 (해당 CSS 선택자 검색시 총 4개의 요소가 잡히며 상세정보-리뷰-Q&A-반품/교환정보순, 1번째인 리뷰를 선택)
        self.review_btn = self.driver.find_elements(By.CSS_SELECTOR, 'a._11xjFby3Le')[1]
        self.review_btn.click() # 리뷰 메뉴 선택
        print('url : {0} 에 성공적으로 접속했습니다.'.format(url)) # 페이지 접속 성공 메세지 출력
        time.sleep(0.5) # 페이지 로드 대기

    def rip_review(self, x): # 단일 리뷰 페이지의 리뷰 데이터를 수집하는 메서드, x는 크롬드라이버의 .page_source 메서드로 생성된 소스 데이터
        self.soup = BeautifulSoup(x) # 현재 크롬드라이버의 소스 코드를 수집하여 soup 객체 생성
        self.reviews = self.soup.select('div._1McWUwk15j') # 페이지당 20개의 리뷰가 존재하며, 해당 20개의 리뷰 영역을 선택하는 CSS 선택자
        self.review_list = [] # 리뷰 데이터를 담을 리스트 생성

        for i in self.reviews: # 20개의 리뷰 영역에 대하여 반복문 수행
            self.review_temp = {} # 1개 분량의 리뷰 데이터를 담을 딕셔너리 생성

            try: # 선택한 상품 옵션을 추출
                self.review_temp['선택상품'] = i.select('div._2FXNMst_ak')[0].text.strip()
            except:
                self.review_temp['선택상품'] = None

            try: # 리뷰 작성일 추출
                self.review_temp['리뷰작성일'] = i.select('div.iWGqB6S4Lq span._2L3vDiadT9')[0].text.strip()
            except:
                self.review_temp['리뷰작성일'] = None

            try: # 별점을 정수형 데이터로 추출
                self.review_temp['별점'] = int(i.select('em._15NU42F3kT')[0].text.strip())
            except:
                self.review_temp['별점'] = None

            # 추출한 정수형 별점 데이터가 3 이상일 경우 긍정 판정, 별점이 2 이하일 경우 부정, 별점을 추출하지 못했을 경우 결측치로 처리
            if self.review_temp['별점'] >= 3:
                self.review_temp['긍정/부정'] = '긍정'
            elif self.review_temp['별점'] == None:
                self.review_temp['긍정/부정'] = None
            else:
                self.review_temp['긍정/부정'] = '부정'

            try: # 리뷰의 내용을 추출
                self.review_temp['리뷰내용'] = i.select('div._1kMfD5ErZ6 span._2L3vDiadT9')[0].text.replace("\n", " ").strip()
            except:
                self.review_temp['리뷰내용'] = None

            self.review_list.append(self.review_temp) # 추출한 리뷰 정보를 담은 딕셔너리를 리뷰 리스트에 추가
        
        return self.review_list # 최종적으로 20개의 리뷰를 반환
    
    def rip_all(self): # 현재 조회중인 단일 url의 전체 리뷰를 수집하는 메서드
        self.all_reviews = [] # 모든 리뷰를 담을 리스트 생성
        self.idx = 1 # 조회하는 페이지를 판별하는 index 변수 생성

        while True: # 반복을 수행할 횟수가 불분명하므로 무한루프 설정
            self.all_reviews += self.rip_review(self.driver.page_source) # rip_review 메서드를 이용하여 모든 리뷰를 담을 리스트에 데이터를 추가
            self.idx += 1 # 현재 페이지의 리뷰를 모두 수집했으므로 수집할 페이지 변수를 1 증가시킴

            self.button_list = self.driver.find_elements(By.CSS_SELECTOR, 'div._1HJarNZHiI._2UJrM31-Ry a') # 모든 리뷰 페이지 버튼을 탐색하는 CSS 선택자
            self.button_text = [] # 리뷰 페이지 버튼의 실제 텍스트를 담을 임시 리스트 정의
            for i in self.button_list: # 리뷰 페이지 버튼을 담은 리스트에 반복문을 적용하여 버튼의 텍스트를 추출
                try:
                    self.button_text.append(i.text)
                except:
                    self.button_text.append(None)
            
            if self.idx > 200: # 테스트용 리뷰 수집 갯수 제약 (100페이지 x 20개 = 2000개)
                break
                
            try:
            # 탐색하고자 하는 리뷰 페이지가 text의 몇 번째 인덱스인지 확인하여 해당 인덱스 번호를 기존 리뷰 페이지 버튼에 적용하여 다음 페이지 버튼을 지정
                self.btn = self.button_list[self.button_text.index(str(self.idx))] 
                self.btn.click() # 다음 페이지 버튼 클릭
                time.sleep(1) # 페이지 로드 대기
            except:
                try:
            # 탐색하고자 하는 리뷰 페이지가 11, 21 페이지 등에 의하여 다음 페이지로 넘어가야 하는 경우 '다음'으로 되어 있는 버튼을 탐색
            # 기존 idx로는 에러가 발생하므로 예외처리
                    self.btn = self.button_list[self.button_text.index('다음')]
                    self.btn.click() # 다음 페이지 버튼 클릭
                    time.sleep(1) # 페이지 로드 대기
                except:
                    break # 다음 idx 페이지도, '다음' 페이지도 모두 없을 경우 페이지의 끝에 도달한 것으로 판단하여 break 문으로 무한루프 해제 

        return self.all_reviews # 현재까지 수집한 모든 리뷰 데이터를 반환
    
    def page_summary(self): # 현재 조회중인 url에서 리뷰 외 추가적인 상품명, 상품 가격을 추출하는 메서드
        summary = {} # 데이터를 담을 딕셔너리 생성
        summary['product_name'] = self.driver.find_element(By.CSS_SELECTOR, 'h3._22kNQuEXmb').text # 상품명 수집
        summary['product_price'] = int(self.driver.find_element(By.CSS_SELECTOR, 'span._1LY7DqCnwR').text.replace(",", "")) # 상품가격 수집
        summary['reviews'] = self.rip_all() # rip_all로 현재 조회중인 url의 리뷰 데이터 수집

        print("상품 페이지에서 총 {0}개의 리뷰를 수집했습니다.".format(len(summary['reviews']))) # 수집한 데이터의 개수 출력
        return summary # 데이터를 담은 딕셔너리 반환

    def rip_list(self, x): # 여러개의 url에서 데이터를 수집하는 메서드, x : url을 원소로 하는 리스트
        self.all_list = [] # 모든 데이터를 수집할 리스트 정의

        for i in x: # connect_url 메서드로 접속하고, page_summary 메서드로 url의 정보를 수집하는 메서드를 반복문으로 수행하여 리스트에 데이터 수집
            self.connect_url(i)
            self.all_list.append(self.page_summary())

        return self.all_list # 수집한 모든 데이터 반환

    def close(self): # 크롬드라이버를 닫는 메서드
        try:
            self.driver.close()
        except:
            pass

# %%
url_list = ['https://smartstore.naver.com/o-ma/products/7363123499',
       'https://brand.naver.com/applestore/products/9360093290',
       'https://smartstore.naver.com/uniyuni/products/6071556962',
       'https://smartstore.naver.com/o-ma/products/7363123499',
       'https://brand.naver.com/sonystore/products/8932776097',
       'https://smartstore.naver.com/cotini/products/5357757813']

# %%
test = naver_review()
all_list = test.rip_list(url_list)
test.close()
# Out:
# url : https://smartstore.naver.com/o-ma/products/7363123499 에 성공적으로 접속했습니다.
# 상품 페이지에서 총 843개의 리뷰를 수집했습니다.
# url : https://brand.naver.com/applestore/products/9360093290 에 성공적으로 접속했습니다.
# 상품 페이지에서 총 1026개의 리뷰를 수집했습니다.
# url : https://smartstore.naver.com/uniyuni/products/6071556962 에 성공적으로 접속했습니다.
# 상품 페이지에서 총 784개의 리뷰를 수집했습니다.
# url : https://smartstore.naver.com/o-ma/products/7363123499 에 성공적으로 접속했습니다.
# 상품 페이지에서 총 843개의 리뷰를 수집했습니다.
# url : https://brand.naver.com/sonystore/products/8932776097 에 성공적으로 접속했습니다.
# 상품 페이지에서 총 1479개의 리뷰를 수집했습니다.
# url : https://smartstore.naver.com/cotini/products/5357757813 에 성공적으로 접속했습니다.
# 상품 페이지에서 총 4000개의 리뷰를 수집했습니다.

# %%
all_list
# Out:
# [{'product_name': '갤럭시 버즈2프로 SM-R510',
#   'product_price': 137480,
#   'reviews': [{'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.12.08.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '일단 같은 삼성 브랜드 제품과의 호환성이 좋았습니다.  이어팁은 대/중/소 사이즈가 있고 기본은 중 사이즈로, 필요하시면 바꾸시면 됩니다. (워낙 가볍고 작은 제품이라 반드시 안빠지게 처음부터 바꿔줘야함.)  충전은 케이스, 이어폰 모두 상당히 빠르게 이루어지고, 이어폰 완충 시 대략 4시간 정도 사용 가능합니다.  음악 듣는 상태에서 입으로 소리를 내면, 외부 소리가 잘 들리도록 바뀌는 기능이 있고,  소음 차단 설정 시 조용하게 음악을 들을 수 있습니다.  단점  1. 터치에 민감한 편이라 가끔 귀에 닿으면 오작동 할 수 있습니다. 2. 소리는 좋습니다만...     하이엔드 음향브랜드 제품이 더 좋습니다.'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.12.09.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '가성비 대만족합니다. 음질도 좋네요. 타제품 비교 노캔이 약간부족한거같긴한데 그렇게 나쁘지도 않아요. 이제품 나름대로의 노캔 영역이라고 해야할까요? 기본적인 소음은 정말 잘잡는편인것 같아요. 아무튼 총점! 가격까지 비교하면 정말 대만족 ! ㅋ 제가 가진 다른 이어폰들하고 크기비교샷도 찍었습니다.'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.11.28.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '이전에 보스제품 코코에서 구입하고 노캔빼고는 가격대비 별로라 반납하고 버즈 고민하다 구입했는데 제귀가 막귀인지 음질차이 잘모르겠네요. 다음 기종나올때 까지 기다릴까도 생각했지만 나와도 20후반대 가격이라면 버즈2프로가 현시점 가격이나 성능에서 현명한 선택이라는 생각이드네요'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.12.16.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '잘 받았어요~!  원래 버즈 프로 보라색 썼는데 신랑이 가져가서 새로 주문했네요~!  소리도 잘 들리고 기존 버즈 프로보다는 살짝 작은거같아요~!  귀가 작아서 전에꺼 끼면 귀가 늘어나면서 따꼼하고 간지러웠는데 이건 그런 느낌이 전혀 없네요~^^   알록달록한걸 좋아해서 흰색은 처음으로 써보는데  흰색도 깔끔하고 예뻐요^^  사진은 케이스 끼우기 전에 찍어놨는데 첨부가 안되서 케이스 끼운뒤 찍은 사진으로 올렸어요~'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.12.12.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '잘 받았어요! 배송이 확실히 빠르고 받자마자 충전 인식 다 잘되서 좋았어요 다음날 오전에 2시간 정도 연속으로 써봤는데 중간에 좀 끊기는 부분이 있었지만 잘 작동되고 있어요 번창하세요!'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.12.05.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '싸게잘산거같아요 배송은끝내주네요 하루도가기전왔어요 아이가너무좋아하구요 가격이너무저렴해서 품질이떨어지면어떡하나걱정했는데 너무좋아요'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.12.07.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '배송 빠르고 작동 잘됩니다  생각보다 작아서 귀엽고 착용감도 좋아요  아직충전중이라 음질은 모르겠지만 갤럭시니 좋을듯요 ㅎㅎ  저렴한 가격에 살수있게해주셔서 감사합니다 ㅎㅎ'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.12.17.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '버즈 라이브 샀다 몇번 착용해보니 귀가 너무 아파서 이번에 버즈 프로 2 로 시봤습니다. 이건 귀가 안아프고 참 편안 하네요. 음질도 좋고 너무 만족합니다. 귀 작으신분들은 절대 버즈 라이브 사면 안돼요 ㅋㅋ'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.12.12.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '착용감이 편하고 주변 소리도 잘 들리고 음질도 괜찮네요. 잘 쓰도록 하겠습니다.'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.12.04.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '잘 받았습니다. 아직 사용전입니다. 귀가 작아 팁을 우선 젤 작은걸로 갈아끼우고 충전하고 있어요.'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.12.08.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '간단하게 유튜브나 게임같은 걸로 확인해봤는데 잘 들리는거 같아요 병원생활하면서 필요성을 느꼈는데 추후에 몇주간 또 해야되서 가격도 저렴한김에 구매했어요 배송도 빠르게 해주셨고 삼성케어에 시리얼번호 입력해봤는데 정품인거 같아요 출시 가격에 반값이상 저렴하게 구매해서 좋아요'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.12.07.',
#     '별점': 1,
#     '긍정/부정': '부정',
#     '리뷰내용': '함께 구매해야 하는 젤리 같지도 않은 뻣뻣하고 얇은 플라스틱 케이스는 품질이 매우 나쁩니다. 실리콘 재질이 아니며 알리익스프레스에서 몇백원에 파는 연질의 플라스틱 제품입니다. 자세한 설명 지우겠습니다.'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.12.11.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '진짜 배송 속도가 미쳤어요... 수요일 늦은 밤에 결제했는데, 금요일 오전 중으로 오다니... 가족 생일 선물로 샀는데, 덕분에 새일 당일에 전달할수 있었습니다! 감사합니다. 번창하세요 ☺️☺️'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.12.16.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '저렴한 가격에 구입했어요 배송도 빠르고 만족스러워요 버즈2쓰다가 분실해서 프로로 구입했는데 나름 차이도 느껴지고 좋습니다'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.12.15.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '급하게 선물할곳이 있었는데 빠른배송 무사히 잘지나갔습니다. 정품~에 케이스도 흠집없이 잘도착했어요. 잘쓰겠습니다.'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.12.10.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '와이프가 이어폰을 찾고 있어서 이것 저것 알아보다가 버즈2프로제품 선택하고 사이트 알아보다가 발견했어요. 저렴한 가격에 좋은 제품 찾게 되어 만족합니다. 노이즈캔슬링, 음질 등 모든 기능에 만족합니다'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.12.15.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '가격 착하고 총알배송에 제품도 하자없고 잘 쓰고있습니다!'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.12.13.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '네이버 최저가에 배송도 하루만에 왔네요. 음질은 이전 모델보다 많이 좋아졌어요. 특히 저음이 빵빵합니다.'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.12.18.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '�
요'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.12.15.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '가성비가 좋습니다~~~'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.11.21.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '빠른배송 그리고 좋네요'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.12.10.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '빠른배송감사합니다.'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.11.25.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '잘 샀습니다~ 수고하세요~'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.12.13.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '너무 마음에들어요!'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.11.11.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '저렴하게 잘 구매했습니다. 감사합니다'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.11.04.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '배송 빠르고 만족합니다. 마음에드네요.'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.12.18.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '듣던대로 좋습니당~~^.^*'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.12.07.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '완전 좋아요 완전 만족'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.12.11.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '항상 만족하는 상품이네요 ㅎ'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.12.13.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '봏네요 ㅎㅎㅎ 잘쓰겠습니다'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.12.05.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '좋아요 ㅎㅎ 감사합니다'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.12.04.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '선물용으로 구매하였습니당 가격이 합리적이라 좋은 것 같아요:)'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.11.23.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '감사히 잘사용 하겠습니다.'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.11.28.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '음질 좋고 귀에 딱 맞아요. 너무 잘 쓰고 있습니다'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.12.07.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '선물할거라 열어보진않았어요  배송 완전 빨라요'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.12.08.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '배송이 빨라서 좋아요'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.12.08.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '빠른 배송 감사합니다'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.12.07.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '좋습니다.역시 이름값을 하네요.'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.12.08.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '가격이 출시때보다 반토막인데 이정도 성능이면 혜자죠.'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.11.22.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '가격도 배송도  만족요'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.11.23.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '보내느라 수고했습니다.'},
#    {'선택상품': '버즈2프로(색상): 그라파이트',
#     '리뷰작성일': '23.10.14.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '버즈사용하다 버즈2 프로로 넘어왔는데 노이즈켄슬링부터 착용감 모두 어마어마 하게 좋아졌네요. 배송도 하루만에오고 가격도 저렴히 잘산거 같아요ㅎ'},
#    {'선택상품': '버즈2프로(색상): 라벤더',
#     '리뷰작성일': '23.11.19.',
#     '별점': 4,
#     '긍정/부정': '긍정',
#     '리뷰내용': '아직 고장 없고 잘 사용하고 있습니다.'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.11.24.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '저렴한 가격이라서 사기인줄알았는데 정품 맞구요 쓰던게 아닌 새거라 좋습니다'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.12.06.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '잘받았습니다 번창하세요'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.12.08.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '음질도 좋고 노이즈 캔슬링도 좋아요'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.12.13.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..빠른 배송 감사합니다. 번창하세요..'},
#    {'선택상품': '버즈2프로(색상): 화이트',
#     '리뷰작성일': '23.12.08.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '아들이 만족해하고 있습니다.'},
#    {'선택상품': '버즈2프로(색상): 화이트',
# ...
#     '리뷰내용': '어투3ㅓ유오뉴콘노노ㅠㄴ'},
#    {'선택상품': '모델선택: QCY T13 블랙',
#     '리뷰작성일': '23.10.21.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '올해 잘산템 중 하나!!! 대만족이에요!!! 에어팟을 사야 하나 버즈를 사야 하나 그 돈주고 샀다가 나랑 안맞아서 실패하느니 차라리 그냥 저렴한거 사자하고 샀는데 기대 이상이에요~~~ 귀에도 잘 맞고 운동하면서 쓰는데 안빠지고 좋아요  받아서 하루에 2~3시간 들었는데 거의 2주? 지나서야 처음 충전했네요 굿♥'},
#    {'선택상품': '모델선택: QCY T13 ANC 블랙',
#     '리뷰작성일': '23.11.15.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': 'Qcy는 처음 써봅니다. 일단은 가격대가 너무 좋으네요! 잘 사용할게요 👍'},
#    {'선택상품': '모델선택: QCY T13 ANC 화이트',
#     '리뷰작성일': '23.11.30.',
#     '별점': 4,
#     '긍정/부정': '긍정',
#     '리뷰내용': '음질 괜찮아요 :)'},
#    {'선택상품': '모델선택: QCY T13 화이트',
#     '리뷰작성일': '23.11.28.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '무난하게 잘 쓰고 있습니다'},
#    {'선택상품': '모델선택: QCY T13 ANC 화이트',
#     '리뷰작성일': '23.11.15.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '저렴한 가격인데 제품은 좋아요. 배송도 빠르고요'},
#    {'선택상품': '모델선택: QCY T13 블랙',
#     '리뷰작성일': '23.11.18.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '배송빠르고 가격대비 너무좋아요'},
#    {'선택상품': '모델선택: QCY T13 블랙',
#     '리뷰작성일': '23.11.22.',
#     '별점': 4,
#     '긍정/부정': '긍정',
#     '리뷰내용': '폰 바꾸면서..선없는 이어폰 사봣는데 괜찮네요.'},
#    {'선택상품': '모델선택: QCY T13 ANC 화이트',
#     '리뷰작성일': '23.11.24.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '아주 잘쓰고 있어요 연결도 잘되고'},
#    {'선택상품': '모델선택: (2) T13 ANC 화이트',
#     '리뷰작성일': '23.12.18.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '음질ㆍ품질 가성비 최고네요'},
#    {'선택상품': '모델선택: QCY T13 ANC 화이트',
#     '리뷰작성일': '23.10.24.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '착용감 편안하고, 최초 배터리 완충해서 사용했더니, 배터리도 오래가고 잘 쓰고 있습니다^^ 다른 블루투스제품들하고 병용하는 중이라, 터치위치를 살짝 헷갈려서 버벅대긴하는데, 소리도 불편하지않고, (껌씹거나 말핻ᆢ)쉽게 빠지거나 하지 않아서 좋습니다!'},
#    {'선택상품': '모델선택: QCY T13 화이트',
#     '리뷰작성일': '23.12.17.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '예뻐서 맘에 들어요'},
#    {'선택상품': '모델선택: QCY T13 ANC 화이트',
#     '리뷰작성일': '23.11.26.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '기격대비 아주 좋아요'},
#    {'선택상품': '모델선택: (2) T13 ANC 화이트',
#     '리뷰작성일': '23.12.14.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '진짜 가격대비 좋네요  노캔이 세지는 않아요'},
#    {'선택상품': '모델선택: QCY T13 ANC 화이트',
#     '리뷰작성일': '23.12.09.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '아직 잘 안쓰고잇어요 노이즈캔슬링은 벼로내요'},
#    {'선택상품': '모델선택: (2) T13 ANC 화이트',
#     '리뷰작성일': '23.12.18.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '가성비 최고 입니다.'},
#    {'선택상품': '모델선택: QCY T13 화이트',
#     '리뷰작성일': '23.10.23.',
#     '별점': 4,
#     '긍정/부정': '긍정',
#     '리뷰내용': '다른 저가 이어폰 한번 써봤다가 음향이 너무 안맞아서 결국은 qcy로 돌아오게 되네요. 디자인 깔끔하고 다좋아요...근데 유일한 단점은 귀가 아픕니다ㅠㅠ 이어팁을 제일 작은걸로 해도 어디가 눌리는 건지 한시간 좀 넘게 착용하면 아파서 잠깐 쉬어야 돼요 ㅎㅎ.. 그것 빼고는 전부 만족스러워요 qcy 짱!'},
#    {'선택상품': '모델선택: QCY T13 화이트',
#     '리뷰작성일': '23.11.26.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '가격대비 만족합니다'},
#    {'선택상품': '모델선택: QCY T13 화이트',
#     '리뷰작성일': '23.11.16.',
#     '별점': 4,
#     '긍정/부정': '긍정',
#     '리뷰내용': '가성비 좋아요. 페어링도 잘됩니다'},
#    {'선택상품': '모델선택: QCY T13 화이트',
#     '리뷰작성일': '23.11.24.',
#     '별점': 4,
#     '긍정/부정': '긍정',
#     '리뷰내용': '가성비로 샀어요 연결이 이전 쓰던거보다 잘되네요'},
#    {'선택상품': '모델선택: QCY T13 ANC 블랙',
#     '리뷰작성일': '23.11.18.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '가성비 좋아요 잘 사용하고 있습니다'},
#    {'선택상품': '모델선택: QCY T13 화이트',
#     '리뷰작성일': '23.12.05.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '빠른 배송 감사드려요 가성비 좋아요'},
#    {'선택상품': '모델선택: QCY T13 ANC 화이트',
#     '리뷰작성일': '23.12.07.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '생각보다 괜찮네요. 가성비 좋습니다.'},
#    {'선택상품': '모델선택: QCY T13 ANC 블랙',
#     '리뷰작성일': '23.12.13.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '아주 좋습니다 만족합니다.'},
#    {'선택상품': '모델선택: QCY T13 ANC 블랙',
#     '리뷰작성일': '23.11.18.',
#     '별점': 4,
#     '긍정/부정': '긍정',
#     '리뷰내용': '가끔 순간적으로 끊김 생길때 말고는 만족하며 잘 사용중입니다.'},
#    {'선택상품': '모델선택: QCY T13 ANC 화이트',
#     '리뷰작성일': '23.12.16.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '예쁘고 잘들리고 좋아요'},
#    {'선택상품': '모델선택: QCY T13 화이트',
#     '리뷰작성일': '23.12.05.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '가성비 짱입니다. 운동할때 듣기 좋아요'},
#    {'선택상품': '모델선택: QCY T13 ANC 화이트',
#     '리뷰작성일': '23.12.12.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '굿굿 아주좋아요 너무 좋아요'},
#    {'선택상품': '모델선택: (1) T13 블랙',
#     '리뷰작성일': '23.12.12.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '디자인이 깔끔하고 좋아요'},
#    {'선택상품': '모델선택: QCY T13 블랙',
#     '리뷰작성일': '23.11.30.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '음 좋은데 좋은데 세컨드용'},
#    {'선택상품': '모델선택: QCY T13 화이트',
#     '리뷰작성일': '23.11.17.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '배송빠르고 디자인도 깔끔했어 좋아요'},
#    {'선택상품': '모델선택: QCY T13 화이트',
#     '리뷰작성일': '23.11.21.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '첫째가 사용중인데 좋다고해서 둘째도 사줬습니다 소리가 잘 들려요'},
#    {'선택상품': '모델선택: QCY T13 블랙',
#     '리뷰작성일': '23.11.10.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '이게 블루투스 연결 할 때 애를 좀 먹었는데 일단 음질도 좋고 잘 사용하구 있어요.'},
#    {'선택상품': '모델선택: (1) T13 블랙',
#     '리뷰작성일': '23.12.09.',
#     '별점': 4,
#     '긍정/부정': '긍정',
#     '리뷰내용': '소리 깔끔하게 잘 들리네요 가성비 좋아요'},
#    {'선택상품': '모델선택: QCY T13 ANC 화이트',
#     '리뷰작성일': '23.12.10.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '가성비가 최고 싼맛에 사서 몇달째 잘 쓰고있습니다'},
#    {'선택상품': '모델선택: QCY T13 ANC 블랙',
#     '리뷰작성일': '23.11.20.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '사용이 편리하고 충전시간이 길어서 좋습니다.'},
#    {'선택상품': '모델선택: QCY T13 화이트',
#     '리뷰작성일': '23.11.21.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '두번째 구입하여 사용하는데 가성비 좋습니다'},
#    {'선택상품': '모델선택: QCY T13 블랙',
#     '리뷰작성일': '23.11.18.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '가성비 좋아서 부모님도 사드렸는데, 만족 하십니다.'},
#    {'선택상품': '모델선택: QCY T13 블랙',
#     '리뷰작성일': '23.11.18.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '가성비 좋아서 부모님도 사드렸는데, 만족 하십니다.'},
#    {'선택상품': '모델선택: QCY T13 화이트',
#     '리뷰작성일': '23.11.18.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '가성비 좋아서 부모님도 사드렸는데, 만족 하십니다.'},
#    {'선택상품': '모델선택: QCY T13 ANC 화이트',
#     '리뷰작성일': '23.11.23.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '빠른 배송에 감사합니다.'},
#    {'선택상품': '모델선택: QCY T13 ANC 화이트',
#     '리뷰작성일': '23.12.13.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '가성비가 뛰어납니다. 좋아요.'},
#    {'선택상품': '모델선택: QCY T13 ANC 블랙',
#     '리뷰작성일': '23.11.14.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '배송빠르고 성능도 괜찬고 가격대비 가성비 짱이에요'},
#    {'선택상품': '모델선택: (1) T13 블랙',
#     '리뷰작성일': '23.12.07.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '소리도 좋고 오래가네요 디자인도 예쁘네요'},
#    {'선택상품': '모델선택: (2) T13 ANC 화이트',
#     '리뷰작성일': '23.12.15.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '충전도 잘되고 약간 빠르게 뛰어도 안빠져요!!'},
#    {'선택상품': '모델선택: QCY T13 화이트',
#     '리뷰작성일': '23.11.19.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '밖에서도 소리도 잘 듵리고 빠른 충전으로 가격대비 좋습니다.'},
#    {'선택상품': '모델선택: QCY T13 화이트',
#     '리뷰작성일': '23.12.10.',
#     '별점': 4,
#     '긍정/부정': '긍정',
#     '리뷰내용': '가성비 갑입니다. 쓸만해요'},
#    {'선택상품': '모델선택: QCY T13 블랙',
#     '리뷰작성일': '23.11.10.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '음질도좋고 가격대비 너무좋아요.  아이들 선물준건데 좋아합니다'},
#    {'선택상품': '모델선택: QCY T13 블랙',
#     '리뷰작성일': '23.11.26.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '인식잘되고 좋습니다'},
#    {'선택상품': '모델선택: (2) T13 ANC 블랙',
#     '리뷰작성일': '23.12.11.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '아직 써보진 않앗지만 색이쁩니다,'},
#    {'선택상품': '모델선택: QCY T13 블랙',
#     '리뷰작성일': '23.11.24.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '가성비 좋고 배송이 빠릅니다'},
#    {'선택상품': '모델선택: QCY T13 ANC 화이트',
#     '리뷰작성일': '23.11.09.',
#     '별점': 4,
#     '긍정/부정': '긍정',
#     '리뷰내용': '무선이어폰 처음써봅니다. 많은분들이 가성비 좋다고 해서  주문했는데  탁월한 선택이었습니다 흰색이라 깔끔하구요'},
#    {'선택상품': '모델선택: QCY T13 화이트',
#     '리뷰작성일': '23.12.17.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '딸아이가 잘 사용중입니다'},
#    {'선택상품': '모델선택: QCY T13 블랙',
#     '리뷰작성일': '23.12.13.',
#     '별점': 1,
#     '긍정/부정': '부정',
#     '리뷰내용': '이랬다저랬다 양쪽에거 왔다갔다 음질들림'},
#    {'선택상품': '모델선택: QCY T13 블랙',
#     '리뷰작성일': '23.12.10.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '간단한 사용법, 편하게 막 쓸수있는 가성비, 부담없는 가격'},
#    {'선택상품': '모델선택: QCY T13 블랙',
#     '리뷰작성일': '23.12.11.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '감사합니다 가성비 갑 맨족해요'},
#    {'선택상품': '모델선택: QCY T13 블랙',
#     '리뷰작성일': '23.11.14.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '괜찮은 가격에 성능 괜찮은 이어폰이예요. 학습용으로 만족해요'},
#    {'선택상품': '모델선택: QCY T13 ANC 화이트',
#     '리뷰작성일': '23.11.17.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '너무 좋아요 재구매의사 있어요'},
#    {'선택상품': '모델선택: QCY T13 ANC 블랙',
#     '리뷰작성일': '23.12.16.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '가격이 저렴해 좋습니다.'},
#    {'선택상품': '모델선택: QCY T13 블랙',
#     '리뷰작성일': '23.11.24.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '배송 디자인 가격 다 좋습니다.'},
#    {'선택상품': '모델선택: (1) T13 화이트',
#     '리뷰작성일': '23.12.20.',
#     '별점': 4,
#     '긍정/부정': '긍정',
#     '리뷰내용': '가성비 좋네요!!!'},
#    {'선택상품': '모델선택: QCY T13 화이트',
#     '리뷰작성일': '23.11.29.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '재구매 해서 쓰고 있어요~~^^'},
#    {'선택상품': '모델선택: QCY T13 ANC 블랙',
#     '리뷰작성일': '23.12.11.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '빠른배송 좋은 제품 잘쓸게요'},
#    {'선택상품': '모델선택: QCY T13 ANC 화이트',
#     '리뷰작성일': '23.11.26.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '역시 가성비 짱입니다.'},
#    {'선택상품': '모델선택: QCY T13 화이트',
#     '리뷰작성일': '23.11.20.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '받자마자 사용해봤는데 소리도 잘들리고 좋아요'},
#    {'선택상품': '모델선택: QCY T13 ANC 화이트',
#     '리뷰작성일': '23.11.23.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '가격대비 성능이 좋은거 같아요~'},
#    {'선택상품': '모델선택: QCY T13 화이트',
#     '리뷰작성일': '23.11.10.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '음질 가격 모두맘에들어요. 이어폰도 깔끔하고 좋네요'},
#    {'선택상품': '모델선택: QCY T13 ANC 화이트',
#     '리뷰작성일': '23.11.01.',
#     '별점': 4,
#     '긍정/부정': '긍정',
#     '리뷰내용': '가격대비 좋아요 상대방도 잘 들린데요.. 그런데 상대방이랑 통화할때  제 목소리가 더 크게 들리고 볼륨설정울 어떻게 하는지 몰라 핸드폰으로 볼륨 설정하고 있어요'},
#    {'선택상품': '모델선택: QCY T13 ANC 블랙',
#     '리뷰작성일': '23.11.01.',
#     '별점': 4,
#     '긍정/부정': '긍정',
#     '리뷰내용': '가격대비 좋아요 상대방도 잘 들린데요.. 그런데 상대방이랑 통화할때  제 목소리가 더 크게 들리고 볼륨설정울 어떻게 하는지 몰라 핸드폰으로 볼륨 설정하고 있어요'},
#    {'선택상품': '모델선택: (2) T13 ANC 화이트',
#     '리뷰작성일': '23.12.14.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '총알배송과 좋아요 좋아'},
#    {'선택상품': '모델선택: QCY T13 화이트',
#     '리뷰작성일': '23.11.13.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '저번에 잃어버려서 디시 구입했어요 봐도봐도 세상 저렴하고 기능 좋고 ㅋ'},
#    {'선택상품': '모델선택: QCY T13 ANC 블랙',
#     '리뷰작성일': '23.11.18.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '부모님 선물로 샀는데 정말 잘 사용중이셔서 만족스럽습니다.'},
#    {'선택상품': '모델선택: QCY T13 화이트',
#     '리뷰작성일': '23.11.07.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '연결잘되고 음질도 좋습니다.^^ 블투스 이어폰 자꾸 고장나서 저렴이로 산건데 만족합니다!'},
#    {'선택상품': '모델선택: QCY T13 블랙',
#     '리뷰작성일': '23.11.23.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '실망시키지 않는 쿼티 좋아요'},
#    {'선택상품': '모델선택: (3) T13X 블랙',
#     '리뷰작성일': '23.12.06.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '후속작 나와서 바로 샀습니다. 국내 배송이라 하루만에 왔어요 좋아요.'},
#    {'선택상품': '모델선택: (1) T13 화이트',
#     '리뷰작성일': '23.12.08.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '평이 하도 좋아서 구매 했는데  진짜 너무 좋네요  잘쓸게요'},
#    {'선택상품': '모델선택: QCY T13 블랙',
#     '리뷰작성일': '23.11.21.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '싸고 좋고 가성비 굿입니다'},
#    {'선택상품': '모델선택: QCY T13 블랙',
#     '리뷰작성일': '23.11.05.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '부담없는 가격에 통화까지 되느 블루투스 이어폰 쓸 수 있는데 불만 없습니다 아버지가 뭘 잘 잃어버리시는데 편히 쓰시라고 사드렸어요 너무 좋아하세요'},
#    {'선택상품': '모델선택: QCY T13 ANC 화이트',
#     '리뷰작성일': '23.12.12.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '소음없이 잘 들리고 사용하기쉽습니다'},
#    {'선택상품': '모델선택: QCY T13 ANC 화이트',
#     '리뷰작성일': '23.10.23.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '무선 블루투스 이어폰 처음사용 하는데, 걱정했는데 음질 사용하기 좋네요.  상품후기. 블로그 찾아서 읽어보고 구매선택 잘한것 같아요^^ 착한 가격으로 가성비 좋고 잘 구입한것 같아서 만족합니다. 잘 사용하겠습니다~~~~~~'},
#    {'선택상품': '모델선택: QCY T13 ANC 블랙',
#     '리뷰작성일': '23.12.03.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '휴대폰을 주머니에 넣어놓으면 많이 끊겨요 .. 불편하긴한데 가성비 좋게 사용합니다'},
#    {'선택상품': '모델선택: QCY T13 ANC 화이트',
#     '리뷰작성일': '23.11.13.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '가격도 엄청 싸서 좋지만 싸다고 성능이 떨어지거나 품질이 안좋다거나 이런 문제가 전혀없음 정말 너무 좋음'},
#    {'선택상품': '모델선택: QCY T13 블랙',
#     '리뷰작성일': '23.12.14.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '우리 애가 만족하러라고요'},
#    {'선택상품': '모델선택: (5) T20 화이트',
#     '리뷰작성일': '23.12.05.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '가성비 좋은 정도가 아니네요. 10만원대 타사 제품보다 좋네요.'},
#    {'선택상품': '모델선택: QCY T13 ANC 화이트',
#     '리뷰작성일': '23.11.20.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '빠른배송 좋아요  분실하지 않기를 ㅠ'},
#    {'선택상품': '모델선택: (2) T13 ANC 블랙',
#     '리뷰작성일': '23.12.14.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '빠른 배송 상품 만족 합니다'},
#    {'선택상품': '모델선택: QCY T13 ANC 블랙',
#     '리뷰작성일': '23.11.02.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '배송 정말  빠르구요. 소문만 들었는데 진짜 대륙의 실수네요. 잘 사용하겠습니다'},
#    {'선택상품': '모델선택: QCY T13 블랙',
#     '리뷰작성일': '23.11.15.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '사무실 음악듣는용으로 추천합니다'},
#    {'선택상품': '모델선택: QCY T13 화이트',
#     '리뷰작성일': '23.11.22.',
#     '별점': 4,
#     '긍정/부정': '긍정',
#     '리뷰내용': '잘사용하고있습니다 너무 좋아요'},
#    {'선택상품': '모델선택: QCY T13 ANC 화이트',
#     '리뷰작성일': '23.11.23.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '배송빠르고 좋아요~'},
#    {'선택상품': '모델선택: QCY T13 ANC 블랙',
#     '리뷰작성일': '23.11.24.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '배송 빠르고 좋아요 ㅎㅎ'},
#    {'선택상품': '모델선택: (1) T13 화이트',
#     '리뷰작성일': '23.12.18.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '좋라여 많이 파세여'},
#    {'선택상품': '모델선택: QCY T13 화이트',
#     '리뷰작성일': '23.11.21.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '좋아요 아주  만족합니다'},
#    {'선택상품': '모델선택: QCY T13 화이트',
#     '리뷰작성일': '23.11.17.',
#     '별점': 4,
#     '긍정/부정': '긍정',
#     '리뷰내용': '아직은 소리 잘 들리고 괜찮게 잘 사용 중이예요 ~~~~ 오래쓰고 싶어요'},
#    {'선택상품': '모델선택: QCY T13 블랙',
#     '리뷰작성일': '23.11.04.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '이미 사서 잘 쓰고 있었는데 한 쪽을 잃어버리는 바람에 다시 구매했습니다. 가성비 갑입니다. 배송도 빠르네요.'},
#    {'선택상품': '모델선택: QCY T13 ANC 화이트',
#     '리뷰작성일': '23.11.09.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '배송도 빠르고 가성비 좋네요 런데이용으로 샀는데 달릴때도 떨어지지 않고 만족해요!'},
#    {'선택상품': '모델선택: QCY T13 블랙',
#     '리뷰작성일': '23.12.17.',
#     '별점': 2,
#     '긍정/부정': '부정',
#     '리뷰내용': '그냥 그레요 그렇다고요'},
#    {'선택상품': '모델선택: QCY T13 블랙',
#     '리뷰작성일': '23.11.23.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '두번째 구매인데 만족합니다'},
#    {'선택상품': '모델선택: QCY T13 ANC 화이트',
#     '리뷰작성일': '23.12.15.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '음질이 좋고 편리해요'},
#    {'선택상품': '모델선택: QCY T13 화이트',
#     '리뷰작성일': '23.12.12.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '가성비 최고! 너무너무 잘 쓰고 있습니다.'},
#    {'선택상품': '모델선택: QCY T13 ANC 블랙',
#     '리뷰작성일': '23.12.01.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '새로운 모델로 3개째 사용하고 있습니다. 비싼거 다 필요없어요~ 이게 최고입니다^^'},
#    {'선택상품': '모델선택: QCY T13 블랙',
#     '리뷰작성일': '23.11.24.',
#     '별점': 4,
#     '긍정/부정': '긍정',
#     '리뷰내용': '가성비 좋아서 재구매했어요.'},
#    {'선택상품': '모델선택: QCY T13 ANC 블랙',
#     '리뷰작성일': '23.11.16.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '잡음없고 좋음 괜찮으니 가성비로 사용하시면 될듯'},
#    {'선택상품': '모델선택: (1) T13 블랙',
#     '리뷰작성일': '23.12.11.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '재구매입니다 화이트에서 이번에는 블랙으로 구매합니다'},
#    {'선택상품': '모델선택: QCY T13 블랙',
#     '리뷰작성일': '23.12.07.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '음질 충전 다 맘에드네요 잘쓰고있어요'},
#    {'선택상품': '모델선택: QCY T13 화이트',
#     '리뷰작성일': '23.12.13.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': 'QCY는 가성비로는 역대 최고인듯 합니다.'},
#    {'선택상품': '모델선택: QCY T13 ANC 화이트',
#     '리뷰작성일': '23.11.22.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '서브용으로 쓰기 좋아요 음질이 좋은건 아니지만 쓰기에는 나쁘지 않은 것 같아요 배터리도 오래가고 좋습니다'},
#    {'선택상품': '모델선택: QCY T13 블랙',
#     '리뷰작성일': '23.12.15.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '잘때 불면증을 해소하기위해 ASMR들으며 자요'},
#    {'선택상품': '모델선택: QCY T13 ANC 화이트',
#     '리뷰작성일': '23.11.19.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '잘 사용하고 있습니다^^~ 가성비 & 성능 굿^^~'},
#    {'선택상품': '모델선택: (1) T13 화이트',
#     '리뷰작성일': '23.12.12.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '좋습니다.~~~ 맘에 들어요'},
#    {'선택상품': '모델선택: QCY T13 화이트',
#     '리뷰작성일': '23.11.23.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '저렴하게 잘 구입한거 같아요'},
#    {'선택상품': '모델선택: QCY T13 블랙',
#     '리뷰작성일': '23.12.08.',
#     '별점': 4,
#     '긍정/부정': '긍정',
#     '리뷰내용': '잘 사용하고ㅠ았어요 감사합니다'},
#    {'선택상품': '모델선택: QCY T13 화이트',
#     '리뷰작성일': '23.11.14.',
#     '별점': 4,
#     '긍정/부정': '긍정',
#     '리뷰내용': '애플이나 삼성 제품의 블루투스와 견주어도 밀리지 않는다'},
#    {'선택상품': '모델선택: QCY T13 블랙',
#     '리뷰작성일': '23.12.07.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '가성비 좋아요!! 문제 없이 잘 쓰고 있습니다ㅎㅎ'},
#    {'선택상품': '모델선택: QCY T13 ANC 화이트',
#     '리뷰작성일': '23.11.22.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '추천 받아써요  좋아욤ㅁ'},
#    {'선택상품': '모델선택: QCY T13 ANC 화이트',
#     '리뷰작성일': '23.11.10.',
#     '별점': 5,
#     '긍정/부정': '긍정',
#     '리뷰내용': '페어링 잘되고 음질좋고 가격착하고 이만하면 된거죠 ㅋ 최곱니다.'},
#    ...]}]

# %%
class input_sql(): # CX_ORACLE을 통하여 SQL 데이터에 접근 및 수정하는 클래스 객체 정의
    def __init__(self): # 생성자에서 DB에 접속
        self.dbcon = cx.connect("hr",
                        "hr",
                        "localhost:1521/xe")
        
    def create_table(self): # SQL 테이블을 생성하는 메서드 정의
        self.cursor = self.dbcon.cursor() # SQL문을 입력할 cursor 객체
        # 상품 정보를 담을 포맷을 가진 테이블 생성
        self.sql_base = "create table PRODUCT_LIST (product_id number not null, product varchar2(255) not null, price number not null, url varchar2(255) not null, primary key(product_id))"
        self.sql_base2 = "create sequence SEQ_PRODUCT start with 1 increment by 1"
        self.cursor.execute(self.sql_base)
        self.cursor.execute(self.sql_base2)
        print("테이블 'PRODUCT_LIST'과 시퀀스를 생성했습니다.")
        self.sql = "create table REVIEW_LIST (id number not null, product_id number not null, product_option varchar2(255), reg_date date not null, score number not null, positive_negative varchar2(25) not null, review clob not null, primary key(id), foreign key(product_id) references PRODUCT_LIST(product_id))"
        self.sql2 = "create sequence SEQ_REVIEW start with 1 increment by 1"
        self.cursor.execute(self.sql)
        self.cursor.execute(self.sql2)
        print("테이블 'REVIEW_LIST'과 시퀀스를 생성했습니다.")
        self.cursor.close() # cursor 객체 접속 종료

    def input_data(self, x, y): # 생성한 테이블에 데이터를 삽입하는 메서드 정의
        self.table = x.copy() # naver_review 클래스의 rip_list로 반환받은 리스트를 입력
        self.url = y.copy() # 상품 정보 테이블에 입력할 url 목록을 리스트로 입력
        self.cursor = self.dbcon.cursor() # SQL문을 입력할 cursor 객체
        self.num_data = 0 # 입력한 데이터 개수를 기록할 변수

        # PRODUCT_LIST에 상품 목록을 기입하는 반복문 수행
        for i, v in enumerate(self.table):
            self.sql_base = "insert into PRODUCT_LIST values({0}, '{1}', {2}, '{3}')"
            self.cursor.execute(self.sql_base.format('SEQ_PRODUCT.nextval', v['product_name'], v['product_price'], self.url[i]))

        # REVIEW_LIST에 리뷰 데이터를 기입하는 반복문 수행
        for i, v in enumerate(self.table): # url 개수만큼의 요소를 갖는 리스트 반복문 수행
            for j, w in enumerate(v['reviews']): # 단일 url 요소인 딕셔리에서 'reviews'인 key의 리스트를 반복문으로 수행
                # 데이터를 입력할 SQL문 포맷 생성
                self.sql = "insert into REVIEW_LIST values({0}, '{1}', '{2}', TO_DATE('{3}', 'YY.MM.DD.'), {4}, '{5}', '{6}')"
                try: # 리뷰가 1000자 이하일 경우 데이터가 정상적으로 기입됨
                    self.cursor.execute(self.sql.format('SEQ_REVIEW.nextval', i+1, w['선택상품'],
                                                    w['리뷰작성일'], w['별점'], w['긍정/부정'], w['리뷰내용'].replace("'", "'||CHR(039)||'")))
                except: # 리뷰 글자수가 1000자 이상일 경우 1000자 단위로 TO_CLOB을 적용시키는 예외문
                    self.sql2 = "insert into REVIEW_LIST values({0}, '{1}', '{2}', TO_DATE('{3}', 'YY.MM.DD.'), {4}, '{5}', {6})"
                    self.temp_txt = w['리뷰내용'].replace("'", "'||CHR(039)||'")
                    self.n = len(self.temp_txt) // 1000
                    self.li = []

                    for z in range(0, self.n + 1):
                        self.li.append(self.temp_txt[1000*z:1000*(z+1)])

                    self.txt = ""
                    for a, b in enumerate(self.li):
                        self.txt += "TO_CLOB('{0}')".format(b)
                        if a < len(self.li) - 1:
                            self.txt += "||"

                    self.cursor.execute(self.sql2.format('SEQ_REVIEW.nextval', i+1, w['선택상품'],
                                                    w['리뷰작성일'], w['별점'], w['긍정/부정'], self.txt))

                self.num_data += 1 # 데이터를 입력했을 경우 입력한 데이터 수를 1 증가시킴
            
            print("'REVIEW_LIST' 테이블에 {0} 상품에 대한 {1}개의 리뷰 데이터를 입력했습니다.".format(v['product_name'], self.num_data)) # 입력한 데이터 수 출력
            self.dbcon.commit() # COMMINT SQL문으로 입력한 데이터를 실제로 적용
            self.num_data = 0 # 다음 테이블에서 사용할 입력한 데이터 수를 위하여 0으로 초기화
        self.cursor.close() # cursor 객체 접속 종료

    def del_all(self): # 데이터 입력이 잘못되었거나 완전히 새로운 데이터를 입력할 경우 테이블와 Sequence를 삭제하는 메서드 정의
        self.cursor = self.dbcon.cursor() # SQL문을 실행할 cursor 객체

        # 리뷰 리스트 테이블과 Sequence 삭제
        # REVIEW_LIST가 외래 키로 PRODUCT_LIST의 product_id를 참조하고 있으므로 정상적인 삭제 프로세스로 REVIEW_LIST를 먼저 삭제해야함
        try: 
            self.cursor.execute("drop table REVIEW_LIST")
            self.cursor.execute("drop sequence SEQ_REVIEW")
            print("리뷰 테이블과 시퀀스를 삭제했습니다.")
        except:
            pass

        try: # PRODUCT_LIST 테이블과 Sequence 삭제
            self.cursor.execute("drop table PRODUCT_LIST")
            self.cursor.execute("drop sequence SEQ_PRODUCT")
            print("상품 테이블과 시퀀스를 삭제했습니다.")
        except:
            pass

        self.cursor.close() # cursor 객체 접속 종료

    def close(self): # DB에 접속한 dbcon을 종료하는 메서드
        try:
            self.dbcon.close()
        except:
            pass

# %%
testing = input_sql()

# %%
testing.create_table()
# Out:
# 테이블 'PRODUCT_LIST'를 생성했습니다.
# 테이블 'REVIEW_LIST'를 생성했습니다.

# %%
testing.input_data(all_list, url_list)
# Out:
# 'REVIEW_LIST' 테이블에 갤럭시 버즈2프로 SM-R510 상품에 대한 843개의 리뷰 데이터를 입력했습니다.
# 'REVIEW_LIST' 테이블에 Apple 2023 에어팟 프로 2세대 USB-C 충전 케이스 모델 (MTJV3KH/A) 상품에 대한 1026개의 리뷰 데이터를 입력했습니다.
# 'REVIEW_LIST' 테이블에 삼성전자 갤럭시 버즈2 SM-R177 상품에 대한 784개의 리뷰 데이터를 입력했습니다.
# 'REVIEW_LIST' 테이블에 갤럭시 버즈2프로 SM-R510 상품에 대한 843개의 리뷰 데이터를 입력했습니다.
# 'REVIEW_LIST' 테이블에 소니 WF-1000XM5(블랙) 상품에 대한 1479개의 리뷰 데이터를 입력했습니다.
# 'REVIEW_LIST' 테이블에 T13 블루투스 이어폰 무선 노이즈 캔슬링 국내AS QCY 상품에 대한 4000개의 리뷰 데이터를 입력했습니다.

# %%
testing.del_all()
# Out:
# 리뷰 테이블과 Sequence를 삭제했습니다.
# 상품 테이블과 Sequence를 삭제했습니다.

# %%
testing.close()
