# %%
import sys
sys.path.append("Y:\Python\Mega_IT")

from yjk_module.preprocessing import *
from yjk_module.ml_module import *

# %%
import warnings
warnings.filterwarnings(action='ignore')

from hossam.util import *
from hossam.plot import *
from hossam.analysis import *
from hossam.classification import *
from hossam.regression import *

from xgboost import XGBRegressor, XGBClassifier, plot_importance, to_graphviz
from lightgbm import LGBMRegressor, LGBMClassifier, plot_importance
from sklearn.model_selection import RandomizedSearchCV

# %%
origin1 = pd.read_excel("./data/pima_indians_diabetes.xlsx")
origin1.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# 정제 대상 필드명
zero_features = ["Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI"]

# 0값을 결측치로 대체후 평균으로 다시 치환
df1 = origin1.copy()
df1[zero_features] = df1[zero_features].replace(0, np.nan)
df1_2 = my_replace_missing_value(df1)

# 결과확인
total_count = len(origin1)

for feature in zero_features:
    zero_count = origin1[origin1[feature] == 0][feature].count()
    print(
        "{0} 0 건수는 {1}, 퍼센트는 {2:.2f} %".format(
            feature, zero_count, 100 * zero_count / total_count
        )
    )

print("---" * 30)

for feature in zero_features:
    zero_count = df1_2[df1_2[feature] == 0][feature].count()
    print(
        "{0} 0 건수는 {1}, 퍼센트는 {2:.2f} %".format(
            feature, zero_count, 100 * zero_count / total_count
        )
    )
# Out:
# Glucose 0 건수는 5, 퍼센트는 0.65 %
# BloodPressure 0 건수는 35, 퍼센트는 4.56 %
# SkinThickness 0 건수는 227, 퍼센트는 29.56 %
# Insulin 0 건수는 374, 퍼센트는 48.70 %
# BMI 0 건수는 11, 퍼센트는 1.43 %
# ------------------------------------------------------------------------------------------
# Glucose 0 건수는 0, 퍼센트는 0.00 %
# BloodPressure 0 건수는 0, 퍼센트는 0.00 %
# SkinThickness 0 건수는 0, 퍼센트는 0.00 %
# Insulin 0 건수는 0, 퍼센트는 0.00 %
# BMI 0 건수는 0, 퍼센트는 0.00 %

# %%
x_train, x_test, y_train, y_test = my_train_test_split(df1_2, "Outcome", scalling=True)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (614, 8) (154, 8) (614,) (154,)

# %%
origin2 = pd.read_excel("./data/boston.xlsx")
origin2.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
x_train2, x_test2, y_train2, y_test2 = my_train_test_split(origin2, "MEDV", scalling=True)
x_train2.shape, x_test2.shape, y_train2.shape, y_test2.shape
# Out:
# ((404, 13), (102, 13), (404,), (102,))

# %%
support = YjkClassifierSupport()
# Out:
# 사용 가능한 모델 : ['LogisticRegression', 'SGDClassifier', 'KNeighborsClassifier', 'LinearSVC', 'SVC', 'GaussianNB', 'DecisionTreeClassifier', 'RandomForestClassifier', 'AdaBoostClassifier', 'GradientBoostingClassifier', 'XGBClassifier', 'LGBMClassifier', 'CatboostClassifier']

# %%
result_df = yjk_classifier_multi_gridsearch(support, x_train, y_train, x_test, y_test)
# Out:
# LogisticRegression 모델 소요 시간 : 0:00:03
# SGDClassifier 모델 소요 시간 : 0:00:00
# KNeighborsClassifier 모델 소요 시간 : 0:00:00
# LinearSVC 모델 소요 시간 : 0:00:00
# SVC 모델 소요 시간 : 0:00:00
# GaussianNB 모델 소요 시간 : 0:00:00
# DecisionTreeClassifier 모델 소요 시간 : 0:00:00
# RandomForestClassifier 모델 소요 시간 : 0:00:12
# AdaBoostClassifier 모델 소요 시간 : 0:00:07
# GradientBoostingClassifier 모델 소요 시간 : 0:00:10
# XGBClassifier 모델 소요 시간 : 0:00:01
# LGBMClassifier 모델 소요 시간 : 0:00:27
# CatboostClassifier 모델 소요 시간 : 0:00:13
# 총 소요 시간 : 0:01:16

# %%
result_df
# Out:
#                                                                    best_model  \
# model_name
# AdaBoostClassifier          (DecisionTreeClassifier(max_depth=7, random_st...
# SGDClassifier               SGDClassifier(alpha=0.1, early_stopping=True, ...
# XGBClassifier               XGBClassifier(base_score=None, booster=None, c...
# CatboostClassifier          <catboost.core.CatBoostClassifier object at 0x...
# LogisticRegression                       LogisticRegression(C=0.1, n_jobs=-1)
# LinearSVC                   LinearSVC(C=0.01, dual=True, loss='hinge', ran...
# LGBMClassifier              LGBMClassifier(colsample_bytree=0.8, learning_...
# KNeighborsClassifier           KNeighborsClassifier(n_jobs=-1, n_neighbors=7)
# SVC                                                 SVC(C=1, kernel='linear')
# GradientBoostingClassifier  ([DecisionTreeRegressor(criterion='friedman_ms...
# GaussianNB                                                       GaussianNB()
# RandomForestClassifier      (DecisionTreeClassifier(max_depth=3, max_featu...
# DecisionTreeClassifier      DecisionTreeClassifier(max_depth=3, min_sample...
#
#                                                                    best_param  \
# model_name
# AdaBoostClassifier                  {'n_estimators': 100, 'learning_rate': 1}
# SGDClassifier               {'tol': 0.0001, 'penalty': 'l2', 'max_iter': 2...
# XGBClassifier               {'subsample': 0.5, 'n_estimators': 100, 'min_c...
# CatboostClassifier                                                         {}
# LogisticRegression               {'penalty': 'l2', 'max_iter': 100, 'C': 0.1}
# LinearSVC                   {'penalty': 'l2', 'max_iter': 1000, 'loss': 'h...
# LGBMClassifier              {'subsample': 0.9, 'num_leaves': 31, 'n_estima...
# KNeighborsClassifier         {'weights': 'uniform', 'p': 2, 'n_neighbors': 7}
# SVC                                 {'kernel': 'linear', 'degree': 3, 'C': 1}
# GradientBoostingClassifier  {'subsample': 0.5, 'n_estimators': 300, 'min_s...
# GaussianNB                                           {'var_smoothing': 1e-09}
# RandomForestClassifier      {'n_estimators': 100, 'min_samples_split': 5, ...
# DecisionTreeClassifier      {'splitter': 'random', 'min_samples_split': 5,...
#
#                             accuracy_train  accuracy_test
# model_name
# AdaBoostClassifier                1.000000       0.824675
# SGDClassifier                     0.758958       0.818182
# XGBClassifier                     0.970684       0.818182
# CatboostClassifier                0.939739       0.811688
# LogisticRegression                0.760586       0.805195
# LinearSVC                         0.762215       0.805195
# LGBMClassifier                    0.962541       0.805195
# KNeighborsClassifier              0.788274       0.798701
# SVC                               0.762215       0.798701
# GradientBoostingClassifier        1.000000       0.798701
# GaussianNB                        0.749186       0.785714
# RandomForestClassifier            0.785016       0.772727
# DecisionTreeClassifier            0.763844       0.746753

# %%
support2 = YjkRegressorSupport()
# Out:
# 사용 가능한 모델 : ['LinearRegressor', 'Ridge', 'Lasso', 'SGDRegressor', 'KneighborsRegressor', 'LinearSVR', 'SVR', 'DecisionTreeRegressor', 'RandomForestRegressor', 'AdaBoostRegressor', 'GradientBoostingRegressor', 'XGBRegressor', 'LGBMRegressor', 'CatBoostRegressor']

# %%
result_df2 = yjk_regressor_multi_gridsearch(support2, x_train2, y_train2, x_test2, y_test2)
# Out:
# LinearRegressor 모델 소요 시간 : 0:00:00
# Ridge 모델 소요 시간 : 0:00:00
# Lasso 모델 소요 시간 : 0:00:00
# SGDRegressor 모델 소요 시간 : 0:00:01
# KneighborsRegressor 모델 소요 시간 : 0:00:00
# LinearSVR 모델 소요 시간 : 0:00:00
# SVR 모델 소요 시간 : 0:00:00
# DecisionTreeRegressor 모델 소요 시간 : 0:00:00
# RandomForestRegressor 모델 소요 시간 : 0:00:06
# AdaBoostRegressor 모델 소요 시간 : 0:00:12
# GradientBoostingRegressor 모델 소요 시간 : 0:00:21
# XGBRegressor 모델 소요 시간 : 0:00:05
# LGBMRegressor 모델 소요 시간 : 0:00:20
# CatBoostRegressor 모델 소요 시간 : 0:00:07
# 총 소요 시간 : 0:01:15

# %%
result_df2
# Out:
#                                                                   best_model  \
# model_name
# DecisionTreeRegressor      DecisionTreeRegressor(criterion='poisson', ran...
# XGBRegressor               XGBRegressor(base_score=None, booster=None, ca...
# LGBMRegressor              LGBMRegressor(colsample_bytree=0.6, max_depth=...
# CatBoostRegressor          <catboost.core.CatBoostRegressor object at 0x0...
# AdaBoostRegressor          (DecisionTreeRegressor(max_depth=7, random_sta...
# GradientBoostingRegressor  ([DecisionTreeRegressor(criterion='friedman_ms...
# SVR                                                      SVR(C=10, degree=5)
# RandomForestRegressor      (DecisionTreeRegressor(max_depth=20, max_featu...
# KneighborsRegressor        KNeighborsRegressor(n_jobs=-1, n_neighbors=3, ...
# LinearRegressor                                  LinearRegression(n_jobs=-1)
# LinearSVR                  LinearSVR(C=1, dual=True, loss='squared_epsilo...
# Lasso                                                      Lasso(alpha=0.01)
# SGDRegressor               SGDRegressor(alpha=0.01, early_stopping=True, ...
# Ridge                                                        Ridge(alpha=10)
#
#                                                                   best_param  \
# model_name
# DecisionTreeRegressor      {'splitter': 'best', 'min_samples_split': 2, '...
# XGBRegressor               {'subsample': 0.75, 'n_estimators': 100, 'min_...
# LGBMRegressor              {'subsample': 0.8, 'num_leaves': 31, 'n_estima...
# CatBoostRegressor                                                         {}
# AdaBoostRegressor          {'n_estimators': 100, 'loss': 'square', 'learn...
# GradientBoostingRegressor  {'subsample': 0.5, 'n_estimators': 300, 'min_s...
# SVR                                  {'kernel': 'rbf', 'degree': 5, 'C': 10}
# RandomForestRegressor      {'min_samples_split': 2, 'min_samples_leaf': 1...
# KneighborsRegressor        {'weights': 'distance', 'p': 1, 'n_neighbors': 3}
# LinearRegressor                                                           {}
# LinearSVR                  {'max_iter': 1000, 'loss': 'squared_epsilon_in...
# Lasso                                                        {'alpha': 0.01}
# SGDRegressor               {'tol': 0.0001, 'penalty': None, 'max_iter': 3...
# Ridge                                                          {'alpha': 10}
#
#                            rmse_train  rmse_test
# model_name
# DecisionTreeRegressor        0.000000   3.963139
# XGBRegressor                 0.424113   4.329904
# LGBMRegressor                0.525707   4.767109
# CatBoostRegressor            0.449500   4.836556
# AdaBoostRegressor            1.162818   4.947240
# GradientBoostingRegressor    0.278344   4.964475
# SVR                          2.703572   5.089660
# RandomForestRegressor        1.135889   5.233229
# KneighborsRegressor          0.000000   5.688329
# LinearRegressor              4.396188   5.783509
# LinearSVR                    4.396315   5.788375
# Lasso                        4.396748   5.795788
# SGDRegressor                 4.454093   5.826158
# Ridge                        4.405748   5.853897

# %%
yjk_classification_vs_ensemble(result_df, x_train, y_train, x_test, y_test)
# Out:
#                                                    estimator  accuracy_train  \
# Solo_Best  (DecisionTreeClassifier(max_depth=7, random_st...        1.000000
# Bagging    ((DecisionTreeClassifier(max_depth=7, random_s...        1.000000
# Voting     VotingClassifier(estimators=[('AdaBoostClassif...        0.853420
# Stacking   StackingClassifier(cv=5,\n                   e...        0.822476
# Boosting   ((DecisionTreeClassifier(max_depth=7, random_s...        1.000000
#
#            accuracy_test
# Solo_Best       0.824675
# Bagging         0.818182
# Voting          0.805195
# Stacking        0.785714
# Boosting        0.785714

# %%
models = ['DecisionTreeRegressor', 'XGBRegressor', 'LGBMRegressor']

# %%
yjk_regression_vs_ensemble(result_df2, x_train2, y_train2, x_test2, y_test2, include_models = models)
# Out:
#                                                    estimator  rmse_train  \
# Voting     VotingRegressor(estimators=[('DecisionTreeRegr...    0.281609
# Solo_Best  DecisionTreeRegressor(criterion='poisson', ran...    0.000000
# Bagging    (DecisionTreeRegressor(criterion='poisson', ra...    1.175386
# Stacking   StackingRegressor(cv=5,\n                  est...    1.124618
# Boosting   (DecisionTreeRegressor(criterion='poisson', ra...    0.197007
#
#            rmse_test
# Voting      3.774158
# Solo_Best   3.963139
# Bagging     4.417386
# Stacking    4.457313
# Boosting    4.685386
