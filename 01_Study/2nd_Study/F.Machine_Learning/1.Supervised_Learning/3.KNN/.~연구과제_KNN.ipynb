# %%
import sys
sys.path.append("Y:\Python\Mega_IT")

from yjk_module.preprocessing import *
from yjk_module.ml_module import *

# %%
from sklearn.neighbors import KNeighborsClassifier
from hossam.util import *
from hossam.plot import *
from hossam.analysis import *
from hossam.classification import *

# %% [markdown]
# - 위스콘신 유방암

# %%
origin1 = my_read_excel("./data/breast-cancer-wisconsin.xlsx", index_col="id", categories=["diagnosis"])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 569 entries, 842302 to 92751
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    category
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
#  13  perimeter_se             569 non-null    float64
#  14  area_se                  569 non-null    float64
#  15  smoothness_se            569 non-null    float64
#  16  compactness_se           569 non-null    float64
#  17  concavity_se             569 non-null    float64
#  18  concave points_se        569 non-null    float64
#  19  symmetry_se              569 non-null    float64
#  20  fractal_dimension_se     569 non-null    float64
#  21  radius_worst             569 non-null    float64
#  22  texture_worst            569 non-null    float64
#  23  perimeter_worst          569 non-null    float64
#  24  area_worst               569 non-null    float64
#  25  smoothness_worst         569 non-null    float64
#  26  compactness_worst        569 non-null    float64
#  27  concavity_worst          569 non-null    float64
#  28  concave points_worst     569 non-null    float64
#  29  symmetry_worst           569 non-null    float64
#  30  fractal_dimension_worst  569 non-null    float64
# dtypes: category(1), float64(30)
# memory usage: 138.5 KB
# None
#
# 데이터프레임 상위 5개 행
# +----------+-------------+---------------+----------------+------------------+-------------+-------------------+--------------------+------------------+-----------------------+-----------------+--------------------------+-------------+--------------+----------------+-----------+-----------------+------------------+----------------+---------------------+---------------+------------------------+----------------+-----------------+-------------------+--------------+--------------------+---------------------+-------------------+------------------------+------------------+---------------------------+
# |       id | diagnosis   |   radius_mean |   texture_mean |   perimeter_mean |   area_mean |   smoothness_mean |   compactness_mean |   concavity_mean |   concave points_mean |   symmetry_mean |   fractal_dimension_mean |   radius_se |   texture_se |   perimeter_se |   area_se |   smoothness_se |   compactness_se |   concavity_se |   concave points_se |   symmetry_se |   fractal_dimension_se |   radius_worst |   texture_worst |   perimeter_worst |   area_worst |   smoothness_worst |   compactness_worst |   concavity_worst |   concave points_worst |   symmetry_worst |   fractal_dimension_worst |
# |----------+-------------+---------------+----------------+------------------+-------------+-------------------+--------------------+------------------+-----------------------+-----------------+--------------------------+-------------+--------------+----------------+-----------+-----------------+------------------+----------------+---------------------+---------------+------------------------+----------------+-----------------+-------------------+--------------+--------------------+---------------------+-------------------+------------------------+------------------+---------------------------|
# |   842302 | M           |         17.99 |          10.38 |            122.8 |        1001 |            0.1184 |             0.2776 |           0.3001 |                0.1471 |          0.2419 |                  0.07871 |       1.095 |       0.9053 |          8.589 |     153.4 |        0.006399 |          0.04904 |        0.05373 |             0.01587 |       0.03003 |               0.006193 |          25.38 |           17.33 |             184.6 |         2019 |             0.1622 |              0.6656 |            0.7119 |                 0.2654 |           0.4601 |                    0.1189 |
# |   842517 | M           |         20.57 |          17.77 |            132.9 |        1326 |           0.08474 |            0.07864 |           0.0869 |               0.07017 |          0.1812 |                  0.05667 |      0.5435 |       0.7339 |          3.398 |     74.08 |        0.005225 |          0.01308 |         0.0186 |              0.0134 |       0.01389 |               0.003532 |          24.99 |           23.41 |             158.8 |         1956 |             0.1238 |              0.1866 |            0.2416 |                  0.186 |            0.275 |                   0.08902 |
# | 84300903 | M           |         19.69 |          21.25 |              130 |        1203 |            0.1096 |             0.1599 |           0.1974 |                0.1279 |          0.2069 |                  0.05999 |      0.7456 |       0.7869 |          4.585 |     94.03 |         0.00615 |          0.04006 |        0.03832 |             0.02058 |        0.0225 |               0.004571 |          23.57 |           25.53 |             152.5 |         1709 |             0.1444 |              0.4245 |            0.4504 |                  0.243 |           0.3613 |                   0.08758 |
# | 84348301 | M           |         11.42 |          20.38 |            77.58 |       386.1 |            0.1425 |             0.2839 |           0.2414 |                0.1052 |          0.2597 |                  0.09744 |      0.4956 |        1.156 |          3.445 |     27.23 |         0.00911 |          0.07458 |        0.05661 |             0.01867 |       0.05963 |               0.009208 |          14.91 |            26.5 |             98.87 |        567.7 |             0.2098 |              0.8663 |            0.6869 |                 0.2575 |           0.6638 |                     0.173 |
# | 84358402 | M           |         20.29 |          14.34 |            135.1 |        1297 |            0.1003 |             0.1328 |            0.198 |                0.1043 |          0.1809 |                  0.05883 |      0.7572 |       0.7813 |          5.438 |     94.44 |         0.01149 |          0.02461 |        0.05688 |             0.01885 |       0.01756 |               0.005115 |          22.54 |           16.67 |             152.2 |         1575 |             0.1374 |               0.205 |               0.4 |                 0.1625 |           0.2364 |                   0.07678 |
# +----------+-------------+---------------+----------------+------------------+-------------+-------------------+--------------------+------------------+-----------------------+-----------------+--------------------------+-------------+--------------+----------------+-----------+-----------------+------------------+----------------+---------------------+---------------+------------------------+----------------+-----------------+-------------------+--------------+--------------------+---------------------+-------------------+------------------------+------------------+---------------------------+
#
# 데이터프레임 하위 5개 행
# +--------+-------------+---------------+----------------+------------------+-------------+-------------------+--------------------+------------------+-----------------------+-----------------+--------------------------+-------------+--------------+----------------+-----------+-----------------+------------------+----------------+---------------------+---------------+------------------------+----------------+-----------------+-------------------+--------------+--------------------+---------------------+-------------------+------------------------+------------------+---------------------------+
# |     id | diagnosis   |   radius_mean |   texture_mean |   perimeter_mean |   area_mean |   smoothness_mean |   compactness_mean |   concavity_mean |   concave points_mean |   symmetry_mean |   fractal_dimension_mean |   radius_se |   texture_se |   perimeter_se |   area_se |   smoothness_se |   compactness_se |   concavity_se |   concave points_se |   symmetry_se |   fractal_dimension_se |   radius_worst |   texture_worst |   perimeter_worst |   area_worst |   smoothness_worst |   compactness_worst |   concavity_worst |   concave points_worst |   symmetry_worst |   fractal_dimension_worst |
# |--------+-------------+---------------+----------------+------------------+-------------+-------------------+--------------------+------------------+-----------------------+-----------------+--------------------------+-------------+--------------+----------------+-----------+-----------------+------------------+----------------+---------------------+---------------+------------------------+----------------+-----------------+-------------------+--------------+--------------------+---------------------+-------------------+------------------------+------------------+---------------------------|
# | 926424 | M           |         21.56 |          22.39 |              142 |        1479 |             0.111 |             0.1159 |           0.2439 |                0.1389 |          0.1726 |                  0.05623 |       1.176 |        1.256 |          7.673 |     158.7 |          0.0103 |          0.02891 |        0.05198 |             0.02454 |       0.01114 |               0.004239 |          25.45 |            26.4 |             166.1 |         2027 |              0.141 |              0.2113 |            0.4107 |                 0.2216 |            0.206 |                   0.07115 |
# | 926682 | M           |         20.13 |          28.25 |            131.2 |        1261 |            0.0978 |             0.1034 |            0.144 |               0.09791 |          0.1752 |                  0.05533 |      0.7655 |        2.463 |          5.203 |     99.04 |        0.005769 |          0.02423 |         0.0395 |             0.01678 |       0.01898 |               0.002498 |          23.69 |           38.25 |               155 |         1731 |             0.1166 |              0.1922 |            0.3215 |                 0.1628 |           0.2572 |                   0.06637 |
# | 926954 | M           |          16.6 |          28.08 |            108.3 |       858.1 |           0.08455 |             0.1023 |          0.09251 |               0.05302 |           0.159 |                  0.05648 |      0.4564 |        1.075 |          3.425 |     48.55 |        0.005903 |          0.03731 |         0.0473 |             0.01557 |       0.01318 |               0.003892 |          18.98 |           34.12 |             126.7 |         1124 |             0.1139 |              0.3094 |            0.3403 |                 0.1418 |           0.2218 |                    0.0782 |
# | 927241 | M           |          20.6 |          29.33 |            140.1 |        1265 |            0.1178 |              0.277 |           0.3514 |                 0.152 |          0.2397 |                  0.07016 |       0.726 |        1.595 |          5.772 |     86.22 |        0.006522 |          0.06158 |        0.07117 |             0.01664 |       0.02324 |               0.006185 |          25.74 |           39.42 |             184.6 |         1821 |              0.165 |              0.8681 |            0.9387 |                  0.265 |           0.4087 |                     0.124 |
# |  92751 | B           |          7.76 |          24.54 |            47.92 |         181 |           0.05263 |            0.04362 |                0 |                     0 |          0.1587 |                  0.05884 |      0.3857 |        1.428 |          2.548 |     19.15 |        0.007189 |          0.00466 |              0 |                   0 |       0.02676 |               0.002783 |          9.456 |           30.37 |             59.16 |        268.6 |            0.08996 |             0.06444 |                 0 |                      0 |           0.2871 |                   0.07039 |
# +--------+-------------+---------------+----------------+------------------+-------------+-------------------+--------------------+------------------+-----------------------+-----------------+--------------------------+-------------+--------------+----------------+-----------+-----------------+------------------+----------------+---------------------+---------------+------------------------+----------------+-----------------+-------------------+--------------+--------------------+---------------------+-------------------+------------------------+------------------+---------------------------+
#
# 기술통계
# +-------------------------+---------+------------+------------+-----------+----------+----------+----------+---------+-------+
# |                         |   count |       mean |        std |       min |      25% |      50% |      75% |     max |   nan |
# |-------------------------+---------+------------+------------+-----------+----------+----------+----------+---------+-------|
# | radius_mean             |     569 |    14.1273 |    3.52405 |     6.981 |     11.7 |    13.37 |    15.78 |   28.11 |     0 |
# | texture_mean            |     569 |    19.2896 |    4.30104 |      9.71 |    16.17 |    18.84 |     21.8 |   39.28 |     0 |
# | perimeter_mean          |     569 |     91.969 |     24.299 |     43.79 |    75.17 |    86.24 |    104.1 |   188.5 |     0 |
# | area_mean               |     569 |    654.889 |    351.914 |     143.5 |    420.3 |    551.1 |    782.7 |    2501 |     0 |
# | smoothness_mean         |     569 |  0.0963603 |  0.0140641 |   0.05263 |  0.08637 |  0.09587 |   0.1053 |  0.1634 |     0 |
# | compactness_mean        |     569 |   0.104341 |  0.0528128 |   0.01938 |  0.06492 |  0.09263 |   0.1304 |  0.3454 |     0 |
# | concavity_mean          |     569 |  0.0887993 |  0.0797198 |         0 |  0.02956 |  0.06154 |   0.1307 |  0.4268 |     0 |
# | concave points_mean     |     569 |  0.0489191 |  0.0388028 |         0 |  0.02031 |   0.0335 |    0.074 |  0.2012 |     0 |
# | symmetry_mean           |     569 |   0.181162 |  0.0274143 |     0.106 |   0.1619 |   0.1792 |   0.1957 |   0.304 |     0 |
# | fractal_dimension_mean  |     569 |  0.0627976 | 0.00706036 |   0.04996 |   0.0577 |  0.06154 |  0.06612 | 0.09744 |     0 |
# | radius_se               |     569 |   0.405172 |   0.277313 |    0.1115 |   0.2324 |   0.3242 |   0.4789 |   2.873 |     0 |
# | texture_se              |     569 |    1.21685 |   0.551648 |    0.3602 |   0.8339 |    1.108 |    1.474 |   4.885 |     0 |
# | perimeter_se            |     569 |    2.86606 |    2.02185 |     0.757 |    1.606 |    2.287 |    3.357 |   21.98 |     0 |
# | area_se                 |     569 |    40.3371 |     45.491 |     6.802 |    17.85 |    24.53 |    45.19 |   542.2 |     0 |
# | smoothness_se           |     569 | 0.00704098 | 0.00300252 |  0.001713 | 0.005169 |  0.00638 | 0.008146 | 0.03113 |     0 |
# | compactness_se          |     569 |  0.0254781 |  0.0179082 |  0.002252 |  0.01308 |  0.02045 |  0.03245 |  0.1354 |     0 |
# | concavity_se            |     569 |  0.0318937 |  0.0301861 |         0 |  0.01509 |  0.02589 |  0.04205 |   0.396 |     0 |
# | concave points_se       |     569 |  0.0117961 | 0.00617029 |         0 | 0.007638 |  0.01093 |  0.01471 | 0.05279 |     0 |
# | symmetry_se             |     569 |  0.0205423 | 0.00826637 |  0.007882 |  0.01516 |  0.01873 |  0.02348 | 0.07895 |     0 |
# | fractal_dimension_se    |     569 |  0.0037949 | 0.00264607 | 0.0008948 | 0.002248 | 0.003187 | 0.004558 | 0.02984 |     0 |
# | radius_worst            |     569 |    16.2692 |    4.83324 |      7.93 |    13.01 |    14.97 |    18.79 |   36.04 |     0 |
# | texture_worst           |     569 |    25.6772 |    6.14626 |     12.02 |    21.08 |    25.41 |    29.72 |   49.54 |     0 |
# | perimeter_worst         |     569 |    107.261 |    33.6025 |     50.41 |    84.11 |    97.66 |    125.4 |   251.2 |     0 |
# | area_worst              |     569 |    880.583 |    569.357 |     185.2 |    515.3 |    686.5 |     1084 |    4254 |     0 |
# | smoothness_worst        |     569 |   0.132369 |  0.0228324 |   0.07117 |   0.1166 |   0.1313 |    0.146 |  0.2226 |     0 |
# | compactness_worst       |     569 |   0.254265 |   0.157336 |   0.02729 |   0.1472 |   0.2119 |   0.3391 |   1.058 |     0 |
# | concavity_worst         |     569 |   0.272188 |   0.208624 |         0 |   0.1145 |   0.2267 |   0.3829 |   1.252 |     0 |
# | concave points_worst    |     569 |   0.114606 |  0.0657323 |         0 |  0.06493 |  0.09993 |   0.1614 |   0.291 |     0 |
# | symmetry_worst          |     569 |   0.290076 |  0.0618675 |    0.1565 |   0.2504 |   0.2822 |   0.3179 |  0.6638 |     0 |
# | fractal_dimension_worst |     569 |  0.0839458 |  0.0180613 |   0.05504 |  0.07146 |  0.08004 |  0.09208 |  0.2075 |     0 |
# +-------------------------+---------+------------+------------+-----------+----------+----------+----------+---------+-------+
#
# 카테고리 정보
# +-------------+---------+
# | diagnosis   |   count |
# |-------------+---------|
# | B           |     357 |
# | M           |     212 |
# +-------------+---------+

# %%
df1 = my_standard_scaler(origin1, 'diagnosis')
df1_2 = my_labelling(df1, 'diagnosis')

# %%
x_train, x_test, y_train, y_test = my_train_test_split(df1_2, 'diagnosis')

# %%
my_logistic_classification(x_train, y_train, x_test, y_test)
# Out:
# [교차검증]
# +----+-------+------------+-----------+-------------------+
# |    |     C |   max_iter | penalty   |   mean_test_score |
# |----+-------+------------+-----------+-------------------|
# |  7 |   0.1 |        500 | l2        |          0.978022 |
# | 10 |     1 |        500 | l2        |          0.978022 |
# | 13 |    10 |        500 | l2        |          0.971429 |
# | 16 |   100 |        500 | l2        |          0.967033 |
# |  4 |  0.01 |        500 | l2        |          0.945055 |
# |  1 | 0.001 |        500 | l2        |          0.883516 |
# +----+-------+------------+-----------+-------------------+
#
# [분류분석 성능평가]
# +-------------------------+--------------+--------------+-----------------------------------------------------------+
# |                         |   훈련데이터 |   검증데이터 | 설명                                                      |
# |-------------------------+--------------+--------------+-----------------------------------------------------------|
# | 의사결정계수(Pseudo R2) |     0.869719 |     0.859307 | 로지스틱회귀의 성능 측정 지표로, 1에 가까울수록 좋은 모델 |
# | 정확도(Accuracy)        |     0.982418 |     0.982456 | 예측 결과(TN,FP,TP,TN)가 실제 결과(TP,TN)와 일치하는 정도 |
# | 정밀도(Precision)       |     0.993939 |            1 | 양성으로 예측한 결과(TP,FP) 중 실제 양성(TP)인 비율       |
# | 재현율(Recall)          |     0.959064 |      0.95122 | 실제 양성(TP,FN) 중 양성(TP)으로 예측한 비율              |
# | 위양성율(Fallout)       |   0.00352113 |            0 | 실제 음성(FP,TN) 중 양성(FP)으로 잘못 예측한 비율         |
# | 특이성(TNR)             |     0.996479 |            1 | 실제 음성(FP,TN) 중 음성(TN)으로 정확히 예측한 비율       |
# | F1 Score                |      0.97619 |        0.975 | 정밀도와 재현율의 조화평균                                |
# | AUC                     |     0.997467 |     0.990311 | ROC Curve의 밑면적으로, 1에 가까울수록 좋은 모델          |
# +-------------------------+--------------+--------------+-----------------------------------------------------------+
#
# [혼동행렬]
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# [Roc Curve]
# [학습곡선]
# +----+------------+-------------------------+--------------------+------------+---------+------------+---------+------------+
# |    | 종속변수   | 독립변수                |   B(비표준화 계수) |   표준오차 |       t |   유의확률 |     VIF |   OddsRate |
# |----+------------+-------------------------+--------------------+------------+---------+------------+---------+------------|
# |  0 | diagnosis  | radius_mean             |             0.3976 |     74.092 |  0.0054 |      0.996 | 7154.91 |     1.4883 |
# |  1 | diagnosis  | texture_mean            |             0.4098 |      3.177 |   0.129 |      0.897 | 10.9017 |     1.5066 |
# |  2 | diagnosis  | perimeter_mean          |             0.3861 |     73.769 |  0.0052 |      0.996 | 8652.28 |     1.4712 |
# |  3 | diagnosis  | area_mean               |             0.3794 |      29.39 |  0.0129 |       0.99 | 710.047 |     1.4614 |
# |  4 | diagnosis  | smoothness_mean         |             0.1662 |      3.064 |  0.0542 |      0.957 | 13.9662 |     1.1808 |
# |  5 | diagnosis  | compactness_mean        |              0.034 |      7.844 |  0.0043 |      0.997 | 69.6279 |     1.0346 |
# |  6 | diagnosis  | concavity_mean          |             0.3587 |      8.321 |  0.0431 |      0.966 | 137.153 |     1.4315 |
# |  7 | diagnosis  | concave points_mean     |             0.4323 |      6.887 |  0.0628 |       0.95 |   101.3 |     1.5409 |
# |  8 | diagnosis  | symmetry_mean           |             0.1105 |      1.484 |  0.0745 |      0.941 | 3.99262 |     1.1168 |
# |  9 | diagnosis  | fractal_dimension_mean  |            -0.2322 |      3.767 | -0.0616 |      0.951 | 14.6266 |     0.7928 |
# | 10 | diagnosis  | radius_se               |             0.4252 |     15.492 |  0.0274 |      0.978 | 280.125 |     1.5299 |
# | 11 | diagnosis  | texture_se              |            -0.0725 |      2.832 | -0.0256 |       0.98 | 4.87224 |     0.9301 |
# | 12 | diagnosis  | perimeter_se            |             0.3075 |       13.5 |  0.0228 |      0.982 |   381.6 |       1.36 |
# | 13 | diagnosis  | area_se                 |             0.3564 |     18.529 |  0.0192 |      0.985 | 113.958 |     1.4282 |
# | 14 | diagnosis  | smoothness_se           |              0.079 |      2.274 |  0.0347 |      0.972 | 8.48963 |     1.0822 |
# | 15 | diagnosis  | compactness_se          |            -0.2354 |     11.079 | -0.0212 |      0.983 | 48.8702 |     0.7903 |
# | 16 | diagnosis  | concavity_se            |            -0.0305 |      8.211 | -0.0037 |      0.997 | 38.3895 |       0.97 |
# | 17 | diagnosis  | concave points_se       |             0.1036 |      4.907 |  0.0211 |      0.983 | 32.7898 |     1.1092 |
# | 18 | diagnosis  | symmetry_se             |            -0.1516 |      3.055 | -0.0496 |       0.96 | 8.56692 |     0.8593 |
# | 19 | diagnosis  | fractal_dimension_se    |            -0.2489 |      7.044 | -0.0353 |      0.972 | 25.1579 |     0.7797 |
# | 20 | diagnosis  | radius_worst            |              0.503 |     33.852 |  0.0149 |      0.988 | 989.505 |     1.6537 |
# | 21 | diagnosis  | texture_worst           |             0.5906 |      4.061 |  0.1455 |      0.884 | 14.5422 |     1.8051 |
# | 22 | diagnosis  | perimeter_worst         |             0.4571 |     23.272 |  0.0196 |      0.984 | 836.304 |     1.5795 |
# | 23 | diagnosis  | area_worst              |             0.4498 |      30.74 |  0.0146 |      0.988 | 443.129 |      1.568 |
# | 24 | diagnosis  | smoothness_worst        |             0.4177 |      3.149 |  0.1326 |      0.894 | 17.9739 |     1.5184 |
# | 25 | diagnosis  | compactness_worst       |             0.1411 |     10.081 |   0.014 |      0.989 | 89.7201 |     1.1515 |
# | 26 | diagnosis  | concavity_worst         |             0.4009 |      7.779 |  0.0515 |      0.959 | 97.1002 |     1.4931 |
# | 27 | diagnosis  | concave points_worst    |             0.5004 |       5.18 |  0.0966 |      0.923 | 65.8185 |     1.6494 |
# | 28 | diagnosis  | symmetry_worst          |             0.3938 |      2.823 |  0.1395 |      0.889 | 10.6323 |     1.4826 |
# | 29 | diagnosis  | fractal_dimension_worst |             0.1085 |      5.932 |  0.0183 |      0.985 | 52.9215 |     1.1146 |
# +----+------------+-------------------------+--------------------+------------+---------+------------+---------+------------+
# LogisticRegression(C=0.1, max_iter=500, n_jobs=-1)

# %%
my_knn_classification(x_train, y_train, x_test, y_test)
# Out:
# [교차검증]
# +----+-----------+---------------+-----------+-------------------+
# |    | metric    |   n_neighbors | weights   |   mean_test_score |
# |----+-----------+---------------+-----------+-------------------|
# |  6 | manhattan |             3 | uniform   |           0.96044 |
# |  7 | manhattan |             3 | distance  |           0.96044 |
# |  4 | euclidean |             7 | uniform   |          0.958242 |
# |  0 | euclidean |             3 | uniform   |          0.956044 |
# |  1 | euclidean |             3 | distance  |          0.956044 |
# |  5 | euclidean |             7 | distance  |          0.956044 |
# |  2 | euclidean |             5 | uniform   |          0.953846 |
# |  3 | euclidean |             5 | distance  |          0.953846 |
# | 10 | manhattan |             7 | uniform   |          0.953846 |
# | 11 | manhattan |             7 | distance  |          0.953846 |
# |  8 | manhattan |             5 | uniform   |          0.951648 |
# |  9 | manhattan |             5 | distance  |          0.951648 |
# +----+-----------+---------------+-----------+-------------------+
#
# [분류분석 성능평가]
# +-------------------+--------------+--------------+-----------------------------------------------------------+
# |                   |   훈련데이터 |   검증데이터 | 설명                                                      |
# |-------------------+--------------+--------------+-----------------------------------------------------------|
# | 정확도(Accuracy)  |      0.98022 |     0.982456 | 예측 결과(TN,FP,TP,TN)가 실제 결과(TP,TN)와 일치하는 정도 |
# | 정밀도(Precision) |     0.993902 |      0.97561 | 양성으로 예측한 결과(TP,FP) 중 실제 양성(TP)인 비율       |
# | 재현율(Recall)    |     0.953216 |      0.97561 | 실제 양성(TP,FN) 중 양성(TP)으로 예측한 비율              |
# | 위양성율(Fallout) |   0.00352113 |    0.0136986 | 실제 음성(FP,TN) 중 양성(FP)으로 잘못 예측한 비율         |
# | 특이성(TNR)       |     0.996479 |     0.986301 | 실제 음성(FP,TN) 중 음성(TN)으로 정확히 예측한 비율       |
# | F1 Score          |     0.973134 |      0.97561 | 정밀도와 재현율의 조화평균                                |
# | AUC               |     0.998476 |     0.986635 | ROC Curve의 밑면적으로, 1에 가까울수록 좋은 모델          |
# +-------------------+--------------+--------------+-----------------------------------------------------------+
#
# [혼동행렬]
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# [Roc Curve]
# [학습곡선]
# KNeighborsClassifier(metric='manhattan', n_jobs=-1, n_neighbors=3)

# %% [markdown]
# - 두 모델의 성능이 비슷함

# %%
support = YjkClassifierSupport()
# Out:
# 사용 가능한 모델 : ['LogisticRegression', 'SGDClassifier', 'KNeighborsClassifier']

# %%
# %%time

result_df = yjk_classifier_multi_gridsearch(support, x_train, x_test, y_train, y_test, randomized_search = False,
                                           models = None)
result_df
# Out:
# CPU times: total: 45.5 s
# Wall time: 39.2 s
#                                                              best_model  \
# model_name
# LogisticRegression                 LogisticRegression(C=0.1, n_jobs=-1)
# SGDClassifier         SGDClassifier(alpha=0.01, loss='log_loss', max...
# KNeighborsClassifier     KNeighborsClassifier(n_jobs=-1, n_neighbors=7)
#
#                                                              best_param  \
# model_name
# LogisticRegression         {'C': 0.1, 'max_iter': 100, 'penalty': 'l2'}
# SGDClassifier         {'alpha': 0.01, 'loss': 'log_loss', 'max_iter'...
# KNeighborsClassifier   {'n_neighbors': 7, 'p': 2, 'weights': 'uniform'}
#
#                       accuracy_train  accuracy_test
# model_name
# LogisticRegression          0.978019       0.982456
# SGDClassifier               0.980193       0.982456
# KNeighborsClassifier        0.962657       0.973684

# %%
origin2 = my_read_excel("./data/titanic.xlsx", index_col='PassengerId', categories=['Survived', 'Pclass', 'Sex', 'Embarked'], info=False)
df2 = origin2.copy()

# %%
mean_age_df = df2[['Survived','Age']].groupby('Survived').mean()
mean_age_df
# Out:
#                 Age
# Survived
# 0         30.510986
# 1         28.931079

# %%
for i in mean_age_df.index:
    mean_age = round(mean_age_df.loc[i]['Age'], 0)
    #print(mean_age)

    expr = (df2['Survived'] == i) & (df2['Age'].isna())
    df2.loc[expr, 'Age'] = df2.loc[expr, 'Age'].fillna(mean_age)

df2['Age'].isna().sum()
# Out:
# 0

# %%
def set_xticks(ax):
    global df2
    min = int(df2['Age'].min())
    max = int(df2['Age'].max())

    x = list(range(min, max+1, 2))
    ax.set_xticks(x)
    ax.set_xticklabels(x)
    ax.set_xlim(min, max)

# %%
my_kdeplot(df2, 'Age', hue='Survived', dpi=100, callback=set_xticks)

# %%
hist, bins = np.histogram(df2['Age'], bins=5)
print(hist)
print(np.round(bins, 0))
# Out:
# [134 787 269 106  13]
# [ 0. 16. 32. 48. 64. 80.]

# %%
df2_2 = df2.copy()
df2_2.loc[ df2_2['Age'] <= 16, "Age"] = 0
df2_2.loc[ (df2_2['Age'] > 16) & (df2_2['Age'] <= 32), "Age"] = 1
df2_2.loc[ (df2_2['Age'] > 32) & (df2_2['Age'] <= 48), "Age"] = 2
df2_2.loc[ (df2_2['Age'] > 48) & (df2_2['Age'] <= 64), "Age"] = 3
df2_2.loc[ df2_2['Age'] > 64, "Age"] = 4

# %%
# 데이터 타입이 float라 함은 해당 값이 결측치라는 의미 --> 객실이 없다는 뜻
df2_2['Has_Cabin'] = df2_2['Cabin'].apply(lambda x:  0 if type(x) == float else 1)
df2_2['Has_Cabin'].value_counts()
# Out:
# Has_Cabin
# 0    1014
# 1     295
# Name: count, dtype: int64

# %%
df2_2['FamilySize'] = df2_2['SibSp'] + df2_2['Parch'] + 1

# %%
df2_2['IsAlone'] = 0
df2_2.loc[df2_2['FamilySize'] == 1, 'IsAlone'] = 1

# %%
most_embarked_df = df2_2[['Survived','Embarked']].groupby('Survived').agg(Series.mode)
most_embarked_df
# Out:
#          Embarked
# Survived
# 0               S
# 1               S

# %%
for i in most_embarked_df.index:
    most = most_embarked_df.loc[i]['Embarked']
    #print(most)

    expr = (df2_2['Survived'] == i) & (df2_2['Embarked'].isna())
    #print(expr)

    df2_2.loc[expr, 'Embarked'] = df2_2.loc[expr, 'Embarked'].fillna(most)

df2_2['Embarked'].isna().sum()
# Out:
# 0

# %%
mean_fare_df = df2_2[['Survived','Fare']].groupby('Survived').mean()
mean_fare_df
# Out:
#                Fare
# Survived
# 0         23.879124
# 1         48.811497

# %%
for i in mean_fare_df.index:
    mean_fare = mean_fare_df.loc[i]['Fare']
    #print(mean_fare)

    expr = (df2_2['Survived'] == i) & (df2_2['Fare'].isna())
    #print(expr)

    df2_2.loc[expr, 'Fare'] = df2_2.loc[expr, 'Fare'].fillna(mean_fare)

df2_2['Fare'].isna().sum()
# Out:
# 0

# %%
import re

# %%
def get_title(name):
    title_search = re.search(' ([A-Za-z]+)\.', name)
    
    if title_search:
        return title_search.group(1)
    
    return ""

# %%
df2_2['Title'] = df2_2['Name'].apply(get_title)
df2_2['Title'].value_counts()
# Out:
# Title
# Mr          757
# Miss        260
# Mrs         197
# Master       61
# Rev           8
# Dr            8
# Col           4
# Mlle          2
# Major         2
# Ms            2
# Lady          1
# Sir           1
# Mme           1
# Don           1
# Capt          1
# Countess      1
# Jonkheer      1
# Dona          1
# Name: count, dtype: int64

# %%
df2_2['Title'] = df2_2['Title'].replace(['Rev', 'Dr', 
                'Mlle', 'Major', 'Col', 'Countess', 'Capt', 'Ms', 
                'Sir', 'Lady', 'Mme', 'Don', 'Jonkheer', 'Dona'], "Rare")

df2_2['Title'].value_counts()
# Out:
# Title
# Mr        757
# Miss      260
# Mrs       197
# Master     61
# Rare       34
# Name: count, dtype: int64

# %%
df2_3 = my_labelling(df2_2, 'Title', 'Embarked', 'Sex')

# %%
df2_3.loc[ df2_3['Fare'] <= 7.9, "Fare"] = 0
df2_3.loc[ (df2_2['Fare'] > 7.9) & (df2_3['Fare'] <= 14.5), "Fare"] = 1
df2_3.loc[ (df2_3['Fare'] > 14.5) & (df2_3['Fare'] <= 31.3), "Fare"] = 2
df2_3.loc[ df2_3['Fare'] > 31.3, "Fare"] = 3

# %%
drop_elements = ['Name', 'Ticket', 'Cabin', 'SibSp', 'Parch']
df2_4 = df2_3.drop(drop_elements, axis = 1)

# %%
df2_4['Survived'] = df2_4['Survived'].astype('int')
x_train, x_test, y_train, y_test = my_train_test_split(df2_4, yname='Survived')

# %%
logi_m = my_logistic_classification(x_train, y_train, x_test, y_test)
# Out:
# [교차검증]
# +----+-------+------------+-----------+-------------------+
# |    |     C |   max_iter | penalty   |   mean_test_score |
# |----+-------+------------+-----------+-------------------|
# | 10 |     1 |        500 | l2        |          0.852896 |
# | 13 |    10 |        500 | l2        |          0.852896 |
# | 16 |   100 |        500 | l2        |          0.852896 |
# |  7 |   0.1 |        500 | l2        |           0.84812 |
# |  4 |  0.01 |        500 | l2        |          0.780314 |
# |  1 | 0.001 |        500 | l2        |           0.62273 |
# +----+-------+------------+-----------+-------------------+
#
# [분류분석 성능평가]
# +-------------------------+--------------+--------------+-----------------------------------------------------------+
# |                         |   훈련데이터 |   검증데이터 | 설명                                                      |
# |-------------------------+--------------+--------------+-----------------------------------------------------------|
# | 의사결정계수(Pseudo R2) |     0.440417 |     0.479668 | 로지스틱회귀의 성능 측정 지표로, 1에 가까울수록 좋은 모델 |
# | 정확도(Accuracy)        |     0.853868 |     0.866412 | 예측 결과(TN,FP,TP,TN)가 실제 결과(TP,TN)와 일치하는 정도 |
# | 정밀도(Precision)       |     0.837989 |     0.826531 | 양성으로 예측한 결과(TP,FP) 중 실제 양성(TP)인 비율       |
# | 재현율(Recall)          |     0.759494 |     0.818182 | 실제 양성(TP,FN) 중 양성(TP)으로 예측한 비율              |
# | 위양성율(Fallout)       |    0.0889571 |     0.104294 | 실제 음성(FP,TN) 중 양성(FP)으로 잘못 예측한 비율         |
# | 특이성(TNR)             |     0.911043 |     0.895706 | 실제 음성(FP,TN) 중 음성(TN)으로 정확히 예측한 비율       |
# | F1 Score                |     0.796813 |     0.822335 | 정밀도와 재현율의 조화평균                                |
# | AUC                     |     0.901728 |     0.919998 | ROC Curve의 밑면적으로, 1에 가까울수록 좋은 모델          |
# +-------------------------+--------------+--------------+-----------------------------------------------------------+
#
# [혼동행렬]
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# [Roc Curve]
# [학습곡선]
# +----+------------+------------+--------------------+------------+---------+------------+---------+------------+
# |    | 종속변수   | 독립변수   |   B(비표준화 계수) |   표준오차 |       t |   유의확률 |     VIF |   OddsRate |
# |----+------------+------------+--------------------+------------+---------+------------+---------+------------|
# |  0 | Survived   | Pclass     |            -0.4416 |      0.399 | -1.1058 |      0.269 |  13.374 |      0.643 |
# |  1 | Survived   | Sex        |            -3.5132 |      0.397 | -8.8545 |          0 | 2.83156 |     0.0298 |
# |  2 | Survived   | Age        |            -0.3014 |      0.278 |  -1.084 |      0.278 | 5.05085 |     0.7398 |
# |  3 | Survived   | Fare       |              0.314 |      0.295 |  1.0652 |      0.287 | 5.71113 |     1.3689 |
# |  4 | Survived   | Embarked   |            -0.0949 |      0.236 | -0.4023 |      0.687 | 5.05385 |     0.9095 |
# |  5 | Survived   | Has_Cabin  |             0.4964 |       0.58 |  0.8562 |      0.392 | 2.23078 |     1.6427 |
# |  6 | Survived   | FamilySize |            -0.3197 |      0.189 | -1.6942 |       0.09 | 7.75284 |     0.7263 |
# |  7 | Survived   | IsAlone    |            -0.3916 |      0.589 | -0.6647 |      0.506 |   4.913 |      0.676 |
# |  8 | Survived   | Title      |            -0.2633 |      0.254 | -1.0368 |        0.3 | 8.06761 |     0.7685 |
# +----+------------+------------+--------------------+------------+---------+------------+---------+------------+

# %%
knn_m = my_knn_classification(x_train, y_train, x_test, y_test)
# Out:
# [교차검증]
# +----+-----------+---------------+-----------+-------------------+
# |    | metric    |   n_neighbors | weights   |   mean_test_score |
# |----+-----------+---------------+-----------+-------------------|
# |  8 | manhattan |             5 | uniform   |          0.842411 |
# | 10 | manhattan |             7 | uniform   |          0.836687 |
# |  6 | manhattan |             3 | uniform   |          0.835721 |
# |  2 | euclidean |             5 | uniform   |          0.831902 |
# | 11 | manhattan |             7 | distance  |          0.829979 |
# |  4 | euclidean |             7 | uniform   |          0.829032 |
# |  9 | manhattan |             5 | distance  |          0.829018 |
# |  7 | manhattan |             3 | distance  |           0.82807 |
# |  5 | euclidean |             7 | distance  |          0.825186 |
# |  0 | euclidean |             3 | uniform   |          0.824261 |
# |  3 | euclidean |             5 | distance  |          0.824242 |
# |  1 | euclidean |             3 | distance  |          0.820424 |
# +----+-----------+---------------+-----------+-------------------+
#
# [분류분석 성능평가]
# +-------------------+--------------+--------------+-----------------------------------------------------------+
# |                   |   훈련데이터 |   검증데이터 | 설명                                                      |
# |-------------------+--------------+--------------+-----------------------------------------------------------|
# | 정확도(Accuracy)  |     0.872015 |     0.870229 | 예측 결과(TN,FP,TP,TN)가 실제 결과(TP,TN)와 일치하는 정도 |
# | 정밀도(Precision) |      0.84252 |     0.842105 | 양성으로 예측한 결과(TP,FP) 중 실제 양성(TP)인 비율       |
# | 재현율(Recall)    |     0.812658 |     0.808081 | 실제 양성(TP,FN) 중 양성(TP)으로 예측한 비율              |
# | 위양성율(Fallout) |    0.0920245 |    0.0920245 | 실제 음성(FP,TN) 중 양성(FP)으로 잘못 예측한 비율         |
# | 특이성(TNR)       |     0.907975 |     0.907975 | 실제 음성(FP,TN) 중 음성(TN)으로 정확히 예측한 비율       |
# | F1 Score          |      0.82732 |     0.824742 | 정밀도와 재현율의 조화평균                                |
# | AUC               |     0.928205 |     0.891089 | ROC Curve의 밑면적으로, 1에 가까울수록 좋은 모델          |
# +-------------------+--------------+--------------+-----------------------------------------------------------+
#
# [혼동행렬]
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# [Roc Curve]
# [학습곡선]

# %% [markdown]
# - KNN의 성능이 더 좋았음

# %%
support = YjkClassifierSupport()
# Out:
# 사용 가능한 모델 : ['LogisticRegression', 'SGDClassifier', 'KNeighborsClassifier']

# %%
# %%time

result_df = yjk_classifier_multi_gridsearch(support, x_train, x_test, y_train, y_test, randomized_search = False,
                                           models = None, metrics = 'accuracy')
result_df

# %%
knn_m.score(x_test, y_test)
# Out:
# 0.8702290076335878

# %%
logi_m.score(x_test, y_test)
# Out:
# 0.8664122137404581

# %%
support = YjkClassifierSupport()
# Out:
# 사용 가능한 모델 : ['LogisticRegression', 'SGDClassifier', 'KNeighborsClassifier']

# %%
support.call_model('SGDClassifier', return_model = False)
# Out:
# [SGDClassifier의 파라미터]
# +--------------+-----------------------------------------------------------+-----------------------------------+
# | 파라미터명   | 파라미터 노트                                             | 파라미터 범위                     |
# |--------------+-----------------------------------------------------------+-----------------------------------|
# | loss         | 손실함수 지정, 기본은 hinge, 예시 외 다수 존재            | ['hinge', 'log_loss', 'huber']    |
# | penalty      | 규제의 종류를 지정, 기본값은 l2                           | [None, 'l1', 'l2', 'elasticnet']  |
# | alpha        | 규제의 강도를 지정, 범위는 0 ~ 무한대, 로그스케일로 지정  | [0.0001, 0.001, 0.01, 0.1, 1, 10] |
# | max_iter     | 수행할 최대 에포크 횟수, 기본 1000                        | [100, 300, 500, 1000]             |
# | tol          | 성능향상이 안될 경우 학습을 종료하는 민감도 값, 기본 1e-3 | [0.0001, 0.001, 0.01]             |
# +--------------+-----------------------------------------------------------+-----------------------------------+

# %%
support.get_params()
# Out:
# {'loss': ['hinge', 'log_loss', 'huber'],
#  'penalty': [None, 'l1', 'l2', 'elasticnet'],
#  'alpha': [0.0001, 0.001, 0.01, 0.1, 1, 10],
#  'max_iter': [100, 300, 500, 1000],
#  'tol': [0.0001, 0.001, 0.01]}
