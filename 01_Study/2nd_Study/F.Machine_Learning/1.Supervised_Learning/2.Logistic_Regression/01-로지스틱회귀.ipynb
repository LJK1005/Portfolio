# %% [markdown]
# # 로지스틱 회귀(이항분류)
#
# 종속변수가 `0`, `1`로만 구성된 회귀분석
#
# `0`은 음성, `1`은 양성으로 본다면 둘 중 하나에 속할 확률을 구하는 것이므로 분류로 이해할 수 있다.
#
# ## #01. 준비작업
#
# ### [1] 패키지 가져오기

# %%
import sys
import os
work_path = os.path.abspath(os.path.join(os.getcwd(), "../.."))
sys.path.append(work_path)

from my_helper.regression import *
from my_helper.util import *
from my_helper.plot import *
from my_helper.analysis import *

# 로지스틱 회귀 모형
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ## Case 1. 닥스훈트와 진돗개 분류 모형
#
# ### [1] 데이터 가져오기
#
# 닥스훈트와 진돗개의 몸 길이와 키를 조사한 가상 데이터
#
# ![img](res/img1.png)

# %%
origin = my_read_excel("https://data.hossam.kr/mldata/dogs.xlsx", categories=['dog'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   dog     200 non-null    category
#  1   length  200 non-null    float64
#  2   height  200 non-null    float64
# dtypes: category(1), float64(2)
# memory usage: 3.6 KB
# None
#
# 데이터프레임 상위 5개 행
# +----+-------+----------+----------+
# |    | dog   |   length |   height |
# |----+-------+----------+----------|
# |  0 | d     |    55.01 |    29.27 |
# |  1 | d     |    59.01 |    29.39 |
# |  2 | d     |    56.53 |     28.5 |
# |  3 | d     |    53.66 |     28.5 |
# |  4 | d     |    49.67 |    31.97 |
# +----+-------+----------+----------+
#
# 데이터프레임 하위 5개 행
# +-----+-------+----------+----------+
# |     | dog   |   length |   height |
# |-----+-------+----------+----------|
# | 195 | j     |    50.95 |    52.37 |
# | 196 | j     |    51.86 |     52.4 |
# | 197 | j     |    54.24 |    47.82 |
# | 198 | j     |    53.13 |    50.22 |
# | 199 | j     |       53 |    51.18 |
# +-----+-------+----------+----------+
#
# 기술통계
# +--------+---------+---------+---------+-------+---------+--------+--------+-------+-------+
# |        |   count |    mean |     std |   min |     25% |    50% |    75% |   max |   nan |
# |--------+---------+---------+---------+-------+---------+--------+--------+-------+-------|
# | length |     200 | 53.7948 | 5.50607 | 39.94 | 50.2225 | 53.445 |   56.9 | 68.31 |     0 |
# | height |     200 | 41.6754 | 10.0361 | 22.76 |  31.965 | 43.785 | 51.185 | 55.87 |     0 |
# +--------+---------+---------+---------+-------+---------+--------+--------+-------+-------+
#
# 카테고리 정보
# +----+-------+
# |    |   dog |
# |----+-------|
# | d  |   100 |
# | j  |   100 |
# +----+-------+

# %% [markdown]
# ### [2] 산점도를 통한 데이터 분포 확인

# %%
my_convex_hull(origin, xname="length", yname="height", hue='dog')

# %% [markdown]
# > 닥스훈트와 진돗개의 품종에 따라 신체적인 특징이 구분됨을 확인할 수 있다.

# %% [markdown]
# ### [3] 데이터 전처리
#
# #### (1) 종속변수 라벨링

# %%
df = origin.copy()
# df['dog'] = df['dog'].map({'d': 0, 'j': 1})
df
# Out:
#     dog  length  height
# 0     d   55.01   29.27
# 1     d   59.01   29.39
# 2     d   56.53   28.50
# 3     d   53.66   28.50
# 4     d   49.67   31.97
# ..   ..     ...     ...
# 195   j   50.95   52.37
# 196   j   51.86   52.40
# 197   j   54.24   47.82
# 198   j   53.13   50.22
# 199   j   53.00   51.18
#
# [200 rows x 3 columns]

# %% [markdown]
# #### (3) 훈련, 검증 데이터 분리

# %%
x_train, x_test, y_train, y_test = my_train_test_split(df, yname='dog', test_size=0.2, scalling=False)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((160, 2), (40, 2), (160,), (40,))

# %% [markdown]
# ### [4] 로지스틱 회귀 모형

# %%
model = LogisticRegression()
model.fit(x_train, y_train)
print("훈련데이터 점수: ", model.score(x_train, y_train))
print("검증데이터 점수: ", model.score(x_test, y_test))
# Out:
# 훈련데이터 점수:  1.0
# 검증데이터 점수:  1.0

# %% [markdown]
# ### [5] 검증데이터를 통한 추정값 생성

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array(['d', 'j', 'd', 'j', 'd', 'j', 'j', 'd', 'j', 'j', 'd', 'j', 'j',
#        'j', 'j', 'd', 'd', 'j', 'j', 'd', 'j', 'd', 'j', 'j', 'j', 'd',
#        'j', 'd', 'j', 'd', 'd', 'd', 'j', 'j', 'd', 'j', 'j', 'j', 'd',
#        'j'], dtype=object)

# %% [markdown]
# ### [6] 결과 시각화

# %%
df1 = x_test.copy()
df1['y_test'] = y_test
df1['y_pred'] = y_pred
df1.head()
# Out:
#      length  height y_test y_pred
# 50    54.08   33.72      d      d
# 127   51.63   51.02      j      j
# 37    55.62   35.05      d      d
# 149   51.83   49.04      j      j
# 19    53.11   38.53      d      d

# %%
my_convex_hull(df1, xname="length", yname="height", hue='y_test')

# %%
my_convex_hull(df1, xname="length", yname="height", hue='y_pred')

# %% [markdown]
# ### [7] 새로운 정보 투입
#
# 훈련 모델에게 임의의 height와 length값을 투입했을 때 어떤 종으로 판별하는지 확인

# %%
input_df = DataFrame({
    'length': [47, 39, 52],
    'height': [23, 42, 49]
})

model.predict(input_df)
# Out:
# array(['d', 'j', 'j'], dtype=object)

# %% [markdown]
# ## Case 2. 대학원 합격 여부 예측 모형
#
# 어느 대학원의 방사선학 석사과정 대학원생 모집을 하였다.
#
# 지원한 학생에 대한 방사선사의 대학원 합격 여부를 예측할 수 있는 모형을 만들어 보자
#
# ### [1] 데이터 가져오기
#
# | 변수 | 구분 | 설명 |
# |---|---|---|
# | 합격여부 | 범주형 | 1=합격, 0=불합격 |
# | 필기점수 | 연속형 | 800점 만점 |
# | 학부성적 | 연속형 | 4.0 만점 |
# | 병원경력 | 범주형 | 10년이상, 5~10년, 1~5년, 1년 미만 |

# %%
origin = my_read_excel("https://data.hossam.kr/mldata/graduate.xlsx", categories=['합격여부', '병원경력'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   합격여부    400 non-null    category
#  1   필기점수    400 non-null    int64
#  2   학부성적    400 non-null    float64
#  3   병원경력    400 non-null    category
# dtypes: category(2), float64(1), int64(1)
# memory usage: 7.5 KB
# None
#
# 데이터프레임 상위 5개 행
# +----+------------+------------+------------+------------+
# |    |   합격여부 |   필기점수 |   학부성적 | 병원경력   |
# |----+------------+------------+------------+------------|
# |  0 |          0 |        380 |       3.61 | 1~5년      |
# |  1 |          1 |        660 |       3.67 | 1~5년      |
# |  2 |          1 |        800 |          4 | 10년 이상  |
# |  3 |          1 |        640 |       3.19 | 1년 미만   |
# |  4 |          0 |        520 |       2.93 | 1년 미만   |
# +----+------------+------------+------------+------------+
#
# 데이터프레임 하위 5개 행
# +-----+------------+------------+------------+------------+
# |     |   합격여부 |   필기점수 |   학부성적 | 병원경력   |
# |-----+------------+------------+------------+------------|
# | 395 |          0 |        620 |          4 | 5~10년     |
# | 396 |          0 |        560 |       3.04 | 1~5년      |
# | 397 |          0 |        460 |       2.63 | 5~10년     |
# | 398 |          0 |        700 |       3.65 | 5~10년     |
# | 399 |          0 |        600 |       3.89 | 1~5년      |
# +-----+------------+------------+------------+------------+
#
# 기술통계
# +----------+---------+--------+----------+-------+-------+-------+-------+-------+-------+
# |          |   count |   mean |      std |   min |   25% |   50% |   75% |   max |   nan |
# |----------+---------+--------+----------+-------+-------+-------+-------+-------+-------|
# | 필기점수 |     400 |  587.7 |  115.517 |   220 |   520 |   580 |   660 |   800 |     0 |
# | 학부성적 |     400 | 3.3899 | 0.380567 |  2.26 |  3.13 | 3.395 |  3.67 |     4 |     0 |
# +----------+---------+--------+----------+-------+-------+-------+-------+-------+-------+
#
# 카테고리 정보
# +----+------------+
# |    |   합격여부 |
# |----+------------|
# |  0 |        273 |
# |  1 |        127 |
# +----+------------+
# +-----------+------------+
# |           |   병원경력 |
# |-----------+------------|
# | 5~10년    |        151 |
# | 1~5년     |        121 |
# | 1년 미만  |         67 |
# | 10년 이상 |         61 |
# +-----------+------------+

# %% [markdown]
# ### [2] 데이터 전처리
#
# #### (1) 스케일링

# %%
std_df = my_standard_scaler(origin, yname='합격여부')
my_pretty_table(std_df.head())
# Out:
# +----+------------+------------+------------+------------+
# |    |   필기점수 |   학부성적 | 병원경력   |   합격여부 |
# |----+------------+------------+------------+------------|
# |  0 |   -1.80026 |   0.579072 | 1~5년      |          0 |
# |  1 |   0.626668 |   0.736929 | 1~5년      |          1 |
# |  2 |    1.84013 |    1.60514 | 10년 이상  |          1 |
# |  3 |   0.453316 |  -0.525927 | 1년 미만   |          1 |
# |  4 |  -0.586797 |   -1.20997 | 1년 미만   |          0 |
# +----+------------+------------+------------+------------+

# %% [markdown]
# #### (2) 더미변수 생성

# %%
dummy_df = my_dummies(std_df, '병원경력')
my_pretty_table(dummy_df.head())
# Out:
# +----+------------+------------+------------+------------------+---------------------+-------------------+
# |    |   필기점수 |   학부성적 |   합격여부 |   병원경력_1~5년 |   병원경력_1년 미만 |   병원경력_5~10년 |
# |----+------------+------------+------------+------------------+---------------------+-------------------|
# |  0 |   -1.80026 |   0.579072 |          0 |                1 |                   0 |                 0 |
# |  1 |   0.626668 |   0.736929 |          1 |                1 |                   0 |                 0 |
# |  2 |    1.84013 |    1.60514 |          1 |                0 |                   0 |                 0 |
# |  3 |   0.453316 |  -0.525927 |          1 |                0 |                   1 |                 0 |
# |  4 |  -0.586797 |   -1.20997 |          0 |                0 |                   1 |                 0 |
# +----+------------+------------+------------+------------------+---------------------+-------------------+

# %% [markdown]
# ### [3] 데이터 분포 확인

# %%
my_convex_hull(dummy_df, xname="필기점수", yname="학부성적", hue='합격여부')

# %% [markdown]
# ### [4] 훈련, 검증 데이터 분리

# %%
x_train, x_test, y_train, y_test = my_train_test_split(dummy_df, yname='합격여부', test_size=0.2, scalling=False)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((320, 5), (80, 5), (320,), (80,))

# %%
x_train, x_test, y_train, y_test = train_test_split(dummy_df.drop('합격여부', axis = 1), dummy_df['합격여부'], test_size = 0.2,
                                        stratify = dummy_df['합격여부'], random_state = 0)

# %% [markdown]
# ### [5] 로지스틱 회귀 모형

# %%
model = LogisticRegression()
model.fit(x_train, y_train)
print("훈련데이터 점수: ", model.score(x_train, y_train))
print("검증데이터 점수: ", model.score(x_test, y_test))
# Out:
# 훈련데이터 점수:  0.690625
# 검증데이터 점수:  0.725

# %%
df = x_test.copy()
df['y_test'] = y_test
df['y_pred'] = model.predict(x_test)
df['result'] = df['y_test'] == df['y_pred']
my_pretty_table(df)
# Out:
# +-----+------------+------------+------------------+---------------------+-------------------+----------+----------+----------+
# |     |   필기점수 |   학부성적 |   병원경력_1~5년 |   병원경력_1년 미만 |   병원경력_5~10년 |   y_test |   y_pred | result   |
# |-----+------------+------------+------------------+---------------------+-------------------+----------+----------+----------|
# |  22 |   0.106612 |   -1.49938 |                0 |                   1 |                 0 |        0 |        0 | True     |
# | 318 |  -0.933502 |   0.842167 |                0 |                   1 |                 0 |        1 |        0 | False    |
# | 390 |    1.84013 |   -0.89426 |                0 |                   0 |                 1 |        1 |        0 | False    |
# | 190 |   0.453316 |   -1.18366 |                0 |                   0 |                 1 |        1 |        0 | False    |
# | 108 |   -1.62691 |   -1.20997 |                1 |                   0 |                 0 |        0 |        0 | True     |
# | 237 |  -0.933502 |    1.60514 |                0 |                   0 |                 1 |        0 |        0 | True     |
# | 273 |   0.626668 |  -0.183904 |                0 |                   0 |                 0 |        0 |        0 | True     |
# |  23 |    0.80002 |  -0.525927 |                0 |                   1 |                 0 |        0 |        0 | True     |
# | 136 |  -0.240093 |  -0.157594 |                0 |                   1 |                 0 |        0 |        0 | True     |
# | 228 |  -0.933502 |   0.105501 |                0 |                   0 |                 1 |        0 |        0 | True     |
# | 288 |    1.84013 |  -0.631165 |                0 |                   1 |                 0 |        0 |        0 | True     |
# | 342 |  -0.760149 |     1.4736 |                0 |                   1 |                 0 |        0 |        0 | True     |
# | 230 | -0.0667406 |  -0.262832 |                0 |                   1 |                 0 |        0 |        0 | True     |
# | 315 |   -2.49367 |   -1.44676 |                0 |                   0 |                 1 |        1 |        0 | False    |
# |  26 |   0.279964 |   0.579072 |                0 |                   0 |                 0 |        1 |        0 | False    |
# |  39 |  -0.586797 |   -1.86771 |                1 |                   0 |                 0 |        1 |        0 | False    |
# | 249 |   0.453316 |   0.894786 |                1 |                   0 |                 0 |        0 |        0 | True     |
# | 232 |   -1.80026 | -0.0260461 |                0 |                   0 |                 1 |        0 |        0 | True     |
# | 285 |   0.106612 |  -0.210213 |                0 |                   1 |                 0 |        0 |        0 | True     |
# |  74 |    1.14672 |    0.15812 |                0 |                   1 |                 0 |        0 |        0 | True     |
# | 118 |    1.84013 |   0.815858 |                0 |                   0 |                 0 |        1 |        1 | True     |
# |  84 |  -0.760149 |   0.552762 |                1 |                   0 |                 0 |        1 |        0 | False    |
# | 361 |  -0.413445 |   0.263358 |                0 |                   0 |                 0 |        1 |        0 | False    |
# |  42 |   0.106612 |  -0.631165 |                0 |                   0 |                 1 |        1 |        0 | False    |
# | 200 |    1.84013 |  -0.210213 |                1 |                   0 |                 0 |        0 |        0 | True     |
# |  91 |    1.14672 |   0.658001 |                0 |                   0 |                 0 |        1 |        1 | True     |
# | 326 |    0.80002 |  -0.210213 |                0 |                   0 |                 1 |        0 |        0 | True     |
# |  47 |  -0.760149 |   -1.10474 |                0 |                   1 |                 0 |        0 |        0 | True     |
# | 198 |   0.106612 |   0.631692 |                1 |                   0 |                 0 |        0 |        0 | True     |
# | 161 |   0.453316 |   0.289668 |                0 |                   0 |                 1 |        0 |        0 | True     |
# | 279 |   0.626668 |  -0.657474 |                0 |                   0 |                 1 |        1 |        0 | False    |
# | 261 |   -1.28021 |  -0.631165 |                0 |                   0 |                 1 |        0 |        0 | True     |
# |  65 |   0.106612 |   0.526453 |                0 |                   0 |                 1 |        0 |        0 | True     |
# | 125 |  -0.413445 | -0.0260461 |                0 |                   1 |                 0 |        0 |        0 | True     |
# | 179 |   -2.49367 |  -0.999498 |                1 |                   0 |                 0 |        0 |        0 | True     |
# |  50 |   0.453316 |    1.23681 |                1 |                   0 |                 0 |        0 |        0 | True     |
# | 115 |   0.279964 |    1.57883 |                1 |                   0 |                 0 |        0 |        0 | True     |
# | 358 |  -0.240093 |   0.789548 |                1 |                   0 |                 0 |        1 |        0 | False    |
# | 331 |   0.626668 |   0.526453 |                1 |                   0 |                 0 |        0 |        0 | True     |
# |  11 |   -1.28021 |  -0.446998 |                0 |                   0 |                 0 |        0 |        0 | True     |
# |  63 |    0.80002 |     1.2105 |                1 |                   0 |                 0 |        1 |        0 | False    |
# |  30 |  -0.413445 |    1.02633 |                0 |                   1 |                 0 |        0 |        0 | True     |
# |  46 | -0.0667406 |    0.18443 |                0 |                   0 |                 1 |        1 |        0 | False    |
# | 122 |  -0.586797 |   -1.42045 |                1 |                   0 |                 0 |        0 |        0 | True     |
# | 316 |   -2.14697 |   -1.02581 |                0 |                   0 |                 1 |        1 |        0 | False    |
# | 291 |    1.84013 |   -1.60462 |                0 |                   0 |                 1 |        0 |        0 | True     |
# | 393 |   0.279964 |   0.947405 |                0 |                   0 |                 1 |        1 |        0 | False    |
# |  34 |   -1.97361 |  -0.657474 |                0 |                   0 |                 0 |        0 |        0 | True     |
# | 193 |   -1.80026 |   0.526453 |                0 |                   1 |                 0 |        0 |        0 | True     |
# |  16 |    1.66678 |    1.26312 |                0 |                   1 |                 0 |        0 |        0 | True     |
# |  37 |  -0.586797 |    -1.2889 |                1 |                   0 |                 0 |        0 |        0 | True     |
# | 366 |   -1.10685 |   -1.20997 |                1 |                   0 |                 0 |        0 |        0 | True     |
# | 282 |   0.626668 |    0.15812 |                0 |                   1 |                 0 |        0 |        0 | True     |
# |  77 |    1.84013 |    1.60514 |                1 |                   0 |                 0 |        1 |        0 | False    |
# | 213 |   0.453316 | -0.0260461 |                1 |                   0 |                 0 |        0 |        0 | True     |
# | 163 |  -0.586797 |   -1.73616 |                0 |                   0 |                 1 |        0 |        0 | True     |
# | 389 |   0.453316 |   0.315977 |                0 |                   0 |                 1 |        0 |        0 | True     |
# | 374 |  -0.240093 |    1.02633 |                0 |                   0 |                 1 |        0 |        0 | True     |
# | 264 |  -0.586797 |    1.34205 |                1 |                   0 |                 0 |        1 |        0 | False    |
# | 129 |   -1.10685 |  -0.631165 |                0 |                   1 |                 0 |        0 |        0 | True     |
# | 360 |  -0.586797 |    1.60514 |                0 |                   0 |                 0 |        1 |        1 | True     |
# | 337 |   0.279964 |  -0.789022 |                0 |                   1 |                 0 |        0 |        0 | True     |
# | 256 |  -0.586797 |  -0.236523 |                0 |                   0 |                 1 |        1 |        0 | False    |
# |  13 |   0.973373 |  -0.815332 |                0 |                   0 |                 1 |        0 |        0 | True     |
# | 170 |   -1.62691 |   0.315977 |                1 |                   0 |                 0 |        0 |        0 | True     |
# | 300 |   0.453316 |  -0.236523 |                0 |                   0 |                 1 |        0 |        0 | True     |
# | 382 |  -0.413445 |   0.315977 |                0 |                   0 |                 1 |        0 |        0 | True     |
# | 158 |   0.626668 |   0.263358 |                0 |                   0 |                 1 |        0 |        0 | True     |
# | 141 |   0.973373 |   0.342287 |                0 |                   1 |                 0 |        1 |        0 | False    |
# | 324 |  -0.586797 |   -1.81509 |                1 |                   0 |                 0 |        0 |        0 | True     |
# | 238 |  -0.760149 |   -1.39414 |                0 |                   1 |                 0 |        0 |        0 | True     |
# | 372 |    0.80002 |   -2.55176 |                0 |                   0 |                 0 |        1 |        0 | False    |
# | 146 |  -0.933502 |  0.0265728 |                0 |                   0 |                 1 |        0 |        0 | True     |
# | 241 |  -0.586797 |    1.10526 |                0 |                   0 |                 0 |        1 |        0 | False    |
# | 239 |   0.973373 |    0.15812 |                1 |                   0 |                 0 |        0 |        0 | True     |
# | 135 |  -0.760149 |   0.473834 |                1 |                   0 |                 0 |        0 |        0 | True     |
# | 226 |   0.279964 |   0.500143 |                0 |                   0 |                 1 |        0 |        0 | True     |
# | 268 |    0.80002 |    0.18443 |                0 |                   0 |                 1 |        1 |        0 | False    |
# | 184 |  -0.760149 |   -1.57831 |                0 |                   1 |                 0 |        0 |        0 | True     |
# |  73 | -0.0667406 |    1.60514 |                0 |                   0 |                 1 |        0 |        0 | True     |
# +-----+------------+------------+------------------+---------------------+-------------------+----------+----------+----------+

# %%
# ?train_test_split
