# %%
import os
os.chdir("Y:\Python\Mega_IT\E.Inferential_statistics/7.Supervised_Learning/3.Naive_Bayes")
os.getcwd()
# Out:
# 'Y:\\Python\\Mega_IT\\E.Inferential_statistics\\7.Supervised_Learning\\3.Naive_Bayes'

# %%
import sys
sys.path.append("Y:\Python\Mega_IT")

import warnings
warnings.filterwarnings('ignore')

from yjk_module.preprocessing import *
from yjk_module.ml_module import *

from sklearnex import patch_sklearn
patch_sklearn()
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
from hossam.util import *
from hossam.plot import *
from hossam.analysis import *
from hossam.classification import *

# %%
from sklearn.naive_bayes import GaussianNB

# %%
origin1 = pd.read_excel("./data/mushrooms.xlsx")

# %%
origin1.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
origin1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %% [markdown]
# - 라벨링

# %%
pp1 = YjkPreprocessor()
pp1.set_strategy(outline = None, null = None, encoder = 'ord')
# Out:
# 아래와 같이 처리합니다.
# +-------------+----------------+
# | 범주        | 처리방법       |
# |-------------+----------------|
# | 이상치 처리 | 처리하지 않음  |
# | 결측치 처리 | 처리하지 않음  |
# | 스케일러    | StandardScaler |
# | 인코딩      | 오디널인코딩   |
# +-------------+----------------+

# %%
df1 = pp1.fit_transform(origin1, yname = 'class', ylabeling = True)
# Out:
# 데이터프레임 크기 : (8124, 23)
# 데이터프레임에 결측치는 없습니다.
# 명목형 데이터 컬럼 : ['cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor', 'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color', 'stalk-shape', 'stalk-root', 'stalk-surface-above-ring', 'stalk-surface-below-ring', 'stalk-color-above-ring', 'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number', 'ring-type', 'spore-print-color', 'population', 'habitat'], 총 22개
# 종속변수 컬럼명 : class / 종속변수 라벨링 여부 : True

# %%
x_train, x_test, y_train, y_test = my_train_test_split(data = df1, yname = 'class', test_size = 0.2, random_state = 0)

# %%
my_nb_classification(x_train, y_train, x_test, y_test)
# Out:
# <class 'sklearn.naive_bayes.GaussianNB'>는 n_jobs를 허용하지 않음
# [교차검증 TOP5]
# +----+-----------------+-------------------+
# |    |   var_smoothing |   mean_test_score |
# |----+-----------------+-------------------|
# |  4 |           1e-05 |          0.923066 |
# |  0 |           1e-09 |           0.92245 |
# |  1 |           1e-08 |           0.92245 |
# |  2 |           1e-07 |           0.92245 |
# |  3 |           1e-06 |           0.92245 |
# +----+-----------------+-------------------+
#
# [분류분석 성능평가]
# +-------------------+--------------+--------------+-----------------------------------------------------------+
# |                   |   훈련데이터 |   검증데이터 | 설명                                                      |
# |-------------------+--------------+--------------+-----------------------------------------------------------|
# | 정확도(Accuracy)  |     0.922911 |     0.916308 | 예측 결과(TN,FP,TP,TN)가 실제 결과(TP,TN)와 일치하는 정도 |
# ...

# %%
my_classification(x_train, y_train, x_test, y_test)
# Out:
# <class 'sklearnex.svm.svc.SVC'>는 n_jobs를 허용하지 않음
# <class 'sklearn.naive_bayes.GaussianNB'>는 n_jobs를 허용하지 않음
# +----------------------+---------------------------+--------------------+---------------------+------------------+---------------------+---------------+------------+----------+
# |                      |   의사결정계수(Pseudo R2) |   정확도(Accuracy) |   정밀도(Precision) |   재현율(Recall) |   위양성율(Fallout) |   특이성(TNR) |   F1 Score |      AUC |
# |----------------------+---------------------------+--------------------+---------------------+------------------+---------------------+---------------+------------+----------|
# | GaussianNB           |                         0 |           0.915692 |            0.900504 |         0.924968 |            0.092723 |      0.907277 |   0.912572 | 0.956342 |
# | KNeighborsClassifier |                         0 |                  1 |                   1 |                1 |                   0 |             1 |          1 |        1 |
# ...

# %%
support = YjkClassifierSupport()
# Out:
# 사용 가능한 모델 : ['LogisticRegression', 'SGDClassifier', 'KNeighborsClassifier', 'LinearSVC', 'SVC', 'GaussianNB', 'CatboostClassifier']

# %%
result_df1 = yjk_classifier_multi_gridsearch(support, x_train, y_train, x_test, y_test, randomized_search = True, secondary_score = ['recall', 'precision', 'roc_auc'])
# Out:
# LogisticRegression 모델 소요 시간 : 0:00:02
# SGDClassifier 모델 소요 시간 : 0:00:02
# KNeighborsClassifier 모델 소요 시간 : 0:00:01
# LinearSVC 모델 소요 시간 : 0:00:23
# SVC 모델 소요 시간 : 0:00:26
# GaussianNB 모델 소요 시간 : 0:00:00
# 총 소요 시간 : 0:00:55

# %%
result_df1
# Out:
#                                                              best_model  \
# model_name
# KNeighborsClassifier  KNeighborsClassifier(n_jobs=-1, n_neighbors=3,...
# SVC                                   SVC(C=1, degree=5, kernel='poly')
# LinearSVC             LinearSVC(C=10, dual=True, loss='hinge', max_i...
# LogisticRegression    LogisticRegression(C=0.001, max_iter=500, n_jo...
# SGDClassifier         SGDClassifier(alpha=0.001, loss='log_loss', ma...
# GaussianNB                              GaussianNB(var_smoothing=1e-05)
#
#                                                              best_param  \
# model_name
# KNeighborsClassifier   {'weights': 'uniform', 'p': 1, 'n_neighbors': 3}
# SVC                             {'kernel': 'poly', 'degree': 5, 'C': 1}
# LinearSVC             {'penalty': 'l2', 'max_iter': 10000, 'loss': '...
# LogisticRegression       {'penalty': None, 'max_iter': 500, 'C': 0.001}
# SGDClassifier         {'tol': 0.0001, 'penalty': None, 'max_iter': 5...
# ...

# %% [markdown]
# - 더미화

# %%
pp2 = YjkPreprocessor()
pp2.set_strategy(outline = None, null = None)
# Out:
# 아래와 같이 처리합니다.
# +-------------+----------------+
# | 범주        | 처리방법       |
# |-------------+----------------|
# | 이상치 처리 | 처리하지 않음  |
# | 결측치 처리 | 처리하지 않음  |
# | 스케일러    | StandardScaler |
# | 인코딩      | 원핫인코딩     |
# +-------------+----------------+

# %%
df1_2 = pp2.fit_transform(origin1, yname = 'class', ylabeling = True)
# Out:
# 데이터프레임 크기 : (8124, 23)
# 데이터프레임에 결측치는 없습니다.
# 명목형 데이터 컬럼 : ['cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor', 'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color', 'stalk-shape', 'stalk-root', 'stalk-surface-above-ring', 'stalk-surface-below-ring', 'stalk-color-above-ring', 'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number', 'ring-type', 'spore-print-color', 'population', 'habitat'], 총 22개
# 종속변수 컬럼명 : class / 종속변수 라벨링 여부 : True

# %%
x_train, x_test, y_train, y_test = my_train_test_split(data = df1_2, yname = 'class', test_size = 0.2, random_state = 0)

# %%
my_nb_classification(x_train, y_train, x_test, y_test)
# Out:
# <class 'sklearn.naive_bayes.GaussianNB'>는 n_jobs를 허용하지 않음
# [교차검증 TOP5]
# +----+-----------------+-------------------+
# |    |   var_smoothing |   mean_test_score |
# |----+-----------------+-------------------|
# |  4 |           1e-05 |          0.988922 |
# |  3 |           1e-06 |          0.988152 |
# |  2 |           1e-07 |          0.983844 |
# |  1 |           1e-08 |          0.973843 |
# |  0 |           1e-09 |          0.957687 |
# +----+-----------------+-------------------+
#
# [분류분석 성능평가]
# +-------------------+--------------+--------------+-----------------------------------------------------------+
# |                   |   훈련데이터 |   검증데이터 | 설명                                                      |
# |-------------------+--------------+--------------+-----------------------------------------------------------|
# | 정확도(Accuracy)  |      0.98846 |     0.992615 | 예측 결과(TN,FP,TP,TN)가 실제 결과(TP,TN)와 일치하는 정도 |
# ...

# %%
my_classification(x_train, y_train, x_test, y_test)
# Out:
# <class 'sklearnex.svm.svc.SVC'>는 n_jobs를 허용하지 않음<class 'sklearn.naive_bayes.GaussianNB'>는 n_jobs를 허용하지 않음
#
# +----------------------+---------------------------+--------------------+---------------------+------------------+---------------------+---------------+------------+----------+
# |                      |   의사결정계수(Pseudo R2) |   정확도(Accuracy) |   정밀도(Precision) |   재현율(Recall) |   위양성율(Fallout) |   특이성(TNR) |   F1 Score |      AUC |
# |----------------------+---------------------------+--------------------+---------------------+------------------+---------------------+---------------+------------+----------|
# | GaussianNB           |                         0 |           0.966769 |            0.934704 |                1 |           0.0633803 |       0.93662 |    0.96625 | 0.995892 |
# | KNeighborsClassifier |                         0 |                  1 |                   1 |                1 |                   0 |             1 |          1 |        1 |
# ...

# %%
result_df2 = yjk_classifier_multi_gridsearch(support, x_train, y_train, x_test, y_test, randomized_search = True)
# Out:
# LogisticRegression 모델 소요 시간 : 0:00:02
# SGDClassifier 모델 소요 시간 : 0:00:01
# KNeighborsClassifier 모델 소요 시간 : 0:00:01
# LinearSVC 모델 소요 시간 : 0:00:02
# SVC 모델 소요 시간 : 0:00:18
# GaussianNB 모델 소요 시간 : 0:00:00
# 총 소요 시간 : 0:00:26

# %%
result_df2
# Out:
#                                                              best_model  \
# model_name
# LogisticRegression    LogisticRegression(C=0.001, n_jobs=-1, penalty...
# SGDClassifier         SGDClassifier(alpha=0.001, max_iter=5000, n_jo...
# KNeighborsClassifier  KNeighborsClassifier(n_jobs=-1, n_neighbors=3,...
# LinearSVC             LinearSVC(C=10, dual=False, max_iter=100, pena...
# SVC                                 SVC(C=0.1, degree=4, kernel='poly')
# GaussianNB                              GaussianNB(var_smoothing=1e-05)
#
#                                                              best_param  \
# model_name
# LogisticRegression       {'penalty': None, 'max_iter': 100, 'C': 0.001}
# SGDClassifier         {'tol': 0.001, 'penalty': 'elasticnet', 'max_i...
# KNeighborsClassifier   {'weights': 'uniform', 'p': 1, 'n_neighbors': 3}
# LinearSVC             {'penalty': 'l1', 'max_iter': 100, 'loss': 'sq...
# SVC                           {'kernel': 'poly', 'degree': 4, 'C': 0.1}
# ...

# %%
support.call_model('CatboostClassifier', return_model = False)
# Out:
# [CatboostClassifier의 파라미터]
# +-----------------+---------------------------------------------+----------------------+
# | 파라미터명      | 파라미터 노트                               | 파라미터 범위        |
# |-----------------+---------------------------------------------+----------------------|
# | iterations      | Tree 개수                                   | [100, 500]           |
# | depth           | Tree의 깊이                                 | [-1, 3, 5, 7, 9]     |
# | learning_rate   | 학습률 지정, 기본 0.009                     | [0.001, 0.009, 0.01] |
# | random_strength | 무작위성 트리 구조 선택 강도, 과적합 조정용 | [4, 6, 8]            |
# | l2_leaf_reg     | L2 규제항의 계수                            | [4, 6, 8]            |
# +-----------------+---------------------------------------------+----------------------+

# %%
param_ov = {
    'CatboostClassifier' : {'depth' : [3, 5, 7]}}

# %%
result_grid = yjk_classifier_multi_gridsearch(support, x_train, y_train, x_test, y_test, secondary_score = ['precision', 'recall', 'roc_auc'],
                                              include_models = 'all', param_override = param_ov)
# Out:
# LogisticRegression 모델 소요 시간 : 0:00:02
# SGDClassifier 모델 소요 시간 : 0:00:13
# KNeighborsClassifier 모델 소요 시간 : 0:00:02
# LinearSVC 모델 소요 시간 : 0:00:02
# SVC 모델 소요 시간 : 0:00:18
# GaussianNB 모델 소요 시간 : 0:00:00
# CatboostClassifier 모델 소요 시간 : 0:00:15
# 총 소요 시간 : 0:00:56

# %%
result_grid
# Out:
#                                                              best_model  \
# model_name
# LogisticRegression    LogisticRegression(C=0.001, n_jobs=-1, penalty...
# SGDClassifier         SGDClassifier(max_iter=100, n_jobs=-1, penalty...
# KNeighborsClassifier  KNeighborsClassifier(n_jobs=-1, n_neighbors=3,...
# LinearSVC             LinearSVC(C=0.1, dual=True, max_iter=100, rand...
# SVC                                 SVC(C=0.1, degree=4, kernel='poly')
# CatboostClassifier    <catboost.core.CatBoostClassifier object at 0x...
# GaussianNB                              GaussianNB(var_smoothing=1e-05)
#
#                                                              best_param  \
# model_name
# LogisticRegression       {'C': 0.001, 'max_iter': 100, 'penalty': None}
# SGDClassifier         {'alpha': 0.0001, 'loss': 'hinge', 'max_iter':...
# KNeighborsClassifier   {'n_neighbors': 3, 'p': 1, 'weights': 'uniform'}
# LinearSVC             {'C': 0.1, 'dual': True, 'loss': 'squared_hing...
# ...
