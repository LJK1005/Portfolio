# %% [markdown]
# # 연구과제 예시 - 네이버 뉴스 수집
#
# ## #01. 준비과정
#
# ### [1] 패키지 참조

# %%
import datetime as dt
import requests
import os
import time
import re
from bs4 import BeautifulSoup
import markdownify as mf
from tqdm.notebook import tqdm
import concurrent.futures as futures

# %% [markdown]
# ### [2] 필요한 변수 정의
#
# #### (1) 카테고리별 URL 패턴
#
# 네이버 뉴스(`https://news.naver.com`)에서 카테고리별로 기사 목록 페이지의 URL을 확인하여 패턴을 찾음
#
# | 분류 | 기사목록 URL |
# |---|---|
# | 정치 | https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=100 |
# | 경제 | https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=101 |
# | 사회 | https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=102 |
# | 생활, 문화 | https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=103 |
#
# > `sid1`으로 전달되는 숫자값에 의해 카테고리가 분류됨을 확인
#
# #### (2) 페이지별 URL 패턴
#
# ```
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=103#&date=%2000:00:00&page=1
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=103#&date=%2000:00:00&page=3
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=103#&date=%2000:00:00&page=5
# ```
#
# > 카테고리를 의미하는 `sid1`값이 고정된 상태에서 `page`변수의 값이 1단위로 증가함을 확인

# %%
# 네이버 뉴스의 카테고리별 sid값
SID1 = {"IT,과학" : 105, "경제" : 101, "사회" : 102, "생활,문화" : 103, "세계" : 104, "정치" : 100}

# 수집하고자하는 페이지 범위
PAGES = range(1, 11)

# 네이버 뉴스 기사 목록 URL
URL_FORMAT = 'https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1={sid1}#&date=%2000:00:00&page={page}'

# %% [markdown]
# ### [3] 세션 생성

# %%
session = requests.Session()

session.headers.update({
    "Referer": "",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
})

# %% [markdown]
# ## #02. 전체 기사 목록 가져오기
#
# ### [1] 함수 정의

# %%
def getArticleList(session, category, url):
    try:
        r = session.get(url)
        
        if r.status_code != 200:
            msg = "[%d Error] %s 에러가 발생함" % (r.status_code, r.reason)
            raise Exception(msg)
    except Exception as e:
        print("접속에 실패했습니다.")
        print(e)
        
    r.encoding = "euc-kr"
    soup = BeautifulSoup(r.text)
    #print(soup)
    
    
    # 뉴스 기사 제목을 위한 CSS 선택자
    selector = ".sh_text > .sh_text_headline,  .cluster_text > .cluster_text_headline,  .type06_headline dt:not(.photo),  .list_text_inner .list_tit,  .list_txt a"
    
    # 뉴스기사 제목 추출
    headlines = soup.select(selector)
    #print(headlines)
    
    
    # 각 페이지별로 추출된 뉴스기사의 본문 URL
    urls = []
    for h in headlines:
        if "href" in h.attrs:
            item = {'category': category, 'title': h.text.strip(), 'url': h.attrs['href']}
            
            # 수집된 URL이 정정기사 리스트 페이지로의 링크인 경우는 제외
            # ex) https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
            if item['url'][-7:] == "mid=omb":
                print("제외 URL:", item['url'])
                continue
            
            urls.append(item)
        
    time.sleep(0.05)
        
    return urls

# %% [markdown]
# #### 함수 테스트

# %%
getArticleList(session, "사회", "https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=102")
# Out:
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# [{'category': '사회',
#   'title': '내일 전국 비바람…수도권 이틀간 강수량 최대 80㎜',
#   'url': 'https://n.news.naver.com/mnews/article/277/0005354515?sid=102'},
#  {'category': '사회',
#   'title': '완도 해조류·전복산업특구 ‘탁월 특구’ 선정',
#   'url': 'https://n.news.naver.com/mnews/article/003/0012266241?sid=102'},
#  {'category': '사회',
#   'title': '“군인은 3000원 더 내세요”… 온라인서 뭇매 맞은 고깃집',
#   'url': 'https://n.news.naver.com/mnews/article/023/0003804671?sid=102'},
#  {'category': '사회',
#   'title': '초등 학부모 채팅방 ‘아이들 살해’ 협박 글 올린 고교생.. 경찰, 구속영장',
#   'url': 'https://n.news.naver.com/mnews/article/023/0003804599?sid=102'},
#  {'category': '사회',
#   'title': '익산 산란계 농장 두 곳 고병원성 AI…누적 10건',
#   'url': 'https://n.news.naver.com/mnews/article/422/0000634302?sid=102'},
#  {'category': '사회',
#   'title': '한 총리 "청년주택 청약 당첨 시 2%대 금리로 40년까지 대출"',
#   'url': 'https://n.news.naver.com/mnews/article/421/0007233037?sid=102'},
#  {'category': '사회',
#   'title': '"죄질이 극히 불량"…40대 여성 납치·성폭행한 중학생 징역형',
#   'url': 'https://n.news.naver.com/mnews/article/088/0000851416?sid=102'},
#  {'category': '사회',
#   'title': '\'女제자와 불륜\' 교수 아내, 입장 밝혔다.."제발 멈춰달라"',
#   'url': 'https://n.news.naver.com/mnews/article/014/0005114476?sid=102'},
#  {'category': '사회',
#   'title': '에쓰오일, 협력업체 안전보건경영시스템 인증 지원',
#   'url': 'https://n.news.naver.com/mnews/article/018/0005637484?sid=102'},
#  {'category': '사회',
#   'title': "'무료 과외' 갔다가 피멍 들게 맞은 수험생…폭행 이유는?",
#   'url': 'https://n.news.naver.com/mnews/article/015/0004925205?sid=102'},
#  {'category': '사회',
#   'title': '(126) “한국형 LNG 화물창 결함 책임, 가스公에” 1150억 배상 판결 이끈 화우',
#   'url': 'https://n.news.naver.com/mnews/hotissue/article/366/0000954482?type=series&cid=1087840'},
#  {'category': '사회',
#   'title': '(125) 계약직 뽑은 부서 없어졌는데 부당해고? 1심 뒤집은 대륙아주',
#   'url': 'https://n.news.naver.com/mnews/hotissue/article/366/0000951344?type=series&cid=1087840'},
#  {'category': '사회',
#   'title': '(124) ‘대신증권, 라임 투자자에 전액 배상’ 판단 뒤집은 태평양 전략은',
#   'url': 'https://n.news.naver.com/mnews/hotissue/article/366/0000949937?type=series&cid=1087840'},
#  {'category': '사회',
#   'title': '(123) 코웨이 정수기 ‘살균 기술’ 특허 지킨 법무법인 광장',
#   'url': 'https://n.news.naver.com/mnews/hotissue/article/366/0000943619?type=series&cid=1087840'},
#  {'category': '사회',
#   'title': '영화 ‘서울의 봄’에 분노한 2030세대, 역사를 다시 봄',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/082/0001246540?ntype=RANKING&sid=001'},
#  {'category': '사회',
#   'title': '"퇴마의식"…병원 입원한 장모에게 불붙인 사위 징역형',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/422/0000634340?ntype=RANKING&sid=001'},
#  {'category': '사회',
#   'title': '“‘이것’하면 뇌 쪼그라든다” 알츠하이머·치매 연관 주목',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/020/0003536828?ntype=RANKING&sid=001'},
#  {'category': '사회',
#   'title': '"못 사서 벼락 거지 됐어요"…\'5배 폭등\' 주식에 개미들 …',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/015/0004925218?ntype=RANKING&sid=001'},
#  {'category': '사회',
#   'title': '김기현 출마 고집에 윤 대통령 격노…대표직 사퇴로 일단 봉 …',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/028/0002668649?ntype=RANKING&sid=001'},
#  {'category': '사회',
#   'title': "2024년 부동산 제도 이렇게 바뀐다…'청년·출산' 주목",
#   'url': 'https://n.news.naver.com/mnews/ranking/article/648/0000021730?ntype=RANKING&sid=001'},
#  {'category': '사회',
#   'title': '“전기차, 진짜 큰일났다”…안팔리는데 설상가상, 3천만원대 …',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/009/0005229798?ntype=RANKING&sid=001'},
#  {'category': '사회',
#   'title': '소녀에서 산악인으로! 남미 최고봉 도전기 1회',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/094/0000011413?ntype=RANKING&sid=001'},
#  {'category': '사회',
#   'title': '"15살 나이 안 믿겨"‥성폭행 중학생 \'징역 10년\'',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/214/0001318326?ntype=RANKING&sid=001'},
#  {'category': '사회',
#   'title': '“군 장병이세요? 3천 원 더 내세요”…무한리필 고깃집 논 …',
#   'url': 'https://n.news.naver.com/mnews/ranking/article
ntype=RANKING&sid=001'},
#  {'category': '사회',
#   'title': "딸기 '수직 재배 기술' 개발···생산량 3배 늘리고 노동 …",
#   'url': 'https://n.news.naver.com/mnews/ranking/article/657/0000021179?ntype=RANKING&sid=001'},
#  {'category': '사회',
#   'title': '씨라이프 부산 아쿠아리움-공격에 최적화된 상어 이빨[박수현 …',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/033/0000046593?ntype=RANKING&sid=001'},
#  {'category': '사회',
#   'title': "딸기 '수직 재배 기술' 개발···생산량 3배 늘리고 노동 …",
#   'url': 'https://n.news.naver.com/mnews/ranking/article/657/0000021179?ntype=RANKING&sid=001'},
#  {'category': '사회',
#   'title': "세종 아파트 고층에서 떨어진 아령에 지나던 주민 '철렁'",
#   'url': 'https://n.news.naver.com/mnews/ranking/article/656/0000072807?ntype=RANKING&sid=001'},
#  {'category': '사회',
#   'title': '"질책 수용할까 눈 가리고 아웅할까" 카카오T 향한 두 질 …',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/665/0000002108?ntype=RANKING&sid=001'},
#  {'category': '사회',
#   'title': '가장 유명한 트랜스젠더 케이틀린 제너 “트랜스젠더, 여성  …',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/145/0000020102?ntype=RANKING&sid=001'},
#  {'category': '사회',
#   'title': '한·네덜란드 ‘반도체 동맹’ 첫 명문화… “공급망 위기 함께 대응”',
#   'url': 'https://n.news.naver.com/mnews/article/081/0003416410?sid=100'},
#  {'category': '사회',
#   'title': '이낙연, 새해 신당 창당 공식화…“욕심대로라면 제1당 돼야”',
#   'url': 'https://n.news.naver.com/mnews/article/056/0011621859?sid=100'},
#  {'category': '사회',
#   'title': '일본 “핵오염수? 후쿠시마 주민들도 돌아왔다..중국 협의할 것”',
#   'url': 'https://n.news.naver.com/mnews/article/014/0005114442?sid=100'},
#  {'category': '사회',
#   'title': '“한미일, 며칠 내 북 미사일 정보 실시간 공유 개시”',
#   'url': 'https://n.news.naver.com/mnews/article/056/0011622091?sid=104'},
#  {'category': '사회',
#   'title': '“가자는 지상 지옥”…바이든, 이스라엘 강경책 변화 촉구',
#   'url': 'https://n.news.naver.com/mnews/article/056/0011621385?sid=104'},
#  {'category': '사회',
#   'title': '김밥 3,292원·김치찌개 7,923원…외식비 또 올라',
#   'url': 'https://n.news.naver.com/mnews/article/056/0011622123?sid=101'},
#  {'category': '사회',
#   'title': '美 연준, 3회 연속 금리 동결...내년 3차례 인하 예고',
#   'url': 'https://n.news.naver.com/mnews/article/014/0005114418?sid=101'},
#  {'category': '사회',
#   'title': '카카오모빌리티 가맹 택시 수수료율 2.8%로 인하',
#   'url': 'https://n.news.naver.com/mnews/article/028/0002668681?sid=101'},
#  {'category': '사회',
#   'title': '초전도학회 검증위 “LK-99 초전도체 근거 전혀 없다”',
#   'url': 'https://n.news.naver.com/mnews/article/081/0003416179?sid=105'},
#  {'category': '사회',
#   'title': '카카오 신임 대표에 정신아 카카오벤처스 대표',
#   'url': 'https://n.news.naver.com/mnews/article/005/0001659240?sid=101'},
#  {'category': '사회',
#   'title': '"아이 해치겠다" 학부모 단체방에 살해 협박 10대 구속 면해[와글와글]',
#   'url': 'https://n.news.naver.com/mnews/article/214/0001318304?sid=102'},
#  {'category': '사회',
#   'title': '도문열 서울시의회 도시계획균형위원회 위원장, 고립·은둔청년 성과공유회 참석',
#   'url': 'https://n.news.naver.com/mnews/article/081/0003416275?sid=102'},
#  {'category': '사회',
#   'title': '“욕설 폭행했다” 더니…아들과 짜고 남편 살해한 40대女 ‘대반전’',
#   'url': 'https://n.news.naver.com/mnews/article/009/0005229809?sid=102'},
#  {'category': '사회',
#   'title': '토요타 5세대 프리우스 출시…2.0ℓ HEV·PHEV 파워트레인 도입',
#   'url': 'https://n.news.naver.com/mnews/article/009/0005229331?sid=103'},
#  {'category': '사회',
#   'title': '“해상전 장면만 100분… 충무공 최후 전투 온전히 담았다”',
#   'url': 'https://n.news.naver.com/mnews/article/081/0003416473?sid=103'}]

# %% [markdown]
# ### [2] 기사 URL 추출

# %%
articles = []

# 카테고리수 x 페이지 수가 전체 가져와야 할 수량
progress = tqdm(total=len(SID1) * len(PAGES))

for c in list(SID1.keys()):
    for p in PAGES:
        url = URL_FORMAT.format(sid1=SID1[c], page=p)
        #print(url)
        articles += getArticleList(session, c, url)
        progress.update()
        
print("수집된 URL수:", len(articles)) 
articles
# Out:
#   0%|          | 0/60 [00:00<?, ?it/s]
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb
# 제외 URL: https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb
# 수집된 URL수: 6829
# [{'category': 'IT,과학',
#   'title': "개인정보위, '해킹 무방비' 안전조치 의무 위반 업체 2곳 제재",
#   'url': 'https://n.news.naver.com/mnews/article/001/0014389726?sid=105'},
#  {'category': 'IT,과학',
#   'title': '초전도학회 검증위 “‘LK-99’ 상온 상압 초전도체 근거 없어”',
#   'url': 'https://n.news.naver.com/mnews/article/056/0011621374?sid=105'},
#  {'category': 'IT,과학',
#   'title': '네이처, 2023 과학계 화제의 인물에…‘챗GPT’ 선정',
#   'url': 'https://n.news.naver.com/mnews/article/016/0002238643?sid=105'},
#  {'category': 'IT,과학',
#   'title': '카카오, 신임 대표로 정신아 카카오벤처스 대표 내정',
#   'url': 'https://n.news.naver.com/mnews/article/366/0000954583?sid=105'},
#  {'category': 'IT,과학',
#   'title': 'KT의 갤럭시S23 FE 고객 절반 이상, 구독서비스 이용',
#   'url': 'https://n.news.naver.com/mnews/article/008/0004973978?sid=105'},
#  {'category': 'IT,과학',
#   'title': "'美상장 추진' 네이버웹툰…다시 조명받는 이해진 역할",
#   'url': 'https://n.news.naver.com/mnews/article/018/0005637559?sid=105'},
#  {'category': 'IT,과학',
#   'title': "구글 최신 AI 언어모델 '제미나이' 기업용 서비스에 탑재",
#   'url': 'https://n.news.naver.com/mnews/article/001/0014389207?sid=105'},
#  {'category': 'IT,과학',
#   'title': "'아이폰 통녹' 이어 실시간 통역콜까지…SKT, 에이닷 업데이트",
#   'url': 'https://n.news.naver.com/mnews/article/014/0005114531?sid=105'},
#  {'category': 'IT,과학',
#   'title': "ASML 보유 네덜란드-韓 삼성·SK 반도체 '동맹'…TSMC 추월 '희망가' 부른다",
#   'url': 'https://n.news.naver.com/mnews/hotissue/article/138/0002162869?type=series&cid=2000113'},
#  {'category': 'IT,과학',
#   'title': 'AI 규제법 발효 앞둔 EU…HBM 수요에 미칠 영향은?',
#   'url': 'https://n.news.naver.com/mnews/hotissue/article/138/0002162758?type=series&cid=2000113'},
#  {'category': 'IT,과학',
#   'title': "'D램 서버' 삼성전자 역전한 SK하이닉스…'DDR5' 우위 주효",
#   'url': 'https://n.news.naver.com/mnews/hotissue/article/138/0002162027?type=series&cid=2000113'},
#  {'category': 'IT,과학',
#   'title': '佛 엔지니어의 유창한 한국어…’ST 터치GFX’ 알렸다',
#   'url': 'https://n.news.naver.com/mnews/hotissue/article/138/0002161822?type=series&cid=2000113'},
#  {'category': 'IT,과학',
#   'title': '은행권 이사회 권한 강해진다…거수기 오명 벗을까',
#   'url': 'https://n.news.naver.com/mnews/hotissue/article
ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '재벌 총수들 열에 아홉은 쓴다는 ‘안경’은 어떻게 맞출까  …',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/050/0000070213?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': 'Local retail giant Daiso becomes …',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/044/0000252659?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '美연준, 금리 3회 연속 동결…내년 3차례 인하 시사',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/123/0002323165?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '의대 정원 늘어나면 ‘누가 의대에 가야 할까?’',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/308/0000033891?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '1월부터 아기 낳고 집 사면 1%대 대출 받을 수 있다',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/417/0000968778?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': "먹이를 물에 '찍먹' 하는 앵무새…사람처럼 '식감' 따진다",
#   'url': 'https://n.news.naver.com/mnews/ranking/article/584/0000025269?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '“마음 치유해 준 임영웅, 잠자던 설렘 세포를 깨웠다” [ …',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/262/0000017052?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '씨라이프 부산 아쿠아리움-공격에 최적화된 상어 이빨[박수현 …',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/033/0000046593?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': "휴가내고 인사청문 준비하는 '권익위원장 겸 방통위원장 후보 …",
#   'url': 'https://n.news.naver.com/mnews/ranking/article/127/0000034997?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '세계 최대 ‘용인 반도체 클러스터’ 최고 수혜지는?',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/037/0000033528?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '무면허·음주 뺑소니 사고낸 군인 검거...피해자는 뇌사 상 …',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/655/0000015075?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '임혜동 "쳐봐", 김하성 "너 뭐하냐?"... 술자리 동석 …',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/053/0000040185?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': "딸기 '수직 재배 기술' 개발···생산량 3배 늘리고 노동 …",
#   'url': 'https://n.news.naver.com/mnews/ranking/article/657/0000021179?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '소녀에서 산악인으로! 남미 최고봉 도전기 1회',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/094/0000011413?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': "세종 아파트 고층에서 떨어진 아령에 지나던 주민 '철렁'",
#   'url': 'https://n.news.naver.com/mnews/ranking/article/656/0000072807?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '가자는 ‘절멸수용소’가 되어가고 있습니다',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/007/0000007528?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': "‘개인 젓가락으로 쏙’ 尹 대통령 왔던 부산 떡볶이집 '행 …",
#   'url': 'https://n.news.naver.com/mnews/ranking/article/658/0000060553?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '가자는 ‘절멸수용소’가 되어가고 있습니다',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/007/0000007528?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': "‘개인 젓가락으로 쏙’ 尹 대통령 왔던 부산 떡볶이집 '행 …",
#   'url': 'https://n.news.naver.com/mnews/ranking/article/658/0000060553?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '[단독]"감기약 부족해요" 독감 환자 급증에 제주 약국 비 …',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/661/0000034644?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '"질책 수용할까 눈 가리고 아웅할까" 카카오T 향한 두 질 …',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/665/0000002108?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '가장 유명한 트랜스젠더 케이틀린 제너 “트랜스젠더, 여성  …',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/145/0000020102?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': "김건희 여사, 네덜란드서 '개 식용 금지' 말한 까닭은",
#   'url': 'https://n.news.naver.com/mnews/article/015/0004925302?sid=100'},
#  {'category': 'IT,과학',
#   'title': '두산 로봇, 암스테르담공항 수하물 처리한다…한·네덜란드 협력 강화',
#   'url': 'https://n.news.naver.com/mnews/article/016/0002238688?sid=101'},
#  {'category': 'IT,과학',
#   'title': '尹 "한-네덜란드 반도체 동맹 목표, 세계 최고 수준 초격차 만드는 것"',
#   'url': 'https://n.news.naver.com/mnews/article/011/0004274066?sid=100'},
#  {'category': 'IT,과학',
#   'title': '국제유가 1% 상승…미 재고 감소·연준 금리인하 시사',
#   'url': 'https://n.news.naver.com/mnews/article/123/0002323170?sid=104'},
#  {'category': 'IT,과학',
#   'title': "제2의 낙태권되나…美 대선 변수로 떠오른 '반유대주의 논란'",
#   'url': 'https://n.news.naver.com/mnews/article/015/0004924926?sid=104'},
#  {'category': 'IT,과학',
#   'title': '현대차증권 "미국, 내년 세 차례 금리 인하 예상"',
#   'url': 'https://n.news.naver.com/mnews/article/421/0007233884?sid=101'},
#  {'category': 'IT,과학',
#   'title': 'CJ대한통운 건설부문, ‘서초구 기부자 예우의 날’ 행사에서 감사패 수상',
#   'url': 'https://n.news.naver.com/mnews/article/018/0005637514?sid=101'},
#  {'category': 'IT,과학',
#   'title': '카카오모빌리티, 택시업계와 합의…수수료 낮추고 배차 알고리즘 바꾼다',
#   'url': 'https://n.news.naver.com/mnews/article/011/0004274059?sid=105'},
#  {'category': 'IT,과학',
#   'title': '네이버웹툰 美 본사, 데이비드 리 CFO 영입',
#   'url': 'https://n.news.naver.com/mnews/article/366/0000954881?sid=105'},
#  {'category': 'IT,과학',
#   'title': '“LK-99 초전도체 근거 전혀 없다”…검증위 결론',
#   'url': 'https://n.news.naver.com/mnews/article/020/0003536740?sid=105'},
#  {'category': 'IT,과학',
#   'title': "'돈 봉투·불법 정치자금 8억' 혐의…송영길에 구속영장 청구",
#   'url': 'https://n.news.naver.com/mnews/article/055/0001114170?sid=102'},
#  {'category': 'IT,과학',
#   'title': '야경에 취한다… 동궁과 월지 ‘한국관광의 별’',
#   'url': 'https://n.news.naver.com/mnews/article/020/0003536959?sid=103'},
#  {'category': 'IT,과학',
#   'title': '"15살 짓이라니" 판사도 깜짝…40대女 성폭행한 중학생 장기 10년',
#   'url': 'https://n.news.naver.com/mnews/article/008/0004973553?sid=102'},
#  {'category': 'IT,과학',
#   'title': '“담배 피우면 뇌도 쪼그라든다”…알츠하이머·치매 연관 주목',
#   'url': 'https://n.news.naver.com/mnews/article/056/0011621465?sid=104'},
#  {'category': 'IT,과학',
#   'title': '도요타 신형 프리우스 韓 출시',
#   'url': 'https://n.news.naver.com/mnews/article/277/0005354218?sid=103'},
#  {'category': 'IT,과학',
#   'title': '카카오 신임 대표에 정신아 카카오벤처스 대표',
#   'url': 'https://n.news.naver.com/mnews/article/005/0001659240?sid=105'},
#  {'category': 'IT,과학',
#   'title': '[영상] 주식시장까지 뒤집어 놓았던 "초전도체는 없다"는 게 학계의 정설…이라는 게 검증위의 결론',
#   'url': 'https://n.news.naver.com/mnews/article/055/0001114153?sid=105'},
#  {'category': 'IT,과학',
#   'title': '네이버웹툰, 美 본사에 데이비드 리 CFO 영입…김용수 CSO 승진',
#   'url': 'https://n.news.naver.com/mnews/article/008/0004973946?sid=105'},
#  {'category': 'IT,과학',
#   'title': '\'0원폰\'도 가능한 갤S23 FE…"구매자 절반 이상이 구독서비스" KT',
#   'url': 'https://n.news.naver.com/mnews/article/014/0005114597?sid=105'},
#  {'category': 'IT,과학',
#   'title': '과기정통부, 네덜란드 경제기후정책부와 디지털 분야 협의체 운영',
#   'url': 'https://n.news.naver.com/mnews/article/018/0005637564?sid=105'},
#  {'category': 'IT,과학',
#   'title': "챗GPT, '네이처' 올해 10대 과학계 인물에 뽑혔다",
#   'url': 'https://n.news.naver.com/mnews/article/025/0003328430?sid=105'},
#  {'category': 'IT,과학',
#   'title': '이미지에 텍스트도 생성해준다, 구글 이마젠2 공개',
#   'url': 'https://n.news.naver.com/mnews/article/009/0005229785?sid=105'},
#  {'category': 'IT,과학',
#   'title': '“화석 연료로부터 전환” 합의한 COP28…퇴출·감축 다투더니, 전환은 뭐야?',
#   'url': 'https://n.news.naver.com/mnews/hotissue/article/016/0002238574?type=series&cid=2000342'},
#  {'category': 'IT,과학',
#   'title': '오늘은 영상 10도, 내일은 영하 10도…더웠다 추웠다 겨울 날씨, 도대체 왜 이러는 거야?',
#   'url': 'https://n.news.naver.com/mnews/hotissue/article/016/0002238514?type=series&cid=2000342'},
#  {'category': 'IT,과학',
#   'title': '“전기 요금만 1300조원” 어마어마하게 아낀다…에어컨 잘 틀면 벌어지는 놀라운 일',
#   'url': 'https://n.news.naver.com/mnews/hotissue/article/016/0002237890?type=series&cid=2000342'},
#  {'category': 'IT,과학',
#   'title': '“의사 없는 것도 서러운데” 이대로 뒀다가는 큰일…위험에 빠진 지방 병원들',
#   'url': 'https://n.news.naver.com/mnews/hotissue/article/016/0002235754?type=series&cid=2000342'},
#  {'category': 'IT,과학',
#   'title': '美 금리인하 기대에 비트코인도 가격 회복…김치프리미엄은 7%',
#   'url': 'https://n.news.naver.com/mnews/hotissue/article/421/0007233855?type=series&cid=2000729'},
#  {'category': 'IT,과학',
#   'title': "비트코인 김치프리미엄 6%…업비트 상장 '크레딧코인' 200% 상승",
#   'url': 'https://n.news.naver.com/mnews/hotissue/article/421/0007231394?type=series&cid=2000729'},
#  {'category': 'IT,과학',
#   'title': '냉각기 맞은 비트코인, 5%대 급락…"건강한 조정" 분석 우세',
#   'url': 'https://n.news.naver.com/mnews/hotissue/article/421/0007229065?type=series&cid=2000729'},
#  {'category': 'IT,과학',
#   'title': "비트코인, FOMC 앞두고 '주춤'…5960만원대서 약보합",
#   'url': 'https://n.news.naver.com/mnews/hotissue/article/421/0007226935?type=series&cid=2000729'},
#  {'category': 'IT,과학',
#   'title': '원칙과 상식 "이재명 대표 기득권 내려놓고 통합비대위로 가 …',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/437/0000370802?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '은행 점포가 사라진다… 신한·우리 내년 영업점 15곳 통폐 …',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/366/0000954820?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '김기현 출마 고집에 윤 대통령 격노…대표직 사퇴로 일단 봉 …',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/028/0002668649?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '"매달 두세 군데씩 폐업하는 실정"…운전 학원에 무슨 일',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/055/0001114251?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '뇌 축소 막으려면…"당장 끊어라"',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/215/0001138965?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '"내가 누군지 알아" 경찰 머리 때린 예비 女검사…변호사  …',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/025/0003328415?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '김기현, 이준석이 회동 공개하자… 30분 만에 회견 없이  …',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/023/0003804768?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '“군 장병이세요? 3천 원 더 내세요”…무한리필 고깃집 논 …',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/056/0011621966?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '“전기차, 진짜 큰일났다”…안팔리는데 설상가상, 3천만원대 …',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/009/0005229798?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': "12억 찍은 아파트가 7억원대로…노·도·강 '울상'",
#   'url': 'https://n.news.naver.com/mnews/ranking/article/003/0012265860?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '"1년간 돌본 환자 숨졌는데.." 고인 체크카드로 4천만  …',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/660/0000051353?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '포르쉐 차주의 갑질… 민폐주차 딱지에 ‘경비원 잘라라’',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/005/0001659525?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '"엄마가 나약해서가 아니야…" 대전교사 사망 100일 여전 …',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/001/0014389296?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '“‘이것’하면 뇌 쪼그라든다” 알츠하이머·치매 연관 주목',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/020/0003536828?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '"못 사서 벼락 거지 됐어요"…\'5배 폭등\' 주식에 개미들 …',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/015/0004925218?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '김건희 여사 "개 식용 금지, 대통령 약속...빠른 입법  …',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/052/0001972358?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '영화 ‘서울의 봄’에 분노한 2030세대, 역사를 다시 봄',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/082/0001246540?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '"걸그룹 출신 여성 재혼남은 \'제2 전청조\'" 논란 커지자 …',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/011/0004274073?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '[단독] 檢 "송영길, 차명폰으로 수사 상황 파악"…\'증거 …',
#   'url': 'https://n.news.naver.com/mnews/ranking/article
#   'title': '尹 "한-네덜란드 반도체 동맹 목표, 세계 최고 수준 초격차 만드는 것"',
#   'url': 'https://n.news.naver.com/mnews/article/011/0004274066?sid=100'},
#  {'category': 'IT,과학',
#   'title': '국제유가 1% 상승…미 재고 감소·연준 금리인하 시사',
#   'url': 'https://n.news.naver.com/mnews/article/123/0002323170?sid=104'},
#  {'category': 'IT,과학',
#   'title': "제2의 낙태권되나…美 대선 변수로 떠오른 '반유대주의 논란'",
#   'url': 'https://n.news.naver.com/mnews/article/015/0004924926?sid=104'},
#  {'category': 'IT,과학',
#   'title': '현대차증권 "미국, 내년 세 차례 금리 인하 예상"',
#   'url': 'https://n.news.naver.com/mnews/article/421/0007233884?sid=101'},
#  {'category': 'IT,과학',
#   'title': 'CJ대한통운 건설부문, ‘서초구 기부자 예우의 날’ 행사에서 감사패 수상',
#   'url': 'https://n.news.naver.com/mnews/article/018/0005637514?sid=101'},
#  {'category': 'IT,과학',
#   'title': '카카오모빌리티, 택시업계와 합의…수수료 낮추고 배차 알고리즘 바꾼다',
#   'url': 'https://n.news.naver.com/mnews/article/011/0004274059?sid=105'},
#  {'category': 'IT,과학',
#   'title': '네이버웹툰 美 본사, 데이비드 리 CFO 영입',
#   'url': 'https://n.news.naver.com/mnews/article/366/0000954881?sid=105'},
#  {'category': 'IT,과학',
#   'title': '“LK-99 초전도체 근거 전혀 없다”…검증위 결론',
#   'url': 'https://n.news.naver.com/mnews/article/020/0003536740?sid=105'},
#  {'category': 'IT,과학',
#   'title': "'돈 봉투·불법 정치자금 8억' 혐의…송영길에 구속영장 청구",
#   'url': 'https://n.news.naver.com/mnews/article/055/0001114170?sid=102'},
#  {'category': 'IT,과학',
#   'title': '야경에 취한다… 동궁과 월지 ‘한국관광의 별’',
#   'url': 'https://n.news.naver.com/mnews/article/020/0003536959?sid=103'},
#  {'category': 'IT,과학',
#   'title': '"15살 짓이라니" 판사도 깜짝…40대女 성폭행한 중학생 장기 10년',
#   'url': 'https://n.news.naver.com/mnews/article/008/0004973553?sid=102'},
#  {'category': 'IT,과학',
#   'title': '“담배 피우면 뇌도 쪼그라든다”…알츠하이머·치매 연관 주목',
#   'url': 'https://n.news.naver.com/mnews/article/056/0011621465?sid=104'},
#  {'category': 'IT,과학',
#   'title': '도요타 신형 프리우스 韓 출시',
#   'url': 'https://n.news.naver.com/mnews/article/277/0005354218?sid=103'},
#  {'category': 'IT,과학',
#   'title': '카카오 새 대표에 정신아 카카오벤처스 대표…“무거운 책임감”',
#   'url': 'https://n.news.naver.com/mnews/article/020/0003536766?sid=105'},
#  {'category': 'IT,과학',
#   'title': "'상장 추진' 네이버웹툰 美본사, 데이비드 리 CFO 영입",
#   'url': 'https://n.news.naver.com/mnews/article/421/0007234225?sid=105'},
#  {'category': 'IT,과학',
#   'title': '\'꿈의 물질\'로 남겨진 초전도체... 검증위, "LK-99, 초전도체 근거 없다" [앵커리포트]',
#   'url': 'https://n.news.naver.com/mnews/article/052/0001972139?sid=105'},
#  {'category': 'IT,과학',
#   'title': '구글 최신 AI 언어모델 제미나이, 기업용 서비스에 탑재',
#   'url': 'https://n.news.naver.com/mnews/article/366/0000954870?sid=105'},
#  {'category': 'IT,과학',
#   'title': 'SKT, \'에이닷 통역콜\' 출시…"AI가 통화 중 실시간 통역"',
#   'url': 'https://n.news.naver.com/mnews/article/277/0005354738?sid=105'},
#  {'category': 'IT,과학',
#   'title': '방송협회 “빅테크 기업, AI 학습에 방송사 저작물 사용 여부 알려달라”',
#   'url': 'https://n.news.naver.com/mnews/article/056/0011622159?sid=105'},
#  {'category': 'IT,과학',
#   'title': '"2년 뒤 반납 때 출고가 절반 보상"…KT \'갤S23 FE\' 가입자 절반이 선택',
#   'url': 'https://n.news.naver.com/mnews/article/421/0007233897?sid=105'},
#  {'category': 'IT,과학',
#   'title': '과기정통부, 네덜란드 경제기후정책부와 디지털 분야 협의체 운영',
#   'url': 'https://n.news.naver.com/mnews/article/018/0005637564?sid=105'},
#  {'category': 'IT,과학',
#   'title': '양쪽 지느러미에 엄지손가락?…돌연변이 돌고래 발견',
#   'url': 'https://n.news.naver.com/mnews/hotissue/article/081/0003415997?type=series&cid=1064685'},
#  {'category': 'IT,과학',
#   'title': '‘스위트홈’ 괴물 능력, 현실로?…스스로 상처 치유하는 인간세포 로봇 개발',
#   'url': 'https://n.news.naver.com/mnews/hotissue/article/081/0003413357?type=series&cid=1064685'},
#  {'category': 'IT,과학',
#   'title': '4100년 전 ‘집단 참수’ 학살 흔적 中서 최초 발견',
#   'url': 'https://n.news.naver.com/mnews/hotissue/article/081/0003411917?type=series&cid=1064685'},
#  {'category': 'IT,과학',
#   'title': '서울 6배 ‘세계 최대 빙산’...30여 년 만에 본격 이동',
#   'url': 'https://n.news.naver.com/mnews/hotissue/article/081/0003411567?type=series&cid=1064685'},
#  {'category': 'IT,과학',
#   'title': '메리 `노플`(노플라스틱)`  크리스마스…로블레스 자작나무 트리',
#   'url': 'https://n.news.naver.com/mnews/hotissue/article/029/0002843017?type=series&cid=1089878'},
#  {'category': 'IT,과학',
#   'title': '`불멍`으로 마음 면역력 높이기',
#   'url': 'https://n.news.naver.com/mnews/hotissue/article/029/0002841485?type=series&cid=1089878'},
#  {'category': 'IT,과학',
#   'title': '새해 다이어리도 내 라이프스타일에 맞게 조립해 쓰자',
#   'url': 'https://n.news.naver.com/mnews/hotissue/article/029/0002840130?type=series&cid=1089878'},
#  {'category': 'IT,과학',
#   'title': '싸늘하다, 손끝이 얼음이다… 걱정마라, 온열매트 있으니',
#   'url': 'https://n.news.naver.com/mnews/hotissue/article/029/0002838515?type=series&cid=1089878'},
#  {'category': 'IT,과학',
#   'title': '영화 ‘서울의 봄’에 분노한 2030세대, 역사를 다시 봄',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/082/0001246540?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '"퇴마의식"…병원 입원한 장모에게 불붙인 사위 징역형',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/422/0000634340?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '“‘이것’하면 뇌 쪼그라든다” 알츠하이머·치매 연관 주목',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/020/0003536828?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '"못 사서 벼락 거지 됐어요"…\'5배 폭등\' 주식에 개미들 …',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/015/0004925218?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '김기현 출마 고집에 윤 대통령 격노…대표직 사퇴로 일단 봉 …',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/028/0002668649?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': "2024년 부동산 제도 이렇게 바뀐다…'청년·출산' 주목",
#   'url': 'https://n.news.naver.com/mnews/ranking/article/648/0000021730?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '“전기차, 진짜 큰일났다”…안팔리는데 설상가상, 3천만원대 …',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/009/0005229798?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '소녀에서 산악인으로! 남미 최고봉 도전기 1회',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/094/0000011413?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '"15살 나이 안 믿겨"‥성폭행 중학생 \'징역 10년\'',
#   'url': 'https://n.news.naver.com/mnews/ranking/article
…',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/002/0002311756?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '이준석, 이례적 尹 칭찬? “공산주의자 활동 이력 이위종  …',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/021/0002610656?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '"1년간 돌본 환자 숨졌는데.." 고인 체크카드로 4천만  …',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/660/0000051353?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '인구 위기가 \'나혼산\' \'금쪽이\' 때문?..."시청자는 바 …',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/469/0000775173?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '"망사용료 비싸" 한국 떠난 트위치, \'빈틈\' 노리는 네이 …',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/006/0000121301?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': "'표절 시비' 전북 로고 급변경, '검수'도 안 했다?",
#   'url': 'https://n.news.naver.com/mnews/ranking/article/659/0000017194?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '김한규 "이낙연, 신당 창당은 수순… 지난 주말 마음 굳혀 …',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/079/0003843287?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '하노이 사람과 거리를 그리고 또 그리다',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/036/0000049137?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '"가성비 유행이라더니"…30만원짜리 케이크 없어서 못 산다',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/031/0000796451?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '당뇨병 환자, 약 먹어도 체중 줄여야 하는 이유는?',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/662/0000033894?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '與 장제원 불출마·김기현 사퇴…野 "이재명은?" 후폭풍',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/629/0000254634?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': "'기각' 확신 송영길, '발부' 자신 檢…한 쪽은 치명상",
#   'url': 'https://n.news.naver.com/mnews/ranking/article/586/0000069423?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '세계 최대 ‘용인 반도체 클러스터’ 최고 수혜지는?',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/037/0000033528?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '[날씨]전국에 많은 비...강원영동 내일까지 120mm 폭 …',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/310/0000112732?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '소액주주 상륙작전',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/607/0000001772?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': 'Leaders of Korea, Netherlands de …',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/640/0000047257?ntype=RANKING&sid=001'},
#  {'category': 'IT,과학',
#   'title': '삼성물산, 美 행동주의 펀드에 또 공격 받았다',
#   'url': 'https://n.news.naver.com/mnews/ranking/article/293/0000049701?ntype=RANKING&sid=001'},
#  ...]

# %%
q = len(articles)

for i in range(q-1, -1, -1):
    url = articles[i]['url']

    for j in range(i-1, -1, -1):
        if url == articles[j]['url']:
            del(articles[i])
            break

r = len(articles)

print("before:", q, "after:", r)

# %% [markdown]
# - 리스트의 중복제거를 내장함수로 앞 순서대로 하게 되면 삭제된 원소에 의해 순서가 꼬일 우려가 있기 때문에 뒤에서부터 하는것이 원칙

# %% [markdown]
# ## #03. 기사 본문 가져오기
#
# ### [1] 함수 정의

# %%
def getArticleBody(session, url):
    try:
        r = session.get(url)
        
        if r.status_code != 200:
            msg = "[%d Error] %s 에러가 발생함" % (r.status_code, r.reason)
            raise Exception(msg)
    except Exception as e:
        print("접속에 실패했습니다.")
        print(e)
        
    r.encoding = "utf-8"
    soup = BeautifulSoup(r.text)
    
    content = soup.select("#dic_area")
    
    if not content:
        print("컨텐츠 수집 실패 >>", url)
        return
    
    content = content[0]
    
    # 본문 요소에 포함되어 있는 불필요 항목 제거
    for target in content.find_all("table", {"class": "nbd_table"}):
        target.extract()
        
    for target in content.find_all("span", {"class": "end_photo_org"}):
        target.extract()
                    
    for target in content.find_all("strong", {"class": "media_end_summary"}):
        target.extract()
        
    for target in content.find_all("div", {"class": "highlightBlock"}):
        target.extract()
        
    for target in content.find_all("div", {"style": "display:none;"}):
        target.extract()
        
    for target in content.find_all("br"):
        target.replace_with("\n")
    
    #print(content.text.strip())
    
    #print(mf.markdownify(str(content)).strip())
    
    return content.text.strip()

# %% [markdown]
# #### 함수 테스트

# %%
txt = getArticleBody(session, "https://n.news.naver.com/mnews/article/018/0005637593?sid=102")
print(txt)
# Out:
# [이데일리 홍수현 기자] 중앙분리대 틈 사이를 기어 나와 무단횡단을 시도하는 보행자 모습이 포착돼 공분을 사고 있다.
#
# 14일 MBC는 대구 북구 침산동의 한 도로에서 지난 주말 찍힌 차량 블랙박스 영상을 보도하며 무단횡단에 대한 경각심을 일깨웠다.
#
# 영상은 1차선으로 주행 중인 블랙박스 차량 시점으로 시작된다. 이때 갑자기 중앙분리대 밑에서 무언가 꿈틀하더니 쑥 올라와 운전자를 당황하게 만들었다. 중앙분리대 밑에서 기어나온 건 다름아닌 사람이었다.
#
# 이 사람은 차량이 연이어 오는데도 아랑곳 않고 기어이 중앙분리대 밑에서 나와 무단횡단을 이어갔다. 사방이 어둑한 상태라 자칫 큰 사고로 이어질 수 있는 상황이었다.
#
# 이런 일이 이번이 처음은 아니다. 지난달 인천에서도 중앙분리대 밑을 기어나오는 어르신이 목격됐다.
#
# 당시에도 이 모습을 본 차량이 급히 속도를 줄이면서 다행히 사고로 이어지진 않았지만 노인을 향한 비판의 목소리가 거셌다.

# %% [markdown]
# ### [2] 기사 본문 수집
#
# 하나의 기사를 수집하는 즉시 파일로 저장한다.
#
# 약 10만건의 기사 본문을 수집하여 빈 리스트에 저장할 경우 컴퓨터 메모리 낭비가 심하기 때문에 1건씩 파일로 기록하고 별도의 메모리 공간에는 저장하지 않도록 하는 것이 이상적인 처리이다.
#
# #### 파일이 저장될 폴더 생성

# %%
# 파일이 저장될 폴더 생성
dirname = dt.datetime.now().strftime("뉴스기사_수집_%y%m%d_%H%M%S")

if not os.path.exists(dirname):
    os.mkdir(dirname)

# %% [markdown]
# #### 뉴스기사 수집
#
# 파일이름에 포함 될 수 없는 특수문자는 `\`, `/`, `:`, `*`, `?`, `<`, `>`, `|`, `"`, `'`, 이다.
#
# 파이썬은 정규표현식을 지원하는 re 패키지를 제공한다.
#
# 원본 문자열에서 정규표현식을 충족하는 글자를 다른 내용으로 치환하기
#
# ```python
# import re
# foo = re.sub(정규표현식, 변경할내용, 원본문자열)
# ```
#
# ```python
# title = '<제목> "입"\'\'니다**'
# filename = re.sub("[\\/:*?<>|\"\']", "", title) + '.xls'
# ```

# %%
progress = tqdm(total=len(articles))

with futures.ThreadPoolExecutor(max_workers=10) as executor:
    for i, v in enumerate(articles):
        #print(v)
        
        #print(v['category'])
        #print(v['title'])
        #print(v['url'])
        
        fu = executor.submit(getArticleBody, session, v['url'])
        result = fu.result()
        fu.add_done_callback(lambda x : progress.update())
        
        if result:
            title = re.sub("[\\/:*?<>|\"\']", "", v['title'])
            
            fname = "%s/[%s] %s.txt" % (dirname, v['category'], title)
            with open(fname, 'w', encoding='utf-8') as f:
                f.write(result)
                
            print(fname,"(이)가 생성되었습니다.")
# Out:
#   0%|          | 0/6829 [00:00<?, ?it/s]
# 뉴스기사_수집_231214_110556/[IT,과학] 개인정보위, 해킹 무방비 안전조치 의무 위반 업체 2곳 제재.txt (이)가 생성되었습니다.
# 뉴스기사_수집_231214_110556/[IT,과학]
….txt (이)가 생성되었습니다.
# 뉴스기사_수집_231214_110556/[IT,과학] 불륜 교수·여대생 신상 퍼지자…폭로한 아내 제발 멈춰 ….txt (이)가 생성되었습니다.
# 뉴스기사_수집_231214_110556/[IT,과학] 엄마가 나약해서가 아니야… 대전교사 사망 100일 여전 ….txt (이)가 생성되었습니다.
# 뉴스기사_수집_231214_110556/[IT,과학] 인구 위기가 나혼산 금쪽이 때문...시청자는 바 ….txt (이)가 생성되었습니다.
# 뉴스기사_수집_231214_110556/[IT,과학] [단독] 법원 전광훈 구속심사 수갑 착용 위법…국가가 배 ….txt (이)가 생성되었습니다.
# 뉴스기사_수집_231214_110556/[IT,과학] 할 얘기가 있어요 40대 성폭행 피해자, 가해 중학생  ….txt (이)가 생성되었습니다.
# 뉴스기사_수집_231214_110556/[IT,과학] 은행 점포가 사라진다… 신한·우리 내년 영업점 15곳 통폐 ….txt (이)가 생성되었습니다.
# 뉴스기사_수집_231214_110556/[IT,과학] 영화 ‘서울의 봄’에 분노한 2030세대, 역사를 다시 봄.txt (이)가 생성되었습니다.
# 뉴스기사_수집_231214_110556/[IT,과학] 통신사 와이파이존, 타사 고객 못쓴다.txt (이)가 생성되었습니다.
# 뉴스기사_수집_231214_110556/[IT,과학] “눈에 ‘돌’ 있다” 실제 사진 충격…너도나도 끼던 렌즈  ….txt (이)가 생성되었습니다.
# 뉴스기사_수집_231214_110556/[IT,과학] 망사용료 비싸 한국 떠난 트위치, 빈틈 노리는 네이 ….txt (이)가 생성되었습니다.
# 뉴스기사_수집_231214_110556/[IT,과학] 12억 찍은 아파트가 7억원대로…노·도·강 울상.txt (이)가 생성되었습니다.
# 뉴스기사_수집_231214_110556/[IT,과학] “전기차, 진짜 큰일났다”…안팔리는데 설상가상, 3천만원대 ….txt (이)가 생성되었습니다.
# 뉴스기사_수집_231214_110556/[IT,과학] 국민 57.5% 민주당 분당…이낙연 신당 지지율 7 ….txt (이)가 생성되었습니다.
# 뉴스기사_수집_231214_110556/[IT,과학] 이준석, 이례적 尹 칭찬 “공산주의자 활동 이력 이위종  ….txt (이)가 생성되었습니다.
# 뉴스기사_수집_231214_110556/[IT,과학] 흉물 방치 두산연수원, 호텔·콘도 변경 추진.txt (이)가 생성되었습니다.
# 뉴스기사_수집_231214_110556/[IT,과학] 애 낳으면 5억 파격 대출…올해 애 낳았는데, 대출 될까요 ….txt (이)가 생성되었습니다.
# 뉴스기사_수집_231214_110556/[IT,과학] 태국 20대 여성의원, 징역 6년형…대체 무슨 일이.txt (이)가 생성되었습니다.
# 뉴스기사_수집_231214_110556/[IT,과학] 뇌 축소 막으려면…당장 끊어라.txt (이)가 생성되었습니다.
# 뉴스기사_수집_231214_110556/[IT,과학] [타임라인] 승자의 저주...SM 인수부터 대표  ….txt (이)가 생성되었습니다.
# 뉴스기사_수집_231214_110556/[IT,과학] 황의조·친형수, 알고 보니 같은 로펌이었다…‘쌍방대리’ 지 ….txt (이)가 생성되었습니다.
# 뉴스기사_수집_231214_110556/[IT,과학] 퇴마의식…병원 입원한 장모에게 불붙인 사위 징역형.txt (이)가 생성되었습니다.
# 뉴스기사_수집_231214_110556/[IT,과학] ‘서울의 봄’ 단체관람 막겠다고…학교 앞까지 들이닥친 극우 ….txt (이)가 생성되었습니다.
# 뉴스기사_수집_231214_110556/[IT,과학] “‘이것’하면 뇌 쪼그라든다” 알츠하이머·치매 연관 주목.txt (이)가 생성되었습니다.
# 뉴스기사_수집_231214_110556/[IT,과학] 김건희 여사 개 식용 금지는 대통령 약속…조속히 통과 되 ….txt (이)가 생성되었습니다.
# 뉴스기사_수집_231214_110556/[IT,과학] 아이폰서 삼성페이 가능해지나…애플, NFC 개방.txt (이)가 생성되었습니다.
# 뉴스기사_수집_231214_110556/[IT,과학] [단독]김기현, 사퇴 전 이상민과 회동 “국민의힘 입당 논 ….txt (이)가 생성되었습니다.
# 뉴스기사_수집_231214_110556/[IT,과학] 두바이서 날아온 사망진단서... 세계 경악시킨 석유공사 ….txt (이)가 생성되었습니다.
# 뉴스기사_수집_231214_110556/[IT,과학] 2024년 부동산 제도 이렇게 바뀐다…청년·출산 주목.txt (이)가 생성되었습니다.
# 뉴스기사_수집_231214_110556/[IT,과학] 기각 확신 송영길, 발부 자신 檢…한 쪽은 치명상.txt (이)가 생성되었습니다.
# 뉴스기사_수집_231214_110556/[IT,과학] SM시세조종 첫 재판서 딱 잡아뗀 카카오…검찰 “폰 비번  ….txt (이)가 생성되었습니다.
# 뉴스기사_수집_231214_110556/[IT,과학] 美연준, 금리 3회 연속 동결…내년 3차례 인하 시사.txt (이)가 생성되었습니다.
# 뉴스기사_수집_231214_110556/[IT,과학] [단독] 檢 송영길, 차명폰으로 수사 상황 파악…증거 ….txt (이)가 생성되었습니다.
# 뉴스기사_수집_231214_110556/[IT,과학] 중학생 아들과 짜고 남편 잔인하게 살해한 40대 무기징역  ….txt (이)가 생성되었습니다.
# 뉴스기사_수집_231214_110556/[IT,과학] 1년간 돌본 환자 숨졌는데.. 고인 체크카드로 4천만  ….txt (이)가 생성되었습니다.
# 뉴스기사_수집_231214_110556/[IT,과학] 소액주주 상륙작전.txt (이)가 생성되었습니다.
# 뉴스기사_수집_231214_110556/[IT,과학] 한동훈에 견제구 안철수 한동훈은 尹정권 책임자…확장성 ….txt (이)가 생성되었습니다.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 12
#       4 for i, v in enumerate(articles):
#       5     #print(v)
#       6
#       7     #print(v['category'])
#       8     #print(v['title'])
#       9     #print(v['url'])
#      11     fu = executor.submit(getArticleBody, session, v['url'])
# ---> 12     result = fu.result()
#      13     fu.add_done_callback(lambda x : progress.update())
#      15     if result:
#
# File c:\Users\leekh\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File c:\Users\leekh\AppData\Local\Programs\Python\Python312\Lib\threading.py:334, in Condition.wait(self, timeout)
#     332 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     333     if timeout is None:
# --> 334         waiter.acquire()
#     335         gotit = True
#     336     else:
#
# KeyboardInterrupt:
