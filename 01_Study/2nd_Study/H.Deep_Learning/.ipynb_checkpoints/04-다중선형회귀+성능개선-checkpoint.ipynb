# %% [markdown]
# # 다중선형회귀 + 학습성능 개선
#
# > 농어의 무게 예측 데이터 셋
#
# 텐서플로우의 학습성능을 개선하기 위해 아래의 기능을 사용할 수 있음
#
# - 데이터 표준화: 학습률 향상에 도움을 줌
# - 콜백함수: 모델의 학습 방향, 저장 시점, 학습 정지 시점 등에 관한 상황을 설정 하기 위한 도구
#
# ## #01. 준비작업
#
# ### [1] 패키지 가져오기

# %%
import os
os.chdir("Y:\Python\Mega_IT\H.Deep_Learning")
os.getcwd()
# Out:
# 'Y:\\Python\\Mega_IT\\H.Deep_Learning'

# %%
# 연결된 모듈이 업데이트 되면 즉시 자동 로드함
# %load_ext autoreload
# %autoreload 2

from hossam.util import *
from hossam.plot import *

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# 학습에 대한 콜백함수 참조
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### [2] 데이터셋 준비하기

# %%
origin = my_read_excel('https://data.hossam.kr/mldata/fish.xlsx', info=False)

# %% [markdown]
# ## #02. 데이터 전처리
#
# ### [1] 훈련/검증 데이터 분리
#
# **데이터 정규화(스케일링)** 을 수행함
#
# 데이터에 정규화 처리를 적용하면 쉽게 최적값에 도달할 수 있으며 학습률을 상대적으로 높여서 사용할 수 있기 때문에 빠르게 훈련시킬 수 있다.

# %%
x_train, x_test, y_train, y_test = my_train_test_split(origin, yname='무게', scalling=True)
rows, cols = x_train.shape
rows, cols
# Out:
# (44, 3)

# %% [markdown]
# ## #03. 훈련 모델 적합
#
# ### [1] 신경망 정의
#
# | 구분 | 모델 | 활성화 함수 | 옵티마이저 | 손실함수 | 평가지표 | 대표예제 |
# |--|--|--|--|--|--|--|
# | 회귀 | 단순선형회귀 | relu, relu, linear | adam | mse | mae | 보스턴 집값 예측 |

# %%
model = Sequential()
# 최종 검증 손실률: 169142.234375, 최종 검증 절대오차: 315.249176
# model.add(Dense(4, activation = 'relu', input_shape = (cols, )))
# model.add(Dense(2, activation = 'relu'))

# 최종 검증 손실률: 193492.796875, 최종 검증 절대오차: 347.600739
model.add(Dense(8, activation = 'relu', input_shape = (cols, )))
model.add(Dense(4, activation = 'relu'))

# ... (16, 8), (32, 16) 에 대한 테스트 결과는 생략함

# 최종 검증 손실률: 2974.242920, 최종 검증 절대오차: 36.543842
model.add(Dense(64, activation = 'relu', input_shape = (cols, )))
model.add(Dense(32, activation = 'relu'))

# 최종 검증 손실률: 4515.570801, 최종 검증 절대오차: 40.064499
# model.add(Dense(128, activation = 'relu', input_shape = (cols, )))
# model.add(Dense(64, activation = 'relu'))

model.add(Dense(1, activation='linear'))
model.compile(optimizer = 'adam', loss = 'mse', metrics = ['mae'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 8)                 32
#
#  dense_1 (Dense)             (None, 4)                 36
#
#  dense_2 (Dense)             (None, 64)                320
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  dense_4 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2,501
# Trainable params: 2,501
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### 8, 4
#
# 최종 검증 손실률: 193492.796875, 최종 검증 절대오차: 347.600739
#
# ![img](res/fish-8,4.png)
#
# #### 64, 32
#
# 최종 검증 손실률: 2974.242920, 최종 검증 절대오차: 36.543842
#
# ![img](res/fish-64,32.png)
#
# #### 128, 64
#
# 최종 검증 손실률: 4515.570801, 최종 검증 절대오차: 40.064499
#
# ![img](res/fish-128,64.png)

# %% [markdown]
# ### [2] 콜백함수를 적용하여 학습하기
#
# 모델의 학습 방향, 저장 시점, 학습 정지 시점 등에 관한 상황을 설정하기 위한 도구
#
# #### 콜백함수 사용 방법
#
# ```python
# # 콜백 정의
# callbacks = [  콜백1, 콜백2, ... 콜백n  ]
#
# # 학습을 위한 fit() 함수에서 callbacks 파라미터에 미리 정의한 리스트를 지정
# callbacks = [콜백1, 콜백2, ... , 콜백n]
# model.fit(x_train, y_train, validation_data = (x_val, y_val), epochs = 500,
#         callbacks = callbacks)
# ```
#
# 혹은
#
# ```python
# model.fit(x_train, y_train, validation_data = (x_val, y_val), epochs = 500,
#     callbacks = [
#         콜백1, 콜백2, ... , 콜백n
# ])
# ```
#
# #### 콜백함수 종류
#
# ##### 1) EarlyStopping()
#
# 모델 학습 시에 지정된 기간 동안 모니터링하는 평가지표에서 더 이상 성능 향상이 일어나지 않은 경우 학습을 스스로 중단
#
# ```python
# EarlyStopping(monitor='평가지표', patience=10, verbose=1)
# ```
#
# - patience: 지정한 수만큼의 기간에서 평가지표의 향상이 일어나지 않을 경우 학습을 중단 (기간이라 함은 에폭을 의미) 예를 들어 patience=10일 때, 10에폭 동안 성능 향상이 일어나지 않으면 학습을 중단. 즉, 10회 이상 성능향상이 발견되지 않으면 중단함
# - verbose: 콜백의 수행 과정 노출 여부를 지정.
#     - 0: 아무런 표시 하지 않음(기본값)
#     - 1: 프로그래스바로 표시
#     - 2: 매 에폭마다 수행과정을 자세하게 출력함.
#
#
# ##### 2) ReduceLROnPlateau()
#
# EarlyStopping 콜백과 같이 patience 인자를 지정하여, 지정된 기간 동안 평가지표에서 성능 향상이 일어나지 않으면 학습률을 조정하는 콜백
#
# ```python
# ReduceLROnPlateau(monitor='평가지표', factor=0.1, patience=10, min_lr=0, verbose=1)
# ```
#
# - factor: 학습률 조정에 사용되는 값 (새로운 학습률 = factor * 기존 학습률)
# - patience: 지정한 수만큼의 기간에서 성능 향상이 일어나지 않을 경우, 학습률을 조정
# - min_lr: 학습률의 하한을 지정
# - verbose: 콜백의 수행 과정 노출 여부를 지정.
#
#
# ##### 3) ModelCheckpoint()
#
# 지정한 평가지표를 기준으로 가장 뛰어난 성능을 보여주는 모델을 저장 할 때 사용
#
# ```python
# ModelCheckpoint(filepath, monitor='평가지표', verbose=1, save_best_only=True|False, save_weights_only=False)
# ```
#
# - filepath: 모델의 저장 경로를 지정
# - save_best_only: True인 경우, 가장 성능이 뛰어난 모델만 저장. 그보다 좋지 않은 모델의 경우는 덮어쓰지 않는다.
# - save_weights_only: 모델의 가중치만 저장

# %%
# %%time
# 파일이 저장될 경로(폴더) 지정 (한글,공백,점(.)이 포함되어 있을 경우 에러 발생함)

result = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=500, verbose=0, callbacks=[
    EarlyStopping(monitor='val_loss', patience=10, verbose=0),
    ReduceLROnPlateau(monitor= "val_loss", patience=3, factor = 0.1, min_lr=0.0001, verbose=0),
    ModelCheckpoint(filepath="./models/ex/model04-cp-{epoch:04d}-ckpt.keras", monitor='val_loss', verbose=1, save_best_only=True)
])

evaluate1 = model.evaluate(x_train, y_train)
print("최종 훈련 손실률: %f, 최종 훈련 절대오차: %f" % (evaluate1[0], evaluate1[1]))

evaluate2 = model.evaluate(x_test, y_test)
print("최종 검증 손실률: %f, 최종 검증 절대오차: %f" % (evaluate2[0], evaluate2[1]))

result_df = DataFrame(result.history)
result_df["epochs"] = result_df.index + 1
result_df.set_index('epochs', inplace=True)
result_df
# Out:
# Epoch 1: val_loss improved from inf to 313996.28125, saving model to ./models/ex\model04-cp-0001-ckpt.keras
#
# Epoch 2: val_loss improved from 313996.28125 to 313974.96875, saving model to ./models/ex\model04-cp-0002-ckpt.keras
#
# Epoch 3: val_loss improved from 313974.96875 to 313953.18750, saving model to ./models/ex\model04-cp-0003-ckpt.keras
#
# Epoch 4: val_loss improved from 313953.18750 to 313929.96875, saving model to ./models/ex\model04-cp-0004-ckpt.keras
#
# Epoch 5: val_loss improved from 313929.96875 to 313905.75000, saving model to ./models/ex\model04-cp-0005-ckpt.keras
#
# Epoch 6: val_loss improved from 313905.75000 to 313880.21875, saving model to ./models/ex\model04-cp-0006-ckpt.keras
#
# Epoch 7: val_loss improved from 313880.21875 to 313852.84375, saving model to ./models/ex\model04-cp-0007-ckpt.keras
#
# Epoch 8: val_loss improved from 313852.84375 to 313823.15625, saving model to ./models/ex\model04-cp-0008-ckpt.keras
#
# Epoch 9: val_loss improved from 313823.15625 to 313790.90625, saving model to ./models/ex\model04-cp-0009-ckpt.keras
#
# Epoch 10: val_loss improved from 313790.90625 to 313756.28125, saving model to ./models/ex\model04-cp-0010-ckpt.keras
#
# Epoch 11: val_loss improved from 313756.28125 to 313718.53125, saving model to ./models/ex\model04-cp-0011-ckpt.keras
#
# Epoch 12: val_loss improved from 313718.53125 to 313676.90625, saving model to ./models/ex\model04-cp-0012-ckpt.keras
#
# Epoch 13: val_loss improved from 313676.90625 to 313631.56250, saving model to ./models/ex\model04-cp-0013-ckpt.keras
#
# Epoch 14: val_loss improved from 313631.56250 to 313582.25000, saving model to ./models/ex\model04-cp-0014-ckpt.keras
#
# Epoch 15: val_loss improved from 313582.25000 to 313528.78125, saving model to ./models/ex\model04-cp-0015-ckpt.keras
#
# Epoch 16: val_loss improved from 313528.78125 to 313471.00000, saving model to ./models/ex\model04-cp-0016-ckpt.keras
#
# Epoch 17: val_loss improved from 313471.00000 to 313408.09375, saving model to ./models/ex\model04-cp-0017-ckpt.keras
#
# Epoch 18: val_loss improved from 313408.09375 to 313338.96875, saving model to ./models/ex\model04-cp-0018-ckpt.keras
#
# Epoch 19: val_loss improved from 313338.96875 to 313263.59375, saving model to ./models/ex\model04-cp-0019-ckpt.keras
#
# Epoch 20: val_loss improved from 313263.59375 to 313181.34375, saving model to ./models/ex\model04-cp-0020-ckpt.keras
#
# Epoch 21: val_loss improved from 313181.34375 to 313090.65625, saving model to ./models/ex\model04-cp-0021-ckpt.keras
#
# Epoch 22: val_loss improved from 313090.65625 to 312991.68750, saving model to ./models/ex\model04-cp-0022-ckpt.keras
#
# Epoch 23: val_loss improved from 312991.68750 to 312883.46875, saving model to ./models/ex\model04-cp-0023-ckpt.keras
#
# Epoch 24: val_loss improved from 312883.46875 to 312765.09375, saving model to ./models/ex\model04-cp-0024-ckpt.keras
#
# Epoch 25: val_loss improved from 312765.09375 to 312636.56250, saving model to ./models/ex\model04-cp-0025-ckpt.keras
#
# Epoch 26: val_loss improved from 312636.56250 to 312496.81250, saving model to ./models/ex\model04-cp-0026-ckpt.keras
#
# Epoch 27: val_loss improved from 312496.81250 to 312347.15625, saving model to ./models/ex\model04-cp-0027-ckpt.keras
#
# Epoch 28: val_loss improved from 312347.15625 to 312185.21875, saving model to ./models/ex\model04-cp-0028-ckpt.keras
#
# Epoch 29: val_loss improved from 312185.21875 to 312007.37500, saving model to ./models/ex\model04-cp-0029-ckpt.keras
#
# Epoch 30: val_loss improved from 312007.37500 to 311810.96875, saving model to ./models/ex\model04-cp-0030-ckpt.keras
#
# Epoch 31: val_loss improved from 311810.96875 to 311597.00000, saving model to ./models/ex\model04-cp-0031-ckpt.keras
#
# Epoch 32: val_loss improved from 311597.00000 to 311362.03125, saving model to ./models/ex\model04-cp-0032-ckpt.keras
#
# Epoch 33: val_loss improved from 311362.03125 to 311105.90625, saving model to ./models/ex\model04-cp-0033-ckpt.keras
#
# Epoch 34: val_loss improved from 311105.90625 to 310827.78125, saving model to ./models/ex\model04-cp-0034-ckpt.keras
#
# Epoch 35: val_loss improved from 310827.78125 to 310527.40625, saving model to ./models/ex\model04-cp-0035-ckpt.keras
#
# Epoch 36: val_loss improved from 310527.40625 to 310199.34375, saving model to ./models/ex\model04-cp-0036-ckpt.keras
#
# Epoch 37: val_loss improved from 310199.34375 to 309846.68750, saving model to ./models/ex\model04-cp-0037-ckpt.keras
#
# Epoch 38: val_loss improved from 309846.68750 to 309466.46875, saving model to ./models/ex\model04-cp-0038-ckpt.keras
#
# Epoch 39: val_loss improved from 309466.46875 to 309051.15625, saving model to ./models/ex\model04-cp-0039-ckpt.keras
#
# Epoch 40: val_loss improved from 309051.15625 to 308599.40625, saving model to ./models/ex\model04-cp-0040-ckpt.keras
#
# Epoch 41: val_loss improved from 308599.40625 to 308105.46875, saving model to ./models/ex\model04-cp-0041-ckpt.keras
#
# Epoch 42: val_loss improved from 308105.46875 to 307573.46875, saving model to ./models/ex\model04-cp-0042-ckpt.keras
#
# Epoch 43: val_loss improved from 307573.46875 to 307008.71875, saving model to ./models/ex\model04-cp-0043-ckpt.keras
#
# Epoch 44: val_loss improved from 307008.71875 to 306417.59375, saving model to ./models/ex\model04-cp-0044-ckpt.keras
#
# Epoch 45: val_loss improved from 306417.59375 to 305776.18750, saving model to ./models/ex\model04-cp-0045-ckpt.keras
#
# Epoch 46: val_loss improved from 305776.18750 to 305075.62500, saving model to ./models/ex\model04-cp-0046-ckpt.keras
#
# Epoch 47: val_loss improved from 305075.62500 to 304312.87500, saving model to ./models/ex\model04-cp-0047-ckpt.keras
#
# Epoch 48: val_loss improved from 304312.87500 to 303484.03125, saving model to ./models/ex\model04-cp-0048-ckpt.keras
#
# Epoch 49: val_loss improved from 303484.03125 to 302591.09375, saving model to ./models/ex\model04-cp-0049-ckpt.keras
#
# Epoch 50: val_loss improved from 302591.09375 to 301624.00000, saving model to ./models/ex\model04-cp-0050-ckpt.keras
#
# Epoch 51: val_loss improved from 301624.00000 to 300588.87500, saving model to ./models/ex\model04-cp-0051-ckpt.keras
#
# Epoch 52: val_loss improved from 300588.87500 to 299465.62500, saving model to ./models/ex\model04-cp-0052-ckpt.keras
#
# Epoch 53: val_loss improved from 299465.62500 to 298274.62500, saving model to ./models/ex\model04-cp-0053-ckpt.keras
#
# Epoch 54: val_loss improved from 298274.62500 to 297005.90625, saving model to ./models/ex\model04-cp-0054-ckpt.keras
#
# Epoch 55: val_loss improved from 297005.90625 to 295638.46875, saving model to ./models/ex\model04-cp-0055-ckpt.keras
#
# Epoch 56: val_loss improved from 295638.46875 to 294158.53125, saving model to ./models/ex\model04-cp-0056-ckpt.keras
#
# Epoch 57: val_loss improved from 294158.53125 to 292568.71875, saving model to ./models/ex\model04-cp-0057-ckpt.keras
#
# Epoch 58: val_loss improved from 292568.71875 to 290880.21875, saving model to ./models/ex\model04-cp-0058-ckpt.keras
#
# Epoch 59: val_loss improved from 290880.21875 to 289074.09375, saving model to ./models/ex\model04-cp-0059-ckpt.keras
#
# Epoch 60: val_loss improved from 289074.09375 to 287159.40625, saving model to ./models/ex\model04-cp-0060-ckpt.keras
#
# Epoch 61: val_loss improved from 287159.40625 to 285107.81250, saving model to ./models/ex\model04-cp-0061-ckpt.keras
#
# Epoch 62: val_loss improved from 285107.81250 to 282900.09375, saving model to ./models/ex\model04-cp-0062-ckpt.keras
#
# Epoch 63: val_loss improved from 282900.09375 to 280571.21875, saving model to ./models/ex\model04-cp-0063-ckpt.keras
#
# Epoch 64: val_loss improved from 280571.21875 to 278085.28125, saving model to ./models/ex\model04-cp-0064-ckpt.keras
#
# Epoch 65: val_loss improved from 278085.28125 to 275418.90625, saving model to ./models/ex\model04-cp-0065-ckpt.keras
#
# Epoch 66: val_loss improved from 275418.90625 to 272586.56250, saving model to ./models/ex\model04-cp-0066-ckpt.keras
#
# Epoch 67: val_loss improved from 272586.56250 to 269599.65625, saving model to ./models/ex\model04-cp-0067-ckpt.keras
#
# Epoch 68: val_loss improved from 269599.65625 to 266499.62500, saving model to ./models/ex\model04-cp-0068-ckpt.keras
#
# Epoch 69: val_loss improved from 266499.62500 to 263222.75000, saving model to ./models/ex\model04-cp-0069-ckpt.keras
#
# Epoch 70: val_loss improved from 263222.75000 to 259819.14062, saving model to ./models/ex\model04-cp-0070-ckpt.keras
#
# Epoch 71: val_loss improved from 259819.14062 to 256191.56250, saving model to ./models/ex\model04-cp-0071-ckpt.keras
#
# Epoch 72: val_loss improved from 256191.56250 to 252382.79688, saving model to ./models/ex\model04-cp-0072-ckpt.keras
#
# Epoch 73: val_loss improved from 252382.79688 to 248370.26562, saving model to ./models/ex\model04-cp-0073-ckpt.keras
#
# Epoch 74: val_loss improved from 248370.26562 to 244180.50000, saving model to ./models/ex\model04-cp-0074-ckpt.keras
#
# Epoch 75: val_loss improved from 244180.50000 to 239817.32812, saving model to ./models/ex\model04-cp-0075-ckpt.keras
#
# Epoch 76: val_loss improved from 239817.32812 to 235326.12500, saving model to ./models/ex\model04-cp-0076-ckpt.keras
#
# Epoch 77: val_loss improved from 235326.12500 to 230692.64062, saving model to ./models/ex\model04-cp-0077-ckpt.keras
#
# Epoch 78: val_loss improved from 230692.64062 to 225798.07812, saving model to ./models/ex\model04-cp-0078-ckpt.keras
#
# Epoch 79: val_loss improved from 225798.07812 to 220649.79688, saving model to ./models/ex\model04-cp-0079-ckpt.keras
#
# Epoch 80: val_loss improved from 220649.79688 to 215373.50000, saving model to ./models/ex\model04-cp-0080-ckpt.keras
#
# Epoch 81: val_loss improved from 215373.50000 to 210013.07812, saving model to ./models/ex\model04-cp-0081-ckpt.keras
#
# Epoch 82: val_loss improved from 210013.07812 to 204429.60938, saving model to ./models/ex\model04-cp-0082-ckpt.keras
#
# Epoch 83: val_loss improved from 204429.60938 to 198606.37500, saving model to ./models/ex\model04-cp-0083-ckpt.keras
#
# Epoch 84: val_loss improved from 198606.37500 to 192682.14062, saving model to ./models/ex\model04-cp-0084-ckpt.keras
#
# Epoch 85: val_loss improved from 192682.14062 to 186519.76562, saving model to ./models/ex\model04-cp-0085-ckpt.keras
#
# Epoch 86: val_loss improved from 186519.76562 to 180269.62500, saving model to ./models/ex\model04-cp-0086-ckpt.keras
#
# Epoch 87: val_loss improved from 180269.62500 to 173973.48438, saving model to ./models/ex\model04-cp-0087-ckpt.keras
#
# Epoch 88: val_loss improved from 173973.48438 to 167452.12500, saving model to ./models/ex\model04-cp-0088-ckpt.keras
#
# Epoch 89: val_loss improved from 167452.12500 to 160814.65625, saving model to ./models/ex\model04-cp-0089-ckpt.keras
#
# Epoch 90: val_loss improved from 160814.65625 to 154254.01562, saving model to ./models/ex\model04-cp-0090-ckpt.keras
#
# Epoch 91: val_loss improved from 154254.01562 to 147500.25000, saving model to ./models/ex\model04-cp-0091-ckpt.keras
#
# Epoch 92: val_loss improved from 147500.25000 to 140670.46875, saving model to ./models/ex\model04-cp-0092-ckpt.keras
#
# Epoch 93: val_loss improved from 140670.46875 to 133762.14062, saving model to ./models/ex\model04-cp-0093-ckpt.keras
#
# Epoch 94: val_loss improved from 133762.14062 to 126833.57031, saving model to ./models/ex\model04-cp-0094-ckpt.keras
#
# Epoch 95: val_loss improved from 126833.57031 to 119899.31250, saving model to ./models/ex\model04-cp-0095-ckpt.keras
#
# Epoch 96: val_loss improved from 119899.31250 to 112846.06250, saving model to ./models/ex\model04-cp-0096-ckpt.keras
#
# Epoch 97: val_loss improved from 112846.06250 to 106052.28125, saving model to ./models/ex\model04-cp-0097-ckpt.keras
#
# Epoch 98: val_loss improved from 106052.28125 to 99477.18750, saving model to ./models/ex\model04-cp-0098-ckpt.keras
#
# Epoch 99: val_loss improved from 99477.18750 to 93037.46094, saving model to ./models/ex\model04-cp-0099-ckpt.keras
#
# Epoch 100: val_loss improved from 93037.46094 to 86637.99219, saving model to ./models/ex\model04-cp-0100-ckpt.keras
#
# Epoch 101: val_loss improved from 86637.99219 to 80214.32031, saving model to ./models/ex\model04-cp-0101-ckpt.keras
#
# Epoch 102: val_loss improved from 80214.32031 to 73817.56250, saving model to ./models/ex\model04-cp-0102-ckpt.keras
#
# Epoch 103: val_loss improved from 73817.56250 to 67607.22656, saving model to ./models/ex\model04-cp-0103-ckpt.keras
#
# Epoch 104: val_loss improved from 67607.22656 to 61562.54297, saving model to ./models/ex\model04-cp-0104-ckpt.keras
#
# Epoch 105: val_loss improved from 61562.54297 to 55734.62109, saving model to ./models/ex\model04-cp-0105-ckpt.keras
#
# Epoch 106: val_loss improved from 55734.62109 to 50139.37500, saving model to ./models/ex\model04-cp-0106-ckpt.keras
#
# Epoch 107: val_loss improved from 50139.37500 to 44762.67578, saving model to ./models/ex\model04-cp-0107-ckpt.keras
#
# Epoch 108: val_loss improved from 44762.67578 to 39681.62500, saving model to ./models/ex\model04-cp-0108-ckpt.keras
#
# Epoch 109: val_loss improved from 39681.62500 to 35026.86328, saving model to ./models/ex\model04-cp-0109-ckpt.keras
#
# Epoch 110: val_loss improved from 35026.86328 to 30717.01367, saving model to ./models/ex\model04-cp-0110-ckpt.keras
#
# Epoch 111: val_loss improved from 30717.01367 to 26720.00781, saving model to ./models/ex\model04-cp-0111-ckpt.keras
#
# Epoch 112: val_loss improved from 26720.00781 to 23035.40625, saving model to ./models/ex\model04-cp-0112-ckpt.keras
#
# Epoch 113: val_loss improved from 23035.40625 to 19766.78516, saving model to ./models/ex\model04-cp-0113-ckpt.keras
#
# Epoch 114: val_loss improved from 19766.78516 to 16901.06836, saving model to ./models/ex\model04-cp-0114-ckpt.keras
#
# Epoch 115: val_loss improved from 16901.06836 to 14414.59277, saving model to ./models/ex\model04-cp-0115-ckpt.keras
#
# Epoch 116: val_loss improved from 14414.59277 to 12235.09082, saving model to ./models/ex\model04-cp-0116-ckpt.keras
#
# Epoch 117: val_loss improved from 12235.09082 to 10317.21973, saving model to ./models/ex\model04-cp-0117-ckpt.keras
#
# Epoch 118: val_loss improved from 10317.21973 to 8657.62207, saving model to ./models/ex\model04-cp-0118-ckpt.keras
#
# Epoch 119: val_loss improved from 8657.62207 to 7257.60693, saving model to ./models/ex\model04-cp-0119-ckpt.keras
#
# Epoch 120: val_loss improved from 7257.60693 to 6050.42822, saving model to ./models/ex\model04-cp-0120-ckpt.keras
#
# Epoch 121: val_loss improved from 6050.42822 to 5035.36133, saving model to ./models/ex\model04-cp-0121-ckpt.keras
#
# Epoch 122: val_loss improved from 5035.36133 to 4215.19727, saving model to ./models/ex\model04-cp-0122-ckpt.keras
#
# Epoch 123: val_loss improved from 4215.19727 to 3561.86108, saving model to ./models/ex\model04-cp-0123-ckpt.keras
#
# Epoch 124: val_loss improved from 3561.86108 to 3055.57153, saving model to ./models/ex\model04-cp-0124-ckpt.keras
#
# Epoch 125: val_loss improved from 3055.57153 to 2660.25073, saving model to ./models/ex\model04-cp-0125-ckpt.keras
#
# Epoch 126: val_loss improved from 2660.25073 to 2350.58350, saving model to ./models/ex\model04-cp-0126-ckpt.keras
#
# Epoch 127: val_loss improved from 2350.58350 to 2129.52441, saving model to ./models/ex\model04-cp-0127-ckpt.keras
#
# Epoch 128: val_loss improved from 2129.52441 to 1977.60168, saving model to ./models/ex\model04-cp-0128-ckpt.keras
#
# Epoch 129: val_loss improved from 1977.60168 to 1881.19666, saving model to ./models/ex\model04-cp-0129-ckpt.keras
#
# Epoch 130: val_loss improved from 1881.19666 to 1824.73596, saving model to ./models/ex\model04-cp-0130-ckpt.keras
#
# Epoch 131: val_loss improved from 1824.73596 to 1790.07507, saving model to ./models/ex\model04-cp-0131-ckpt.keras
#
# Epoch 132: val_loss improved from 1790.07507 to 1770.86829, saving model to ./models/ex\model04-cp-0132-ckpt.keras
#
# Epoch 133: val_loss improved from 1770.86829 to 1765.06189, saving model to ./models/ex\model04-cp-0133-ckpt.keras
#
# Epoch 134: val_loss did not improve from 1765.06189
#
# Epoch 135: val_loss did not improve from 1765.06189
#
# Epoch 136: val_loss did not improve from 1765.06189
#
# Epoch 137: val_loss did not improve from 1765.06189
#
# Epoch 138: val_loss did not improve from 1765.06189
#
# Epoch 139: val_loss did not improve from 1765.06189
#
# Epoch 140: val_loss did not improve from 1765.06189
#
# Epoch 141: val_loss did not improve from 1765.06189
#
# Epoch 142: val_loss did not improve from 1765.06189
#
# Epoch 143: val_loss did not improve from 1765.06189
# 2/2 [==============================] - 0s 2ms/step - loss: 2772.4470 - mae: 41.8630
# 최종 훈련 손실률: 2772.447021, 최종 훈련 절대오차: 41.863037
# 1/1 [==============================] - 0s 15ms/step - loss: 1793.8812 - mae: 31.0944
# 최종 검증 손실률: 1793.881226, 최종 검증 절대오차: 31.094381
# CPU times: total: 1.11 s
# Wall time: 7.46 s
#                  loss         mae       val_loss     val_mae      lr
# epochs
# 1       251358.187500  365.738251  313996.281250  442.729340  0.0010
# 2       251336.937500  365.711517  313974.968750  442.706573  0.0010
# 3       251318.500000  365.685547  313953.187500  442.683685  0.0010
# 4       251299.343750  365.659760  313929.968750  442.659760  0.0010
# 5       251278.546875  365.633331  313905.750000  442.635010  0.0010
# ...               ...         ...            ...         ...     ...
# 139       2786.051025   41.962734    1787.731812   31.029928  0.0001
# 140       2783.303467   41.945248    1789.545532   31.048553  0.0001
# 141       2781.004150   41.927822    1791.178711   31.065527  0.0001
# 142       2777.404541   41.901699    1792.423462   31.078638  0.0001
# 143       2775.008545   41.881485    1793.881226   31.094381  0.0001
#
# [143 rows x 5 columns]

# %% [markdown]
# ### [3] 훈련 결과 시각화

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 5), dpi=150)
result_df.plot(y=['loss', 'val_loss'], ax=ax[0])
result_df.plot(y=['mae', 'val_mae'], ax=ax[1])
ax[0].set_title('loss')
ax[1].set_title('mae')
ax[0].grid()
ax[1].grid()
plt.show()
plt.close()

# %% [markdown]
# ## #04. 예측 결과 활용
#
# ### [1] 예측치 구하기

# %%
pred =  model.predict(x_test, verbose=0)
pred
# Out:
# array([[ 117.23009 ],
#        [ 122.64312 ],
#        [ 806.0064  ],
#        [ 137.58162 ],
#        [ 715.2829  ],
#        [ 125.75735 ],
#        [1000.00214 ],
#        [ 276.9826  ],
#        [ 830.84814 ],
#        [ 119.735535],
#        [ 750.2011  ],
#        [ 116.97539 ]], dtype=float32)

# %% [markdown]
# ### [2] 결과 데이터 셋 구성

# %%
kdf = DataFrame({
    '길이': x_test['길이'],
    '실제값': y_test,
    '예측값' : pred.flatten()
})

kdf['오차'] = kdf['실제값']-kdf['예측값']

my_pretty_table(kdf)
# Out:
# +----+-----------+----------+----------+----------+
# |    |      길이 |   실제값 |   예측값 |     오차 |
# |----+-----------+----------+----------+----------|
# | 18 | -0.588079 |      110 |   117.23 | -7.23009 |
# | 13 |  -0.66412 |      130 |  122.643 |  7.35688 |
# | 50 |   1.36725 |      820 |  806.006 |  13.9936 |
# | 26 | -0.305643 |      188 |  137.582 |  50.4184 |
# | 41 |  0.932731 |      700 |  715.283 | -15.2829 |
# | 27 | -0.262192 |      180 |  125.757 |  54.2427 |
# | 53 |   1.69314 |     1100 |     1000 |  99.9979 |
# | 35 |  0.139737 |      300 |  276.983 |  23.0174 |
# | 39 |  0.824101 |      840 |  830.848 |  9.15186 |
# | 21 | -0.512039 |      145 |  119.736 |  25.2645 |
# | 40 |  0.987045 |      685 |  750.201 | -65.2011 |
# | 11 | -0.696709 |      115 |  116.975 | -1.97539 |
# +----+-----------+----------+----------+----------+

# %% [markdown]
# ### [3] 관측치와 예측치 비교 시각화

# %%
fig = plt.figure(figsize=(10, 5), dpi=150)
ax = fig.gca()

sb.regplot(data=kdf, x='길이', y='실제값', label='실제값', ax=ax)
sb.regplot(data=kdf, x='길이', y='예측값', label='예측값', ax=ax)
ax.legend()
ax.grid()
plt.show()
plt.close()
