# %% [markdown]
# # 단순선형회귀
#
# > 속도에 따른 제동거리 예측 데이터셋
#
# ## #01. 준비작업
#
# ### [1] 패키지 가져오기

# %%
# 연결된 모듈이 업데이트 되면 즉시 자동 로드함
# %load_ext autoreload
# %autoreload 2

from hossam.util import *
from hossam.plot import *

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

from ipywidgets import interact
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### [2] 데이터셋 준비하기

# %%
origin = my_read_excel('https://data.hossam.kr/mldata/cars.xlsx', info=False)
# Out:
# 상위 5개 행
# +----+---------+--------+
# |    |   speed |   dist |
# |----+---------+--------|
# |  0 |       4 |      2 |
# |  1 |       4 |     10 |
# |  2 |       7 |      4 |
# |  3 |       7 |     22 |
# |  4 |       8 |     16 |
# +----+---------+--------+

# %% [markdown]
# ## #02. 데이터 전처리
#
# ### [1] 훈련/검증 데이터 분리

# %%
x_train, x_test, y_train, y_test = my_train_test_split(origin, yname='dist', test_size = 0.3)
rows, cols = x_train.shape
rows, cols
# Out:
# (35, 1)

# %% [markdown]
# ## #03. 훈련 모델 적합
#
# ### [1] 신경망 정의
#
# | 구분 | 모델 | 활성화 함수 | 옵티마이저 | 손실함수 | 평가지표 | 대표예제 |
# |--|--|--|--|--|--|--|
# | 회귀 | 단순선형회귀 | relu, linear | adam | mse | mae | |

# %%
model = Sequential()

# 최종 검증 손실률: 374.854431, 최종 검증 절대오차: 15.983886
# model.add(Dense(2, activation = 'relu', input_shape = (cols, )))

# 최종 검증 손실률: 376.018341, 최종 검증 절대오차: 15.594769
model.add(Dense(4, activation = 'relu', input_shape = (cols, )))

# 최종 검증 손실률: 377.073425, 최종 검증 절대오차: 16.292393
# model.add(Dense(8, activation = 'relu', input_shape = (cols, )))

# 최종 검증 손실률: 380.726410, 최종 검증 절대오차: 16.663055
# model.add(Dense(16, activation = 'relu', input_shape = (cols, )))

# 최종 검증 손실률: 386.750305, 최종 검증 절대오차: 17.112757
# model.add(Dense(32, activation = 'relu', input_shape = (cols, )))

# 하나의 값을 출력
# -> 정답의 범위가 정해지지 않기 때문에 활성화 함수는 linear
# -> linear는 기본값이므로 생략 가능함.
model.add(Dense(1, activation='linear'))

# 손실함수는 mse, 최적화 함수는 adam --> 문자열로 지정하는 것도 가능함
model.compile(optimizer = 'adam', loss = 'mse', metrics = ['mae'])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 4)              │             8 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13 (52.00 B)
#  Trainable params: 13 (52.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### [2] 학습하기

# %%
# %%time
result = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=500, verbose=0)

evaluate1 = model.evaluate(x_train, y_train)
print("최종 훈련 손실률: %f, 최종 훈련 절대오차: %f" % (evaluate1[0], evaluate1[1]))

evaluate2 = model.evaluate(x_test, y_test)
print("최종 검증 손실률: %f, 최종 검증 절대오차: %f" % (evaluate2[0], evaluate2[1]))

result_df = DataFrame(result.history)
result_df["epochs"] = result_df.index + 1
result_df.set_index('epochs', inplace=True)
result_df
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 639.0485 - mae: 18.0403
# 최종 훈련 손실률: 650.734680, 최종 훈련 절대오차: 18.251259
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 634.9805 - mae: 17.4422
# 최종 검증 손실률: 634.980469, 최종 검증 절대오차: 17.442221
# CPU times: total: 27.4 s
# Wall time: 23.3 s
#                loss        mae     val_loss    val_mae
# epochs
# 1       4418.603027  58.631523  3743.888184  55.649868
# 2       4407.999512  58.553089  3734.807373  55.573910
# 3       4397.397461  58.475674  3725.759033  55.498127
# 4       4387.000977  58.398697  3716.879150  55.423656
# 5       4376.460938  58.321751  3708.109375  55.350010
# ...             ...        ...          ...        ...
# 496      668.393066  18.561043   645.579163  17.648853
# 497      664.801636  18.494797   643.012451  17.599190
# 498      661.265503  18.435520   640.342529  17.547277
# 499      657.813477  18.371801   637.624268  17.494158
# 500      654.162964  18.307901   634.980469  17.442221
#
# [500 rows x 4 columns]

# %% [markdown]
# ### [3] 훈련 결과 시각화

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 5), dpi=150)
result_df.plot(y=['loss', 'val_loss'], ax=ax[0])
result_df.plot(y=['mae', 'val_mae'], ax=ax[1])
ax[0].set_title('손실률')
ax[1].set_title('절대오차')
ax[0].grid()
ax[1].grid()
plt.show()
plt.close()

# %% [markdown]
# ## #04. 예측 결과 활용
#
# ### [1] 예측치 구하기

# %%
pred =  model.predict(x_test, verbose=0)
pred
# Out:
# array([[29.1828  ],
#        [21.334694],
#        [19.765072],
#        [33.891663],
#        [13.486587],
#        [27.613178],
#        [33.891663],
#        [30.752419],
#        [24.473938],
#        [15.056208],
#        [30.752419],
#        [32.322044],
#        [27.613178],
#        [30.752419],
#        [22.904316]], dtype=float32)

# %% [markdown]
# ### [2] 결과 데이터 셋 구성

# %%
kdf = DataFrame({
    '검증데이터': x_test['speed'],
    '실제값': y_test,
    '예측값' : pred.flatten()
})

kdf['오차'] = kdf['실제값']-kdf['예측값']

my_pretty_table(kdf)
# Out:
# +----+--------------+----------+----------+----------+
# |    |   검증데이터 |   실제값 |   예측값 |     오차 |
# |----+--------------+----------+----------+----------|
# | 28 |           17 |       32 |  29.1828 |   2.8172 |
# | 11 |           12 |       14 |  21.3347 | -7.33469 |
# | 10 |           11 |       28 |  19.7651 |  8.23493 |
# | 41 |           20 |       56 |  33.8917 |  22.1083 |
# |  2 |            7 |        4 |  13.4866 | -9.48659 |
# | 27 |           16 |       40 |  27.6132 |  12.3868 |
# | 38 |           20 |       32 |  33.8917 | -1.89166 |
# | 31 |           18 |       42 |  30.7524 |  11.2476 |
# | 22 |           14 |       80 |  24.4739 |  55.5261 |
# |  4 |            8 |       16 |  15.0562 | 0.943792 |
# | 33 |           18 |       76 |  30.7524 |  45.2476 |
# | 35 |           19 |       36 |   32.322 |  3.67796 |
# | 26 |           16 |       32 |  27.6132 |  4.38682 |
# | 34 |           18 |       84 |  30.7524 |  53.2476 |
# | 18 |           13 |       46 |  22.9043 |  23.0957 |
# +----+--------------+----------+----------+----------+

# %% [markdown]
# ### [3] 관측치와 예측치 비교 시각화

# %%
fig = plt.figure(figsize=(10, 5), dpi=150)
ax = fig.gca()

sb.regplot(data=kdf, x='검증데이터', y='실제값', label='실제값', ax=ax)
sb.regplot(data=kdf, x='검증데이터', y='예측값', label='예측값', ax=ax)
ax.legend()
ax.grid()
plt.show()
plt.close()

# %% [markdown]
# ### [3] 임의의 값에 대한 머신러닝 예측 결과
#
# #### (1) 단일 값을 통한 예측

# %%
my_speed = 50
my_speed_arr = np.array([[my_speed]])
my_dist = model.predict(my_speed_arr, verbose=0)
print("속도가 %d인 자동차의 제동거리는 %d로 예상됩니다." % (my_speed, my_dist))
# Out:
# 속도가 50인 자동차의 제동거리는 80로 예상됩니다.

# %% [markdown]
# ### [4] 사용자 인터페이스 적용

# %%
@interact(x= (0, 100, 1))
def test(x):
    #print(x)
    input_x = np.array([[x]])
    output_y = model.predict(input_x, verbose=0)
    print("속도가 %d인 자동차의 제동거리는 %d로 예상됩니다." % (x, output_y))
# Out:
# interactive(children=(IntSlider(value=50, description='x'), Output()), _dom_classes=('widget-interact',))

# %%
@interact(my_choose=['train', 'test'])
def show_data(my_choose):
    yname = '실제값' if my_choose == 'test' else '예측값'

    fig = plt.figure(figsize=(10, 5), dpi=100)
    ax = fig.gca()
    sb.regplot(data=kdf, x='검증데이터', y=yname, ax=ax)
    ax.grid()
    plt.show()
    plt.close()
# Out:
# interactive(children=(Dropdown(description='dataset', options=('train', 'test'), value='train'), Output()), _d…
