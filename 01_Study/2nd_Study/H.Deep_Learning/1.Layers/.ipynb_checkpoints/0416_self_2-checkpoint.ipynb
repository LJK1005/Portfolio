# %%
import sys, warnings
sys.path.append("Y:\Python\Mega_IT")
warnings.filterwarnings('ignore')

from yjk_module.preprocessing import *
from yjk_module.ml_module import *
from yjk_module.dl_module import *

import os
os.chdir("Y:\Python\Mega_IT\H.Deep_Learning")
os.getcwd()

from hossam.util import *
from hossam.plot import *
from hossam.tensor import *
from hossam.classification import *
import joblib

from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.optimizers import RMSprop, Adam
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, Callback, History
from keras.utils import to_categorical

# %%
from keras.datasets.mnist import load_data

# %%
(x_train, y_train), (x_test, y_test) = load_data()

# %%
print(np.max(x_train[1234]))
print(np.min(x_train[1234]))
# Out:
# 255
# 0

# %%
y_train[1234]
# Out:
# 3

# %%
fig, ax = plt.subplots(1, 5, figsize = (15, 3))

for i in range(0, len(ax)):
    ax[i].imshow(x_train[i], cmap = 'gray')
    ax[i].set_title(f"Label : {y_train[i]}")

plt.show()

# %%
y_train_oh = to_categorical(y_train)
y_test_oh = to_categorical(y_test)

# %%
kh = YjkKerasHelper('c')
# Out:
# [손실함수]
# +---------------------------------+----------------------------------------------------+------------------------------------------+
# | 손실함수                        | 내용                                               | 비고                                     |
# |---------------------------------+----------------------------------------------------+------------------------------------------|
# | binary_crossentropy             | 예측값과 실제값간 교차 엔트로피 손실               | 이진 분류에 사용, 라벨링 필요            |
# | sparse_categorical_crossentropy | 예측값과 실제값간 교차 엔트로피 손실               | 다중 클래스 분류에 사용, 라벨링 필요     |
# | categorical_crossentropy        | 클래스 확률 분포와 실제 값 간의 교차 엔트로피 손실 | 다중 클래스 분류에 사용, 원핫인코딩 필요 |
# +---------------------------------+----------------------------------------------------+------------------------------------------+
#
# [평가지표]
# +---------------------------------+----------------------------------------------------+------------------------------------------+
# | 평가지표                        | 내용                                               | 비고                                     |
# |---------------------------------+----------------------------------------------------+------------------------------------------|
# | accuracy                        | 모델의 예측값과 실제값이 일치하는 비율             | 모든 분류에 사용가능                     |
# | binary_accuracy                 | 모델의 예측값과 실제값이 일치하는 비율             | 이진 분류에 사용                         |
# | binary_crossentropy             | 예측값과 실제값간 교차 엔트로피 손실               | 이진 분류에 사용, 라벨링 필요            |
# | sparse_categorical_crossentropy | 예측값과 실제값간 교차 엔트로피 손실               | 다중 클래스 분류에 사용, 라벨링 필요     |
# | categorical_crossentropy        | 클래스 확률 분포와 실제 값 간의 교차 엔트로피 손실 | 다중 클래스 분류에 사용, 원핫인코딩 필요 |
# +---------------------------------+----------------------------------------------------+------------------------------------------+
#
# 사용 가능한 옵티마이저 : ['adam', 'adagrad', 'nadam', 'rmsprop', 'sgd']

# %%
x_train_nm = x_train / 255
x_test_nm = x_test / 255

# %%
model = Sequential([
    Flatten(),
    Dense(256, activation = 'relu', input_shape = (x_train_nm[0].shape[0] * x_train_nm[0].shape[1],)),
    Dropout(0.2),
    Dense(128, activation = 'relu'),
    Dropout(0.2),
    Dense(len(y_train_oh[0]), activation = 'softmax')
])

model.compile(loss = 'categorical_crossentropy', metrics = ['accuracy'], optimizer = 'adam')

# %%
# %%time

history = model.fit(x_train_nm, y_train_oh, validation_data = (x_test_nm, y_test_oh), epochs = 1000, callbacks = [
    EarlyStopping(patience = 8, restore_best_weights = True)
])
# Out:
# Epoch 1/1000
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2589 - accuracy: 0.9213 - val_loss: 0.1088 - val_accuracy: 0.9645
# Epoch 2/1000
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1225 - accuracy: 0.9641 - val_loss: 0.0913 - val_accuracy: 0.9721
# Epoch 3/1000
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0908 - accuracy: 0.9715 - val_loss: 0.0745 - val_accuracy: 0.9761
# Epoch 4/1000
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0788 - accuracy: 0.9753 - val_loss: 0.0765 - val_accuracy: 0.9773
# Epoch 5/1000
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0670 - accuracy: 0.9791 - val_loss: 0.0792 - val_accuracy: 0.9759
# Epoch 6/1000
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0600 - accuracy: 0.9810 - val_loss: 0.0762 - val_accuracy: 0.9779
# Epoch 7/1000
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0525 - accuracy: 0.9831 - val_loss: 0.0753 - val_accuracy: 0.9786
# Epoch 8/1000
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0496 - accuracy: 0.9847 - val_loss: 0.0682 - val_accuracy: 0.9799
# Epoch 9/1000
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0438 - accuracy: 0.9859 - val_loss: 0.0648 - val_accuracy: 0.9802
# Epoch 10/1000
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0402 - accuracy: 0.9872 - val_loss: 0.0785 - val_accuracy: 0.9791
# Epoch 11/1000
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0405 - accuracy: 0.9865 - val_loss: 0.0744 - val_accuracy: 0.9803
# Epoch 12/1000
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0372 - accuracy: 0.9880 - val_loss: 0.0808 - val_accuracy: 0.9814
# Epoch 13/1000
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0327 - accuracy: 0.9892 - val_loss: 0.0770 - val_accuracy: 0.9806
# Epoch 14/1000
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0348 - accuracy: 0.9889 - val_loss: 0.0669 - val_accuracy: 0.9834
# Epoch 15/1000
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0303 - accuracy: 0.9900 - val_loss: 0.0713 - val_accuracy: 0.9825
# Epoch 16/1000
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0307 - accuracy: 0.9902 - val_loss: 0.0809 - val_accuracy: 0.9800
# Epoch 17/1000
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0293 - accuracy: 0.9906 - val_loss: 0.0734 - val_accuracy: 0.9833
# CPU times: total: 17.8 s
# Wall time: 1min 27s

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 784)               0
#
#  dense_6 (Dense)             (None, 256)               200960
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 128)               32896
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_8 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 235,146
# Trainable params: 235,146
# Non-trainable params: 0
# _________________________________________________________________

# %%
yjk_dl_history_plot(history, metrics = 'accuracy')
# Out:
# +--------------+-----------+
# |              |     Value |
# |--------------+-----------|
# | loss         |  0.029309 |
# | accuracy     |  0.990583 |
# | val_loss     | 0.0734109 |
# | val_accuracy |    0.9833 |
# +--------------+-----------+

# %%
result = model.predict(x_test_nm)
# Out:
# 313/313 [==============================] - 0s 1ms/step

# %%
arg_result = np.argmax(result, axis = -1)

# %% [markdown]
# - 이미지 로드 패키지 PIL

# %%
from PIL import Image

# %%
img2 = Image.open('./res/손글씨2.jpg')
img2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=28x28>

# %%
img3 = Image.open('./res/손글씨3.jpg')
img3
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=28x28>

# %% [markdown]
# - Grayscale 변환 : RGB 3개의 채널에서 흑백 단일 1개의 채널로 변환되어 차원이 축소됨

# %%
img2_gray = img2.convert(mode = "L")
img2_gray
# Out:
# <PIL.Image.Image image mode=L size=28x28>

# %%
img3_gray = img3.convert(mode = "L")
img3_gray
# Out:
# <PIL.Image.Image image mode=L size=28x28>

# %%
img2_array = np.array(img2_gray)
img3_array = np.array(img3_gray)

img2_array.shape, img3_array.shape
# Out:
# ((28, 28), (28, 28))

# %%
myx = np.array([img2_array, img3_array])
myx_nm = myx / 255

# %%
my_pred = model.predict(myx_nm)
# Out:
# 1/1 [==============================] - 0s 14ms/step

# %%
np.argmax(my_pred, axis = -1)
# Out:
# array([2, 3], dtype=int64)

# %%
from keras.layers import MaxPool2D, Conv2D

# %%
model2 = Sequential([
    Conv2D(32, kernel_size = (3, 3), activation = 'relu', padding = 'same', input_shape = (28, 28, 1)),
    MaxPool2D(2, strides = 1, padding = 'same'),
    Conv2D(64, kernel_size = (3, 3), activation = 'relu', padding = 'same'),
    MaxPool2D(2, strides = 1, padding = 'same'),
    Flatten(),
    Dense(256, activation = 'relu'),
    Dropout(0.3),
    Dense(128, activation = 'relu'),
    Dropout(0.2),
    Dense(10, activation = 'softmax')
])

model2.compile(loss = 'categorical_crossentropy', metrics = ['accuracy'], optimizer = 'adam')

# %%
# %%time

history2 = model2.fit(x_train_nm, y_train_oh, validation_data = (x_test_nm, y_test_oh), epochs = 1000, callbacks = [
    EarlyStopping(patience = 8, restore_best_weights = True)
])
# Out:
# Epoch 1/1000
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1357 - accuracy: 0.9590 - val_loss: 0.0489 - val_accuracy: 0.9845
# Epoch 2/1000
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0546 - accuracy: 0.9844 - val_loss: 0.0348 - val_accuracy: 0.9884
# Epoch 3/1000
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0397 - accuracy: 0.9883 - val_loss: 0.0346 - val_accuracy: 0.9884
# Epoch 4/1000
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0291 - accuracy: 0.9912 - val_loss: 0.0417 - val_accuracy: 0.9871
# Epoch 5/1000
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0252 - accuracy: 0.9925 - val_loss: 0.0362 - val_accuracy: 0.9902
# Epoch 6/1000
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0196 - accuracy: 0.9941 - val_loss: 0.0362 - val_accuracy: 0.9913
# Epoch 7/1000
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0156 - accuracy: 0.9954 - val_loss: 0.0357 - val_accuracy: 0.9911
# Epoch 8/1000
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0160 - accuracy: 0.9954 - val_loss: 0.0415 - val_accuracy: 0.9896
# Epoch 9/1000
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0152 - accuracy: 0.9959 - val_loss: 0.0414 - val_accuracy: 0.9909
# Epoch 10/1000
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0121 - accuracy: 0.9965 - val_loss: 0.0448 - val_accuracy: 0.9899
# Epoch 11/1000
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0111 - accuracy: 0.9968 - val_loss: 0.0392 - val_accuracy: 0.9910
# CPU times: total: 18.8 s
# Wall time: 1min 21s

# %%
yjk_dl_history_plot(history2, metrics = 'accuracy')
# Out:
# +--------------+-----------+
# |              |     Value |
# |--------------+-----------|
# | loss         | 0.0110551 |
# | accuracy     |  0.996783 |
# | val_loss     | 0.0392097 |
# | val_accuracy |     0.991 |
# +--------------+-----------+

# %%
model2.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 28, 28, 32)        320
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 64)        18496
#
#  max_pooling2d_3 (MaxPooling  (None, 28, 28, 64)       0
#  2D)
#
#  flatten_3 (Flatten)         (None, 50176)             0
#
#  dense_9 (Dense)             (None, 256)               12845312
#
#  dropout_6 (Dropout)         (None, 256)               0
#
#  dense_10 (Dense)            (None, 128)               32896
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_11 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 12,898,314
# Trainable params: 12,898,314
# Non-trainable params: 0
# _________________________________________________________________
