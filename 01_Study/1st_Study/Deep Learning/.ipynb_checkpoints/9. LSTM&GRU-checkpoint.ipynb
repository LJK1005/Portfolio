# %% [markdown]
# # LSTM(Long Short-Term Memory) 구조
#
# <img src = "./img/rnn_lstm.jpg" width = 500 height = 500>
#
# - 단기 기억을 오래 하기 위해 고안되었음

# %% [markdown]
# <img src = "./img/lstm.png" width=500 height = 500>

# %% [markdown]
# - 은닉 상태를 만드는 방법
#     - output gate layer(출력 게이트)
#         1. 입력과 이전 타임스텝의 은닉 상태를 가중치에 곱한 후 활성화 함수를 통과시켜 다음 은닉 상태를 만듦
#             - 이 때 기본 순환층과는 달리 시그모이드 활성화 함수를 사용
#         2. tanh 활성화 함수를 통과한 값과 곱해져서 은닉 상태를 만듦
# - LSTM은 순환 되는 상태가 2개
#     - 은닉 상태(hidden state)
#     - 셀 상태(cell state)
#         - 다음 층으로 전달되지 않고 LSTM 셀에서 순환만 되는 값
#
# - 셀 상태를 계산하는 과정
#     - forget gate layer(삭제 게이트)
#         - 정보를 제거하는 역할
#         1. 입력과 은닉 상태를 또 다른 가중치에 곱한 다음 시그모이드 함수를 통과
#         2. 이전 타임스텝의 셀 상태와 곱하여 새로운 셀 상태를 만듦
#             - 이 셀 상태가 오른쪽에서 tanh 함수를 통과하여 새로운 은닉 상태를 만드는 데 기여
#     - input gate layer(입력 게이트)
#         - 새로운 정보를 셀 상태에 추가
#         1. 입력과 은닉 상태를 각기 다른 가중치에 곱함
#         2. 하나는 시그모이드 함수, 하나는 tanh 함수를 통과
#         3. 두 결과를 곱함
#         4. 이전 셀 상태와 더함

# %% [markdown]
# ## 데이터 준비

# %%
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow import keras
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
# 데이터 로드
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words = 500)

# %%
# 훈련 세트와 검증 세트로 나누기
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2, random_state = 4)

# %%
# 패딩
train_seq = pad_sequences(x_train, maxlen = 100)
val_seq = pad_sequences(x_val, maxlen = 100)

# %%
# LSTM 모델 생성
model = keras.Sequential()
model.add(keras.layers.Embedding(500, 16, input_length = 100))
model.add(keras.layers.LSTM(8))
model.add(keras.layers.Dense(1, activation = "sigmoid"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 100, 16)           8000
#
#  lstm (LSTM)                 (None, 8)                 800
#
#  dense (Dense)               (None, 1)                 9
#
# =================================================================
# Total params: 8,809
# Trainable params: 8,809
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# - LSTM 셀 파라미터 개수
#     - ((8 * 8) + (16 * 8) + 8) * 4 = 800

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate = 1e-4)
model.compile(optimizer = rmsprop, loss = "binary_crossentropy", metrics = ["accuracy"])
checkpoint_cb = keras.callbacks.ModelCheckpoint("./model/best-lstm-model.h5", save_best_only = True)
early_stoppinb_cb = keras.callbacks.EarlyStopping(patience = 3, restore_best_weights = True)

# %%
history = model.fit(train_seq, y_train, epochs = 100, batch_size = 64,
                    validation_data = (val_seq, y_val), callbacks = [checkpoint_cb, early_stoppinb_cb])
# Out:
# Epoch 1/100
# 313/313 [==============================] - 9s 12ms/step - loss: 0.6926 - accuracy: 0.5234 - val_loss: 0.6918 - val_accuracy: 0.5530
# Epoch 2/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.6907 - accuracy: 0.5867 - val_loss: 0.6892 - val_accuracy: 0.5984
# Epoch 3/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.6865 - accuracy: 0.6196 - val_loss: 0.6828 - val_accuracy: 0.6438
# Epoch 4/100
# 313/313 [==============================] - 3s 11ms/step - loss: 0.6757 - accuracy: 0.6557 - val_loss: 0.6635 - val_accuracy: 0.6800
# Epoch 5/100
# 313/313 [==============================] - 3s 11ms/step - loss: 0.6330 - accuracy: 0.7128 - val_loss: 0.6022 - val_accuracy: 0.7298
# Epoch 6/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.5824 - accuracy: 0.7393 - val_loss: 0.5791 - val_accuracy: 0.7274
# Epoch 7/100
# 313/313 [==============================] - 3s 11ms/step - loss: 0.5594 - accuracy: 0.7527 - val_loss: 0.5650 - val_accuracy: 0.7370
# Epoch 8/100
# 313/313 [==============================] - 3s 11ms/step - loss: 0.5402 - accuracy: 0.7623 - val_loss: 0.5456 - val_accuracy: 0.7464
# Epoch 9/100
# 313/313 [==============================] - 3s 11ms/step - loss: 0.5225 - accuracy: 0.7723 - val_loss: 0.5302 - val_accuracy: 0.7506
# Epoch 10/100
# 313/313 [==============================] - 3s 11ms/step - loss: 0.5065 - accuracy: 0.7777 - val_loss: 0.5174 - val_accuracy: 0.7588
# Epoch 11/100
# 313/313 [==============================] - 3s 11ms/step - loss: 0.4924 - accuracy: 0.7847 - val_loss: 0.5087 - val_accuracy: 0.7614
# Epoch 12/100
# 313/313 [==============================] - 4s 11ms/step - loss: 0.4798 - accuracy: 0.7890 - val_loss: 0.4955 - val_accuracy: 0.7696
# Epoch 13/100
# 313/313 [==============================] - 3s 11ms/step - loss: 0.4685 - accuracy: 0.7948 - val_loss: 0.4867 - val_accuracy: 0.7726
# Epoch 14/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4591 - accuracy: 0.7990 - val_loss: 0.4800 - val_accuracy: 0.7758
# Epoch 15/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4508 - accuracy: 0.8017 - val_loss: 0.4741 - val_accuracy: 0.7778
# Epoch 16/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4441 - accuracy: 0.8051 - val_loss: 0.4706 - val_accuracy: 0.7758
# Epoch 17/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4384 - accuracy: 0.8065 - val_loss: 0.4639 - val_accuracy: 0.7818
# Epoch 18/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4336 - accuracy: 0.8100 - val_loss: 0.4604 - val_accuracy: 0.7804
# Epoch 19/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4298 - accuracy: 0.8105 - val_loss: 0.4602 - val_accuracy: 0.7796
# Epoch 20/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4264 - accuracy: 0.8119 - val_loss: 0.4557 - val_accuracy: 0.7808
# Epoch 21/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4235 - accuracy: 0.8127 - val_loss: 0.4529 - val_accuracy: 0.7854
# Epoch 22/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4207 - accuracy: 0.8129 - val_loss: 0.4506 - val_accuracy: 0.7842
# Epoch 23/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.4187 - accuracy: 0.8127 - val_loss: 0.4487 - val_accuracy: 0.7898
# Epoch 24/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4173 - accuracy: 0.8136 - val_loss: 0.4465 - val_accuracy: 0.7866
# Epoch 25/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4153 - accuracy: 0.8145 - val_loss: 0.4426 - val_accuracy: 0.7864
# Epoch 26/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4144 - accuracy: 0.8159 - val_loss: 0.4438 - val_accuracy: 0.7872
# Epoch 27/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4130 - accuracy: 0.8166 - val_loss: 0.4431 - val_accuracy: 0.7896
# Epoch 28/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4119 - accuracy: 0.8157 - val_loss: 0.4464 - val_accuracy: 0.7870

# %%
plt.figure()
plt.plot(history.history["loss"], label = "train_loss")
plt.plot(history.history["accuracy"], label = "train_acc")
plt.plot(history.history["val_loss"], label = "val_loss")
plt.plot(history.history["val_accuracy"], label = "val_acc")

plt.legend()
plt.xlabel("epoch")
plt.show()

# %% [markdown]
# # GRU(Grated Recurrent Unit) 구조
#
# <img src = "./img/rnn_lstm_gru.png">

# %% [markdown]
# - LSTM을 간소화한 버전
# - LSTM처럼 셀 상태를 계산하지 않고 은닉 상태 하나만 포함
# - LSTM보다 가중치가 적기 때문에 계산량이 적지만 성능은 LSTM과 유사함
#     - 데이터 양이 적을 때는 GRU의 성능이 더 좋고 데이터 양이 많을 때는 LSTM의 성능이 더 좋아지는 경향이 있음
#     - GRU와 LSTM중 어떤 것이 더 낫다라고 말할 수는 없음

# %% [markdown]
# <img src = "./img/gru.png" width=500 height=500>

# %% [markdown]
# - GRU 셀에는 은닉 상태와 입력에 가중치를 곱하고 절편을 더하는 작은 셀 3개가 들어 있음
#     - 2개는 시그모이드 활성화 함수를 사용하고 하나는 tanh활성화 함수를 사용
# - reset_gate
#     - 셀의 출력이 은닉 상태에 바로 곱해져 삭제 게이트 역할을 수행
# - update_gate
#     - 어떤 정보를 얼마만큼 유지하고 어떤 정보를 추가할지 결정하는 역할

# %%
# GRU 모델 생성
model2 = keras.Sequential()
model2.add(keras.layers.Embedding(500, 16, input_length = 100))
model2.add(keras.layers.GRU(8))
model2.add(keras.layers.Dense(1, activation = "sigmoid"))

# %%
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 100, 16)           8000
#
#  gru (GRU)                   (None, 8)                 624
#
#  dense_1 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 8,633
# Trainable params: 8,633
# Non-trainable params: 0
# _________________________________________________________________

# %%
((16 * 8) + (8 * 8) + 8 + 8) * 3
# Out:
# 624

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate = 1e-4)
model2.compile(optimizer = rmsprop, loss = "binary_crossentropy", metrics = ["accuracy"])
checkpoint_cb = keras.callbacks.ModelCheckpoint("./model/best-gru-model.h5", save_best_only = True)
early_stoppinb_cb = keras.callbacks.EarlyStopping(patience = 3, restore_best_weights = True)

# %%
history = model2.fit(train_seq, y_train, epochs = 100, batch_size = 64,
                    validation_data = (val_seq, y_val), callbacks = [checkpoint_cb, early_stoppinb_cb])
# Out:
# Epoch 1/100
# 313/313 [==============================] - 4s 10ms/step - loss: 0.6924 - accuracy: 0.5179 - val_loss: 0.6918 - val_accuracy: 0.5356
# Epoch 2/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6906 - accuracy: 0.5569 - val_loss: 0.6899 - val_accuracy: 0.5642
# Epoch 3/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6880 - accuracy: 0.5785 - val_loss: 0.6869 - val_accuracy: 0.5774
# Epoch 4/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6840 - accuracy: 0.5928 - val_loss: 0.6823 - val_accuracy: 0.5902
# Epoch 5/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6780 - accuracy: 0.6084 - val_loss: 0.6753 - val_accuracy: 0.6082
# Epoch 6/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6692 - accuracy: 0.6211 - val_loss: 0.6650 - val_accuracy: 0.6248
# Epoch 7/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.6562 - accuracy: 0.6346 - val_loss: 0.6493 - val_accuracy: 0.6478
# Epoch 8/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.6365 - accuracy: 0.6558 - val_loss: 0.6246 - val_accuracy: 0.6666
# Epoch 9/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6043 - accuracy: 0.6892 - val_loss: 0.5827 - val_accuracy: 0.7078
# Epoch 10/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.5470 - accuracy: 0.7348 - val_loss: 0.5245 - val_accuracy: 0.7400
# Epoch 11/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.5035 - accuracy: 0.7638 - val_loss: 0.5073 - val_accuracy: 0.7520
# Epoch 12/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4870 - accuracy: 0.7723 - val_loss: 0.4991 - val_accuracy: 0.7558
# Epoch 13/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4746 - accuracy: 0.7825 - val_loss: 0.4912 - val_accuracy: 0.7576
# Epoch 14/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4650 - accuracy: 0.7888 - val_loss: 0.4837 - val_accuracy: 0.7630
# Epoch 15/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4572 - accuracy: 0.7913 - val_loss: 0.4794 - val_accuracy: 0.7684
# Epoch 16/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4496 - accuracy: 0.7976 - val_loss: 0.4748 - val_accuracy: 0.7732
# Epoch 17/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4441 - accuracy: 0.8022 - val_loss: 0.4696 - val_accuracy: 0.7744
# Epoch 18/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4394 - accuracy: 0.8037 - val_loss: 0.4676 - val_accuracy: 0.7760
# Epoch 19/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4350 - accuracy: 0.8069 - val_loss: 0.4640 - val_accuracy: 0.7776
# Epoch 20/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4321 - accuracy: 0.8086 - val_loss: 0.4624 - val_accuracy: 0.7800
# Epoch 21/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4295 - accuracy: 0.8098 - val_loss: 0.4599 - val_accuracy: 0.7806
# Epoch 22/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4272 - accuracy: 0.8105 - val_loss: 0.4590 - val_accuracy: 0.7818
# Epoch 23/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4249 - accuracy: 0.8132 - val_loss: 0.4581 - val_accuracy: 0.7834
# Epoch 24/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4225 - accuracy: 0.8141 - val_loss: 0.4600 - val_accuracy: 0.7822
# Epoch 25/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4215 - accuracy: 0.8134 - val_loss: 0.4564 - val_accuracy: 0.7846
# Epoch 26/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4199 - accuracy: 0.8150 - val_loss: 0.4541 - val_accuracy: 0.7852
# Epoch 27/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4191 - accuracy: 0.8153 - val_loss: 0.4549 - val_accuracy: 0.7856
# Epoch 28/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4179 - accuracy: 0.8154 - val_loss: 0.4566 - val_accuracy: 0.7856
# Epoch 29/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.4165 - accuracy: 0.8159 - val_loss: 0.4520 - val_accuracy: 0.7860
# Epoch 30/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.4159 - accuracy: 0.8156 - val_loss: 0.4525 - val_accuracy: 0.7860
# Epoch 31/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4148 - accuracy: 0.8160 - val_loss: 0.4508 - val_accuracy: 0.7890
# Epoch 32/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4143 - accuracy: 0.8178 - val_loss: 0.4517 - val_accuracy: 0.7878
# Epoch 33/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4131 - accuracy: 0.8177 - val_loss: 0.4526 - val_accuracy: 0.7888
# Epoch 34/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.4124 - accuracy: 0.8180 - val_loss: 0.4500 - val_accuracy: 0.7910
# Epoch 35/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4118 - accuracy: 0.8180 - val_loss: 0.4558 - val_accuracy: 0.7860
# Epoch 36/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4115 - accuracy: 0.8184 - val_loss: 0.4539 - val_accuracy: 0.7860
# Epoch 37/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.4108 - accuracy: 0.8191 - val_loss: 0.4466 - val_accuracy: 0.7922
# Epoch 38/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4105 - accuracy: 0.8185 - val_loss: 0.4467 - val_accuracy: 0.7920
# Epoch 39/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4095 - accuracy: 0.8208 - val_loss: 0.4470 - val_accuracy: 0.7918
# Epoch 40/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4093 - accuracy: 0.8206 - val_loss: 0.4475 - val_accuracy: 0.7878

# %%
plt.figure()
plt.plot(history.history["loss"], label = "train_loss")
plt.plot(history.history["accuracy"], label = "train_acc")
plt.plot(history.history["val_loss"], label = "val_loss")
plt.plot(history.history["val_accuracy"], label = "val_acc")

plt.legend()
plt.xlabel("epoch")
plt.show()

# %% [markdown]
# # 순환층에 드롭아웃 적용
#
# - 순환층은 자체적으로 드롭아웃 기능을 제공
#     - SimpleRNN과 LSTM 클래스 모두 dropout 매개변수와 recurrent_dropout 매개변수를 가지고 있음
#         - dropout : 셀의 입력에 드롭아웃을 적용
#         - recurrent_dropout : 순환되는 은닉 상태에 드롭아웃을 적용
#             - 버전에 따라 recurrent_dropout이 GPU를 사용하지 못하는 경우가 있음

# %%
model3 = keras.Sequential()
model3.add(keras.layers.Embedding(500, 16, input_length = 100))
model3.add(keras.layers.LSTM(8, dropout = 0.3))
model3.add(keras.layers.Dense(1, activation = "sigmoid"))

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate = 1e-4)
model3.compile(optimizer = rmsprop, loss = "binary_crossentropy", metrics = ["accuracy"])
checkpoint_cb = keras.callbacks.ModelCheckpoint("./model/best-dropout-model.h5", save_best_only = True)
early_stoppinb_cb = keras.callbacks.EarlyStopping(patience = 3, restore_best_weights = True)

# %%
history = model3.fit(train_seq, y_train, epochs = 100, batch_size = 64,
                    validation_data = (val_seq, y_val), callbacks = [checkpoint_cb, early_stoppinb_cb])
# Out:
# Epoch 1/100
# 313/313 [==============================] - 5s 11ms/step - loss: 0.6927 - accuracy: 0.5376 - val_loss: 0.6920 - val_accuracy: 0.5760
# Epoch 2/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6912 - accuracy: 0.5793 - val_loss: 0.6901 - val_accuracy: 0.6102
# Epoch 3/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6885 - accuracy: 0.6126 - val_loss: 0.6863 - val_accuracy: 0.6328
# Epoch 4/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6831 - accuracy: 0.6296 - val_loss: 0.6779 - val_accuracy: 0.6452
# Epoch 5/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6700 - accuracy: 0.6486 - val_loss: 0.6550 - val_accuracy: 0.6526
# Epoch 6/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6263 - accuracy: 0.6873 - val_loss: 0.5896 - val_accuracy: 0.7204
# Epoch 7/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.5668 - accuracy: 0.7351 - val_loss: 0.5570 - val_accuracy: 0.7298
# Epoch 8/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.5396 - accuracy: 0.7449 - val_loss: 0.5385 - val_accuracy: 0.7370
# Epoch 9/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.5198 - accuracy: 0.7560 - val_loss: 0.5224 - val_accuracy: 0.7488
# Epoch 10/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.5034 - accuracy: 0.7677 - val_loss: 0.5084 - val_accuracy: 0.7564
# Epoch 11/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4908 - accuracy: 0.7757 - val_loss: 0.4978 - val_accuracy: 0.7630
# Epoch 12/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4793 - accuracy: 0.7834 - val_loss: 0.4882 - val_accuracy: 0.7676
# Epoch 13/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4686 - accuracy: 0.7890 - val_loss: 0.4829 - val_accuracy: 0.7684
# Epoch 14/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4600 - accuracy: 0.7942 - val_loss: 0.4742 - val_accuracy: 0.7786
# Epoch 15/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4541 - accuracy: 0.7955 - val_loss: 0.4688 - val_accuracy: 0.7774
# Epoch 16/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4485 - accuracy: 0.8004 - val_loss: 0.4624 - val_accuracy: 0.7840
# Epoch 17/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4438 - accuracy: 0.8026 - val_loss: 0.4614 - val_accuracy: 0.7854
# Epoch 18/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4390 - accuracy: 0.8049 - val_loss: 0.4562 - val_accuracy: 0.7846
# Epoch 19/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4365 - accuracy: 0.8041 - val_loss: 0.4581 - val_accuracy: 0.7828
# Epoch 20/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4341 - accuracy: 0.8032 - val_loss: 0.4531 - val_accuracy: 0.7862
# Epoch 21/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4321 - accuracy: 0.8062 - val_loss: 0.4507 - val_accuracy: 0.7848
# Epoch 22/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4275 - accuracy: 0.8088 - val_loss: 0.4509 - val_accuracy: 0.7876
# Epoch 23/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4286 - accuracy: 0.8067 - val_loss: 0.4633 - val_accuracy: 0.7808
# Epoch 24/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4262 - accuracy: 0.8098 - val_loss: 0.4476 - val_accuracy: 0.7856
# Epoch 25/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4250 - accuracy: 0.8094 - val_loss: 0.4451 - val_accuracy: 0.7882
# Epoch 26/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4218 - accuracy: 0.8108 - val_loss: 0.4444 - val_accuracy: 0.7874
# Epoch 27/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4220 - accuracy: 0.8094 - val_loss: 0.4448 - val_accuracy: 0.7874
# Epoch 28/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4241 - accuracy: 0.8094 - val_loss: 0.4446 - val_accuracy: 0.7876
# Epoch 29/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4198 - accuracy: 0.8104 - val_loss: 0.4419 - val_accuracy: 0.7886
# Epoch 30/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4187 - accuracy: 0.8102 - val_loss: 0.4423 - val_accuracy: 0.7892
# Epoch 31/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4181 - accuracy: 0.8113 - val_loss: 0.4524 - val_accuracy: 0.7880
# Epoch 32/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4172 - accuracy: 0.8091 - val_loss: 0.4425 - val_accuracy: 0.7898

# %%
plt.figure()
plt.plot(history.history["loss"], label = "train_loss")
plt.plot(history.history["accuracy"], label = "train_acc")
plt.plot(history.history["val_loss"], label = "val_loss")
plt.plot(history.history["val_accuracy"], label = "val_acc")

plt.legend()
plt.xlabel("epoch")
plt.show()

# %% [markdown]
# # 2개의 층을 연결
#
# - 순환층을 연결할 때의 주의점
#     - 순환층의 은닉 상태는 샘플의 마지막 타임스텝에 대한 은닉 상태만 다음 층으로 전달
#         - 순환층을 쌓게 되면 모든 순환층에 순차 데이터가 필요함
#         - 앞쪽의 순환층이 모든 타입스텝에 대한 은닉 상태를 출력해야함
#             - return_sequences 매개변수를 True로 지정

# %%
model4 = keras.Sequential()
model4.add(keras.layers.Embedding(500, 16, input_length = 100))
model4.add(keras.layers.LSTM(8, dropout = 0.3, return_sequences = True))
model4.add(keras.layers.LSTM(8, dropout = 0.3))
model4.add(keras.layers.Dense(1, activation = "sigmoid"))

# %%
model4.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 100, 16)           8000
#
#  lstm_2 (LSTM)               (None, 100, 8)            800
#
#  lstm_3 (LSTM)               (None, 8)                 544
#
#  dense_3 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 9,353
# Trainable params: 9,353
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# - 첫 번째 LSTM
#     - 모든 타임스텝(100개)의 은닉상태를 출력하기 때문에 출력의 크기가 (None, 100, 8)
# - 두 번째 LSTM
#     - 마지막 타임스텝의 은닉상태만 출력하기 때문에 출력의 크기가 (None, 8)

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate = 1e-4)
model4.compile(optimizer = rmsprop, loss = "binary_crossentropy", metrics = ["accuracy"])
checkpoint_cb = keras.callbacks.ModelCheckpoint("./model/best-2rnn-model.h5", save_best_only = True)
early_stoppinb_cb = keras.callbacks.EarlyStopping(patience = 3, restore_best_weights = True)

# %%
history = model4.fit(train_seq, y_train, epochs = 100, batch_size = 64,
                    validation_data = (val_seq, y_val), callbacks = [checkpoint_cb, early_stoppinb_cb])
# Out:
# Epoch 1/100
# 313/313 [==============================] - 8s 18ms/step - loss: 0.6925 - accuracy: 0.5371 - val_loss: 0.6914 - val_accuracy: 0.6022
# Epoch 2/100
# 313/313 [==============================] - 5s 15ms/step - loss: 0.6878 - accuracy: 0.6102 - val_loss: 0.6801 - val_accuracy: 0.6566
# Epoch 3/100
# 313/313 [==============================] - 5s 15ms/step - loss: 0.6510 - accuracy: 0.6733 - val_loss: 0.6104 - val_accuracy: 0.7052
# Epoch 4/100
# 313/313 [==============================] - 5s 16ms/step - loss: 0.5878 - accuracy: 0.7146 - val_loss: 0.5774 - val_accuracy: 0.7148
# Epoch 5/100
# 313/313 [==============================] - 5s 17ms/step - loss: 0.5545 - accuracy: 0.7393 - val_loss: 0.5469 - val_accuracy: 0.7348
# Epoch 6/100
# 313/313 [==============================] - 5s 17ms/step - loss: 0.5310 - accuracy: 0.7516 - val_loss: 0.5331 - val_accuracy: 0.7402
# Epoch 7/100
# 313/313 [==============================] - 5s 17ms/step - loss: 0.5150 - accuracy: 0.7596 - val_loss: 0.5182 - val_accuracy: 0.7528
# Epoch 8/100
# 313/313 [==============================] - 5s 17ms/step - loss: 0.5010 - accuracy: 0.7680 - val_loss: 0.5141 - val_accuracy: 0.7520
# Epoch 9/100
# 313/313 [==============================] - 5s 16ms/step - loss: 0.4962 - accuracy: 0.7672 - val_loss: 0.5057 - val_accuracy: 0.7536
# Epoch 10/100
# 313/313 [==============================] - 5s 16ms/step - loss: 0.4853 - accuracy: 0.7777 - val_loss: 0.5089 - val_accuracy: 0.7552
# Epoch 11/100
# 313/313 [==============================] - 5s 15ms/step - loss: 0.4758 - accuracy: 0.7819 - val_loss: 0.4965 - val_accuracy: 0.7590
# Epoch 12/100
# 313/313 [==============================] - 5s 15ms/step - loss: 0.4719 - accuracy: 0.7833 - val_loss: 0.4837 - val_accuracy: 0.7666
# Epoch 13/100
# 313/313 [==============================] - 5s 15ms/step - loss: 0.4663 - accuracy: 0.7858 - val_loss: 0.4817 - val_accuracy: 0.7714
# Epoch 14/100
# 313/313 [==============================] - 5s 15ms/step - loss: 0.4610 - accuracy: 0.7911 - val_loss: 0.4740 - val_accuracy: 0.7738
# Epoch 15/100
# 313/313 [==============================] - 5s 15ms/step - loss: 0.4573 - accuracy: 0.7925 - val_loss: 0.4755 - val_accuracy: 0.7758
# Epoch 16/100
# 313/313 [==============================] - 5s 15ms/step - loss: 0.4547 - accuracy: 0.7905 - val_loss: 0.4715 - val_accuracy: 0.7796
# Epoch 17/100
# 313/313 [==============================] - 5s 15ms/step - loss: 0.4522 - accuracy: 0.7926 - val_loss: 0.4651 - val_accuracy: 0.7792
# Epoch 18/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.4494 - accuracy: 0.7965 - val_loss: 0.4658 - val_accuracy: 0.7806
# Epoch 19/100
# 313/313 [==============================] - 5s 15ms/step - loss: 0.4467 - accuracy: 0.7948 - val_loss: 0.4650 - val_accuracy: 0.7802
# Epoch 20/100
# 313/313 [==============================] - 5s 16ms/step - loss: 0.4450 - accuracy: 0.7976 - val_loss: 0.4606 - val_accuracy: 0.7838
# Epoch 21/100
# 313/313 [==============================] - 5s 16ms/step - loss: 0.4424 - accuracy: 0.8005 - val_loss: 0.4601 - val_accuracy: 0.7830
# Epoch 22/100
# 313/313 [==============================] - 5s 16ms/step - loss: 0.4406 - accuracy: 0.7979 - val_loss: 0.4587 - val_accuracy: 0.7808
# Epoch 23/100
# 313/313 [==============================] - 5s 17ms/step - loss: 0.4405 - accuracy: 0.7989 - val_loss: 0.4578 - val_accuracy: 0.7830
# Epoch 24/100
# 313/313 [==============================] - 5s 16ms/step - loss: 0.4393 - accuracy: 0.7977 - val_loss: 0.4573 - val_accuracy: 0.7830
# Epoch 25/100
# 313/313 [==============================] - 5s 15ms/step - loss: 0.4363 - accuracy: 0.7990 - val_loss: 0.4551 - val_accuracy: 0.7852
# Epoch 26/100
# 313/313 [==============================] - 5s 15ms/step - loss: 0.4351 - accuracy: 0.8014 - val_loss: 0.4552 - val_accuracy: 0.7836
# Epoch 27/100
# 313/313 [==============================] - 5s 15ms/step - loss: 0.4318 - accuracy: 0.8020 - val_loss: 0.4516 - val_accuracy: 0.7898
# Epoch 28/100
# 313/313 [==============================] - 5s 15ms/step - loss: 0.4314 - accuracy: 0.8035 - val_loss: 0.4514 - val_accuracy: 0.7852
# Epoch 29/100
# 313/313 [==============================] - 5s 15ms/step - loss: 0.4314 - accuracy: 0.8038 - val_loss: 0.4525 - val_accuracy: 0.7846
# Epoch 30/100
# 313/313 [==============================] - 5s 15ms/step - loss: 0.4286 - accuracy: 0.8060 - val_loss: 0.4527 - val_accuracy: 0.7884
# Epoch 31/100
# 313/313 [==============================] - 5s 16ms/step - loss: 0.4292 - accuracy: 0.8030 - val_loss: 0.4503 - val_accuracy: 0.7862
# Epoch 32/100
# 313/313 [==============================] - 5s 15ms/step - loss: 0.4287 - accuracy: 0.8034 - val_loss: 0.4524 - val_accuracy: 0.7844
# Epoch 33/100
# 313/313 [==============================] - 5s 14ms/step - loss: 0.4286 - accuracy: 0.8059 - val_loss: 0.4502 - val_accuracy: 0.7838
# Epoch 34/100
# 313/313 [==============================] - 5s 15ms/step - loss: 0.4287 - accuracy: 0.8036 - val_loss: 0.4520 - val_accuracy: 0.7852
# Epoch 35/100
# 313/313 [==============================] - 5s 15ms/step - loss: 0.4285 - accuracy: 0.8036 - val_loss: 0.4471 - val_accuracy: 0.7878
# Epoch 36/100
# 313/313 [==============================] - 5s 16ms/step - loss: 0.4257 - accuracy: 0.8057 - val_loss: 0.4483 - val_accuracy: 0.7878
# Epoch 37/100
# 313/313 [==============================] - 5s 16ms/step - loss: 0.4278 - accuracy: 0.8043 - val_loss: 0.4512 - val_accuracy: 0.7862
# Epoch 38/100
# 313/313 [==============================] - 5s 15ms/step - loss: 0.4240 - accuracy: 0.8079 - val_loss: 0.4502 - val_accuracy: 0.7856

# %%
plt.figure()
plt.plot(history.history["loss"], label = "train_loss")
plt.plot(history.history["accuracy"], label = "train_acc")
plt.plot(history.history["val_loss"], label = "val_loss")
plt.plot(history.history["val_accuracy"], label = "val_acc")

plt.legend()
plt.xlabel("epoch")
plt.show()

# %% [markdown]
# # best model 검증

# %%
test_seq = pad_sequences(x_test, maxlen = 100)
rnn_model = keras.models.load_model("./model/best-dropout-model.h5")
rnn_model.evaluate(test_seq, y_test)
# Out:
# 782/782 [==============================] - 3s 4ms/step - loss: 0.4294 - accuracy: 0.8016
# [0.42942938208580017, 0.8015599846839905]
