# %% [markdown]
# - 머신러닝 알고리즘은 모델의 구조가 어느 정도 고정이 되어 있음
#     - 좋은 성능을 내기 위해서는 매개변수를 조정하고 훈련하는 과정을 반복
# - 딥러닝은 구조를 직접 설계해야함
#     - 좋은 성능을 내기 위해 다룰 수 있는 다양한 개념과 도구들을 이해할 필요가 있음

# %% [markdown]
# # 손실 곡선
#
# - 케라스의 fit() 메서드는 History 클래스의 객체를 반환
#     - History 객체 : 훈련 과정에서 계산한 지표(손실과 정확도값)가 저장되어 있음
#     - 이 값을 사용하여 그래프를 그려서 훈련 성과를 확인

# %%
from tensorflow import keras
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()
scaled_train = x_train / 255.0
scaled_train, scaled_val, y_train, y_val = train_test_split(scaled_train, y_train, test_size = 0.2, random_state = 4)

# %%
# 모델 정의 함수
def model_fn(a_layer = None):
    model = keras.Sequential()
    model.add(keras.layers.Flatten(input_shape = (28, 28)))
    model.add(keras.layers.Dense(100, activation = "relu"))
    if a_layer:
        model.add(a_layer)
    model.add(keras.layers.Dense(10, activation = "softmax"))
    return model

# %%
model = model_fn()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 100)               78500
#
#  dense_1 (Dense)             (None, 10)                1010
#
# ...
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = "sparse_categorical_crossentropy", metrics = "accuracy")
history = model.fit(scaled_train, y_train, epochs = 5)
# Out:
# Epoch 1/5
# 1500/1500 [==============================] - 3s 858us/step - loss: 0.5336 - accuracy: 0.8125
# Epoch 2/5
# 1500/1500 [==============================] - 1s 833us/step - loss: 0.3953 - accuracy: 0.8574
# Epoch 3/5
# 1500/1500 [==============================] - 1s 825us/step - loss: 0.3586 - accuracy: 0.8702
# Epoch 4/5
# 1500/1500 [==============================] - 1s 813us/step - loss: 0.3399 - accuracy: 0.8780
# Epoch 5/5
# 1500/1500 [==============================] - 1s 858us/step - loss: 0.3247 - accuracy: 0.8854

# %%
# history 객체 확인
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy'])

# %% [markdown]
# - 기본적으로 손실을 계산하고
# - compile에서 accuracy를 추가하여서 loss와 accuracy가 포함됨

# %%
plt.figure()
plt.plot(history.history["loss"])
plt.xlabel("epoch")
plt.ylabel("loss")
plt.show()

# %%
plt.figure()
plt.plot(history.history["accuracy"])
plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.show()

# %%
# epoch를 20으로 늘려서 그래프 확인
model = model_fn()
model.compile(loss = "sparse_categorical_crossentropy", metrics = "accuracy")
history = model.fit(scaled_train, y_train, epochs = 20)
# Out:
# Epoch 1/20
# 1500/1500 [==============================] - 1s 868us/step - loss: 0.5405 - accuracy: 0.8093
# Epoch 2/20
# 1500/1500 [==============================] - 1s 833us/step - loss: 0.4000 - accuracy: 0.8561
# Epoch 3/20
# 1500/1500 [==============================] - 1s 837us/step - loss: 0.3622 - accuracy: 0.8681
# Epoch 4/20
# 1500/1500 [==============================] - 1s 835us/step - loss: 0.3424 - accuracy: 0.8777
# Epoch 5/20
# 1500/1500 [==============================] - 1s 835us/step - loss: 0.3282 - accuracy: 0.8844
# Epoch 6/20
# 1500/1500 [==============================] - 1s 831us/step - loss: 0.3132 - accuracy: 0.8887
# Epoch 7/20
# 1500/1500 [==============================] - 1s 849us/step - loss: 0.3056 - accuracy: 0.8915
# Epoch 8/20
# 1500/1500 [==============================] - 1s 849us/step - loss: 0.2964 - accuracy: 0.8967
# Epoch 9/20
# 1500/1500 [==============================] - 1s 851us/step - loss: 0.2870 - accuracy: 0.9006
# Epoch 10/20
# ...

# %%
plt.figure()
plt.plot(history.history["loss"], label = "loss")
plt.plot(history.history["accuracy"], label = "acc")
plt.legend()
plt.xlabel("epoch")
plt.show()

# %% [markdown]
# # 검증 손실
#
# - 에포크에 따른 과대적합과 과소적합을 파악하려면 검증 세트에 대한 점수도 확인해야함
# - 케라스에서는 fit()메서드에 검증 데이터를 전달할 수 있음

# %%
model = model_fn()
model.compile(loss = "sparse_categorical_crossentropy", metrics = "accuracy")
history = model.fit(scaled_train, y_train, epochs = 20, validation_data = (scaled_val, y_val))
# Out:
# Epoch 1/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.5300 - accuracy: 0.8127 - val_loss: 0.4152 - val_accuracy: 0.8482
# Epoch 2/20
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.3964 - accuracy: 0.8572 - val_loss: 0.3800 - val_accuracy: 0.8639
# Epoch 3/20
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.3575 - accuracy: 0.8710 - val_loss: 0.3339 - val_accuracy: 0.8832
# Epoch 4/20
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.3361 - accuracy: 0.8790 - val_loss: 0.3416 - val_accuracy: 0.8782
# Epoch 5/20
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.3225 - accuracy: 0.8857 - val_loss: 0.3543 - val_accuracy: 0.8744
# Epoch 6/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3084 - accuracy: 0.8893 - val_loss: 0.3581 - val_accuracy: 0.8782
# Epoch 7/20
# ...

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.figure()
plt.plot(history.history["loss"], label = "train_loss")
plt.plot(history.history["accuracy"], label = "train_acc")
plt.plot(history.history["val_loss"], label = "val_loss")
plt.plot(history.history["val_accuracy"], label = "val_acc")
plt.xticks(ticks = range(20))
plt.legend()
plt.xlabel("epoch")
plt.show()

# %% [markdown]
# - 훈련 손실은 계속 감소하는데 검증 손실은 감소하다가 상승하여 과대적합 모델이 만들어짐
#     - 검증손실이 상승하는 시점을 가능한한 뒤로 늦출 필요가 있음

# %%
# Adam 옵티마이저 선택
model = model_fn()
model.compile(optimizer = "adam", loss = "sparse_categorical_crossentropy", metrics = "accuracy")
history = model.fit(scaled_train, y_train, epochs = 20, validation_data = (scaled_val, y_val))
# Out:
# Epoch 1/20
# 1500/1500 [==============================] - 2s 950us/step - loss: 0.5281 - accuracy: 0.8144 - val_loss: 0.4113 - val_accuracy: 0.8556
# Epoch 2/20
# 1500/1500 [==============================] - 1s 873us/step - loss: 0.3976 - accuracy: 0.8584 - val_loss: 0.3733 - val_accuracy: 0.8674
# Epoch 3/20
# 1500/1500 [==============================] - 1s 871us/step - loss: 0.3593 - accuracy: 0.8694 - val_loss: 0.3723 - val_accuracy: 0.8675
# Epoch 4/20
# 1500/1500 [==============================] - 1s 856us/step - loss: 0.3333 - accuracy: 0.8781 - val_loss: 0.3351 - val_accuracy: 0.8809
# Epoch 5/20
# 1500/1500 [==============================] - 1s 870us/step - loss: 0.3146 - accuracy: 0.8851 - val_loss: 0.3217 - val_accuracy: 0.8813
# Epoch 6/20
# 1500/1500 [==============================] - 1s 849us/step - loss: 0.2972 - accuracy: 0.8915 - val_loss: 0.3074 - val_accuracy: 0.8886
# Epoch 7/20
# ...

# %%
plt.figure()
plt.plot(history.history["loss"], label = "train_loss")
plt.plot(history.history["accuracy"], label = "train_acc")
plt.plot(history.history["val_loss"], label = "val_loss")
plt.plot(history.history["val_accuracy"], label = "val_acc")
plt.xticks(ticks = range(20))
plt.legend()
plt.xlabel("epoch")
plt.show()

# %% [markdown]
# - RMSprop을 사용할 때 보다 검증 손실 그래프의 감소 추세가 길게 이어지고 있어 Adam 옵티마이저가 이 데이터셋에 잘 맞는 것으로 보임

# %% [markdown]
# # 드롭아웃(dropout)
#
# <img src = "./img/dropout.png">

# %% [markdown]
# - 훈련 과정에서 층의 일부 뉴런을 랜덤하게 끄는 것으로(출력을 0으로 만드는것으로) 과대적합을 방지
#     - 특정 뉴런에 과대하게 의존하는 것을 줄일 수 있음
#     - 일부 뉴런의 출력이 없을 수 있다는 것을 감안하여 학습하게 됨
#         - 모든 입력값에 대해 충분한 주의를 기울이는 방향으로 학습
# - 드롭아웃은 케라스의 Dropout 클래스로 제공
# - 특정 층 뒤에 드롭아웃을 두어 해당 층의 출력을 랜덤하게 0으로 만듦
# - Flatten과 마찬가지로 층 처럼 사용되지만 훈련되는 모델 파라미터가 없음

# %%
model = model_fn(keras.layers.Dropout(0.3))
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_4 (Flatten)         (None, 784)               0
#
#  dense_8 (Dense)             (None, 100)               78500
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense_9 (Dense)             (None, 10)                1010
#
# ...
# Total params: 79510 (310.59 KB)
# Trainable params: 79510 (310.59 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# - 드롭아웃 층은 입력과 출력의 크기가 같음
#     - 일부 뉴런의 출력을 0으로 만들지만 전체 출력배열의 크기를 바꾸지 않음
#
# - 모델 훈련이 끝난 후에 평가나 예측을 수행할 때에는 드롭아웃을 적용하지 않아야 함
#     - 훈련된 모든 유닛을 사용해야 올바른 예측을 수행할 수 있기 때문에
#     - 케라스에서는 모델을 평가와 예측에 사용할 때에는 자동으로 드롭아웃을 적용하지 않음

# %%
model.compile(optimizer = "adam", loss = "sparse_categorical_crossentropy", metrics = "accuracy")
history = model.fit(scaled_train, y_train, epochs = 20, validation_data = (scaled_val, y_val))
# Out:
# Epoch 1/20
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.5933 - accuracy: 0.7912 - val_loss: 0.4395 - val_accuracy: 0.8374
# Epoch 2/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.4432 - accuracy: 0.8406 - val_loss: 0.3822 - val_accuracy: 0.8654
# Epoch 3/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.4077 - accuracy: 0.8539 - val_loss: 0.3744 - val_accuracy: 0.8624
# Epoch 4/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3880 - accuracy: 0.8594 - val_loss: 0.3433 - val_accuracy: 0.8752
# Epoch 5/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3733 - accuracy: 0.8646 - val_loss: 0.3303 - val_accuracy: 0.8807
# Epoch 6/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3562 - accuracy: 0.8689 - val_loss: 0.3286 - val_accuracy: 0.8783
# Epoch 7/20
# ...

# %%
plt.figure()
plt.plot(history.history["loss"], label = "train_loss")
plt.plot(history.history["accuracy"], label = "train_acc")
plt.plot(history.history["val_loss"], label = "val_loss")
plt.plot(history.history["val_accuracy"], label = "val_acc")
plt.xticks(ticks = range(20))
plt.legend()
plt.xlabel("epoch")
plt.show()

# %% [markdown]
# - 앞선 방법들에 비해 loss와 acc가 비교적 일정하게 유지됨

# %% [markdown]
# # 모델 저장과 복원
#
# - 케라스 모델은 모델의 파라미터를 저장하는 sav_weights() 메서드를 제공
# - 모델 구조와 모델 파라미터를 저장하는 save() 메서드도 제공

# %%
model.save_weights("./model/model-weights.h5")

# %%
model.save("./model/model-whole.h5")
# Out:
# C:\Users\yjg10\anaconda3\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
model.save("./model/model-whole.keras")

# %% [markdown]
# ## 모델 파라미터만 읽어오기

# %%
param_model = model_fn(keras.layers.Dropout(0.3))

# %%
param_model.load_weights("./model/model-weights.h5")

# %% [markdown]
# - load_weights() 메서드를 사용하려면 save_weights()로 저장했던 모델과 정확히 같은 구조를 가져야함
# - 텐서플로 버전에 따라 load_weights()의 버그로 인해 evaluate()를 사용하기 전에 compile()을 반드시 실행시켜야 하는 경우가 있음

# %%
val_labels = np.argmax(param_model.predict(scaled_val), axis = -1)
print(np.mean(val_labels == y_val))
# Out:
# 375/375 [==============================] - 1s 2ms/step
# 0.8905833333333333

# %%
param_model.predict(scaled_val[[0]])
# Out:
# 1/1 [==============================] - 0s 92ms/step
# array([[2.9637886e-05, 9.7247410e-01, 3.3969374e-07, 2.7489245e-02,
#         5.7972543e-06, 4.5049029e-13, 9.1180607e-07, 1.6129012e-24,
#         3.2854627e-10, 8.5705335e-17]], dtype=float32)

# %%
np.argmax(param_model.predict(scaled_val[[0]]), axis = -1)
# Out:
# 1/1 [==============================] - 0s 40ms/step
# array([1], dtype=int64)

# %% [markdown]
# - 케라스의 predict() 메서드는 모델의 예측을 수행
#     - 종속변수가 10개의 클래스로 이루어져 있기 때문에 각 클래스에 대한 확률을 반환
#
# - predict()결과에서 가장 큰 값을 고르기 위해 argmax()함수를 사용
#     - 배열에서 가장 큰 값의 인덱스를 반환
#     - 몇 번째 클래스에 대한 확률값이 가장 큰 지 반환
#         - 몇 번째 클래스로 예측을 했는지 알 수 있음
#
# - argmax()함수의 axis = -1은 배열의 마지막 차원을 따라서 최댓값을 고름
#     - axis = 1 이면 열을 따라 각 행의 최댓값의 인덱스를 선택
#     - axis = 0 이면 행을 따라 각 열의 최댓값의 인덱스를 선택
#
# - argmax()로 고른 인덱스와 타깃 인덱스를 비교하여 같으면 1, 다르면 0
#     - 이렇게 구한 값의 평균을 계산하면 정확도가 됨

# %% [markdown]
# ## 모델 전체 읽어오기

# %%
whole_model = keras.models.load_model("./model/model-whole.keras")

# %%
whole_model.evaluate(scaled_val, y_val)
# Out:
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3163 - accuracy: 0.8906
# [0.31628039479255676, 0.890583336353302]

# %% [markdown]
# # 콜백(callback)
#
# - 훈련 과정 중간에 어떤 작업을 수행할 수 있게 하는 객체
# - fit() 메서드의 callbacks 매개변수에 리스트로 전달하여 사용

# %% [markdown]
# ## ModelCheckpoint 콜백
#
# - 최상의 검증 점수를 만드는 모델을 저장

# %%
checkpoint_cb = keras.callbacks.ModelCheckpoint("./model/best-model.h5", save_best_only = True)

# %%
model = model_fn(keras.layers.Dropout(0.3))
model.compile(optimizer = "adam", loss = "sparse_categorical_crossentropy", metrics = "accuracy")
model.fit(scaled_train, y_train, epochs = 1, validation_data = (scaled_val, y_val), callbacks = [checkpoint_cb])
# Out:
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.5889 - accuracy: 0.7917 - val_loss: 0.4068 - val_accuracy: 0.8509

# %% [markdown]
# - 모델이 훈련한 후에 best-model.h5에 최상의 val_loss를 낸 모델이 저장됨

# %%
best_model = keras.models.load_model("./model/best-model.h5")

# %%
best_model.evaluate(scaled_val, y_val)
# Out:
# 375/375 [==============================] - 1s 3ms/step - loss: 0.4068 - accuracy: 0.8509
# [0.4068077802658081, 0.8509166836738586]

# %% [markdown]
# ## EarlyStopping 롤백
#
# - 과대적합이 시작되기 전에(검증점수가 상승할 때) 훈련을 미리 중지하는 것을 조기종료(early stopping)이라고 부름
# - 훈련 에포크 횟수를 제한하는 역할이지만 모델이 과대적합되는 것을 막아주기 때문에 규제 방법 중 하나로 여겨지기도 함

# %%
early_stopping_cb = keras.callbacks.EarlyStopping(patience = 2, restore_best_weights = True)

# %% [markdown]
# - patience
#     - 검증 점수가 향상되지 않더라도 지켜볼 에포크 횟수
#     - patience가 2라면 2번 연속 검증 점수가 향상되지 않으면 훈련 중지
#
# - restore_best_weights
#     - 가장 낮은 검증 손실을 낸 모델의 상태로 되돌림

# %%
model = model_fn(keras.layers.Dropout(0.3))
model.compile(optimizer = "adam", loss = "sparse_categorical_crossentropy", metrics = "accuracy")
history = model.fit(scaled_train, y_train, epochs = 20, validation_data = (scaled_val, y_val), callbacks = [checkpoint_cb, early_stopping_cb])
# Out:
# Epoch 1/20
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.5952 - accuracy: 0.7902 - val_loss: 0.4284 - val_accuracy: 0.8432
# Epoch 2/20
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.4437 - accuracy: 0.8395 - val_loss: 0.3778 - val_accuracy: 0.8612
# Epoch 3/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.4078 - accuracy: 0.8515 - val_loss: 0.3643 - val_accuracy: 0.8678
# Epoch 4/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3830 - accuracy: 0.8591 - val_loss: 0.3335 - val_accuracy: 0.8783
# Epoch 5/20
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.3695 - accuracy: 0.8642 - val_loss: 0.3288 - val_accuracy: 0.8810
# Epoch 6/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3558 - accuracy: 0.8678 - val_loss: 0.3335 - val_accuracy: 0.8818
# Epoch 7/20
# ...

# %% [markdown]
# - 12 에포크까지 훈련한 후 중지됨
#     - patience가 2이기 때문에 10 에포크의 모델이 최상의 모델임

# %%
# 몇번째 에포크까지 진행되었는지 확인하기
print(early_stopping_cb.stopped_epoch)
# Out:
# 11

# %%
model.evaluate(scaled_val, y_val)
# Out:
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3120 - accuracy: 0.8858
# [0.3120248317718506, 0.8858333230018616]

# %%
plt.figure()
plt.plot(history.history["loss"], label = "train_loss")
plt.plot(history.history["accuracy"], label = "train_acc")
plt.plot(history.history["val_loss"], label = "val_loss")
plt.plot(history.history["val_accuracy"], label = "val_acc")
plt.xticks(ticks = range(20))
plt.legend()
plt.xlabel("epoch")
plt.show()

# %% [markdown]
# # validation_split
#
# - 훈련 데이터를 자체적으로 훈련/검증 셋으로 나누어서 훈련/검증을 수행

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()
scaled_train = x_train / 255
scaled_test = x_test / 255

# %%
model = model_fn(keras.layers.Dropout(0.3))
model.compile(optimizer = "adam", loss = "sparse_categorical_crossentropy", metrics = "accuracy")
history = model.fit(scaled_train, y_train, epochs = 20, validation_split = 0.2, callbacks = [checkpoint_cb, early_stopping_cb])
# Out:
# Epoch 1/20
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.5892 - accuracy: 0.7926 - val_loss: 0.4134 - val_accuracy: 0.8518
# Epoch 2/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.4395 - accuracy: 0.8418 - val_loss: 0.3856 - val_accuracy: 0.8578
# Epoch 3/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.4030 - accuracy: 0.8541 - val_loss: 0.3730 - val_accuracy: 0.8619
# Epoch 4/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3807 - accuracy: 0.8615 - val_loss: 0.3609 - val_accuracy: 0.8667
# Epoch 5/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3627 - accuracy: 0.8667 - val_loss: 0.3565 - val_accuracy: 0.8692
# Epoch 6/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3537 - accuracy: 0.8701 - val_loss: 0.3421 - val_accuracy: 0.8776
# Epoch 7/20
# ...

# %%
plt.figure()
plt.plot(history.history["loss"], label = "train_loss")
plt.plot(history.history["accuracy"], label = "train_acc")
plt.plot(history.history["val_loss"], label = "val_loss")
plt.plot(history.history["val_accuracy"], label = "val_acc")
plt.xticks(ticks = range(20))
plt.legend()
plt.xlabel("epoch")
plt.show()
